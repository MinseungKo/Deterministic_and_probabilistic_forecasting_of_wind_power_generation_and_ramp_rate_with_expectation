# %%
import tensorflow as tf

import pandas as pd
import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error


from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
#from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply, Subtract
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout, SpatialDropout1D
from scipy import signal
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pylab as plt
import matplotlib.dates as mdates
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc
from keijzer import *
from tensorflow import keras
from keras.models import Model
from keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply, Embedding, Layer, Reshape
from keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
#from keras.ops import convert_to_tensor, convert_to_numpy
#from keras.utils import plot_model
from keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))



def root_squared_mean_error(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))+K.mean(K.abs(y_pred - y_true))

from keras.layers.advanced_activations import PReLU

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '0' # 여러개 사용시 '0,1,2' 식으로 하나의 문자열에 입력
gpus = tf.config.experimental.list_physical_devices('GPU') # 호스트 러나임에 표시되는 GPU 장치 목록 반환

if gpus: # 반환된 GPU 장치 목록이 있다면
    try: # 해당 장치에 대한 메모리 증가 활성화 여부 설정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e: # try문 실패시에 에러문구 출력
        print(e)

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Import Data & Preprocessing

# %%
data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2020.csv'
data_source1 = pd.read_csv(data_path)
dat_source1 = pd.DataFrame(data_source1)
#dat_source1 = dat_source1.iloc[:-3,:]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2021.csv'
data_source2 = pd.read_csv(data_path)
dat_source2 = pd.DataFrame(data_source2)
dat_source2 = dat_source2.iloc[:8761,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2022.csv'
data_source3 = pd.read_csv(data_path)
dat_source3 = pd.DataFrame(data_source3)
dat_source3 = dat_source3.iloc[:8760,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2023.csv'
data_source4 = pd.read_csv(data_path)
dat_source4 = pd.DataFrame(data_source4)
dat_source4 = dat_source4.iloc[:8760,:9]

dat_arr1 = np.array(dat_source1)
dat_arr2 = np.array(dat_source2)
dat_arr3 = np.array(dat_source3)
dat_arr4 = np.array(dat_source4)

dat_arr = np.concatenate([dat_arr1, dat_arr2, dat_arr3, dat_arr4],axis=0)
dat_arr.shape # 8784, 8761, 8760, 8760

dat_source = pd.DataFrame(dat_arr, columns=['Time-Date stamp','Date','ERCOT Load','Total Wind Output','Total Wind Installed','Wind Output, % of Load','Wind Output, % of Installed','1-hr MW change','1-hr % change'])
dat_source
# Out:
#            Time-Date stamp    Date ERCOT Load Total Wind Output  \
# 0      01-01-2020 00:00:00  Jan-01      36823             12335
# 1      01-01-2020 01:00:00  Jan-01      36511             13300
# 2      01-01-2020 02:00:00  Jan-01      36022             13586
# 3      01-01-2020 03:00:00  Jan-01      35790             14107
# 4      01-01-2020 04:00:00  Jan-01      35642             14887
# ...                    ...     ...        ...               ...
# 35060  12-31-2023 20:00:00  Dec-31      44887             17161
# 35061  12-31-2023 21:00:00  Dec-31      44013             18301
# 35062  12-31-2023 22:00:00  Dec-31      43280             18607
# 35063  12-31-2023 23:00:00  Dec-31      42319             17866
# 35064  01-01-2024 00:00:00  Jan-01      41682             15869
#
#       Total Wind Installed Wind Output, % of Load Wind Output, % of Installed  \
# 0                    27040                   33.5                      45.617
# 1                    27040                   36.4                      49.187
# 2                    27040                   37.7                      50.245
# 3                    27040                   39.4                      52.171
# 4                    27040                   41.8                      55.055
# ...                    ...                    ...                         ...
# 35060                38631                  38.23                       44.42
# 35061                38631                  41.58                       47.37
# 35062                38631                  42.99                       48.17
# 35063                38631                  42.22                       46.25
# 35064                38631                  38.07                       41.08
#
#       1-hr MW change 1-hr % change
# 0                NaN           NaN
# 1              965.4         7.826
# 2              286.2         2.152
# 3              520.9         3.834
# 4              779.6         5.527
# ...              ...           ...
# 35060           2858         19.99
# 35061           1139          6.64
# 35062            307          1.67
# 35063           -741         -3.98
# 35064          -1996        -11.17
#
# [35065 rows x 9 columns]

# %% [markdown]
# ### Dividing by Installed Capacity & Preprocessing

# %%
dat = pd.DataFrame()
dat['MW % change'] = np.array(dat_source.iloc[1:,3], dtype=float)-np.array(dat_source.iloc[0:-1,3], dtype=float)
dat['MW % change'] = np.divide(np.array(dat['MW % change']),np.array(dat_source.iloc[1:,4]))*100
dat['Total Wind Output'] = np.divide(np.array(dat_source.iloc[1:,3]), np.array(dat_source.iloc[1:,4]))

dat
# Out:
#       MW % change Total Wind Output
# 0         3.56879          0.491864
# 1         1.05769          0.502441
# 2         1.92678          0.521709
# 3         2.88462          0.550555
# 4       -0.580621          0.544749
# ...           ...               ...
# 35059      7.3982          0.444229
# 35060       2.951          0.473739
# 35061     0.79211           0.48166
# 35062    -1.91815          0.462478
# 35063    -5.16942          0.410784
#
# [35064 rows x 2 columns]

# %%
ramp_ratio = 20
load_ratio = 10
year_arr = np.concatenate([np.ones(8784)*2020, np.ones(8760)*2021, np.ones(8760)*2022, np.ones(8760)*2023])
year_df = pd.DataFrame(year_arr, columns=['Year'], dtype=int)
wind_df = pd.concat([year_df, dat], axis=1)
wind_df
# Out:
#        Year MW % change Total Wind Output
# 0      2020     3.56879          0.491864
# 1      2020     1.05769          0.502441
# 2      2020     1.92678          0.521709
# 3      2020     2.88462          0.550555
# 4      2020   -0.580621          0.544749
# ...     ...         ...               ...
# 35059  2023      7.3982          0.444229
# 35060  2023       2.951          0.473739
# 35061  2023     0.79211           0.48166
# 35062  2023    -1.91815          0.462478
# 35063  2023    -5.16942          0.410784
#
# [35064 rows x 3 columns]

# %%
wind_df = wind_df.reset_index(drop=True)
std_scaler = sklearn.preprocessing.MinMaxScaler()
std_scaler_load = sklearn.preprocessing.MinMaxScaler()
std_scaler_ramp = sklearn.preprocessing.MinMaxScaler()

wind_df[['Total Wind Output']] = std_scaler.fit_transform(wind_df[['Total Wind Output']])
wind_df[['MW % change']] = std_scaler_ramp.fit_transform(wind_df[['MW % change']])
#wind_df[['Wind Change, % of Load', 'Wind Change']] = std_scaler_ramp.fit_transform(wind_df[['Wind Change, % of Load', 'Wind Change']])
wind_df = wind_df.iloc[:-1,:]
wind_df
# Out:
#        Year  MW % change  Total Wind Output
# 0      2020     0.620197           0.644724
# 1      2020     0.544580           0.658617
# 2      2020     0.570751           0.683924
# 3      2020     0.599594           0.721813
# 4      2020     0.495246           0.714187
# ...     ...          ...                ...
# 35058  2023     0.774643           0.484984
# 35059  2023     0.735512           0.582157
# 35060  2023     0.601593           0.620917
# 35061  2023     0.536583           0.631322
# 35062  2023     0.454969           0.606127
#
# [35063 rows x 3 columns]

# %%
ramp_df = pd.DataFrame(wind_df)
ramp_df.columns=['Year', 'Wind Change', 'Wind Output']
ramp_df
# Out:
#        Year  Wind Change  Wind Output
# 0      2020     0.620197     0.644724
# 1      2020     0.544580     0.658617
# 2      2020     0.570751     0.683924
# 3      2020     0.599594     0.721813
# 4      2020     0.495246     0.714187
# ...     ...          ...          ...
# 35058  2023     0.774643     0.484984
# 35059  2023     0.735512     0.582157
# 35060  2023     0.601593     0.620917
# 35061  2023     0.536583     0.631322
# 35062  2023     0.454969     0.606127
#
# [35063 rows x 3 columns]

# %% [markdown]
# ## Wind Ramp Rate Forecasting

# %% [markdown]
# ### SVD-based Feature Generation

# %%
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc

def create_dataset(dataset, timesteps, output_timesteps, leadtime):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - leadtime - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps + leadtime):(i+timesteps+output_timesteps+leadtime), :])
    return np.array(dataX), np.array(dataY)

# %%
norm_df = np.array(wind_df['Wind Change']).reshape(-1,1)
timesteps = 24*7
output_timesteps = 24
num_features = 1
leadtime = 6
X, Y = create_dataset(norm_df, timesteps, output_timesteps, leadtime)
b_size = timesteps
num_features = X.shape[2]

# %% [markdown]
# ### Training/Test Set Division & Shuffled Learning

# %%
trvaX, teX, trvaY, teY = train_test_split(X, Y, test_size=0.1, shuffle=False)

idx = np.arange(trvaX.shape[0])
np.random.shuffle(idx)
strvaX = trvaX[idx]
strvaY = trvaY[idx]
strvaY = strvaY.reshape(-1, output_timesteps)

trvaY = trvaY.reshape(-1, output_timesteps)
teY = teY.reshape(-1, output_timesteps)

strX, svaX, strY, svaY = train_test_split(strvaX, strvaY, test_size=0.3, shuffle=False)
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=0.3, shuffle=False)

trvaX.shape, trvaY.shape, teX.shape, teY.shape
# Out:
# ((31377, 168, 1), (31377, 24), (3487, 168, 1), (3487, 24))

# %% [markdown]
# ## Wind Ramp Rate Forecasting Model without SVD

# %%
def MAEMD(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

# %%
from keras.layers.advanced_activations import PReLU

# %%
from keras import regularizers

num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1
    beta = 1
    hfilters = 168
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    pera = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(pera)
    den1b = Dense(timesteps, activation='sigmoid')(pera)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])   
    
    ## Permuted Attention Block
    per1 = Permute((2,1))(visible1)
    den2a = Dense(num_features, activation='tanh')(visible1)
    den2b = Dense(num_features, activation='sigmoid')(visible1)
    den2 = Multiply()([den2a, den2b])
    perb2 = Permute((2,1), name='attention_vec2')(den2)
    
    mul2 = Multiply()([per1, perb2])     
    
    ## Parallel DCCNN Blocks 1-1 ~ 3-1
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres01a = Add()([mul1, d1])   # (100, 25) (100, 25)
    rres01b = Subtract()([mul1, d1])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    rres02a = Add()([rres01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    rres02b = Subtract()([rres01b, d2])   # (100, 25) (100, 25) 
    rres02 = Concatenate()([rres02a, rres02b, rres01a, rres01b])
    #rres02 = Dropout(0.2)(rres02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres03a = Add()([rres02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    rres03b = Subtract()([rres02b, d2])
    rres10 = Concatenate()([rres03a, rres03b, rres02])

    ## Right-half DCCNN Blocks 1-2 ~ 3-2
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul2)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([mul2, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([mul2, d1])
    
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    #res02 = Dropout(0.2)(res02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])
    res10 = Concatenate()([res03a, res03b, res02])

    ## Output Blocks
    out1 = Conv1D(24*7, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out1 = Dropout(0.2)(out1)  
    
    out2 = Conv1D(24*7, 1, padding='same', activation=PReLU())(rres10)   # 256, 11X10=110
    out2 = Dropout(0.2)(out2)
    
    out = Concatenate(axis=1)([out1, out2])
    
    ## Output Block
    out = Conv1D(24*7, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)

    #, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
    out = GlobalAveragePooling1D()(out) 

    out = Dense(output_timesteps)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 168, 1)]     0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 1, 168)       0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 168, 1)       2           input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168, 1)       2           input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 1, 168)       28392       permute[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 1, 168)       28392       permute[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 168, 1)       0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 1, 168)       0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 1, 168)       0           input_1[0][0]
# __________________________________________________________________________________________________
# attention_vec2 (Permute)        (None, 1, 168)       0           multiply_2[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 168, 1)       0           multiply[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 1, 168)       0           permute_1[0][0]
#                                                                  attention_vec2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 168, 1)       0           input_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 1, 168)       28392       multiply_3[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 168, 168)     336         multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 1, 168)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 1, 168)       0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 168, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 168, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 1, 168)       0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 168, 168)     0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 1, 168)       56616       multiply_14[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 168, 1)       337         multiply_4[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 1, 168)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 1, 168)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 168, 1)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 168, 1)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 1, 168)       0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 168, 1)       0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 1, 168)       0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 1, 168)       0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 168, 1)       0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 168, 1)       0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 1, 168)       28392       add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 1, 168)       28392       subtract_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 168, 168)     336         add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 168, 168)     336         subtract[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 1, 168)       0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 1, 168)       0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 1, 168)       0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 1, 168)       0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 168, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 168, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 168, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 168, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 1, 168)       0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 1, 168)       0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 168, 168)     0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 168, 168)     0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 1, 168)       56616       multiply_16[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 1, 168)       56616       multiply_18[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 168, 1)       337         multiply_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 168, 1)       337         multiply_8[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 1, 168)       0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 1, 168)       0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 1, 168)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 1, 168)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 168, 1)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 168, 1)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 168, 1)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 168, 1)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 1, 168)       0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 1, 168)       0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 168, 1)       0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 168, 1)       0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 1, 168)       0           add_3[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 1, 168)       0           subtract_3[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 168, 1)       0           add[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 168, 1)       0           subtract[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 1, 672)       0           add_4[0][0]
#                                                                  subtract_4[0][0]
#                                                                  add_3[0][0]
#                                                                  subtract_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 168, 4)       0           add_1[0][0]
#                                                                  subtract_1[0][0]
#                                                                  add[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 1, 168)       113064      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 1, 168)       113064      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 168, 168)     840         concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 168, 168)     840         concatenate[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 1, 168)       0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 1, 168)       0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 1, 168)       0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 1, 168)       0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 168, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 168, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 168, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 168, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 1, 168)       0           activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 1, 168)       0           activation_36[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 168, 168)     0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 168, 168)     0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 1, 168)       56616       multiply_20[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 1, 168)       56616       multiply_22[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 168, 1)       337         multiply_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 168, 1)       337         multiply_12[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 1, 168)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 1, 168)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 1, 168)       0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 1, 168)       0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 168, 1)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 168, 1)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 168, 1)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 168, 1)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 1, 168)       0           activation_34[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 1, 168)       0           activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 168, 1)       0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 168, 1)       0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 1, 168)       0           add_4[0][0]
#                                                                  multiply_21[0][0]
# __________________________________________________________________________________________________
# subtract_5 (Subtract)           (None, 1, 168)       0           subtract_4[0][0]
#                                                                  multiply_23[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 168, 1)       0           add_1[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 168, 1)       0           subtract_1[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1, 1008)      0           add_5[0][0]
#                                                                  subtract_5[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 168, 6)       0           add_2[0][0]
#                                                                  subtract_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 1, 168)       169680      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 168, 168)     29400       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 1, 168)       0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 168, 168)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 169, 168)     0           dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 169, 168)     56784       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 169, 168)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 168)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 24)           4056        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 915,465
# Trainable params: 915,465
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 1353

# %%
    model.compile(loss=MAEMD, optimizer='adam', metrics=['mse','mae', MAEMD])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = 168
    epochs = 1000
    #root_squared_mean_error
    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint

# %%
    # %%time
    b_size = 168
    #hist = model.fit(strvaX, strvaY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(teX, teY), callbacks=[history, early_stopping])  # , checkpoint
    hist = model.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 131/131 [==============================] - 11s 54ms/step - loss: 0.2224 - mse: 0.0338 - mae: 0.1291 - MAEMD: 0.2223 - val_loss: 0.1734 - val_mse: 0.0115 - val_mae: 0.0829 - val_MAEMD: 0.1732
# Epoch 2/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1461 - mse: 0.0182 - mae: 0.1078 - MAEMD: 0.1462 - val_loss: 0.1349 - val_mse: 0.0184 - val_mae: 0.1099 - val_MAEMD: 0.1342
# Epoch 3/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1396 - mse: 0.0188 - mae: 0.1105 - MAEMD: 0.1396 - val_loss: 0.1335 - val_mse: 0.0183 - val_mae: 0.1096 - val_MAEMD: 0.1327
# Epoch 4/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1382 - mse: 0.0188 - mae: 0.1107 - MAEMD: 0.1382 - val_loss: 0.1328 - val_mse: 0.0181 - val_mae: 0.1091 - val_MAEMD: 0.1320
# Epoch 5/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1370 - mse: 0.0188 - mae: 0.1109 - MAEMD: 0.1370 - val_loss: 0.1318 - val_mse: 0.0175 - val_mae: 0.1073 - val_MAEMD: 0.1311
# Epoch 6/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1360 - mse: 0.0188 - mae: 0.1109 - MAEMD: 0.1360 - val_loss: 0.1315 - val_mse: 0.0177 - val_mae: 0.1080 - val_MAEMD: 0.1308
# Epoch 7/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1351 - mse: 0.0186 - mae: 0.1105 - MAEMD: 0.1351 - val_loss: 0.1312 - val_mse: 0.0181 - val_mae: 0.1093 - val_MAEMD: 0.1304
# Epoch 8/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1344 - mse: 0.0186 - mae: 0.1104 - MAEMD: 0.1344 - val_loss: 0.1306 - val_mse: 0.0176 - val_mae: 0.1078 - val_MAEMD: 0.1298
# Epoch 9/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1335 - mse: 0.0185 - mae: 0.1100 - MAEMD: 0.1335 - val_loss: 0.1298 - val_mse: 0.0177 - val_mae: 0.1078 - val_MAEMD: 0.1290
# Epoch 10/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1322 - mse: 0.0182 - mae: 0.1090 - MAEMD: 0.1322 - val_loss: 0.1288 - val_mse: 0.0181 - val_mae: 0.1093 - val_MAEMD: 0.1279
# Epoch 11/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1312 - mse: 0.0180 - mae: 0.1081 - MAEMD: 0.1312 - val_loss: 0.1277 - val_mse: 0.0174 - val_mae: 0.1068 - val_MAEMD: 0.1269
# Epoch 12/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1301 - mse: 0.0176 - mae: 0.1069 - MAEMD: 0.1301 - val_loss: 0.1269 - val_mse: 0.0170 - val_mae: 0.1051 - val_MAEMD: 0.1262
# Epoch 13/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1290 - mse: 0.0175 - mae: 0.1061 - MAEMD: 0.1290 - val_loss: 0.1262 - val_mse: 0.0169 - val_mae: 0.1049 - val_MAEMD: 0.1255
# Epoch 14/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1281 - mse: 0.0173 - mae: 0.1056 - MAEMD: 0.1281 - val_loss: 0.1260 - val_mse: 0.0164 - val_mae: 0.1027 - val_MAEMD: 0.1253
# Epoch 15/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1274 - mse: 0.0172 - mae: 0.1053 - MAEMD: 0.1274 - val_loss: 0.1256 - val_mse: 0.0162 - val_mae: 0.1024 - val_MAEMD: 0.1249
# Epoch 16/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1265 - mse: 0.0170 - mae: 0.1045 - MAEMD: 0.1265 - val_loss: 0.1256 - val_mse: 0.0165 - val_mae: 0.1033 - val_MAEMD: 0.1250
# Epoch 17/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1257 - mse: 0.0170 - mae: 0.1042 - MAEMD: 0.1257 - val_loss: 0.1254 - val_mse: 0.0169 - val_mae: 0.1046 - val_MAEMD: 0.1248
# Epoch 18/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1249 - mse: 0.0169 - mae: 0.1038 - MAEMD: 0.1249 - val_loss: 0.1248 - val_mse: 0.0164 - val_mae: 0.1028 - val_MAEMD: 0.1241
# Epoch 19/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1240 - mse: 0.0168 - mae: 0.1035 - MAEMD: 0.1240 - val_loss: 0.1248 - val_mse: 0.0164 - val_mae: 0.1028 - val_MAEMD: 0.1242
# Epoch 20/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1230 - mse: 0.0166 - mae: 0.1030 - MAEMD: 0.1230 - val_loss: 0.1239 - val_mse: 0.0162 - val_mae: 0.1021 - val_MAEMD: 0.1233
# Epoch 21/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1219 - mse: 0.0164 - mae: 0.1021 - MAEMD: 0.1219 - val_loss: 0.1234 - val_mse: 0.0160 - val_mae: 0.1011 - val_MAEMD: 0.1230
# Epoch 22/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1208 - mse: 0.0163 - mae: 0.1018 - MAEMD: 0.1208 - val_loss: 0.1233 - val_mse: 0.0163 - val_mae: 0.1024 - val_MAEMD: 0.1228
# Epoch 23/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1195 - mse: 0.0162 - mae: 0.1014 - MAEMD: 0.1195 - val_loss: 0.1231 - val_mse: 0.0156 - val_mae: 0.0995 - val_MAEMD: 0.1227
# Epoch 24/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1183 - mse: 0.0160 - mae: 0.1008 - MAEMD: 0.1183 - val_loss: 0.1231 - val_mse: 0.0157 - val_mae: 0.1003 - val_MAEMD: 0.1227
# Epoch 25/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1169 - mse: 0.0160 - mae: 0.1007 - MAEMD: 0.1169 - val_loss: 0.1224 - val_mse: 0.0157 - val_mae: 0.0999 - val_MAEMD: 0.1220
# Epoch 26/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1153 - mse: 0.0158 - mae: 0.1000 - MAEMD: 0.1153 - val_loss: 0.1222 - val_mse: 0.0157 - val_mae: 0.1002 - val_MAEMD: 0.1218
# Epoch 27/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1140 - mse: 0.0157 - mae: 0.0998 - MAEMD: 0.1140 - val_loss: 0.1227 - val_mse: 0.0155 - val_mae: 0.0993 - val_MAEMD: 0.1223
# Epoch 28/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1128 - mse: 0.0157 - mae: 0.0996 - MAEMD: 0.1128 - val_loss: 0.1220 - val_mse: 0.0163 - val_mae: 0.1023 - val_MAEMD: 0.1215
# Epoch 29/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1106 - mse: 0.0155 - mae: 0.0990 - MAEMD: 0.1106 - val_loss: 0.1218 - val_mse: 0.0160 - val_mae: 0.1008 - val_MAEMD: 0.1213
# Epoch 30/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1094 - mse: 0.0154 - mae: 0.0989 - MAEMD: 0.1094 - val_loss: 0.1217 - val_mse: 0.0157 - val_mae: 0.1001 - val_MAEMD: 0.1213
# Epoch 31/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1083 - mse: 0.0153 - mae: 0.0985 - MAEMD: 0.1083 - val_loss: 0.1217 - val_mse: 0.0158 - val_mae: 0.1002 - val_MAEMD: 0.1211
# Epoch 32/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1069 - mse: 0.0152 - mae: 0.0980 - MAEMD: 0.1069 - val_loss: 0.1209 - val_mse: 0.0153 - val_mae: 0.0987 - val_MAEMD: 0.1202
# Epoch 33/1000
# 131/131 [==============================] - 6s 44ms/step - loss: 0.1051 - mse: 0.0150 - mae: 0.0974 - MAEMD: 0.1050 - val_loss: 0.1207 - val_mse: 0.0158 - val_mae: 0.1005 - val_MAEMD: 0.1200
# Epoch 34/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1038 - mse: 0.0150 - mae: 0.0971 - MAEMD: 0.1038 - val_loss: 0.1198 - val_mse: 0.0158 - val_mae: 0.1004 - val_MAEMD: 0.1191
# Epoch 35/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1022 - mse: 0.0148 - mae: 0.0965 - MAEMD: 0.1022 - val_loss: 0.1207 - val_mse: 0.0155 - val_mae: 0.0993 - val_MAEMD: 0.1199
# Epoch 36/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.1012 - mse: 0.0147 - mae: 0.0964 - MAEMD: 0.1012 - val_loss: 0.1213 - val_mse: 0.0151 - val_mae: 0.0978 - val_MAEMD: 0.1206
# Epoch 37/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0997 - mse: 0.0146 - mae: 0.0958 - MAEMD: 0.0997 - val_loss: 0.1210 - val_mse: 0.0152 - val_mae: 0.0979 - val_MAEMD: 0.1203
# Epoch 38/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0982 - mse: 0.0145 - mae: 0.0957 - MAEMD: 0.0982 - val_loss: 0.1212 - val_mse: 0.0150 - val_mae: 0.0975 - val_MAEMD: 0.1204
# Epoch 39/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0969 - mse: 0.0143 - mae: 0.0950 - MAEMD: 0.0968 - val_loss: 0.1207 - val_mse: 0.0149 - val_mae: 0.0969 - val_MAEMD: 0.1200
# Epoch 40/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0957 - mse: 0.0143 - mae: 0.0947 - MAEMD: 0.0957 - val_loss: 0.1205 - val_mse: 0.0153 - val_mae: 0.0983 - val_MAEMD: 0.1196
# Epoch 41/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0945 - mse: 0.0142 - mae: 0.0942 - MAEMD: 0.0945 - val_loss: 0.1207 - val_mse: 0.0148 - val_mae: 0.0969 - val_MAEMD: 0.1199
# Epoch 42/1000
# 131/131 [==============================] - 6s 44ms/step - loss: 0.0934 - mse: 0.0141 - mae: 0.0941 - MAEMD: 0.0934 - val_loss: 0.1193 - val_mse: 0.0152 - val_mae: 0.0981 - val_MAEMD: 0.1186
# Epoch 43/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0920 - mse: 0.0139 - mae: 0.0934 - MAEMD: 0.0920 - val_loss: 0.1195 - val_mse: 0.0156 - val_mae: 0.0996 - val_MAEMD: 0.1188
# Epoch 44/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0910 - mse: 0.0139 - mae: 0.0933 - MAEMD: 0.0910 - val_loss: 0.1194 - val_mse: 0.0152 - val_mae: 0.0984 - val_MAEMD: 0.1186
# Epoch 45/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0902 - mse: 0.0138 - mae: 0.0929 - MAEMD: 0.0902 - val_loss: 0.1191 - val_mse: 0.0153 - val_mae: 0.0984 - val_MAEMD: 0.1182
# Epoch 46/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0896 - mse: 0.0138 - mae: 0.0927 - MAEMD: 0.0896 - val_loss: 0.1188 - val_mse: 0.0148 - val_mae: 0.0968 - val_MAEMD: 0.1180
# Epoch 47/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0887 - mse: 0.0136 - mae: 0.0922 - MAEMD: 0.0887 - val_loss: 0.1186 - val_mse: 0.0150 - val_mae: 0.0972 - val_MAEMD: 0.1177
# Epoch 48/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0881 - mse: 0.0136 - mae: 0.0919 - MAEMD: 0.0881 - val_loss: 0.1176 - val_mse: 0.0154 - val_mae: 0.0986 - val_MAEMD: 0.1169
# Epoch 49/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0876 - mse: 0.0136 - mae: 0.0920 - MAEMD: 0.0875 - val_loss: 0.1175 - val_mse: 0.0160 - val_mae: 0.1011 - val_MAEMD: 0.1168
# Epoch 50/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0862 - mse: 0.0135 - mae: 0.0915 - MAEMD: 0.0862 - val_loss: 0.1180 - val_mse: 0.0155 - val_mae: 0.0993 - val_MAEMD: 0.1172
# Epoch 51/1000
# 131/131 [==============================] - 6s 44ms/step - loss: 0.0857 - mse: 0.0134 - mae: 0.0912 - MAEMD: 0.0857 - val_loss: 0.1177 - val_mse: 0.0154 - val_mae: 0.0992 - val_MAEMD: 0.1167
# Epoch 52/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0849 - mse: 0.0133 - mae: 0.0908 - MAEMD: 0.0849 - val_loss: 0.1184 - val_mse: 0.0154 - val_mae: 0.0990 - val_MAEMD: 0.1176
# Epoch 53/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0843 - mse: 0.0133 - mae: 0.0907 - MAEMD: 0.0842 - val_loss: 0.1179 - val_mse: 0.0154 - val_mae: 0.0988 - val_MAEMD: 0.1172
# Epoch 54/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0836 - mse: 0.0131 - mae: 0.0901 - MAEMD: 0.0836 - val_loss: 0.1178 - val_mse: 0.0153 - val_mae: 0.0986 - val_MAEMD: 0.1171
# Epoch 55/1000
# 131/131 [==============================] - 6s 44ms/step - loss: 0.0828 - mse: 0.0130 - mae: 0.0897 - MAEMD: 0.0828 - val_loss: 0.1178 - val_mse: 0.0155 - val_mae: 0.0992 - val_MAEMD: 0.1171
# Epoch 56/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0819 - mse: 0.0130 - mae: 0.0897 - MAEMD: 0.0819 - val_loss: 0.1182 - val_mse: 0.0149 - val_mae: 0.0972 - val_MAEMD: 0.1175
# Epoch 57/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0813 - mse: 0.0129 - mae: 0.0891 - MAEMD: 0.0813 - val_loss: 0.1174 - val_mse: 0.0150 - val_mae: 0.0977 - val_MAEMD: 0.1167
# Epoch 58/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0806 - mse: 0.0128 - mae: 0.0890 - MAEMD: 0.0806 - val_loss: 0.1179 - val_mse: 0.0151 - val_mae: 0.0979 - val_MAEMD: 0.1172
# Epoch 59/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0799 - mse: 0.0127 - mae: 0.0884 - MAEMD: 0.0799 - val_loss: 0.1172 - val_mse: 0.0147 - val_mae: 0.0961 - val_MAEMD: 0.1165
# Epoch 60/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0791 - mse: 0.0126 - mae: 0.0880 - MAEMD: 0.0790 - val_loss: 0.1164 - val_mse: 0.0152 - val_mae: 0.0981 - val_MAEMD: 0.1156
# Epoch 61/1000
# 131/131 [==============================] - 6s 44ms/step - loss: 0.0778 - mse: 0.0125 - mae: 0.0876 - MAEMD: 0.0778 - val_loss: 0.1173 - val_mse: 0.0145 - val_mae: 0.0958 - val_MAEMD: 0.1165
# Epoch 62/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0774 - mse: 0.0124 - mae: 0.0873 - MAEMD: 0.0774 - val_loss: 0.1173 - val_mse: 0.0143 - val_mae: 0.0951 - val_MAEMD: 0.1165
# Epoch 63/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0766 - mse: 0.0123 - mae: 0.0870 - MAEMD: 0.0766 - val_loss: 0.1174 - val_mse: 0.0147 - val_mae: 0.0964 - val_MAEMD: 0.1166
# Epoch 64/1000
# 131/131 [==============================] - 6s 44ms/step - loss: 0.0762 - mse: 0.0123 - mae: 0.0867 - MAEMD: 0.0761 - val_loss: 0.1175 - val_mse: 0.0142 - val_mae: 0.0943 - val_MAEMD: 0.1168
# Epoch 65/1000
# 131/131 [==============================] - 6s 44ms/step - loss: 0.0760 - mse: 0.0122 - mae: 0.0865 - MAEMD: 0.0760 - val_loss: 0.1156 - val_mse: 0.0144 - val_mae: 0.0953 - val_MAEMD: 0.1149
# Epoch 66/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0748 - mse: 0.0120 - mae: 0.0858 - MAEMD: 0.0748 - val_loss: 0.1176 - val_mse: 0.0140 - val_mae: 0.0936 - val_MAEMD: 0.1169
# Epoch 67/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0748 - mse: 0.0121 - mae: 0.0860 - MAEMD: 0.0748 - val_loss: 0.1155 - val_mse: 0.0143 - val_mae: 0.0947 - val_MAEMD: 0.1149
# Epoch 68/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0746 - mse: 0.0120 - mae: 0.0857 - MAEMD: 0.0746 - val_loss: 0.1168 - val_mse: 0.0142 - val_mae: 0.0943 - val_MAEMD: 0.1161
# Epoch 69/1000
# 131/131 [==============================] - 6s 44ms/step - loss: 0.0736 - mse: 0.0118 - mae: 0.0850 - MAEMD: 0.0736 - val_loss: 0.1174 - val_mse: 0.0140 - val_mae: 0.0938 - val_MAEMD: 0.1167
# Epoch 70/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0735 - mse: 0.0119 - mae: 0.0851 - MAEMD: 0.0735 - val_loss: 0.1172 - val_mse: 0.0142 - val_mae: 0.0943 - val_MAEMD: 0.1166
# Epoch 71/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0730 - mse: 0.0118 - mae: 0.0847 - MAEMD: 0.0730 - val_loss: 0.1166 - val_mse: 0.0138 - val_mae: 0.0928 - val_MAEMD: 0.1160
# Epoch 72/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0728 - mse: 0.0117 - mae: 0.0846 - MAEMD: 0.0728 - val_loss: 0.1157 - val_mse: 0.0137 - val_mae: 0.0925 - val_MAEMD: 0.1151
# Epoch 73/1000
# 131/131 [==============================] - 6s 44ms/step - loss: 0.0724 - mse: 0.0117 - mae: 0.0844 - MAEMD: 0.0724 - val_loss: 0.1160 - val_mse: 0.0138 - val_mae: 0.0930 - val_MAEMD: 0.1155
# Epoch 74/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0725 - mse: 0.0117 - mae: 0.0844 - MAEMD: 0.0725 - val_loss: 0.1164 - val_mse: 0.0140 - val_mae: 0.0937 - val_MAEMD: 0.1158
# Epoch 75/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0719 - mse: 0.0116 - mae: 0.0840 - MAEMD: 0.0719 - val_loss: 0.1157 - val_mse: 0.0141 - val_mae: 0.0939 - val_MAEMD: 0.1149
# Epoch 76/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0714 - mse: 0.0115 - mae: 0.0837 - MAEMD: 0.0713 - val_loss: 0.1159 - val_mse: 0.0142 - val_mae: 0.0945 - val_MAEMD: 0.1151
# Epoch 77/1000
# 131/131 [==============================] - 6s 43ms/step - loss: 0.0707 - mse: 0.0114 - mae: 0.0832 - MAEMD: 0.0706 - val_loss: 0.1167 - val_mse: 0.0143 - val_mae: 0.0951 - val_MAEMD: 0.1158
# Wall time: 7min 22s

# %%
model.save('Basic Ramp Model Final_woSVD.h5')

# %%
gc.collect()
# Out:
# 4592

# %%
testPredict = model.predict(teX, batch_size=batch_size)

# %%
with tf.device('/gpu:0'):
    model = keras.models.load_model('Basic Ramp Model Final_woSVD.h5', custom_objects={'MAEMD': MAEMD})
    gc.collect()
    testPredict = model.predict(teX, batch_size=b_size)

# %%
def npMAEMS(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true))*100
def npMAEMD(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true-np.mean(y_true)))*100
def npMSE(y_true, y_pred):
    return np.mean(np.square(-y_true+y_pred))
def npMAE(y_true, y_pred):
    return np.mean(abs(-y_true+y_pred))

# %%
tePredict = testPredict.reshape(-1)
testY = teY.reshape(-1)
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMS == ', npMAEMD(testY, tePredict))
# Out:
# Error Test Score > MSE ==  0.014563983292347203  MAE ==  0.09586270895687088  MAEMS ==  0.10891742033808452

# %% [markdown]
# ## Proposed Model

# %%
dec_num = timesteps
high_ind = 35

addX = np.zeros((X.shape[0], dec_num, high_ind+1))

def svdadd(X, start, end, b_size):
    dec_x = X[start:end, :, :]
    U, S, Vh = svd(dec_x.reshape(b_size, -1))

    high_sig = np.matmul(np.matmul(U[:,:high_ind], np.diag(S[0:high_ind])), Vh[:high_ind,:])
    low_sig = X[:dec_num, :, :].reshape(b_size,-1)-high_sig

    rec_x = np.zeros((b_size, b_size, high_ind))
    #print(sum(S[0:high_ind])/sum(S))
    for i in range(high_ind):
        rec_x[:,:,i] = np.matmul((U[:,i]*S[i]).reshape(-1,1), Vh[i,:].reshape(1,-1))    
    return rec_x, low_sig

for k in range(X.shape[0]//dec_num):
    rec_x, low_sig = svdadd(X, k*dec_num, (k+1)*dec_num, b_size)
    addX[k*dec_num:k*dec_num+dec_num,:, :-1] = rec_x
    addX[k*dec_num:k*dec_num+dec_num,:, -1] = low_sig
    
rec_x, low_sig = svdadd(X, X.shape[0]-dec_num, X.shape[0], b_size)
addX[X.shape[0]-dec_num:X.shape[0], :, :-1] = rec_x
addX[X.shape[0]-dec_num:X.shape[0],:, -1] = low_sig

addX_det = addX[:, :, :-1]
addX_det = np.sum(addX_det, axis=2)
X = np.concatenate([X, addX], axis=2)
num_features = X.shape[2]

# %%
trvaX, teX, trvaY, teY = train_test_split(X, Y, test_size=0.1, shuffle=False)

idx = np.arange(trvaX.shape[0])
np.random.shuffle(idx)
strvaX = trvaX[idx]
strvaY = trvaY[idx]
strvaY = strvaY.reshape(-1, output_timesteps)

trvaY = trvaY.reshape(-1, output_timesteps)
teY = teY.reshape(-1, output_timesteps)

trvaX.shape, trvaY.shape, teX.shape, teY.shape
# Out:
# ((31377, 168, 37), (31377, 24), (3487, 168, 37), (3487, 24))

# %%
with tf.device('/gpu:0'):
    ramp_model = keras.models.load_model('Basic Ramp Model Final_lead.h5', custom_objects={'MAEMD': MAEMD})
    gc.collect()
    testPredict2 = ramp_model.predict(teX, batch_size=b_size)

# %%
tePredict2 = testPredict2.reshape(-1)
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMD == ', npMAEMD(testY, tePredict))
print('Error Test Score > MSE == ', npMSE(testY, tePredict2), ' MAE == ', npMAE(testY, tePredict2), ' MAEMD == ', npMAEMD(testY, tePredict2))
# Out:
# Error Test Score > MSE ==  0.014563983292347203  MAE ==  0.09586270895687088  MAEMD ==  0.10891742033808452
# Error Test Score > MSE ==  0.013735278704296769  MAE ==  0.09257788506004408  MAEMD ==  0.1032740317521866

# %%
from statsmodels.stats.diagnostic import acorr_ljungbox
from scipy.stats import norm

def diebold_mariano_test(forecast1, forecast2, actual, opt): 
    
    if opt==0: # MSE
        e1 = actual-forecast1
        e2 = actual-forecast2
        d = e1**2 - e2**2
    elif opt==1: # MAE
        e1 = abs(actual-forecast1)
        e2 = abs(actual-forecast2)
        d = e1 - e2
    else:
        e1 = np.multiply(abs(actual - forecast1), (actual-np.mean(actual))**2)
        e2 = np.multiply(abs(actual - forecast2), (actual-np.mean(actual))**2)
        d = e1-e2
    
    # Mean of the loss differentials
    mean_d = np.mean(d)
    
    # Standard deviation of the loss differentials
    std_d = np.std(d, ddof=1)
    
    # Calculate the test statistic
    test_stat = (mean_d / std_d) * np.sqrt(len(d))
    
    # Calculate the p-value using a two-tailed test
    p_value = 2 * (1 - norm.cdf(abs(test_stat)))
    
    return test_stat, p_value

# %%
diebold_mariano_test(testPredict, testPredict2, teY, 0), diebold_mariano_test(testPredict, testPredict2, teY, 1), diebold_mariano_test(testPredict, testPredict2, teY, 2)
# Out:
# ((2.1172650994249826, 0.0342373551457027),
#  (2.366812075685584, 0.017942040563362127),
#  (1.7185177443902808, 0.08570222070499178))
