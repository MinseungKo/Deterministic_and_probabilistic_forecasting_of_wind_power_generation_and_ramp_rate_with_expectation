# %%
import tensorflow as tf

import pandas as pd
import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
#from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply, Subtract
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout, SpatialDropout1D
from scipy import signal
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pylab as plt
import matplotlib.dates as mdates
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc
from keijzer import *
from tensorflow import keras
from keras.models import Model
from keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply, Embedding, Layer, Reshape
from keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
#from keras.ops import convert_to_tensor, convert_to_numpy
#from keras.utils import plot_model
from keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))



def root_squared_mean_error(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))+K.mean(K.abs(y_pred - y_true))

from keras.layers.advanced_activations import PReLU

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '0' # 여러개 사용시 '0,1,2' 식으로 하나의 문자열에 입력
gpus = tf.config.experimental.list_physical_devices('GPU') # 호스트 러나임에 표시되는 GPU 장치 목록 반환

if gpus: # 반환된 GPU 장치 목록이 있다면
    try: # 해당 장치에 대한 메모리 증가 활성화 여부 설정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e: # try문 실패시에 에러문구 출력
        print(e)

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Import Data & Preprocessing

# %%
data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2020.csv'
data_source1 = pd.read_csv(data_path)
dat_source1 = pd.DataFrame(data_source1)
#dat_source1 = dat_source1.iloc[:-3,:]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2021.csv'
data_source2 = pd.read_csv(data_path)
dat_source2 = pd.DataFrame(data_source2)
dat_source2 = dat_source2.iloc[:8761,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2022.csv'
data_source3 = pd.read_csv(data_path)
dat_source3 = pd.DataFrame(data_source3)
dat_source3 = dat_source3.iloc[:8760,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2023.csv'
data_source4 = pd.read_csv(data_path)
dat_source4 = pd.DataFrame(data_source4)
dat_source4 = dat_source4.iloc[:8760,:9]

dat_arr1 = np.array(dat_source1)
dat_arr2 = np.array(dat_source2)
dat_arr3 = np.array(dat_source3)
dat_arr4 = np.array(dat_source4)

dat_arr = np.concatenate([dat_arr1, dat_arr2, dat_arr3, dat_arr4],axis=0)
dat_arr.shape # 8784, 8761, 8760, 8760

dat_source = pd.DataFrame(dat_arr, columns=['Time-Date stamp','Date','ERCOT Load','Total Wind Output','Total Wind Installed','Wind Output, % of Load','Wind Output, % of Installed','1-hr MW change','1-hr % change'])
dat_source
# Out:
#            Time-Date stamp    Date ERCOT Load Total Wind Output  \
# 0      01-01-2020 00:00:00  Jan-01      36823             12335
# 1      01-01-2020 01:00:00  Jan-01      36511             13300
# 2      01-01-2020 02:00:00  Jan-01      36022             13586
# 3      01-01-2020 03:00:00  Jan-01      35790             14107
# 4      01-01-2020 04:00:00  Jan-01      35642             14887
# ...                    ...     ...        ...               ...
# 35060  12-31-2023 20:00:00  Dec-31      44887             17161
# 35061  12-31-2023 21:00:00  Dec-31      44013             18301
# 35062  12-31-2023 22:00:00  Dec-31      43280             18607
# 35063  12-31-2023 23:00:00  Dec-31      42319             17866
# 35064  01-01-2024 00:00:00  Jan-01      41682             15869
#
#       Total Wind Installed Wind Output, % of Load Wind Output, % of Installed  \
# 0                    27040                   33.5                      45.617
# 1                    27040                   36.4                      49.187
# 2                    27040                   37.7                      50.245
# 3                    27040                   39.4                      52.171
# 4                    27040                   41.8                      55.055
# ...                    ...                    ...                         ...
# 35060                38631                  38.23                       44.42
# 35061                38631                  41.58                       47.37
# 35062                38631                  42.99                       48.17
# 35063                38631                  42.22                       46.25
# 35064                38631                  38.07                       41.08
#
#       1-hr MW change 1-hr % change
# 0                NaN           NaN
# 1              965.4         7.826
# 2              286.2         2.152
# 3              520.9         3.834
# 4              779.6         5.527
# ...              ...           ...
# 35060           2858         19.99
# 35061           1139          6.64
# 35062            307          1.67
# 35063           -741         -3.98
# 35064          -1996        -11.17
#
# [35065 rows x 9 columns]

# %% [markdown]
# ### Dividing by Installed Capacity & Preprocessing

# %%
dat = pd.DataFrame()
dat['MW % change'] = np.array(dat_source.iloc[1:,3], dtype=float)-np.array(dat_source.iloc[0:-1,3], dtype=float)
dat['MW % change'] = np.divide(np.array(dat['MW % change']),np.array(dat_source.iloc[1:,4]))*100
dat['Total Wind Output'] = np.divide(np.array(dat_source.iloc[1:,3]), np.array(dat_source.iloc[1:,4]))

dat
# Out:
#       MW % change Total Wind Output
# 0         3.56879          0.491864
# 1         1.05769          0.502441
# 2         1.92678          0.521709
# 3         2.88462          0.550555
# 4       -0.580621          0.544749
# ...           ...               ...
# 35059      7.3982          0.444229
# 35060       2.951          0.473739
# 35061     0.79211           0.48166
# 35062    -1.91815          0.462478
# 35063    -5.16942          0.410784
#
# [35064 rows x 2 columns]

# %%
ramp_ratio = 20
load_ratio = 10
year_arr = np.concatenate([np.ones(8784)*2020, np.ones(8760)*2021, np.ones(8760)*2022, np.ones(8760)*2023])
year_df = pd.DataFrame(year_arr, columns=['Year'], dtype=int)
wind_df = pd.concat([year_df, dat], axis=1)
wind_df
# Out:
#        Year MW % change Total Wind Output
# 0      2020     3.56879          0.491864
# 1      2020     1.05769          0.502441
# 2      2020     1.92678          0.521709
# 3      2020     2.88462          0.550555
# 4      2020   -0.580621          0.544749
# ...     ...         ...               ...
# 35059  2023      7.3982          0.444229
# 35060  2023       2.951          0.473739
# 35061  2023     0.79211           0.48166
# 35062  2023    -1.91815          0.462478
# 35063  2023    -5.16942          0.410784
#
# [35064 rows x 3 columns]

# %%
wind_df = wind_df.reset_index(drop=True)
std_scaler = sklearn.preprocessing.MinMaxScaler()
std_scaler_load = sklearn.preprocessing.MinMaxScaler()
std_scaler_ramp = sklearn.preprocessing.MinMaxScaler()

wind_df[['Total Wind Output']] = std_scaler.fit_transform(wind_df[['Total Wind Output']])
wind_df[['MW % change']] = std_scaler_ramp.fit_transform(wind_df[['MW % change']])
#wind_df[['Wind Change, % of Load', 'Wind Change']] = std_scaler_ramp.fit_transform(wind_df[['Wind Change, % of Load', 'Wind Change']])
wind_df = wind_df.iloc[:-1,:]
wind_df
# Out:
#        Year  MW % change  Total Wind Output
# 0      2020     0.620197           0.644724
# 1      2020     0.544580           0.658617
# 2      2020     0.570751           0.683924
# 3      2020     0.599594           0.721813
# 4      2020     0.495246           0.714187
# ...     ...          ...                ...
# 35058  2023     0.774643           0.484984
# 35059  2023     0.735512           0.582157
# 35060  2023     0.601593           0.620917
# 35061  2023     0.536583           0.631322
# 35062  2023     0.454969           0.606127
#
# [35063 rows x 3 columns]

# %%
ramp_df = pd.DataFrame(wind_df)
ramp_df.columns=['Year', 'Wind Change', 'Wind Output']
ramp_df
# Out:
#        Year  Wind Change  Wind Output
# 0      2020     0.620197     0.644724
# 1      2020     0.544580     0.658617
# 2      2020     0.570751     0.683924
# 3      2020     0.599594     0.721813
# 4      2020     0.495246     0.714187
# ...     ...          ...          ...
# 35058  2023     0.774643     0.484984
# 35059  2023     0.735512     0.582157
# 35060  2023     0.601593     0.620917
# 35061  2023     0.536583     0.631322
# 35062  2023     0.454969     0.606127
#
# [35063 rows x 3 columns]

# %% [markdown]
# ## Wind Ramp Rate Forecasting

# %% [markdown]
# ### SVD-based Feature Generation

# %%
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc

def create_dataset(dataset, timesteps, output_timesteps, leadtime):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - leadtime - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps + leadtime):(i+timesteps+output_timesteps+leadtime), :])
    return np.array(dataX), np.array(dataY)

# %%
norm_df = np.array(wind_df['Wind Change']).reshape(-1,1)
timesteps = 24*7
output_timesteps = 24
num_features = 1
leadtime = 6
X, Y = create_dataset(norm_df, timesteps, output_timesteps, leadtime)
b_size = timesteps

# %%
dec_num = timesteps
high_ind = 35

addX = np.zeros((X.shape[0], dec_num, high_ind+1))

def svdadd(X, start, end, b_size):
    dec_x = X[start:end, :, :]
    U, S, Vh = svd(dec_x.reshape(b_size, -1))

    high_sig = np.matmul(np.matmul(U[:,:high_ind], np.diag(S[0:high_ind])), Vh[:high_ind,:])
    low_sig = X[:dec_num, :, :].reshape(b_size,-1)-high_sig

    rec_x = np.zeros((b_size, b_size, high_ind))
    #print(sum(S[0:high_ind])/sum(S))
    for i in range(high_ind):
        rec_x[:,:,i] = np.matmul((U[:,i]*S[i]).reshape(-1,1), Vh[i,:].reshape(1,-1))    
    return rec_x, low_sig

for k in range(X.shape[0]//dec_num):
    rec_x, low_sig = svdadd(X, k*dec_num, (k+1)*dec_num, b_size)
    addX[k*dec_num:k*dec_num+dec_num,:, :-1] = rec_x
    addX[k*dec_num:k*dec_num+dec_num,:, -1] = low_sig
    
rec_x, low_sig = svdadd(X, X.shape[0]-dec_num, X.shape[0], b_size)
addX[X.shape[0]-dec_num:X.shape[0], :, :-1] = rec_x
addX[X.shape[0]-dec_num:X.shape[0],:, -1] = low_sig

addX_det = addX[:, :, :-1]
addX_det = np.sum(addX_det, axis=2)
X = np.concatenate([X, addX], axis=2)
num_features = X.shape[2]

# %% [markdown]
# ### Training/Test Set Division & Shuffled Learning

# %%
trvaX, teX, trvaY, teY = train_test_split(X, Y, test_size=0.1, shuffle=False)

idx = np.arange(trvaX.shape[0])
np.random.shuffle(idx)
strvaX = trvaX[idx]
strvaY = trvaY[idx]
strvaY = strvaY.reshape(-1, output_timesteps)

trvaY = trvaY.reshape(-1, output_timesteps)
teY = teY.reshape(-1, output_timesteps)

strX, svaX, strY, svaY = train_test_split(strvaX, strvaY, test_size=0.3, shuffle=False)
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=0.3, shuffle=False)

trvaX.shape, trvaY.shape, teX.shape, teY.shape
# Out:
# ((31377, 168, 37), (31377, 24), (3487, 168, 37), (3487, 24))

# %% [markdown]
# ## Wind Ramp Rate Forecasting Basic Model

# %%
def MAEMD(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

# %%
from keras.layers.advanced_activations import PReLU

# %%
from keras import regularizers

num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1
    beta = 1
    hfilters = 168
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    pera = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(pera)
    den1b = Dense(timesteps, activation='sigmoid')(pera)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])   
    
    ## Permuted Attention Block
    per1 = Permute((2,1))(visible1)
    den2a = Dense(num_features, activation='tanh')(visible1)
    den2b = Dense(num_features, activation='sigmoid')(visible1)
    den2 = Multiply()([den2a, den2b])
    perb2 = Permute((2,1), name='attention_vec2')(den2)
    
    mul2 = Multiply()([per1, perb2])     
    
    ## Parallel DCCNN Blocks 1-1 ~ 3-1
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres01a = Add()([mul1, d1])   # (100, 25) (100, 25)
    rres01b = Subtract()([mul1, d1])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    rres02a = Add()([rres01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    rres02b = Subtract()([rres01b, d2])   # (100, 25) (100, 25) 
    rres02 = Concatenate()([rres02a, rres02b, rres01a, rres01b])
    #rres02 = Dropout(0.2)(rres02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres03a = Add()([rres02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    rres03b = Subtract()([rres02b, d2])
    rres10 = Concatenate()([rres03a, rres03b, rres02])

    ## Right-half DCCNN Blocks 1-2 ~ 3-2
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul2)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([mul2, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([mul2, d1])
    
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    #res02 = Dropout(0.2)(res02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])
    res10 = Concatenate()([res03a, res03b, res02])

    ## Output Blocks
    out1 = Conv1D(24*7, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out1 = Dropout(0.2)(out1)  
    
    out2 = Conv1D(24*7, 1, padding='same', activation=PReLU())(rres10)   # 256, 11X10=110
    out2 = Dropout(0.2)(out2)
    
    out = Concatenate(axis=1)([out1, out2])
    
    ## Output Block
    out = Conv1D(24*7, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)

    #, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
    out = GlobalAveragePooling1D()(out) 

    out = Dense(output_timesteps)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 168, 37)]    0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 37, 168)      0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 168, 37)      1406        input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168, 37)      1406        input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 37, 168)      28392       permute[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 37, 168)      28392       permute[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 168, 37)      0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 37, 168)      0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 37, 168)      0           input_1[0][0]
# __________________________________________________________________________________________________
# attention_vec2 (Permute)        (None, 37, 168)      0           multiply_2[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 168, 37)      0           multiply[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 37, 168)      0           permute_1[0][0]
#                                                                  attention_vec2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 168, 37)      0           input_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 37, 168)      28392       multiply_3[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 168, 168)     6384        multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 168, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 168, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 37, 168)      0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 168, 168)     0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 37, 168)      56616       multiply_14[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 168, 37)      12469       multiply_4[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 168)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 37, 168)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 168, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 168, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 37, 168)      0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 168, 37)      0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 37, 168)      0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 37, 168)      0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 168, 37)      0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 168, 37)      0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 37, 168)      28392       add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 37, 168)      28392       subtract_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 168, 168)     6384        add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 168, 168)     6384        subtract[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 37, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 37, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 37, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 37, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 168, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 168, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 168, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 168, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 37, 168)      0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 37, 168)      0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 168, 168)     0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 168, 168)     0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 37, 168)      56616       multiply_16[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 37, 168)      56616       multiply_18[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 168, 37)      12469       multiply_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 168, 37)      12469       multiply_8[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 37, 168)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 37, 168)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 37, 168)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 37, 168)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 168, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 168, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 168, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 168, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 37, 168)      0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 37, 168)      0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 168, 37)      0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 168, 37)      0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 168)      0           add_3[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 37, 168)      0           subtract_3[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 168, 37)      0           add[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 168, 37)      0           subtract[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 37, 672)      0           add_4[0][0]
#                                                                  subtract_4[0][0]
#                                                                  add_3[0][0]
#                                                                  subtract_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 168, 148)     0           add_1[0][0]
#                                                                  subtract_1[0][0]
#                                                                  add[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 37, 168)      113064      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 37, 168)      113064      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 168, 168)     25032       concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 168, 168)     25032       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 37, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 37, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 37, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 37, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 168, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 168, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 168, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 168, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 37, 168)      0           activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 37, 168)      0           activation_36[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 168, 168)     0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 168, 168)     0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 37, 168)      56616       multiply_20[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 37, 168)      56616       multiply_22[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 168, 37)      12469       multiply_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 168, 37)      12469       multiply_12[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 37, 168)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 37, 168)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 37, 168)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 37, 168)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 168, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 168, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 168, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 168, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 37, 168)      0           activation_34[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 37, 168)      0           activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 168, 37)      0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 168, 37)      0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 168)      0           add_4[0][0]
#                                                                  multiply_21[0][0]
# __________________________________________________________________________________________________
# subtract_5 (Subtract)           (None, 37, 168)      0           subtract_4[0][0]
#                                                                  multiply_23[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 168, 37)      0           add_1[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 168, 37)      0           subtract_1[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 37, 1008)     0           add_5[0][0]
#                                                                  subtract_5[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 168, 222)     0           add_2[0][0]
#                                                                  subtract_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 37, 168)      175728      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 168, 168)     65688       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 37, 168)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 168, 168)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 205, 168)     0           dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 205, 168)     62832       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 205, 168)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 168)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 24)           4056        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,093,845
# Trainable params: 1,093,845
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 1969

# %%
    model.compile(loss='mse', optimizer='adam', metrics=['mse','mae', MAEMD])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = 168
    epochs = 1000
    #root_squared_mean_error
    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint

# %%
    # %%time
    b_size = 168
    batch_size = 168
    #hist = model.fit(strvaX, strvaY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(teX, teY), callbacks=[history, early_stopping])  # , checkpoint
    hist = model.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 131/131 [==============================] - 15s 85ms/step - loss: 0.0259 - mse: 0.0259 - mae: 0.1084 - MAEMD: 0.2168 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0759 - val_MAEMD: 0.1931
# Epoch 2/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0105 - mse: 0.0105 - mae: 0.0767 - MAEMD: 0.1966 - val_loss: 0.0103 - val_mse: 0.0103 - val_mae: 0.0758 - val_MAEMD: 0.1929
# Epoch 3/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0104 - mse: 0.0104 - mae: 0.0760 - MAEMD: 0.1949 - val_loss: 0.0096 - val_mse: 0.0096 - val_mae: 0.0730 - val_MAEMD: 0.1841
# Epoch 4/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0091 - mse: 0.0091 - mae: 0.0713 - MAEMD: 0.1743 - val_loss: 0.0087 - val_mse: 0.0087 - val_mae: 0.0695 - val_MAEMD: 0.1680
# Epoch 5/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0089 - mse: 0.0089 - mae: 0.0703 - MAEMD: 0.1697 - val_loss: 0.0087 - val_mse: 0.0087 - val_mae: 0.0696 - val_MAEMD: 0.1671
# Epoch 6/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0088 - mse: 0.0088 - mae: 0.0700 - MAEMD: 0.1686 - val_loss: 0.0086 - val_mse: 0.0086 - val_mae: 0.0691 - val_MAEMD: 0.1656
# Epoch 7/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0087 - mse: 0.0087 - mae: 0.0697 - MAEMD: 0.1676 - val_loss: 0.0086 - val_mse: 0.0086 - val_mae: 0.0692 - val_MAEMD: 0.1652
# Epoch 8/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0087 - mse: 0.0087 - mae: 0.0695 - MAEMD: 0.1670 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0689 - val_MAEMD: 0.1641
# Epoch 9/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0694 - MAEMD: 0.1664 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0689 - val_MAEMD: 0.1639
# Epoch 10/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0692 - MAEMD: 0.1658 - val_loss: 0.0085 - val_mse: 0.0085 - val_mae: 0.0686 - val_MAEMD: 0.1630
# Epoch 11/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0689 - MAEMD: 0.1646 - val_loss: 0.0084 - val_mse: 0.0084 - val_mae: 0.0684 - val_MAEMD: 0.1612
# Epoch 12/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0085 - mse: 0.0085 - mae: 0.0687 - MAEMD: 0.1630 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0680 - val_MAEMD: 0.1600
# Epoch 13/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0684 - MAEMD: 0.1621 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0679 - val_MAEMD: 0.1593
# Epoch 14/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0084 - mse: 0.0084 - mae: 0.0683 - MAEMD: 0.1615 - val_loss: 0.0083 - val_mse: 0.0083 - val_mae: 0.0678 - val_MAEMD: 0.1586
# Epoch 15/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0681 - MAEMD: 0.1608 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0677 - val_MAEMD: 0.1583
# Epoch 16/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0083 - mse: 0.0083 - mae: 0.0679 - MAEMD: 0.1602 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0675 - val_MAEMD: 0.1575
# Epoch 17/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0677 - MAEMD: 0.1596 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0674 - val_MAEMD: 0.1569
# Epoch 18/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0082 - mse: 0.0082 - mae: 0.0676 - MAEMD: 0.1589 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0674 - val_MAEMD: 0.1562
# Epoch 19/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0674 - MAEMD: 0.1581 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0674 - val_MAEMD: 0.1555
# Epoch 20/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0081 - mse: 0.0081 - mae: 0.0671 - MAEMD: 0.1571 - val_loss: 0.0081 - val_mse: 0.0081 - val_mae: 0.0672 - val_MAEMD: 0.1547
# Epoch 21/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0080 - mse: 0.0080 - mae: 0.0668 - MAEMD: 0.1559 - val_loss: 0.0080 - val_mse: 0.0080 - val_mae: 0.0669 - val_MAEMD: 0.1533
# Epoch 22/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0666 - MAEMD: 0.1546 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0667 - val_MAEMD: 0.1519
# Epoch 23/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0663 - MAEMD: 0.1533 - val_loss: 0.0079 - val_mse: 0.0079 - val_mae: 0.0665 - val_MAEMD: 0.1509
# Epoch 24/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0661 - MAEMD: 0.1522 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0662 - val_MAEMD: 0.1501
# Epoch 25/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0078 - mse: 0.0078 - mae: 0.0659 - MAEMD: 0.1513 - val_loss: 0.0078 - val_mse: 0.0078 - val_mae: 0.0659 - val_MAEMD: 0.1492
# Epoch 26/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0657 - MAEMD: 0.1506 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0658 - val_MAEMD: 0.1484
# Epoch 27/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0077 - mse: 0.0077 - mae: 0.0656 - MAEMD: 0.1497 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0656 - val_MAEMD: 0.1478
# Epoch 28/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0653 - MAEMD: 0.1489 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0655 - val_MAEMD: 0.1474
# Epoch 29/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0076 - mse: 0.0076 - mae: 0.0652 - MAEMD: 0.1482 - val_loss: 0.0077 - val_mse: 0.0077 - val_mae: 0.0656 - val_MAEMD: 0.1473
# Epoch 30/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0649 - MAEMD: 0.1473 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0653 - val_MAEMD: 0.1466
# Epoch 31/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0075 - mse: 0.0075 - mae: 0.0648 - MAEMD: 0.1465 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0653 - val_MAEMD: 0.1466
# Epoch 32/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0645 - MAEMD: 0.1456 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0653 - val_MAEMD: 0.1458
# Epoch 33/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0074 - mse: 0.0074 - mae: 0.0644 - MAEMD: 0.1449 - val_loss: 0.0076 - val_mse: 0.0076 - val_mae: 0.0652 - val_MAEMD: 0.1456
# Epoch 34/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0641 - MAEMD: 0.1438 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0649 - val_MAEMD: 0.1450
# Epoch 35/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0638 - MAEMD: 0.1429 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0648 - val_MAEMD: 0.1448
# Epoch 36/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0072 - mse: 0.0072 - mae: 0.0636 - MAEMD: 0.1419 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0648 - val_MAEMD: 0.1443
# Epoch 37/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0634 - MAEMD: 0.1411 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0648 - val_MAEMD: 0.1443
# Epoch 38/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0071 - mse: 0.0071 - mae: 0.0631 - MAEMD: 0.1399 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0646 - val_MAEMD: 0.1435
# Epoch 39/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0628 - MAEMD: 0.1388 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0648 - val_MAEMD: 0.1430
# Epoch 40/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0625 - MAEMD: 0.1377 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0649 - val_MAEMD: 0.1426
# Epoch 41/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0069 - mse: 0.0069 - mae: 0.0623 - MAEMD: 0.1366 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0650 - val_MAEMD: 0.1424
# Epoch 42/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0620 - MAEMD: 0.1351 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0638 - val_MAEMD: 0.1415
# Epoch 43/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0068 - mse: 0.0068 - mae: 0.0618 - MAEMD: 0.1341 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0651 - val_MAEMD: 0.1423
# Epoch 44/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0067 - mse: 0.0067 - mae: 0.0614 - MAEMD: 0.1328 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0652 - val_MAEMD: 0.1414
# Epoch 45/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0066 - mse: 0.0066 - mae: 0.0609 - MAEMD: 0.1312 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0649 - val_MAEMD: 0.1394
# Epoch 46/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0064 - mse: 0.0064 - mae: 0.0604 - MAEMD: 0.1294 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0647 - val_MAEMD: 0.1381
# Epoch 47/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0600 - MAEMD: 0.1277 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0647 - val_MAEMD: 0.1387
# Epoch 48/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0597 - MAEMD: 0.1263 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0647 - val_MAEMD: 0.1375
# Epoch 49/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0062 - mse: 0.0062 - mae: 0.0595 - MAEMD: 0.1246 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0642 - val_MAEMD: 0.1372
# Epoch 50/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0587 - MAEMD: 0.1227 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0638 - val_MAEMD: 0.1357
# Epoch 51/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0060 - mse: 0.0060 - mae: 0.0583 - MAEMD: 0.1210 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0636 - val_MAEMD: 0.1350
# Epoch 52/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0577 - MAEMD: 0.1190 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0635 - val_MAEMD: 0.1338
# Epoch 53/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0057 - mse: 0.0057 - mae: 0.0572 - MAEMD: 0.1172 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0640 - val_MAEMD: 0.1341
# Epoch 54/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0056 - mse: 0.0056 - mae: 0.0567 - MAEMD: 0.1154 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0640 - val_MAEMD: 0.1335
# Epoch 55/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0562 - MAEMD: 0.1139 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0636 - val_MAEMD: 0.1323
# Epoch 56/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0055 - mse: 0.0055 - mae: 0.0559 - MAEMD: 0.1125 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0635 - val_MAEMD: 0.1326
# Epoch 57/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0555 - MAEMD: 0.1110 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0642 - val_MAEMD: 0.1314
# Epoch 58/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0550 - MAEMD: 0.1093 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0644 - val_MAEMD: 0.1299
# Epoch 59/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0052 - mse: 0.0052 - mae: 0.0545 - MAEMD: 0.1076 - val_loss: 0.0072 - val_mse: 0.0072 - val_mae: 0.0647 - val_MAEMD: 0.1304mae:
# Epoch 60/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0051 - mse: 0.0051 - mae: 0.0540 - MAEMD: 0.1060 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0643 - val_MAEMD: 0.1297
# Epoch 61/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0535 - MAEMD: 0.1043 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0640 - val_MAEMD: 0.1291
# Epoch 62/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0531 - MAEMD: 0.1030 - val_loss: 0.0074 - val_mse: 0.0074 - val_mae: 0.0655 - val_MAEMD: 0.1300
# Epoch 63/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0530 - MAEMD: 0.1021 - val_loss: 0.0073 - val_mse: 0.0073 - val_mae: 0.0654 - val_MAEMD: 0.1295
# Epoch 64/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0531 - MAEMD: 0.1017 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0641 - val_MAEMD: 0.1289
# Epoch 65/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0049 - mse: 0.0049 - mae: 0.0533 - MAEMD: 0.1017 - val_loss: 0.0069 - val_mse: 0.0069 - val_mae: 0.0631 - val_MAEMD: 0.1267
# Epoch 66/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0048 - mse: 0.0048 - mae: 0.0528 - MAEMD: 0.1003 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0646 - val_MAEMD: 0.1263
# Epoch 67/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0525 - MAEMD: 0.0993 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0617 - val_MAEMD: 0.1242
# Epoch 68/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0522 - MAEMD: 0.0984 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0620 - val_MAEMD: 0.1225
# Epoch 69/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0045 - mse: 0.0045 - mae: 0.0513 - MAEMD: 0.0964 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0625 - val_MAEMD: 0.1216
# Epoch 70/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0044 - mse: 0.0044 - mae: 0.0506 - MAEMD: 0.0946 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0630 - val_MAEMD: 0.1203
# Epoch 71/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0502 - MAEMD: 0.0934 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0624 - val_MAEMD: 0.1203
# Epoch 72/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0500 - MAEMD: 0.0926 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0619 - val_MAEMD: 0.12093 - mse: 0.0043 - mae: 0.05
# Epoch 73/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0499 - MAEMD: 0.0920 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0622 - val_MAEMD: 0.1198
# Epoch 74/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0495 - MAEMD: 0.0910 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0624 - val_MAEMD: 0.1196
# Epoch 75/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0042 - mse: 0.0042 - mae: 0.0491 - MAEMD: 0.0898 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0616 - val_MAEMD: 0.1191
# Epoch 76/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0487 - MAEMD: 0.0889 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0614 - val_MAEMD: 0.1191
# Epoch 77/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0041 - mse: 0.0041 - mae: 0.0485 - MAEMD: 0.0881 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0616 - val_MAEMD: 0.1187
# Epoch 78/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0485 - MAEMD: 0.0876 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0619 - val_MAEMD: 0.1187
# Epoch 79/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0484 - MAEMD: 0.0876 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0618 - val_MAEMD: 0.1198
# Epoch 80/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0485 - MAEMD: 0.0873 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0613 - val_MAEMD: 0.1204
# Epoch 81/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0040 - mse: 0.0040 - mae: 0.0481 - MAEMD: 0.0866 - val_loss: 0.0064 - val_mse: 0.0064 - val_mae: 0.0609 - val_MAEMD: 0.1205
# Epoch 82/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0478 - MAEMD: 0.0858 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0611 - val_MAEMD: 0.1201
# Epoch 83/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0476 - MAEMD: 0.0851 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0613 - val_MAEMD: 0.1203
# Epoch 84/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0472 - MAEMD: 0.0840 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0619 - val_MAEMD: 0.1207
# Epoch 85/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0473 - MAEMD: 0.0840 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0621 - val_MAEMD: 0.1215
# Epoch 86/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0474 - MAEMD: 0.0840 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0630 - val_MAEMD: 0.1214
# Epoch 87/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0475 - MAEMD: 0.0838 - val_loss: 0.0070 - val_mse: 0.0070 - val_mae: 0.0640 - val_MAEMD: 0.1222
# Epoch 88/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0474 - MAEMD: 0.0834 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0633 - val_MAEMD: 0.1218
# Epoch 89/1000
# 131/131 [==============================] - 9s 72ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0466 - MAEMD: 0.0820 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0627 - val_MAEMD: 0.1213
# Epoch 90/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0462 - MAEMD: 0.0807 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0616 - val_MAEMD: 0.1201
# Epoch 91/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0459 - MAEMD: 0.0800 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0616 - val_MAEMD: 0.1202
# Wall time: 13min 59s

# %%
model.save('Basic Ramp Model Final_mse.h5')

# %%
gc.collect()
# Out:
# 4592

# %%
#with tf.device('/gpu:0'):
#    model = keras.models.load_model('Basic Ramp Model Final_lead.h5', custom_objects={'MAEMD': MAEMD})
#    gc.collect()

# %%
testPredict = model.predict(teX, batch_size=batch_size)

# %%
def npMAEMS(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true))*100
def npMAEMD(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true-np.mean(y_true)))*100
def npMSE(y_true, y_pred):
    return np.mean(np.square(-y_true+y_pred))
def npMAE(y_true, y_pred):
    return np.mean(abs(-y_true+y_pred))

# %%
tePredict = testPredict.reshape(-1)
testY = teY.reshape(-1)
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMD == ', npMAEMD(testY, tePredict))
# Out:
# Error Test Score > MSE ==  0.007587188363190825  MAE ==  0.06743621775679717  MAEMD ==  0.11371393847027236

# %% [markdown]
# ## Model Trained with MAE

# %%
from keras import regularizers

num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1
    beta = 1
    hfilters = 168
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    pera = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(pera)
    den1b = Dense(timesteps, activation='sigmoid')(pera)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])   
    
    ## Permuted Attention Block
    per1 = Permute((2,1))(visible1)
    den2a = Dense(num_features, activation='tanh')(visible1)
    den2b = Dense(num_features, activation='sigmoid')(visible1)
    den2 = Multiply()([den2a, den2b])
    perb2 = Permute((2,1), name='attention_vec2')(den2)
    
    mul2 = Multiply()([per1, perb2])     
    
    ## Parallel DCCNN Blocks 1-1 ~ 3-1
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres01a = Add()([mul1, d1])   # (100, 25) (100, 25)
    rres01b = Subtract()([mul1, d1])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    rres02a = Add()([rres01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    rres02b = Subtract()([rres01b, d2])   # (100, 25) (100, 25) 
    rres02 = Concatenate()([rres02a, rres02b, rres01a, rres01b])
    #rres02 = Dropout(0.2)(rres02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres03a = Add()([rres02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    rres03b = Subtract()([rres02b, d2])
    rres10 = Concatenate()([rres03a, rres03b, rres02])

    ## Right-half DCCNN Blocks 1-2 ~ 3-2
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul2)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([mul2, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([mul2, d1])
    
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    #res02 = Dropout(0.2)(res02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])
    res10 = Concatenate()([res03a, res03b, res02])

    ## Output Blocks
    out1 = Conv1D(24*7, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out1 = Dropout(0.2)(out1)  
    
    out2 = Conv1D(24*7, 1, padding='same', activation=PReLU())(rres10)   # 256, 11X10=110
    out2 = Dropout(0.2)(out2)
    
    out = Concatenate(axis=1)([out1, out2])
    
    ## Output Block
    out = Conv1D(24*7, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)

    #, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
    out = GlobalAveragePooling1D()(out) 

    out = Dense(output_timesteps)(out) 
    model2 = Model(inputs=[visible1], outputs=[out])
    
    print(model2.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 168, 37)]    0
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 37, 168)      0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 168, 37)      1406        input_2[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 168, 37)      1406        input_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 37, 168)      28392       permute_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 37, 168)      28392       permute_2[0][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 168, 37)      0           dense_7[0][0]
#                                                                  dense_8[0][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 37, 168)      0           dense_5[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# permute_3 (Permute)             (None, 37, 168)      0           input_2[0][0]
# __________________________________________________________________________________________________
# attention_vec2 (Permute)        (None, 37, 168)      0           multiply_26[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 168, 37)      0           multiply_24[0][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 37, 168)      0           permute_3[0][0]
#                                                                  attention_vec2[0][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 168, 37)      0           input_2[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 37, 168)      28392       multiply_27[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 168, 168)     6384        multiply_25[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 37, 168)      0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 37, 168)      0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 168, 168)     0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 168, 168)     0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 37, 168)      0           activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 168, 168)     0           activation_40[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 37, 168)      56616       multiply_38[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 168, 37)      12469       multiply_28[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 37, 168)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 37, 168)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 168, 37)      0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 168, 37)      0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 37, 168)      0           activation_62[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 168, 37)      0           activation_42[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 37, 168)      0           multiply_27[0][0]
#                                                                  multiply_39[0][0]
# __________________________________________________________________________________________________
# subtract_9 (Subtract)           (None, 37, 168)      0           multiply_27[0][0]
#                                                                  multiply_39[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 168, 37)      0           multiply_25[0][0]
#                                                                  multiply_29[0][0]
# __________________________________________________________________________________________________
# subtract_6 (Subtract)           (None, 168, 37)      0           multiply_25[0][0]
#                                                                  multiply_29[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 37, 168)      28392       add_9[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 37, 168)      28392       subtract_9[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 168, 168)     6384        add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 168, 168)     6384        subtract_6[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 37, 168)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 37, 168)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 37, 168)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 37, 168)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 168, 168)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 168, 168)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 168, 168)     0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 168, 168)     0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 37, 168)      0           activation_64[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 37, 168)      0           activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 168, 168)     0           activation_44[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 168, 168)     0           activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 37, 168)      56616       multiply_40[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 37, 168)      56616       multiply_42[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 168, 37)      12469       multiply_30[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 168, 37)      12469       multiply_32[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 37, 168)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 37, 168)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 37, 168)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 37, 168)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 168, 37)      0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 168, 37)      0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 168, 37)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 168, 37)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 37, 168)      0           activation_66[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 37, 168)      0           activation_70[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 168, 37)      0           activation_46[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 168, 37)      0           activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 37, 168)      0           add_9[0][0]
#                                                                  multiply_41[0][0]
# __________________________________________________________________________________________________
# subtract_10 (Subtract)          (None, 37, 168)      0           subtract_9[0][0]
#                                                                  multiply_43[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 168, 37)      0           add_6[0][0]
#                                                                  multiply_31[0][0]
# __________________________________________________________________________________________________
# subtract_7 (Subtract)           (None, 168, 37)      0           subtract_6[0][0]
#                                                                  multiply_33[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 37, 672)      0           add_10[0][0]
#                                                                  subtract_10[0][0]
#                                                                  add_9[0][0]
#                                                                  subtract_9[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 168, 148)     0           add_7[0][0]
#                                                                  subtract_7[0][0]
#                                                                  add_6[0][0]
#                                                                  subtract_6[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 37, 168)      113064      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 37, 168)      113064      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 168, 168)     25032       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 168, 168)     25032       concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 37, 168)      0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 37, 168)      0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 37, 168)      0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 37, 168)      0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 168, 168)     0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 168, 168)     0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 168, 168)     0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 168, 168)     0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# multiply_44 (Multiply)          (None, 37, 168)      0           activation_72[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# multiply_46 (Multiply)          (None, 37, 168)      0           activation_76[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 168, 168)     0           activation_52[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 168, 168)     0           activation_56[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 37, 168)      56616       multiply_44[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 37, 168)      56616       multiply_46[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 168, 37)      12469       multiply_34[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 168, 37)      12469       multiply_36[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 37, 168)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 37, 168)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 37, 168)      0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 37, 168)      0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 168, 37)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 168, 37)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 168, 37)      0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 168, 37)      0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# multiply_45 (Multiply)          (None, 37, 168)      0           activation_74[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# multiply_47 (Multiply)          (None, 37, 168)      0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 168, 37)      0           activation_54[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 168, 37)      0           activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 37, 168)      0           add_10[0][0]
#                                                                  multiply_45[0][0]
# __________________________________________________________________________________________________
# subtract_11 (Subtract)          (None, 37, 168)      0           subtract_10[0][0]
#                                                                  multiply_47[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 168, 37)      0           add_7[0][0]
#                                                                  multiply_35[0][0]
# __________________________________________________________________________________________________
# subtract_8 (Subtract)           (None, 168, 37)      0           subtract_7[0][0]
#                                                                  multiply_37[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 37, 1008)     0           add_11[0][0]
#                                                                  subtract_11[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 168, 222)     0           add_8[0][0]
#                                                                  subtract_8[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_43 (Conv1D)              (None, 37, 168)      175728      concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_44 (Conv1D)              (None, 168, 168)     65688       concatenate_6[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 37, 168)      0           conv1d_43[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 168, 168)     0           conv1d_44[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 205, 168)     0           dropout_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 205, 168)     62832       concatenate_9[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 205, 168)     0           conv1d_45[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 168)          0           dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_9 (Dense)                 (None, 24)           4056        global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 1,093,845
# Trainable params: 1,093,845
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 5002

# %%
    model2.compile(loss='mae', optimizer='adam', metrics=['mse','mae', MAEMD])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    epochs = 1000
    #root_squared_mean_error
    history2 = LossHistory()
    history2.init()

# %%
    # %%time
    b_size = 168
    batch_size = 168
    #hist = model.fit(strvaX, strvaY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(teX, teY), callbacks=[history, early_stopping])  # , checkpoint
    hist2 = model2.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 131/131 [==============================] - 13s 77ms/step - loss: 0.1082 - mse: 0.0260 - mae: 0.1082 - MAEMD: 0.2171 - val_loss: 0.0767 - val_mse: 0.0105 - val_mae: 0.0767 - val_MAEMD: 0.1935
# Epoch 2/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0768 - mse: 0.0106 - mae: 0.0768 - MAEMD: 0.1967 - val_loss: 0.0772 - val_mse: 0.0106 - val_mae: 0.0772 - val_MAEMD: 0.1933
# Epoch 3/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0745 - mse: 0.0100 - mae: 0.0745 - MAEMD: 0.1890 - val_loss: 0.0711 - val_mse: 0.0091 - val_mae: 0.0711 - val_MAEMD: 0.1730
# Epoch 4/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0703 - mse: 0.0090 - mae: 0.0703 - MAEMD: 0.1736 - val_loss: 0.0702 - val_mse: 0.0089 - val_mae: 0.0702 - val_MAEMD: 0.1692
# Epoch 5/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0697 - mse: 0.0088 - mae: 0.0697 - MAEMD: 0.1711 - val_loss: 0.0697 - val_mse: 0.0088 - val_mae: 0.0697 - val_MAEMD: 0.1677
# Epoch 6/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0694 - mse: 0.0087 - mae: 0.0694 - MAEMD: 0.1704 - val_loss: 0.0702 - val_mse: 0.0089 - val_mae: 0.0702 - val_MAEMD: 0.1677
# Epoch 7/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0692 - mse: 0.0087 - mae: 0.0692 - MAEMD: 0.1697 - val_loss: 0.0698 - val_mse: 0.0088 - val_mae: 0.0698 - val_MAEMD: 0.1667
# Epoch 8/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0689 - mse: 0.0086 - mae: 0.0689 - MAEMD: 0.1689 - val_loss: 0.0687 - val_mse: 0.0085 - val_mae: 0.0687 - val_MAEMD: 0.1660
# Epoch 9/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0687 - mse: 0.0086 - mae: 0.0687 - MAEMD: 0.1680 - val_loss: 0.0694 - val_mse: 0.0087 - val_mae: 0.0694 - val_MAEMD: 0.1653
# Epoch 10/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0683 - mse: 0.0085 - mae: 0.0683 - MAEMD: 0.1656 - val_loss: 0.0679 - val_mse: 0.0084 - val_mae: 0.0679 - val_MAEMD: 0.1625
# Epoch 11/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0679 - mse: 0.0084 - mae: 0.0679 - MAEMD: 0.1642 - val_loss: 0.0679 - val_mse: 0.0083 - val_mae: 0.0679 - val_MAEMD: 0.1617
# Epoch 12/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0676 - mse: 0.0083 - mae: 0.0676 - MAEMD: 0.1632 - val_loss: 0.0675 - val_mse: 0.0083 - val_mae: 0.0675 - val_MAEMD: 0.1610
# Epoch 13/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0674 - mse: 0.0083 - mae: 0.0674 - MAEMD: 0.1625 - val_loss: 0.0673 - val_mse: 0.0082 - val_mae: 0.0673 - val_MAEMD: 0.1601
# Epoch 14/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0671 - mse: 0.0082 - mae: 0.0671 - MAEMD: 0.1614 - val_loss: 0.0671 - val_mse: 0.0081 - val_mae: 0.0671 - val_MAEMD: 0.1591
# Epoch 15/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0668 - mse: 0.0081 - mae: 0.0668 - MAEMD: 0.1603 - val_loss: 0.0668 - val_mse: 0.0081 - val_mae: 0.0668 - val_MAEMD: 0.1575
# Epoch 16/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0665 - mse: 0.0081 - mae: 0.0665 - MAEMD: 0.1591 - val_loss: 0.0665 - val_mse: 0.0080 - val_mae: 0.0665 - val_MAEMD: 0.1566
# Epoch 17/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0662 - mse: 0.0080 - mae: 0.0662 - MAEMD: 0.1580 - val_loss: 0.0664 - val_mse: 0.0080 - val_mae: 0.0664 - val_MAEMD: 0.1556
# Epoch 18/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0659 - mse: 0.0079 - mae: 0.0659 - MAEMD: 0.1568 - val_loss: 0.0662 - val_mse: 0.0079 - val_mae: 0.0662 - val_MAEMD: 0.1549
# Epoch 19/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0656 - mse: 0.0079 - mae: 0.0656 - MAEMD: 0.1558 - val_loss: 0.0659 - val_mse: 0.0079 - val_mae: 0.0659 - val_MAEMD: 0.1541
# Epoch 20/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0654 - mse: 0.0078 - mae: 0.0654 - MAEMD: 0.1552 - val_loss: 0.0660 - val_mse: 0.0079 - val_mae: 0.0660 - val_MAEMD: 0.1534
# Epoch 21/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0652 - mse: 0.0078 - mae: 0.0652 - MAEMD: 0.1544 - val_loss: 0.0659 - val_mse: 0.0078 - val_mae: 0.0659 - val_MAEMD: 0.1531
# Epoch 22/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0649 - mse: 0.0077 - mae: 0.0649 - MAEMD: 0.1537 - val_loss: 0.0663 - val_mse: 0.0079 - val_mae: 0.0663 - val_MAEMD: 0.1534
# Epoch 23/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0647 - mse: 0.0077 - mae: 0.0647 - MAEMD: 0.1531 - val_loss: 0.0653 - val_mse: 0.0077 - val_mae: 0.0653 - val_MAEMD: 0.1523
# Epoch 24/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0644 - mse: 0.0076 - mae: 0.0644 - MAEMD: 0.1523 - val_loss: 0.0653 - val_mse: 0.0077 - val_mae: 0.0653 - val_MAEMD: 0.1515
# Epoch 25/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0641 - mse: 0.0076 - mae: 0.0641 - MAEMD: 0.1516 - val_loss: 0.0650 - val_mse: 0.0077 - val_mae: 0.0650 - val_MAEMD: 0.1509
# Epoch 26/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0639 - mse: 0.0075 - mae: 0.0639 - MAEMD: 0.1509 - val_loss: 0.0649 - val_mse: 0.0077 - val_mae: 0.0649 - val_MAEMD: 0.1512
# Epoch 27/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0637 - mse: 0.0075 - mae: 0.0637 - MAEMD: 0.1502 - val_loss: 0.0654 - val_mse: 0.0077 - val_mae: 0.0654 - val_MAEMD: 0.1511
# Epoch 28/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0635 - mse: 0.0074 - mae: 0.0635 - MAEMD: 0.1495 - val_loss: 0.0651 - val_mse: 0.0077 - val_mae: 0.0651 - val_MAEMD: 0.1505
# Epoch 29/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0632 - mse: 0.0074 - mae: 0.0632 - MAEMD: 0.1488 - val_loss: 0.0650 - val_mse: 0.0076 - val_mae: 0.0650 - val_MAEMD: 0.1493
# Epoch 30/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0629 - mse: 0.0073 - mae: 0.0629 - MAEMD: 0.1480 - val_loss: 0.0655 - val_mse: 0.0077 - val_mae: 0.0655 - val_MAEMD: 0.1496
# Epoch 31/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0627 - mse: 0.0073 - mae: 0.0627 - MAEMD: 0.1472 - val_loss: 0.0649 - val_mse: 0.0076 - val_mae: 0.0649 - val_MAEMD: 0.1486
# Epoch 32/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0625 - mse: 0.0073 - mae: 0.0625 - MAEMD: 0.1467 - val_loss: 0.0639 - val_mse: 0.0074 - val_mae: 0.0639 - val_MAEMD: 0.1473
# Epoch 33/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0621 - mse: 0.0072 - mae: 0.0621 - MAEMD: 0.1455 - val_loss: 0.0639 - val_mse: 0.0074 - val_mae: 0.0639 - val_MAEMD: 0.1473
# Epoch 34/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0618 - mse: 0.0071 - mae: 0.0618 - MAEMD: 0.1445 - val_loss: 0.0651 - val_mse: 0.0076 - val_mae: 0.0651 - val_MAEMD: 0.1470
# Epoch 35/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0616 - mse: 0.0071 - mae: 0.0616 - MAEMD: 0.1437 - val_loss: 0.0640 - val_mse: 0.0074 - val_mae: 0.0640 - val_MAEMD: 0.1455
# Epoch 36/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0611 - mse: 0.0070 - mae: 0.0611 - MAEMD: 0.1425 - val_loss: 0.0633 - val_mse: 0.0073 - val_mae: 0.0633 - val_MAEMD: 0.1450
# Epoch 37/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0607 - mse: 0.0069 - mae: 0.0607 - MAEMD: 0.1416 - val_loss: 0.0632 - val_mse: 0.0073 - val_mae: 0.0632 - val_MAEMD: 0.1426
# Epoch 38/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0602 - mse: 0.0068 - mae: 0.0602 - MAEMD: 0.1402 - val_loss: 0.0628 - val_mse: 0.0072 - val_mae: 0.0628 - val_MAEMD: 0.1439
# Epoch 39/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0598 - mse: 0.0067 - mae: 0.0598 - MAEMD: 0.1390 - val_loss: 0.0625 - val_mse: 0.0072 - val_mae: 0.0625 - val_MAEMD: 0.1436
# Epoch 40/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0593 - mse: 0.0066 - mae: 0.0593 - MAEMD: 0.1376 - val_loss: 0.0624 - val_mse: 0.0071 - val_mae: 0.0624 - val_MAEMD: 0.1422
# Epoch 41/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0588 - mse: 0.0065 - mae: 0.0588 - MAEMD: 0.1363 - val_loss: 0.0623 - val_mse: 0.0071 - val_mae: 0.0623 - val_MAEMD: 0.1420
# Epoch 42/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0582 - mse: 0.0064 - mae: 0.0582 - MAEMD: 0.1349 - val_loss: 0.0619 - val_mse: 0.0070 - val_mae: 0.0619 - val_MAEMD: 0.1423
# Epoch 43/1000
# 131/131 [==============================] - 9s 72ms/step - loss: 0.0577 - mse: 0.0063 - mae: 0.0577 - MAEMD: 0.1334 - val_loss: 0.0619 - val_mse: 0.0070 - val_mae: 0.0619 - val_MAEMD: 0.1407
# Epoch 44/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0572 - mse: 0.0062 - mae: 0.0572 - MAEMD: 0.1320 - val_loss: 0.0617 - val_mse: 0.0070 - val_mae: 0.0617 - val_MAEMD: 0.1398
# Epoch 45/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0567 - mse: 0.0061 - mae: 0.0567 - MAEMD: 0.1305 - val_loss: 0.0621 - val_mse: 0.0070 - val_mae: 0.0621 - val_MAEMD: 0.1391
# Epoch 46/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0563 - mse: 0.0061 - mae: 0.0563 - MAEMD: 0.1293 - val_loss: 0.0620 - val_mse: 0.0070 - val_mae: 0.0620 - val_MAEMD: 0.1396
# Epoch 47/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0558 - mse: 0.0060 - mae: 0.0558 - MAEMD: 0.1278 - val_loss: 0.0614 - val_mse: 0.0069 - val_mae: 0.0614 - val_MAEMD: 0.1373
# Epoch 48/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0552 - mse: 0.0059 - mae: 0.0552 - MAEMD: 0.1262 - val_loss: 0.0615 - val_mse: 0.0069 - val_mae: 0.0615 - val_MAEMD: 0.1372
# Epoch 49/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0549 - mse: 0.0058 - mae: 0.0549 - MAEMD: 0.1251 - val_loss: 0.0627 - val_mse: 0.0071 - val_mae: 0.0627 - val_MAEMD: 0.1379
# Epoch 50/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0547 - mse: 0.0057 - mae: 0.0547 - MAEMD: 0.1239 - val_loss: 0.0609 - val_mse: 0.0068 - val_mae: 0.0609 - val_MAEMD: 0.1340
# Epoch 51/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0540 - mse: 0.0056 - mae: 0.0540 - MAEMD: 0.1224 - val_loss: 0.0608 - val_mse: 0.0068 - val_mae: 0.0608 - val_MAEMD: 0.1354
# Epoch 52/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0535 - mse: 0.0055 - mae: 0.0535 - MAEMD: 0.1209 - val_loss: 0.0610 - val_mse: 0.0068 - val_mae: 0.0610 - val_MAEMD: 0.1338
# Epoch 53/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0532 - mse: 0.0055 - mae: 0.0532 - MAEMD: 0.1201 - val_loss: 0.0605 - val_mse: 0.0067 - val_mae: 0.0605 - val_MAEMD: 0.1335
# Epoch 54/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0532 - mse: 0.0054 - mae: 0.0532 - MAEMD: 0.1196 - val_loss: 0.0617 - val_mse: 0.0069 - val_mae: 0.0617 - val_MAEMD: 0.1357
# Epoch 55/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0528 - mse: 0.0054 - mae: 0.0528 - MAEMD: 0.1184 - val_loss: 0.0607 - val_mse: 0.0067 - val_mae: 0.0607 - val_MAEMD: 0.1346
# Epoch 56/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0525 - mse: 0.0053 - mae: 0.0525 - MAEMD: 0.1175 - val_loss: 0.0591 - val_mse: 0.0064 - val_mae: 0.0591 - val_MAEMD: 0.1324
# Epoch 57/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0521 - mse: 0.0052 - mae: 0.0521 - MAEMD: 0.1161 - val_loss: 0.0589 - val_mse: 0.0064 - val_mae: 0.0589 - val_MAEMD: 0.1314
# Epoch 58/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0519 - mse: 0.0052 - mae: 0.0519 - MAEMD: 0.1150 - val_loss: 0.0604 - val_mse: 0.0066 - val_mae: 0.0604 - val_MAEMD: 0.1312
# Epoch 59/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0513 - mse: 0.0051 - mae: 0.0513 - MAEMD: 0.1138 - val_loss: 0.0601 - val_mse: 0.0066 - val_mae: 0.0601 - val_MAEMD: 0.1287
# Epoch 60/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0507 - mse: 0.0050 - mae: 0.0507 - MAEMD: 0.1126 - val_loss: 0.0598 - val_mse: 0.0065 - val_mae: 0.0598 - val_MAEMD: 0.1288
# Epoch 61/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0505 - mse: 0.0049 - mae: 0.0505 - MAEMD: 0.1114 - val_loss: 0.0586 - val_mse: 0.0063 - val_mae: 0.0586 - val_MAEMD: 0.1276
# Epoch 62/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0500 - mse: 0.0049 - mae: 0.0500 - MAEMD: 0.1104 - val_loss: 0.0587 - val_mse: 0.0063 - val_mae: 0.0587 - val_MAEMD: 0.1289
# Epoch 63/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0496 - mse: 0.0048 - mae: 0.0496 - MAEMD: 0.1094 - val_loss: 0.0587 - val_mse: 0.0063 - val_mae: 0.0587 - val_MAEMD: 0.1284
# Epoch 64/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0493 - mse: 0.0047 - mae: 0.0493 - MAEMD: 0.1084 - val_loss: 0.0586 - val_mse: 0.0063 - val_mae: 0.0586 - val_MAEMD: 0.1270
# Epoch 65/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0488 - mse: 0.0047 - mae: 0.0488 - MAEMD: 0.1069 - val_loss: 0.0592 - val_mse: 0.0064 - val_mae: 0.0592 - val_MAEMD: 0.1254
# Epoch 66/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.0490 - mse: 0.0047 - mae: 0.0490 - MAEMD: 0.1069 - val_loss: 0.0603 - val_mse: 0.0066 - val_mae: 0.0603 - val_MAEMD: 0.1278
# Epoch 67/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0488 - mse: 0.0046 - mae: 0.0488 - MAEMD: 0.1063 - val_loss: 0.0611 - val_mse: 0.0067 - val_mae: 0.0611 - val_MAEMD: 0.1295
# Epoch 68/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0487 - mse: 0.0046 - mae: 0.0487 - MAEMD: 0.1059 - val_loss: 0.0580 - val_mse: 0.0062 - val_mae: 0.0580 - val_MAEMD: 0.1286
# Epoch 69/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0488 - mse: 0.0046 - mae: 0.0488 - MAEMD: 0.1056 - val_loss: 0.0579 - val_mse: 0.0062 - val_mae: 0.0579 - val_MAEMD: 0.1264
# Epoch 70/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0480 - mse: 0.0045 - mae: 0.0480 - MAEMD: 0.1042 - val_loss: 0.0577 - val_mse: 0.0061 - val_mae: 0.0577 - val_MAEMD: 0.1252
# Epoch 71/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0476 - mse: 0.0044 - mae: 0.0476 - MAEMD: 0.1032 - val_loss: 0.0578 - val_mse: 0.0061 - val_mae: 0.0578 - val_MAEMD: 0.1239
# Epoch 72/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0474 - mse: 0.0044 - mae: 0.0474 - MAEMD: 0.1025 - val_loss: 0.0583 - val_mse: 0.0062 - val_mae: 0.0583 - val_MAEMD: 0.1259
# Epoch 73/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0469 - mse: 0.0043 - mae: 0.0469 - MAEMD: 0.1015 - val_loss: 0.0587 - val_mse: 0.0063 - val_mae: 0.0587 - val_MAEMD: 0.1240
# Epoch 74/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0468 - mse: 0.0043 - mae: 0.0468 - MAEMD: 0.1011 - val_loss: 0.0580 - val_mse: 0.0061 - val_mae: 0.0580 - val_MAEMD: 0.1226
# Epoch 75/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0467 - mse: 0.0043 - mae: 0.0467 - MAEMD: 0.1005 - val_loss: 0.0587 - val_mse: 0.0063 - val_mae: 0.0587 - val_MAEMD: 0.1235
# Epoch 76/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0467 - mse: 0.0043 - mae: 0.0467 - MAEMD: 0.1002 - val_loss: 0.0583 - val_mse: 0.0062 - val_mae: 0.0583 - val_MAEMD: 0.1227
# Epoch 77/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0464 - mse: 0.0042 - mae: 0.0464 - MAEMD: 0.0993 - val_loss: 0.0576 - val_mse: 0.0061 - val_mae: 0.0576 - val_MAEMD: 0.1225
# Epoch 78/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0462 - mse: 0.0042 - mae: 0.0462 - MAEMD: 0.0986 - val_loss: 0.0572 - val_mse: 0.0060 - val_mae: 0.0572 - val_MAEMD: 0.1229
# Epoch 79/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0456 - mse: 0.0041 - mae: 0.0456 - MAEMD: 0.0974 - val_loss: 0.0568 - val_mse: 0.0059 - val_mae: 0.0568 - val_MAEMD: 0.1215
# Epoch 80/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0453 - mse: 0.0040 - mae: 0.0453 - MAEMD: 0.0964 - val_loss: 0.0566 - val_mse: 0.0059 - val_mae: 0.0566 - val_MAEMD: 0.1205
# Epoch 81/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0450 - mse: 0.0040 - mae: 0.0450 - MAEMD: 0.0957 - val_loss: 0.0568 - val_mse: 0.0059 - val_mae: 0.0568 - val_MAEMD: 0.1207
# Epoch 82/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0449 - mse: 0.0040 - mae: 0.0449 - MAEMD: 0.0953 - val_loss: 0.0571 - val_mse: 0.0060 - val_mae: 0.0571 - val_MAEMD: 0.1211
# Epoch 83/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0450 - mse: 0.0040 - mae: 0.0450 - MAEMD: 0.0951 - val_loss: 0.0568 - val_mse: 0.0059 - val_mae: 0.0568 - val_MAEMD: 0.1209
# Epoch 84/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0456 - mse: 0.0041 - mae: 0.0456 - MAEMD: 0.0954 - val_loss: 0.0567 - val_mse: 0.0059 - val_mae: 0.0567 - val_MAEMD: 0.1220
# Epoch 85/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0461 - mse: 0.0041 - mae: 0.0461 - MAEMD: 0.0961 - val_loss: 0.0571 - val_mse: 0.0060 - val_mae: 0.0571 - val_MAEMD: 0.1230
# Epoch 86/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0456 - mse: 0.0040 - mae: 0.0456 - MAEMD: 0.0954 - val_loss: 0.0567 - val_mse: 0.0059 - val_mae: 0.0567 - val_MAEMD: 0.1216
# Epoch 87/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0446 - mse: 0.0039 - mae: 0.0446 - MAEMD: 0.0935 - val_loss: 0.0562 - val_mse: 0.0059 - val_mae: 0.0562 - val_MAEMD: 0.1222
# Epoch 88/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0446 - mse: 0.0039 - mae: 0.0446 - MAEMD: 0.0935 - val_loss: 0.0567 - val_mse: 0.0059 - val_mae: 0.0567 - val_MAEMD: 0.1217
# Epoch 89/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0440 - mse: 0.0038 - mae: 0.0440 - MAEMD: 0.0924 - val_loss: 0.0567 - val_mse: 0.0059 - val_mae: 0.0567 - val_MAEMD: 0.1204
# Epoch 90/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0436 - mse: 0.0038 - mae: 0.0436 - MAEMD: 0.0916 - val_loss: 0.0566 - val_mse: 0.0059 - val_mae: 0.0566 - val_MAEMD: 0.1200
# Epoch 91/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0431 - mse: 0.0037 - mae: 0.0431 - MAEMD: 0.0902 - val_loss: 0.0565 - val_mse: 0.0059 - val_mae: 0.0565 - val_MAEMD: 0.1220
# Epoch 92/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0429 - mse: 0.0037 - mae: 0.0429 - MAEMD: 0.0897 - val_loss: 0.0569 - val_mse: 0.0059 - val_mae: 0.0569 - val_MAEMD: 0.1208
# Epoch 93/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0430 - mse: 0.0037 - mae: 0.0430 - MAEMD: 0.0895 - val_loss: 0.0573 - val_mse: 0.0060 - val_mae: 0.0573 - val_MAEMD: 0.1220
# Epoch 94/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0430 - mse: 0.0037 - mae: 0.0430 - MAEMD: 0.0893 - val_loss: 0.0574 - val_mse: 0.0060 - val_mae: 0.0574 - val_MAEMD: 0.1218
# Epoch 95/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0430 - mse: 0.0037 - mae: 0.0430 - MAEMD: 0.0893 - val_loss: 0.0579 - val_mse: 0.0061 - val_mae: 0.0579 - val_MAEMD: 0.1217
# Epoch 96/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0428 - mse: 0.0036 - mae: 0.0428 - MAEMD: 0.0888 - val_loss: 0.0577 - val_mse: 0.0060 - val_mae: 0.0577 - val_MAEMD: 0.1217
# Epoch 97/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0424 - mse: 0.0036 - mae: 0.0424 - MAEMD: 0.0878 - val_loss: 0.0575 - val_mse: 0.0060 - val_mae: 0.0575 - val_MAEMD: 0.1204
# Wall time: 15min

# %%
model2.save('Basic Ramp Model Final_mae.h5')

# %%
gc.collect()
# Out:
# 4581

# %%
testPredict2 = model2.predict(teX, batch_size=batch_size)
tePredict2 = testPredict2.reshape(-1)

# %% [markdown]
# ## Proposed Model

# %%
with tf.device('/gpu:0'):
    model3 = keras.models.load_model('Basic Ramp Model Final_lead.h5', custom_objects={'MAEMD': MAEMD})
    gc.collect()

# %%
testPredict3 = model3.predict(teX, batch_size=batch_size)
tePredict3 = testPredict3.reshape(-1)

# %%
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMD == ', npMAEMD(testY, tePredict))
print('Error Test Score > MSE == ', npMSE(testY, tePredict2), ' MAE == ', npMAE(testY, tePredict2), ' MAEMD == ', npMAEMD(testY, tePredict2))
print('Error Test Score > MSE == ', npMSE(testY, tePredict3), ' MAE == ', npMAE(testY, tePredict3), ' MAEMD == ', npMAEMD(testY, tePredict3))
# Out:
# Error Test Score > MSE ==  0.007587188363190825  MAE ==  0.06743621775679717  MAEMD ==  0.11371393847027236
# Error Test Score > MSE ==  0.0075830073548658035  MAE ==  0.06692710233404568  MAEMD ==  0.11853126870621064
# Error Test Score > MSE ==  0.012545236034750638  MAE ==  0.08871766697564458  MAEMD ==  0.10671293457164993

# %%
hram = (testY>0.8) | (testY<0.2)
testY2 = testY[hram]
tePredicth = tePredict[hram]
tePredicth2 = tePredict2[hram]
tePredicth3 = tePredict3[hram]

# %%
print('Error Test Score > MSE == ', npMSE(testY2, tePredicth), ' MAE == ', npMAE(testY2, tePredicth), ' MAEMD == ', npMAEMD(testY2, tePredicth))
print('Error Test Score > MSE == ', npMSE(testY2, tePredicth2), ' MAE == ', npMAE(testY2, tePredicth2), ' MAEMD == ', npMAEMD(testY2, tePredicth2))
print('Error Test Score > MSE == ', npMSE(testY2, tePredicth3), ' MAE == ', npMAE(testY2, tePredicth3), ' MAEMD == ', npMAEMD(testY2, tePredicth3))
# Out:
# Error Test Score > MSE ==  0.05581185143192879  MAE ==  0.22007208960424357  MAEMD ==  1.5503821082817928
# Error Test Score > MSE ==  0.06251802578133767  MAE ==  0.23770723488265935  MAEMD ==  1.6128385448953033
# Error Test Score > MSE ==  0.051290522827113084  MAE ==  0.20008009883004454  MAEMD ==  1.334887211416586
