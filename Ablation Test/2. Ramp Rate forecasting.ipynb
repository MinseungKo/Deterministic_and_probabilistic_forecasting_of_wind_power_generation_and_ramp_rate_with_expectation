# %%
import tensorflow as tf

import pandas as pd
import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
#from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply, Subtract
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout, SpatialDropout1D
from scipy import signal
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pylab as plt
import matplotlib.dates as mdates
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc
from keijzer import *
from tensorflow import keras
from keras.models import Model
from keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply, Embedding, Layer, Reshape
from keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
#from keras.ops import convert_to_tensor, convert_to_numpy
#from keras.utils import plot_model
from keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))



def root_squared_mean_error(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))+K.mean(K.abs(y_pred - y_true))

from keras.layers.advanced_activations import PReLU

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '0' # 여러개 사용시 '0,1,2' 식으로 하나의 문자열에 입력
gpus = tf.config.experimental.list_physical_devices('GPU') # 호스트 러나임에 표시되는 GPU 장치 목록 반환

if gpus: # 반환된 GPU 장치 목록이 있다면
    try: # 해당 장치에 대한 메모리 증가 활성화 여부 설정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e: # try문 실패시에 에러문구 출력
        print(e)

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Import Data & Preprocessing

# %%
data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2020.csv'
data_source1 = pd.read_csv(data_path)
dat_source1 = pd.DataFrame(data_source1)
#dat_source1 = dat_source1.iloc[:-3,:]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2021.csv'
data_source2 = pd.read_csv(data_path)
dat_source2 = pd.DataFrame(data_source2)
dat_source2 = dat_source2.iloc[:8761,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2022.csv'
data_source3 = pd.read_csv(data_path)
dat_source3 = pd.DataFrame(data_source3)
dat_source3 = dat_source3.iloc[:8760,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2023.csv'
data_source4 = pd.read_csv(data_path)
dat_source4 = pd.DataFrame(data_source4)
dat_source4 = dat_source4.iloc[:8760,:9]

dat_arr1 = np.array(dat_source1)
dat_arr2 = np.array(dat_source2)
dat_arr3 = np.array(dat_source3)
dat_arr4 = np.array(dat_source4)

dat_arr = np.concatenate([dat_arr1, dat_arr2, dat_arr3, dat_arr4],axis=0)
dat_arr.shape # 8784, 8761, 8760, 8760

dat_source = pd.DataFrame(dat_arr, columns=['Time-Date stamp','Date','ERCOT Load','Total Wind Output','Total Wind Installed','Wind Output, % of Load','Wind Output, % of Installed','1-hr MW change','1-hr % change'])
dat_source
# Out:
#            Time-Date stamp    Date ERCOT Load Total Wind Output  \
# 0      01-01-2020 00:00:00  Jan-01      36823             12335
# 1      01-01-2020 01:00:00  Jan-01      36511             13300
# 2      01-01-2020 02:00:00  Jan-01      36022             13586
# 3      01-01-2020 03:00:00  Jan-01      35790             14107
# 4      01-01-2020 04:00:00  Jan-01      35642             14887
# ...                    ...     ...        ...               ...
# 35060  12-31-2023 20:00:00  Dec-31      44887             17161
# 35061  12-31-2023 21:00:00  Dec-31      44013             18301
# 35062  12-31-2023 22:00:00  Dec-31      43280             18607
# 35063  12-31-2023 23:00:00  Dec-31      42319             17866
# 35064  01-01-2024 00:00:00  Jan-01      41682             15869
#
#       Total Wind Installed Wind Output, % of Load Wind Output, % of Installed  \
# 0                    27040                   33.5                      45.617
# 1                    27040                   36.4                      49.187
# 2                    27040                   37.7                      50.245
# 3                    27040                   39.4                      52.171
# 4                    27040                   41.8                      55.055
# ...                    ...                    ...                         ...
# 35060                38631                  38.23                       44.42
# 35061                38631                  41.58                       47.37
# 35062                38631                  42.99                       48.17
# 35063                38631                  42.22                       46.25
# 35064                38631                  38.07                       41.08
#
#       1-hr MW change 1-hr % change
# 0                NaN           NaN
# 1              965.4         7.826
# 2              286.2         2.152
# 3              520.9         3.834
# 4              779.6         5.527
# ...              ...           ...
# 35060           2858         19.99
# 35061           1139          6.64
# 35062            307          1.67
# 35063           -741         -3.98
# 35064          -1996        -11.17
#
# [35065 rows x 9 columns]

# %% [markdown]
# ### Dividing by Installed Capacity & Preprocessing

# %%
dat = pd.DataFrame()
dat['MW % change'] = np.array(dat_source.iloc[1:,3], dtype=float)-np.array(dat_source.iloc[0:-1,3], dtype=float)
dat['MW % change'] = np.divide(np.array(dat['MW % change']),np.array(dat_source.iloc[1:,4]))*100
dat['Total Wind Output'] = np.divide(np.array(dat_source.iloc[1:,3]), np.array(dat_source.iloc[1:,4]))

dat
# Out:
#       MW % change Total Wind Output
# 0         3.56879          0.491864
# 1         1.05769          0.502441
# 2         1.92678          0.521709
# 3         2.88462          0.550555
# 4       -0.580621          0.544749
# ...           ...               ...
# 35059      7.3982          0.444229
# 35060       2.951          0.473739
# 35061     0.79211           0.48166
# 35062    -1.91815          0.462478
# 35063    -5.16942          0.410784
#
# [35064 rows x 2 columns]

# %%
ramp_ratio = 20
load_ratio = 10
year_arr = np.concatenate([np.ones(8784)*2020, np.ones(8760)*2021, np.ones(8760)*2022, np.ones(8760)*2023])
year_df = pd.DataFrame(year_arr, columns=['Year'], dtype=int)
wind_df = pd.concat([year_df, dat], axis=1)
wind_df
# Out:
#        Year MW % change Total Wind Output
# 0      2020     3.56879          0.491864
# 1      2020     1.05769          0.502441
# 2      2020     1.92678          0.521709
# 3      2020     2.88462          0.550555
# 4      2020   -0.580621          0.544749
# ...     ...         ...               ...
# 35059  2023      7.3982          0.444229
# 35060  2023       2.951          0.473739
# 35061  2023     0.79211           0.48166
# 35062  2023    -1.91815          0.462478
# 35063  2023    -5.16942          0.410784
#
# [35064 rows x 3 columns]

# %%
wind_df = wind_df.reset_index(drop=True)
std_scaler = sklearn.preprocessing.MinMaxScaler()
std_scaler_load = sklearn.preprocessing.MinMaxScaler()
std_scaler_ramp = sklearn.preprocessing.MinMaxScaler()

wind_df[['Total Wind Output']] = std_scaler.fit_transform(wind_df[['Total Wind Output']])
wind_df[['MW % change']] = std_scaler_ramp.fit_transform(wind_df[['MW % change']])
#wind_df[['Wind Change, % of Load', 'Wind Change']] = std_scaler_ramp.fit_transform(wind_df[['Wind Change, % of Load', 'Wind Change']])
wind_df = wind_df.iloc[:-1,:]
wind_df
# Out:
#        Year  MW % change  Total Wind Output
# 0      2020     0.620197           0.644724
# 1      2020     0.544580           0.658617
# 2      2020     0.570751           0.683924
# 3      2020     0.599594           0.721813
# 4      2020     0.495246           0.714187
# ...     ...          ...                ...
# 35058  2023     0.774643           0.484984
# 35059  2023     0.735512           0.582157
# 35060  2023     0.601593           0.620917
# 35061  2023     0.536583           0.631322
# 35062  2023     0.454969           0.606127
#
# [35063 rows x 3 columns]

# %%
ramp_df = pd.DataFrame(wind_df)
ramp_df.columns=['Year', 'Wind Change', 'Wind Output']
ramp_df
# Out:
#        Year  Wind Change  Wind Output
# 0      2020     0.620197     0.644724
# 1      2020     0.544580     0.658617
# 2      2020     0.570751     0.683924
# 3      2020     0.599594     0.721813
# 4      2020     0.495246     0.714187
# ...     ...          ...          ...
# 35058  2023     0.774643     0.484984
# 35059  2023     0.735512     0.582157
# 35060  2023     0.601593     0.620917
# 35061  2023     0.536583     0.631322
# 35062  2023     0.454969     0.606127
#
# [35063 rows x 3 columns]

# %% [markdown]
# ## Wind Ramp Rate Forecasting

# %% [markdown]
# ### SVD-based Feature Generation

# %%
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc

def create_dataset(dataset, timesteps, output_timesteps, leadtime):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - leadtime - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps + leadtime):(i+timesteps+output_timesteps+leadtime), :])
    return np.array(dataX), np.array(dataY)

# %%
norm_df = np.array(wind_df['Wind Change']).reshape(-1,1)
timesteps = 24*7
output_timesteps = 24
num_features = 1
leadtime = 6
X, Y = create_dataset(norm_df, timesteps, output_timesteps, leadtime)
b_size = timesteps

# %%
dec_num = timesteps
high_ind = 35

addX = np.zeros((X.shape[0], dec_num, high_ind+1))

def svdadd(X, start, end, b_size):
    dec_x = X[start:end, :, :]
    U, S, Vh = svd(dec_x.reshape(b_size, -1))

    high_sig = np.matmul(np.matmul(U[:,:high_ind], np.diag(S[0:high_ind])), Vh[:high_ind,:])
    low_sig = X[:dec_num, :, :].reshape(b_size,-1)-high_sig

    rec_x = np.zeros((b_size, b_size, high_ind))
    #print(sum(S[0:high_ind])/sum(S))
    for i in range(high_ind):
        rec_x[:,:,i] = np.matmul((U[:,i]*S[i]).reshape(-1,1), Vh[i,:].reshape(1,-1))    
    return rec_x, low_sig

for k in range(X.shape[0]//dec_num):
    rec_x, low_sig = svdadd(X, k*dec_num, (k+1)*dec_num, b_size)
    addX[k*dec_num:k*dec_num+dec_num,:, :-1] = rec_x
    addX[k*dec_num:k*dec_num+dec_num,:, -1] = low_sig
    
rec_x, low_sig = svdadd(X, X.shape[0]-dec_num, X.shape[0], b_size)
addX[X.shape[0]-dec_num:X.shape[0], :, :-1] = rec_x
addX[X.shape[0]-dec_num:X.shape[0],:, -1] = low_sig

addX_det = addX[:, :, :-1]
addX_det = np.sum(addX_det, axis=2)
X = np.concatenate([X, addX], axis=2)
num_features = X.shape[2]

# %% [markdown]
# ### Training/Test Set Division & Shuffled Learning

# %%
trvaX, teX, trvaY, teY = train_test_split(X, Y, test_size=0.1, shuffle=False)

idx = np.arange(trvaX.shape[0])
np.random.shuffle(idx)
strvaX = trvaX[idx]
strvaY = trvaY[idx]
strvaY = strvaY.reshape(-1, output_timesteps)

trvaY = trvaY.reshape(-1, output_timesteps)
teY = teY.reshape(-1, output_timesteps)

strX, svaX, strY, svaY = train_test_split(strvaX, strvaY, test_size=0.3, shuffle=False)
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=0.3, shuffle=False)

trvaX.shape, trvaY.shape, teX.shape, teY.shape
# Out:
# ((31377, 168, 37), (31377, 24), (3487, 168, 37), (3487, 24))

# %% [markdown]
# ## Wind Ramp Rate Forecasting Model without Attention Blcok

# %%
def MAEMD(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

# %%
from keras.layers.advanced_activations import PReLU

# %%
from keras import regularizers

num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1
    beta = 1
    hfilters = 168
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1 = Input(shape=(timesteps, num_features))
    per = Permute((2,1))(visible1)
    
    
    ## Parallel DCCNN Blocks 1-1 ~ 3-1
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(visible1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres01a = Add()([visible1, d1])   # (100, 25) (100, 25)
    rres01b = Subtract()([visible1, d1])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    rres02a = Add()([rres01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    rres02b = Subtract()([rres01b, d2])   # (100, 25) (100, 25) 
    rres02 = Concatenate()([rres02a, rres02b, rres01a, rres01b])
    #rres02 = Dropout(0.2)(rres02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres03a = Add()([rres02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    rres03b = Subtract()([rres02b, d2])
    rres10 = Concatenate()([rres03a, rres03b, rres02])

    ## Right-half DCCNN Blocks 1-2 ~ 3-2
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(per)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([per, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([per, d1])
    
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    #res02 = Dropout(0.2)(res02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])
    res10 = Concatenate()([res03a, res03b, res02])

    ## Output Blocks
    out1 = Conv1D(24*7, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out1 = Dropout(0.2)(out1)  
    
    out2 = Conv1D(24*7, 1, padding='same', activation=PReLU())(rres10)   # 256, 11X10=110
    out2 = Dropout(0.2)(out2)
    
    out = Concatenate(axis=1)([out1, out2])
    
    ## Output Block
    out = Conv1D(24*7, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)

    #, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
    out = GlobalAveragePooling1D()(out) 

    out = Dense(output_timesteps)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 168, 37)]    0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 37, 168)      0           input_1[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 37, 168)      28392       permute[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 168, 168)     6384        input_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 168, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 168, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 37, 168)      0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 168, 168)     0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 37, 168)      56616       multiply_10[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 168, 37)      12469       multiply[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 168)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 37, 168)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 168, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 168, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 37, 168)      0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 168, 37)      0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 37, 168)      0           permute[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 37, 168)      0           permute[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 168, 37)      0           input_1[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 168, 37)      0           input_1[0][0]
#                                                                  multiply_1[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 37, 168)      28392       add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 37, 168)      28392       subtract_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 168, 168)     6384        add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 168, 168)     6384        subtract[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 37, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 37, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 37, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 37, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 168, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 168, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 168, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 168, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 37, 168)      0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 37, 168)      0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 168, 168)     0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 168, 168)     0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 37, 168)      56616       multiply_12[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 37, 168)      56616       multiply_14[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 168, 37)      12469       multiply_2[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 168, 37)      12469       multiply_4[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 37, 168)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 37, 168)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 37, 168)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 37, 168)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 168, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 168, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 168, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 168, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 37, 168)      0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 37, 168)      0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 168, 37)      0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 168, 37)      0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 168)      0           add_3[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 37, 168)      0           subtract_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 168, 37)      0           add[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 168, 37)      0           subtract[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 37, 672)      0           add_4[0][0]
#                                                                  subtract_4[0][0]
#                                                                  add_3[0][0]
#                                                                  subtract_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 168, 148)     0           add_1[0][0]
#                                                                  subtract_1[0][0]
#                                                                  add[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 37, 168)      113064      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 37, 168)      113064      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 168, 168)     25032       concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 168, 168)     25032       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 37, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 37, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 37, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 37, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 168, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 168, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 168, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 168, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 37, 168)      0           activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 37, 168)      0           activation_36[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 168, 168)     0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 168, 168)     0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 37, 168)      56616       multiply_16[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 37, 168)      56616       multiply_18[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 168, 37)      12469       multiply_6[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 168, 37)      12469       multiply_8[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 37, 168)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 37, 168)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 37, 168)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 37, 168)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 168, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 168, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 168, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 168, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 37, 168)      0           activation_34[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 37, 168)      0           activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 168, 37)      0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 168, 37)      0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 168)      0           add_4[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# subtract_5 (Subtract)           (None, 37, 168)      0           subtract_4[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 168, 37)      0           add_1[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 168, 37)      0           subtract_1[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 37, 1008)     0           add_5[0][0]
#                                                                  subtract_5[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 168, 222)     0           add_2[0][0]
#                                                                  subtract_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 37, 168)      175728      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 168, 168)     65688       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 37, 168)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 168, 168)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 205, 168)     0           dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 205, 168)     62832       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 205, 168)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 168)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 24)           4056        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,034,249
# Trainable params: 1,034,249
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 2510

# %%
    model.compile(loss=MAEMD, optimizer='adam', metrics=['mse','mae', MAEMD])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = 100
    epochs = 1000
    #root_squared_mean_error
    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint

# %%
    # %%time
    b_size = 168
    hist = model.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 131/131 [==============================] - 15s 82ms/step - loss: 0.2033 - mse: 0.0246 - mae: 0.1133 - MAEMD: 0.2032 - val_loss: 0.1513 - val_mse: 0.0145 - val_mae: 0.0952 - val_MAEMD: 0.1513
# Epoch 2/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1426 - mse: 0.0180 - mae: 0.1070 - MAEMD: 0.1426 - val_loss: 0.1393 - val_mse: 0.0183 - val_mae: 0.1083 - val_MAEMD: 0.1391
# Epoch 3/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1371 - mse: 0.0180 - mae: 0.1073 - MAEMD: 0.1371 - val_loss: 0.1351 - val_mse: 0.0181 - val_mae: 0.1078 - val_MAEMD: 0.1349
# Epoch 4/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1349 - mse: 0.0178 - mae: 0.1068 - MAEMD: 0.1349 - val_loss: 0.1328 - val_mse: 0.0176 - val_mae: 0.1063 - val_MAEMD: 0.1327
# Epoch 5/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1331 - mse: 0.0177 - mae: 0.1065 - MAEMD: 0.1332 - val_loss: 0.1319 - val_mse: 0.0171 - val_mae: 0.1045 - val_MAEMD: 0.1319
# Epoch 6/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1305 - mse: 0.0174 - mae: 0.1052 - MAEMD: 0.1305 - val_loss: 0.1297 - val_mse: 0.0167 - val_mae: 0.1025 - val_MAEMD: 0.1297
# Epoch 7/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1278 - mse: 0.0169 - mae: 0.1033 - MAEMD: 0.1278 - val_loss: 0.1285 - val_mse: 0.0168 - val_mae: 0.1023 - val_MAEMD: 0.1284
# Epoch 8/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1257 - mse: 0.0167 - mae: 0.1025 - MAEMD: 0.1257 - val_loss: 0.1262 - val_mse: 0.0170 - val_mae: 0.1032 - val_MAEMD: 0.1262
# Epoch 9/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1242 - mse: 0.0165 - mae: 0.1017 - MAEMD: 0.1242 - val_loss: 0.1245 - val_mse: 0.0162 - val_mae: 0.1009 - val_MAEMD: 0.1244
# Epoch 10/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1222 - mse: 0.0162 - mae: 0.1009 - MAEMD: 0.1222 - val_loss: 0.1227 - val_mse: 0.0160 - val_mae: 0.0998 - val_MAEMD: 0.1227
# Epoch 11/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1203 - mse: 0.0159 - mae: 0.0999 - MAEMD: 0.1204 - val_loss: 0.1216 - val_mse: 0.0158 - val_mae: 0.0994 - val_MAEMD: 0.1216
# Epoch 12/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1189 - mse: 0.0158 - mae: 0.0993 - MAEMD: 0.1189 - val_loss: 0.1213 - val_mse: 0.0160 - val_mae: 0.0997 - val_MAEMD: 0.1213
# Epoch 13/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1179 - mse: 0.0156 - mae: 0.0987 - MAEMD: 0.1179 - val_loss: 0.1192 - val_mse: 0.0152 - val_mae: 0.0970 - val_MAEMD: 0.1193
# Epoch 14/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1161 - mse: 0.0153 - mae: 0.0979 - MAEMD: 0.1161 - val_loss: 0.1195 - val_mse: 0.0151 - val_mae: 0.0972 - val_MAEMD: 0.1194
# Epoch 15/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1133 - mse: 0.0149 - mae: 0.0962 - MAEMD: 0.1134 - val_loss: 0.1177 - val_mse: 0.0143 - val_mae: 0.0945 - val_MAEMD: 0.1177
# Epoch 16/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1104 - mse: 0.0143 - mae: 0.0944 - MAEMD: 0.1104 - val_loss: 0.1152 - val_mse: 0.0136 - val_mae: 0.0918 - val_MAEMD: 0.1151
# Epoch 17/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1083 - mse: 0.0140 - mae: 0.0933 - MAEMD: 0.1083 - val_loss: 0.1152 - val_mse: 0.0136 - val_mae: 0.0919 - val_MAEMD: 0.1152
# Epoch 18/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1061 - mse: 0.0137 - mae: 0.0920 - MAEMD: 0.1061 - val_loss: 0.1150 - val_mse: 0.0133 - val_mae: 0.0908 - val_MAEMD: 0.1150
# Epoch 19/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1032 - mse: 0.0134 - mae: 0.0911 - MAEMD: 0.1032 - val_loss: 0.1122 - val_mse: 0.0131 - val_mae: 0.0898 - val_MAEMD: 0.1121
# Epoch 20/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1009 - mse: 0.0132 - mae: 0.0904 - MAEMD: 0.1009 - val_loss: 0.1118 - val_mse: 0.0131 - val_mae: 0.0899 - val_MAEMD: 0.1117
# Epoch 21/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0987 - mse: 0.0131 - mae: 0.0898 - MAEMD: 0.0987 - val_loss: 0.1106 - val_mse: 0.0128 - val_mae: 0.0890 - val_MAEMD: 0.1104
# Epoch 22/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0966 - mse: 0.0130 - mae: 0.0895 - MAEMD: 0.0966 - val_loss: 0.1136 - val_mse: 0.0140 - val_mae: 0.0935 - val_MAEMD: 0.1135
# Epoch 23/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0948 - mse: 0.0128 - mae: 0.0888 - MAEMD: 0.0948 - val_loss: 0.1123 - val_mse: 0.0134 - val_mae: 0.0915 - val_MAEMD: 0.1122
# Epoch 24/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0936 - mse: 0.0128 - mae: 0.0888 - MAEMD: 0.0936 - val_loss: 0.1104 - val_mse: 0.0130 - val_mae: 0.0896 - val_MAEMD: 0.1103
# Epoch 25/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0934 - mse: 0.0128 - mae: 0.0887 - MAEMD: 0.0934 - val_loss: 0.1086 - val_mse: 0.0124 - val_mae: 0.0875 - val_MAEMD: 0.1087
# Epoch 26/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0924 - mse: 0.0128 - mae: 0.0886 - MAEMD: 0.0924 - val_loss: 0.1114 - val_mse: 0.0125 - val_mae: 0.0880 - val_MAEMD: 0.1114
# Epoch 27/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0915 - mse: 0.0126 - mae: 0.0882 - MAEMD: 0.0915 - val_loss: 0.1126 - val_mse: 0.0127 - val_mae: 0.0888 - val_MAEMD: 0.1124
# Epoch 28/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0903 - mse: 0.0126 - mae: 0.0878 - MAEMD: 0.0903 - val_loss: 0.1103 - val_mse: 0.0127 - val_mae: 0.0887 - val_MAEMD: 0.1100
# Epoch 29/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0896 - mse: 0.0125 - mae: 0.0877 - MAEMD: 0.0896 - val_loss: 0.1102 - val_mse: 0.0132 - val_mae: 0.0904 - val_MAEMD: 0.1099
# Epoch 30/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0891 - mse: 0.0125 - mae: 0.0875 - MAEMD: 0.0891 - val_loss: 0.1084 - val_mse: 0.0124 - val_mae: 0.0874 - val_MAEMD: 0.1082
# Epoch 31/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0869 - mse: 0.0122 - mae: 0.0865 - MAEMD: 0.0869 - val_loss: 0.1077 - val_mse: 0.0130 - val_mae: 0.0897 - val_MAEMD: 0.1075
# Epoch 32/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0852 - mse: 0.0121 - mae: 0.0859 - MAEMD: 0.0852 - val_loss: 0.1069 - val_mse: 0.0130 - val_mae: 0.0898 - val_MAEMD: 0.1067
# Epoch 33/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0847 - mse: 0.0121 - mae: 0.0860 - MAEMD: 0.0847 - val_loss: 0.1060 - val_mse: 0.0123 - val_mae: 0.0873 - val_MAEMD: 0.1059
# Epoch 34/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0848 - mse: 0.0120 - mae: 0.0856 - MAEMD: 0.0848 - val_loss: 0.1050 - val_mse: 0.0129 - val_mae: 0.0895 - val_MAEMD: 0.1048
# Epoch 35/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0833 - mse: 0.0119 - mae: 0.0850 - MAEMD: 0.0833 - val_loss: 0.1064 - val_mse: 0.0132 - val_mae: 0.0908 - val_MAEMD: 0.1062
# Epoch 36/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0823 - mse: 0.0118 - mae: 0.0847 - MAEMD: 0.0823 - val_loss: 0.1064 - val_mse: 0.0140 - val_mae: 0.0936 - val_MAEMD: 0.1063
# Epoch 37/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0810 - mse: 0.0116 - mae: 0.0841 - MAEMD: 0.0810 - val_loss: 0.1060 - val_mse: 0.0138 - val_mae: 0.0928 - val_MAEMD: 0.1060
# Epoch 38/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0802 - mse: 0.0116 - mae: 0.0838 - MAEMD: 0.0802 - val_loss: 0.1017 - val_mse: 0.0130 - val_mae: 0.0899 - val_MAEMD: 0.1017
# Epoch 39/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0795 - mse: 0.0115 - mae: 0.0835 - MAEMD: 0.0795 - val_loss: 0.1021 - val_mse: 0.0126 - val_mae: 0.0884 - val_MAEMD: 0.1021
# Epoch 40/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0783 - mse: 0.0114 - mae: 0.0829 - MAEMD: 0.0783 - val_loss: 0.1017 - val_mse: 0.0123 - val_mae: 0.0875 - val_MAEMD: 0.1017
# Epoch 41/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0780 - mse: 0.0114 - mae: 0.0830 - MAEMD: 0.0780 - val_loss: 0.1027 - val_mse: 0.0126 - val_mae: 0.0886 - val_MAEMD: 0.1027
# Epoch 42/1000
# 131/131 [==============================] - 21s 163ms/step - loss: 0.0777 - mse: 0.0113 - mae: 0.0829 - MAEMD: 0.0777 - val_loss: 0.1021 - val_mse: 0.0127 - val_mae: 0.0890 - val_MAEMD: 0.1021
# Epoch 43/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0770 - mse: 0.0113 - mae: 0.0827 - MAEMD: 0.0770 - val_loss: 0.1019 - val_mse: 0.0124 - val_mae: 0.0877 - val_MAEMD: 0.1018
# Epoch 44/1000
# 131/131 [==============================] - 20s 151ms/step - loss: 0.0778 - mse: 0.0114 - mae: 0.0833 - MAEMD: 0.0778 - val_loss: 0.1032 - val_mse: 0.0125 - val_mae: 0.0882 - val_MAEMD: 0.1032
# Epoch 45/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0775 - mse: 0.0112 - mae: 0.0825 - MAEMD: 0.0774 - val_loss: 0.1007 - val_mse: 0.0121 - val_mae: 0.0869 - val_MAEMD: 0.1007
# Epoch 46/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0757 - mse: 0.0111 - mae: 0.0818 - MAEMD: 0.0757 - val_loss: 0.1022 - val_mse: 0.0119 - val_mae: 0.0861 - val_MAEMD: 0.1022
# Epoch 47/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0746 - mse: 0.0109 - mae: 0.0810 - MAEMD: 0.0746 - val_loss: 0.1013 - val_mse: 0.0118 - val_mae: 0.0856 - val_MAEMD: 0.1013
# Epoch 48/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0734 - mse: 0.0108 - mae: 0.0807 - MAEMD: 0.0734 - val_loss: 0.1008 - val_mse: 0.0117 - val_mae: 0.0852 - val_MAEMD: 0.1008
# Epoch 49/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0733 - mse: 0.0107 - mae: 0.0804 - MAEMD: 0.0733 - val_loss: 0.1042 - val_mse: 0.0129 - val_mae: 0.0900 - val_MAEMD: 0.1043
# Epoch 50/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0735 - mse: 0.0107 - mae: 0.0805 - MAEMD: 0.0735 - val_loss: 0.1044 - val_mse: 0.0128 - val_mae: 0.0899 - val_MAEMD: 0.1048
# Epoch 51/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0737 - mse: 0.0106 - mae: 0.0802 - MAEMD: 0.0737 - val_loss: 0.1034 - val_mse: 0.0125 - val_mae: 0.0885 - val_MAEMD: 0.1038
# Epoch 52/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0725 - mse: 0.0107 - mae: 0.0802 - MAEMD: 0.0725 - val_loss: 0.1009 - val_mse: 0.0116 - val_mae: 0.0851 - val_MAEMD: 0.1013
# Epoch 53/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0717 - mse: 0.0105 - mae: 0.0797 - MAEMD: 0.0717 - val_loss: 0.1034 - val_mse: 0.0124 - val_mae: 0.0883 - val_MAEMD: 0.1038
# Epoch 54/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0709 - mse: 0.0104 - mae: 0.0792 - MAEMD: 0.0709 - val_loss: 0.0989 - val_mse: 0.0116 - val_mae: 0.0852 - val_MAEMD: 0.0993
# Epoch 55/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0697 - mse: 0.0102 - mae: 0.0784 - MAEMD: 0.0697 - val_loss: 0.0996 - val_mse: 0.0118 - val_mae: 0.0859 - val_MAEMD: 0.0999
# Epoch 56/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0697 - mse: 0.0103 - mae: 0.0786 - MAEMD: 0.0697 - val_loss: 0.0995 - val_mse: 0.0113 - val_mae: 0.0840 - val_MAEMD: 0.0997
# Epoch 57/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0697 - mse: 0.0103 - mae: 0.0788 - MAEMD: 0.0698 - val_loss: 0.0949 - val_mse: 0.0106 - val_mae: 0.0810 - val_MAEMD: 0.0952
# Epoch 58/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0708 - mse: 0.0104 - mae: 0.0791 - MAEMD: 0.0708 - val_loss: 0.0936 - val_mse: 0.0106 - val_mae: 0.0807 - val_MAEMD: 0.0936
# Epoch 59/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0697 - mse: 0.0102 - mae: 0.0783 - MAEMD: 0.0697 - val_loss: 0.0943 - val_mse: 0.0110 - val_mae: 0.0826 - val_MAEMD: 0.0944
# Epoch 60/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0678 - mse: 0.0099 - mae: 0.0770 - MAEMD: 0.0678 - val_loss: 0.0958 - val_mse: 0.0121 - val_mae: 0.0868 - val_MAEMD: 0.0958
# Epoch 61/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0660 - mse: 0.0097 - mae: 0.0761 - MAEMD: 0.0660 - val_loss: 0.0970 - val_mse: 0.0121 - val_mae: 0.0869 - val_MAEMD: 0.0968
# Epoch 62/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0655 - mse: 0.0097 - mae: 0.0760 - MAEMD: 0.0655 - val_loss: 0.0956 - val_mse: 0.0115 - val_mae: 0.0847 - val_MAEMD: 0.0957
# Epoch 63/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0643 - mse: 0.0095 - mae: 0.0752 - MAEMD: 0.0643 - val_loss: 0.0954 - val_mse: 0.0113 - val_mae: 0.0836 - val_MAEMD: 0.0954
# Epoch 64/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.0638 - mse: 0.0094 - mae: 0.0751 - MAEMD: 0.0638 - val_loss: 0.0961 - val_mse: 0.0119 - val_mae: 0.0860 - val_MAEMD: 0.0960
# Epoch 65/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0635 - mse: 0.0094 - mae: 0.0747 - MAEMD: 0.0635 - val_loss: 0.0944 - val_mse: 0.0108 - val_mae: 0.0816 - val_MAEMD: 0.0943
# Epoch 66/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0633 - mse: 0.0093 - mae: 0.0747 - MAEMD: 0.0633 - val_loss: 0.0960 - val_mse: 0.0107 - val_mae: 0.0817 - val_MAEMD: 0.0960
# Epoch 67/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0636 - mse: 0.0094 - mae: 0.0748 - MAEMD: 0.0636 - val_loss: 0.0955 - val_mse: 0.0103 - val_mae: 0.0799 - val_MAEMD: 0.0956
# Epoch 68/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.0628 - mse: 0.0092 - mae: 0.0743 - MAEMD: 0.0628 - val_loss: 0.0949 - val_mse: 0.0100 - val_mae: 0.0788 - val_MAEMD: 0.0950
# Wall time: 10min 29s

# %%
model.save('Basic Ramp Model_woAttention.h5')

# %%
gc.collect()
# Out:
# 4585

# %%
testPredict = model.predict(teX, batch_size=batch_size)

# %%
with tf.device('/gpu:0'):
    model = keras.models.load_model('Basic Ramp Model_woAttention.h5', custom_objects={'MAEMD': MAEMD})
    gc.collect()
    testPredict = model.predict(teX, batch_size=b_size)

# %%
def npMAEMS(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true))*100
def npMAEMD(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true-np.mean(y_true)))*100
def npMSE(y_true, y_pred):
    return np.mean(np.square(-y_true+y_pred))
def npMAE(y_true, y_pred):
    return np.mean(abs(-y_true+y_pred))

# %%
tePredict = testPredict.reshape(-1)
testY = teY.reshape(-1)
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMD == ', npMAEMD(testY, tePredict))
# Out:
# Error Test Score > MSE ==  0.011599200695636039  MAE ==  0.08491603645830721  MAEMD ==  0.10749349925427328

# %% [markdown]
# ## Without Output Block

# %%
from keras import regularizers

num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1
    beta = 1
    hfilters = 168
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    pera = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(pera)
    den1b = Dense(timesteps, activation='sigmoid')(pera)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])   
    
    ## Permuted Attention Block
    per1 = Permute((2,1))(visible1)
    den2a = Dense(num_features, activation='tanh')(visible1)
    den2b = Dense(num_features, activation='sigmoid')(visible1)
    den2 = Multiply()([den2a, den2b])
    perb2 = Permute((2,1), name='attention_vec2')(den2)
    
    mul2 = Multiply()([per1, perb2])     
    
    ## Parallel DCCNN Blocks 1-1 ~ 3-1
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres01a = Add()([mul1, d1])   # (100, 25) (100, 25)
    rres01b = Subtract()([mul1, d1])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    rres02a = Add()([rres01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    rres02b = Subtract()([rres01b, d2])   # (100, 25) (100, 25) 
    rres02 = Concatenate()([rres02a, rres02b, rres01a, rres01b])
    #rres02 = Dropout(0.2)(rres02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres03a = Add()([rres02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    rres03b = Subtract()([rres02b, d2])
    rres10 = Concatenate()([rres03a, rres03b, rres02])

    ## Right-half DCCNN Blocks 1-2 ~ 3-2
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul2)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([mul2, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([mul2, d1])
    
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    #res02 = Dropout(0.2)(res02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])
    res10 = Concatenate()([res03a, res03b, res02])

    out = GlobalAveragePooling1D()(res10) 

    out = Dense(output_timesteps)(out) 
    model2 = Model(inputs=[visible1], outputs=[out])
    
    print(model2.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 168, 37)]    0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168, 37)      1406        input_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 168, 37)      1406        input_2[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 168, 37)      0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 37, 168)      0           input_2[0][0]
# __________________________________________________________________________________________________
# attention_vec2 (Permute)        (None, 37, 168)      0           multiply_22[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 37, 168)      0           permute_2[0][0]
#                                                                  attention_vec2[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 37, 168)      28392       multiply_23[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 37, 168)      0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 37, 168)      0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 37, 168)      0           activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 37, 168)      56616       multiply_34[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 37, 168)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 37, 168)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 37, 168)      0           activation_62[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 37, 168)      0           multiply_23[0][0]
#                                                                  multiply_35[0][0]
# __________________________________________________________________________________________________
# subtract_9 (Subtract)           (None, 37, 168)      0           multiply_23[0][0]
#                                                                  multiply_35[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 37, 168)      28392       add_9[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 37, 168)      28392       subtract_9[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 37, 168)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 37, 168)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 37, 168)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 37, 168)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 37, 168)      0           activation_64[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 37, 168)      0           activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 37, 168)      56616       multiply_36[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 37, 168)      56616       multiply_38[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 37, 168)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 37, 168)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 37, 168)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 37, 168)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 37, 168)      0           activation_66[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 37, 168)      0           activation_70[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 37, 168)      0           add_9[0][0]
#                                                                  multiply_37[0][0]
# __________________________________________________________________________________________________
# subtract_10 (Subtract)          (None, 37, 168)      0           subtract_9[0][0]
#                                                                  multiply_39[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 37, 672)      0           add_10[0][0]
#                                                                  subtract_10[0][0]
#                                                                  add_9[0][0]
#                                                                  subtract_9[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 37, 168)      113064      concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 37, 168)      113064      concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 37, 168)      0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 37, 168)      0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 37, 168)      0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 37, 168)      0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 37, 168)      0           activation_72[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 37, 168)      0           activation_76[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 37, 168)      56616       multiply_40[0][0]
# __________________________________________________________________________________________________
# conv1d_42 (Conv1D)              (None, 37, 168)      56616       multiply_42[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 37, 168)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 37, 168)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 37, 168)      0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 37, 168)      0           conv1d_42[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 37, 168)      0           activation_74[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 37, 168)      0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 37, 168)      0           add_10[0][0]
#                                                                  multiply_41[0][0]
# __________________________________________________________________________________________________
# subtract_11 (Subtract)          (None, 37, 168)      0           subtract_10[0][0]
#                                                                  multiply_43[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 37, 1008)     0           add_11[0][0]
#                                                                  subtract_11[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 1008)         0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 24)           24216       global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 621,412
# Trainable params: 621,412
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 4628

# %%
    model2.compile(loss=MAEMD, optimizer='adam', metrics=['mse','mae', MAEMD])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    epochs = 1000
    #root_squared_mean_error
    history2 = LossHistory()
    history2.init()
    hist2 = model2.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history2, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
#   6/131 [>.............................] - ETA: 3s - loss: 0.5206 - mse: 0.2429 - mae: 0.4813 - MAEMD: 0.5206 WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0128s vs `on_train_batch_end` time: 0.0131s). Check your callbacks.
# 131/131 [==============================] - 6s 31ms/step - loss: 0.2156 - mse: 0.0287 - mae: 0.1209 - MAEMD: 0.2156 - val_loss: 0.1929 - val_mse: 0.0138 - val_mae: 0.0919 - val_MAEMD: 0.1931
# Epoch 2/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1700 - mse: 0.0145 - mae: 0.0938 - MAEMD: 0.1699 - val_loss: 0.1430 - val_mse: 0.0158 - val_mae: 0.0991 - val_MAEMD: 0.1428
# Epoch 3/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1381 - mse: 0.0170 - mae: 0.1037 - MAEMD: 0.1381 - val_loss: 0.1336 - val_mse: 0.0175 - val_mae: 0.1057 - val_MAEMD: 0.1334
# Epoch 4/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1327 - mse: 0.0177 - mae: 0.1063 - MAEMD: 0.1327 - val_loss: 0.1317 - val_mse: 0.0180 - val_mae: 0.1074 - val_MAEMD: 0.1315
# Epoch 5/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1300 - mse: 0.0177 - mae: 0.1061 - MAEMD: 0.1301 - val_loss: 0.1293 - val_mse: 0.0177 - val_mae: 0.1056 - val_MAEMD: 0.1291
# Epoch 6/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1276 - mse: 0.0174 - mae: 0.1046 - MAEMD: 0.1276 - val_loss: 0.1276 - val_mse: 0.0173 - val_mae: 0.1039 - val_MAEMD: 0.1275
# Epoch 7/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1266 - mse: 0.0173 - mae: 0.1041 - MAEMD: 0.1267 - val_loss: 0.1275 - val_mse: 0.0172 - val_mae: 0.1037 - val_MAEMD: 0.1274
# Epoch 8/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1259 - mse: 0.0172 - mae: 0.1040 - MAEMD: 0.1260 - val_loss: 0.1272 - val_mse: 0.0171 - val_mae: 0.1034 - val_MAEMD: 0.1271
# Epoch 9/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1252 - mse: 0.0171 - mae: 0.1038 - MAEMD: 0.1252 - val_loss: 0.1268 - val_mse: 0.0171 - val_mae: 0.1037 - val_MAEMD: 0.1267
# Epoch 10/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1243 - mse: 0.0170 - mae: 0.1033 - MAEMD: 0.1243 - val_loss: 0.1260 - val_mse: 0.0169 - val_mae: 0.1031 - val_MAEMD: 0.1260
# Epoch 11/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1233 - mse: 0.0167 - mae: 0.1026 - MAEMD: 0.1233 - val_loss: 0.1242 - val_mse: 0.0162 - val_mae: 0.1007 - val_MAEMD: 0.1241
# Epoch 12/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1222 - mse: 0.0164 - mae: 0.1017 - MAEMD: 0.1222 - val_loss: 0.1233 - val_mse: 0.0161 - val_mae: 0.1006 - val_MAEMD: 0.1232
# Epoch 13/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1212 - mse: 0.0162 - mae: 0.1008 - MAEMD: 0.1212 - val_loss: 0.1225 - val_mse: 0.0158 - val_mae: 0.0994 - val_MAEMD: 0.1223
# Epoch 14/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1202 - mse: 0.0159 - mae: 0.0998 - MAEMD: 0.1202 - val_loss: 0.1223 - val_mse: 0.0159 - val_mae: 0.0998 - val_MAEMD: 0.1221
# Epoch 15/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1195 - mse: 0.0157 - mae: 0.0990 - MAEMD: 0.1195 - val_loss: 0.1219 - val_mse: 0.0158 - val_mae: 0.0997 - val_MAEMD: 0.1218
# Epoch 16/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1187 - mse: 0.0155 - mae: 0.0984 - MAEMD: 0.1187 - val_loss: 0.1216 - val_mse: 0.0158 - val_mae: 0.0997 - val_MAEMD: 0.1215
# Epoch 17/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1181 - mse: 0.0154 - mae: 0.0980 - MAEMD: 0.1181 - val_loss: 0.1212 - val_mse: 0.0157 - val_mae: 0.0994 - val_MAEMD: 0.1211
# Epoch 18/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1176 - mse: 0.0153 - mae: 0.0977 - MAEMD: 0.1176 - val_loss: 0.1210 - val_mse: 0.0156 - val_mae: 0.0989 - val_MAEMD: 0.1209
# Epoch 19/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1170 - mse: 0.0152 - mae: 0.0974 - MAEMD: 0.1171 - val_loss: 0.1205 - val_mse: 0.0156 - val_mae: 0.0992 - val_MAEMD: 0.1204
# Epoch 20/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1163 - mse: 0.0151 - mae: 0.0970 - MAEMD: 0.1163 - val_loss: 0.1207 - val_mse: 0.0158 - val_mae: 0.0997 - val_MAEMD: 0.1206
# Epoch 21/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1157 - mse: 0.0150 - mae: 0.0967 - MAEMD: 0.1157 - val_loss: 0.1204 - val_mse: 0.0157 - val_mae: 0.0993 - val_MAEMD: 0.12030968 - MAEMD: 0.
# Epoch 22/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1152 - mse: 0.0149 - mae: 0.0965 - MAEMD: 0.1152 - val_loss: 0.1202 - val_mse: 0.0156 - val_mae: 0.0991 - val_MAEMD: 0.1201
# Epoch 23/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1145 - mse: 0.0148 - mae: 0.0962 - MAEMD: 0.1146 - val_loss: 0.1197 - val_mse: 0.0153 - val_mae: 0.0979 - val_MAEMD: 0.1196
# Epoch 24/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1139 - mse: 0.0147 - mae: 0.0959 - MAEMD: 0.1140 - val_loss: 0.1197 - val_mse: 0.0152 - val_mae: 0.0973 - val_MAEMD: 0.1196
# Epoch 25/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1132 - mse: 0.0147 - mae: 0.0956 - MAEMD: 0.1133 - val_loss: 0.1196 - val_mse: 0.0153 - val_mae: 0.0978 - val_MAEMD: 0.1194
# Epoch 26/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1124 - mse: 0.0146 - mae: 0.0953 - MAEMD: 0.1124 - val_loss: 0.1190 - val_mse: 0.0153 - val_mae: 0.0979 - val_MAEMD: 0.1189
# Epoch 27/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1116 - mse: 0.0145 - mae: 0.0950 - MAEMD: 0.1116 - val_loss: 0.1184 - val_mse: 0.0151 - val_mae: 0.0971 - val_MAEMD: 0.1182
# Epoch 28/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1107 - mse: 0.0144 - mae: 0.0947 - MAEMD: 0.1107 - val_loss: 0.1177 - val_mse: 0.0149 - val_mae: 0.0965 - val_MAEMD: 0.1176
# Epoch 29/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1098 - mse: 0.0143 - mae: 0.0945 - MAEMD: 0.1098 - val_loss: 0.1178 - val_mse: 0.0149 - val_mae: 0.0962 - val_MAEMD: 0.1176
# Epoch 30/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1089 - mse: 0.0143 - mae: 0.0944 - MAEMD: 0.1089 - val_loss: 0.1175 - val_mse: 0.0148 - val_mae: 0.0959 - val_MAEMD: 0.1173
# Epoch 31/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1081 - mse: 0.0143 - mae: 0.0942 - MAEMD: 0.1081 - val_loss: 0.1169 - val_mse: 0.0147 - val_mae: 0.0958 - val_MAEMD: 0.1166
# Epoch 32/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1071 - mse: 0.0142 - mae: 0.0939 - MAEMD: 0.1072 - val_loss: 0.1166 - val_mse: 0.0145 - val_mae: 0.0953 - val_MAEMD: 0.1163
# Epoch 33/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1063 - mse: 0.0142 - mae: 0.0938 - MAEMD: 0.1063 - val_loss: 0.1163 - val_mse: 0.0145 - val_mae: 0.0952 - val_MAEMD: 0.1161
# Epoch 34/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1050 - mse: 0.0141 - mae: 0.0934 - MAEMD: 0.1050 - val_loss: 0.1159 - val_mse: 0.0144 - val_mae: 0.0948 - val_MAEMD: 0.1157
# Epoch 35/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1042 - mse: 0.0140 - mae: 0.0932 - MAEMD: 0.1042 - val_loss: 0.1162 - val_mse: 0.0144 - val_mae: 0.0943 - val_MAEMD: 0.1160
# Epoch 36/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1032 - mse: 0.0140 - mae: 0.0931 - MAEMD: 0.1032 - val_loss: 0.1159 - val_mse: 0.0142 - val_mae: 0.0941 - val_MAEMD: 0.1158
# Epoch 37/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.1016 - mse: 0.0138 - mae: 0.0924 - MAEMD: 0.1016 - val_loss: 0.1158 - val_mse: 0.0144 - val_mae: 0.0947 - val_MAEMD: 0.1157
# Epoch 38/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0995 - mse: 0.0137 - mae: 0.0918 - MAEMD: 0.0995 - val_loss: 0.1156 - val_mse: 0.0145 - val_mae: 0.0951 - val_MAEMD: 0.1156
# Epoch 39/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0976 - mse: 0.0135 - mae: 0.0913 - MAEMD: 0.0976 - val_loss: 0.1155 - val_mse: 0.0146 - val_mae: 0.0954 - val_MAEMD: 0.1154
# Epoch 40/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0956 - mse: 0.0134 - mae: 0.0907 - MAEMD: 0.0956 - val_loss: 0.1147 - val_mse: 0.0143 - val_mae: 0.0942 - val_MAEMD: 0.1147
# Epoch 41/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0939 - mse: 0.0133 - mae: 0.0904 - MAEMD: 0.0939 - val_loss: 0.1147 - val_mse: 0.0145 - val_mae: 0.0946 - val_MAEMD: 0.1147
# Epoch 42/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0923 - mse: 0.0132 - mae: 0.0899 - MAEMD: 0.0923 - val_loss: 0.1148 - val_mse: 0.0140 - val_mae: 0.0928 - val_MAEMD: 0.1147
# Epoch 43/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0912 - mse: 0.0131 - mae: 0.0897 - MAEMD: 0.0912 - val_loss: 0.1137 - val_mse: 0.0143 - val_mae: 0.0941 - val_MAEMD: 0.1137
# Epoch 44/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0907 - mse: 0.0131 - mae: 0.0898 - MAEMD: 0.0907 - val_loss: 0.1144 - val_mse: 0.0144 - val_mae: 0.0943 - val_MAEMD: 0.1144
# Epoch 45/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0894 - mse: 0.0129 - mae: 0.0891 - MAEMD: 0.0894 - val_loss: 0.1128 - val_mse: 0.0136 - val_mae: 0.0917 - val_MAEMD: 0.1126
# Epoch 46/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0864 - mse: 0.0126 - mae: 0.0878 - MAEMD: 0.0864 - val_loss: 0.1121 - val_mse: 0.0140 - val_mae: 0.0934 - val_MAEMD: 0.1120
# Epoch 47/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0846 - mse: 0.0124 - mae: 0.0872 - MAEMD: 0.0846 - val_loss: 0.1139 - val_mse: 0.0147 - val_mae: 0.0960 - val_MAEMD: 0.1138
# Epoch 48/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0837 - mse: 0.0124 - mae: 0.0871 - MAEMD: 0.0837 - val_loss: 0.1110 - val_mse: 0.0135 - val_mae: 0.0917 - val_MAEMD: 0.1107
# Epoch 49/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0816 - mse: 0.0123 - mae: 0.0865 - MAEMD: 0.0816 - val_loss: 0.1106 - val_mse: 0.0132 - val_mae: 0.0904 - val_MAEMD: 0.1104
# Epoch 50/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0799 - mse: 0.0120 - mae: 0.0857 - MAEMD: 0.0799 - val_loss: 0.1118 - val_mse: 0.0137 - val_mae: 0.0923 - val_MAEMD: 0.1116
# Epoch 51/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0790 - mse: 0.0119 - mae: 0.0853 - MAEMD: 0.0790 - val_loss: 0.1111 - val_mse: 0.0134 - val_mae: 0.0914 - val_MAEMD: 0.1109
# Epoch 52/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0770 - mse: 0.0117 - mae: 0.0844 - MAEMD: 0.0770 - val_loss: 0.1107 - val_mse: 0.0134 - val_mae: 0.0913 - val_MAEMD: 0.1107
# Epoch 53/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0751 - mse: 0.0115 - mae: 0.0836 - MAEMD: 0.0750 - val_loss: 0.1104 - val_mse: 0.0133 - val_mae: 0.0911 - val_MAEMD: 0.1104
# Epoch 54/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0740 - mse: 0.0115 - mae: 0.0833 - MAEMD: 0.0739 - val_loss: 0.1115 - val_mse: 0.0132 - val_mae: 0.0906 - val_MAEMD: 0.1116
# Epoch 55/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0748 - mse: 0.0115 - mae: 0.0837 - MAEMD: 0.0748 - val_loss: 0.1109 - val_mse: 0.0134 - val_mae: 0.0913 - val_MAEMD: 0.1109
# Epoch 56/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0748 - mse: 0.0114 - mae: 0.0833 - MAEMD: 0.0748 - val_loss: 0.1116 - val_mse: 0.0140 - val_mae: 0.0936 - val_MAEMD: 0.1116
# Epoch 57/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0733 - mse: 0.0113 - mae: 0.0829 - MAEMD: 0.0733 - val_loss: 0.1117 - val_mse: 0.0146 - val_mae: 0.0955 - val_MAEMD: 0.1113
# Epoch 58/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0729 - mse: 0.0112 - mae: 0.0827 - MAEMD: 0.0729 - val_loss: 0.1112 - val_mse: 0.0144 - val_mae: 0.0948 - val_MAEMD: 0.1110
# Epoch 59/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0714 - mse: 0.0110 - mae: 0.0817 - MAEMD: 0.0714 - val_loss: 0.1086 - val_mse: 0.0134 - val_mae: 0.0913 - val_MAEMD: 0.1084
# Epoch 60/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0697 - mse: 0.0108 - mae: 0.0809 - MAEMD: 0.0697 - val_loss: 0.1075 - val_mse: 0.0133 - val_mae: 0.0909 - val_MAEMD: 0.1074
# Epoch 61/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0683 - mse: 0.0106 - mae: 0.0801 - MAEMD: 0.0682 - val_loss: 0.1076 - val_mse: 0.0130 - val_mae: 0.0897 - val_MAEMD: 0.1074
# Epoch 62/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0665 - mse: 0.0104 - mae: 0.0791 - MAEMD: 0.0665 - val_loss: 0.1068 - val_mse: 0.0127 - val_mae: 0.0889 - val_MAEMD: 0.1070
# Epoch 63/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0647 - mse: 0.0102 - mae: 0.0783 - MAEMD: 0.0647 - val_loss: 0.1080 - val_mse: 0.0129 - val_mae: 0.0894 - val_MAEMD: 0.1081
# Epoch 64/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0637 - mse: 0.0101 - mae: 0.0777 - MAEMD: 0.0637 - val_loss: 0.1088 - val_mse: 0.0134 - val_mae: 0.0914 - val_MAEMD: 0.1089
# Epoch 65/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0632 - mse: 0.0100 - mae: 0.0775 - MAEMD: 0.0632 - val_loss: 0.1138 - val_mse: 0.0143 - val_mae: 0.0947 - val_MAEMD: 0.1142
# Epoch 66/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0622 - mse: 0.0100 - mae: 0.0772 - MAEMD: 0.0622 - val_loss: 0.1103 - val_mse: 0.0132 - val_mae: 0.0906 - val_MAEMD: 0.1101
# Epoch 67/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0628 - mse: 0.0101 - mae: 0.0776 - MAEMD: 0.0628 - val_loss: 0.1089 - val_mse: 0.0135 - val_mae: 0.0916 - val_MAEMD: 0.1087
# Epoch 68/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0628 - mse: 0.0100 - mae: 0.0773 - MAEMD: 0.0628 - val_loss: 0.1068 - val_mse: 0.0128 - val_mae: 0.0891 - val_MAEMD: 0.1066
# Epoch 69/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0626 - mse: 0.0099 - mae: 0.0772 - MAEMD: 0.0626 - val_loss: 0.1071 - val_mse: 0.0127 - val_mae: 0.0887 - val_MAEMD: 0.1072
# Epoch 70/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0617 - mse: 0.0098 - mae: 0.0765 - MAEMD: 0.0617 - val_loss: 0.1096 - val_mse: 0.0130 - val_mae: 0.0899 - val_MAEMD: 0.1095
# Epoch 71/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0605 - mse: 0.0097 - mae: 0.0760 - MAEMD: 0.0605 - val_loss: 0.1094 - val_mse: 0.0130 - val_mae: 0.0897 - val_MAEMD: 0.1094
# Epoch 72/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0596 - mse: 0.0096 - mae: 0.0757 - MAEMD: 0.0596 - val_loss: 0.1080 - val_mse: 0.0126 - val_mae: 0.0887 - val_MAEMD: 0.1081
# Epoch 73/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0598 - mse: 0.0096 - mae: 0.0758 - MAEMD: 0.0598 - val_loss: 0.1056 - val_mse: 0.0122 - val_mae: 0.0869 - val_MAEMD: 0.1055
# Epoch 74/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0600 - mse: 0.0096 - mae: 0.0756 - MAEMD: 0.0600 - val_loss: 0.1073 - val_mse: 0.0128 - val_mae: 0.0894 - val_MAEMD: 0.1074
# Epoch 75/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0596 - mse: 0.0095 - mae: 0.0753 - MAEMD: 0.0596 - val_loss: 0.1102 - val_mse: 0.0133 - val_mae: 0.0911 - val_MAEMD: 0.1104
# Epoch 76/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0591 - mse: 0.0094 - mae: 0.0747 - MAEMD: 0.0591 - val_loss: 0.1083 - val_mse: 0.0125 - val_mae: 0.0881 - val_MAEMD: 0.1086
# Epoch 77/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0585 - mse: 0.0093 - mae: 0.0746 - MAEMD: 0.0585 - val_loss: 0.1104 - val_mse: 0.0133 - val_mae: 0.0912 - val_MAEMD: 0.1106
# Epoch 78/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0587 - mse: 0.0093 - mae: 0.0746 - MAEMD: 0.0587 - val_loss: 0.1096 - val_mse: 0.0132 - val_mae: 0.0907 - val_MAEMD: 0.1098
# Epoch 79/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0587 - mse: 0.0093 - mae: 0.0745 - MAEMD: 0.0587 - val_loss: 0.1092 - val_mse: 0.0123 - val_mae: 0.0874 - val_MAEMD: 0.1095
# Epoch 80/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0582 - mse: 0.0092 - mae: 0.0741 - MAEMD: 0.0582 - val_loss: 0.1076 - val_mse: 0.0119 - val_mae: 0.0859 - val_MAEMD: 0.1079
# Epoch 81/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0574 - mse: 0.0091 - mae: 0.0736 - MAEMD: 0.0574 - val_loss: 0.1066 - val_mse: 0.0118 - val_mae: 0.0857 - val_MAEMD: 0.1065
# Epoch 82/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0558 - mse: 0.0090 - mae: 0.0728 - MAEMD: 0.0558 - val_loss: 0.1084 - val_mse: 0.0125 - val_mae: 0.0880 - val_MAEMD: 0.1083
# Epoch 83/1000
# 131/131 [==============================] - 3s 26ms/step - loss: 0.0562 - mse: 0.0090 - mae: 0.0731 - MAEMD: 0.0562 - val_loss: 0.1110 - val_mse: 0.0133 - val_mae: 0.0913 - val_MAEMD: 0.1108

# %%
model2.save('Basic Ramp Model_woOutput.h5')
gc.collect()
# Out:
# 4596

# %%
with tf.device('/gpu:0'):
    model2 = keras.models.load_model('Basic Ramp Model_woOutput.h5', custom_objects={'MAEMD': MAEMD})
    gc.collect()
    testPredict2 = model2.predict(teX, batch_size=b_size)

# %%
testPredict2 = model2.predict(teX, batch_size=b_size)
tePredict2 = testPredict2.reshape(-1)

print('Error Test Score > MSE == ', npMSE(testY, tePredict2), ' MAE == ', npMAE(testY, tePredict2), ' MAEMD == ', npMAEMD(testY, tePredict2))
# Out:
# Error Test Score > MSE ==  0.014516399283782719  MAE ==  0.09560079289039354  MAEMD ==  0.10970228456036886

# %% [markdown]
# ## Without PN Residual

# %%
from keras import regularizers

num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1
    beta = 1
    hfilters = 168
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    pera = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(pera)
    den1b = Dense(timesteps, activation='sigmoid')(pera)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])   
    
    ## Permuted Attention Block
    per1 = Permute((2,1))(visible1)
    den2a = Dense(num_features, activation='tanh')(visible1)
    den2b = Dense(num_features, activation='sigmoid')(visible1)
    den2 = Multiply()([den2a, den2b])
    perb2 = Permute((2,1), name='attention_vec2')(den2)
    
    mul2 = Multiply()([per1, perb2])     
    
    ## Parallel DCCNN Blocks 1-1 ~ 3-1
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres01a = Add()([mul1, d1])   # (100, 25) (100, 25)
    rres01b = Add()([mul1, d1])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    rres02a = Add()([rres01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    rres02b = Add()([rres01b, d2])   # (100, 25) (100, 25) 
    rres02 = Concatenate()([rres02a, rres02b, rres01a, rres01b])
    #rres02 = Dropout(0.2)(rres02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres03a = Add()([rres02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    rres03b = Add()([rres02b, d2])
    rres10 = Concatenate()([rres03a, rres03b, rres02])

    ## Right-half DCCNN Blocks 1-2 ~ 3-2
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul2)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([mul2, d1])   # (100, 25) (100, 25)
    res01b = Add()([mul2, d1])
    
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Add()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    #res02 = Dropout(0.2)(res02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Add()([res02b, d2])
    res10 = Concatenate()([res03a, res03b, res02])

    ## Output Blocks
    out1 = Conv1D(24*7, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out1 = Dropout(0.2)(out1)  
    
    out2 = Conv1D(24*7, 1, padding='same', activation=PReLU())(rres10)   # 256, 11X10=110
    out2 = Dropout(0.2)(out2)
    
    out = Concatenate(axis=1)([out1, out2])
    
    ## Output Block
    out = Conv1D(24*7, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)

    #, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
    out = GlobalAveragePooling1D()(out) 

    out = Dense(output_timesteps)(out) 
    model3 = Model(inputs=[visible1], outputs=[out])
    
    print(model3.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 168, 37)]    0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 37, 168)      0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 168, 37)      1406        input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 168, 37)      1406        input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 37, 168)      28392       permute[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 37, 168)      28392       permute[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 168, 37)      0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 37, 168)      0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 37, 168)      0           input_1[0][0]
# __________________________________________________________________________________________________
# attention_vec2 (Permute)        (None, 37, 168)      0           multiply_2[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 168, 37)      0           multiply[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 37, 168)      0           permute_1[0][0]
#                                                                  attention_vec2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 168, 37)      0           input_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 37, 168)      28392       multiply_3[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 168, 168)     6384        multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 168, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 168, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 37, 168)      0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 168, 168)     0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 37, 168)      56616       multiply_14[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 168, 37)      12469       multiply_4[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 168)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 37, 168)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 168, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 168, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 37, 168)      0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 168, 37)      0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 37, 168)      0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 37, 168)      0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 168, 37)      0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 168, 37)      0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 37, 168)      28392       add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 37, 168)      28392       add_7[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 168, 168)     6384        add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 168, 168)     6384        add_1[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 37, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 37, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 37, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 37, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 168, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 168, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 168, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 168, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 37, 168)      0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 37, 168)      0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 168, 168)     0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 168, 168)     0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 37, 168)      56616       multiply_16[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 37, 168)      56616       multiply_18[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 168, 37)      12469       multiply_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 168, 37)      12469       multiply_8[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 37, 168)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 37, 168)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 37, 168)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 37, 168)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 168, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 168, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 168, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 168, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 37, 168)      0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 37, 168)      0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 168, 37)      0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 168, 37)      0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 37, 168)      0           add_6[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 37, 168)      0           add_7[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 168, 37)      0           add[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 168, 37)      0           add_1[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 37, 672)      0           add_8[0][0]
#                                                                  add_9[0][0]
#                                                                  add_6[0][0]
#                                                                  add_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 168, 148)     0           add_2[0][0]
#                                                                  add_3[0][0]
#                                                                  add[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 37, 168)      113064      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 37, 168)      113064      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 168, 168)     25032       concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 168, 168)     25032       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 37, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 37, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 37, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 37, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 168, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 168, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 168, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 168, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 37, 168)      0           activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 37, 168)      0           activation_36[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 168, 168)     0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 168, 168)     0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 37, 168)      56616       multiply_20[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 37, 168)      56616       multiply_22[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 168, 37)      12469       multiply_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 168, 37)      12469       multiply_12[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 37, 168)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 37, 168)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 37, 168)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 37, 168)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 168, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 168, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 168, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 168, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 37, 168)      0           activation_34[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 37, 168)      0           activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 168, 37)      0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 168, 37)      0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 37, 168)      0           add_8[0][0]
#                                                                  multiply_21[0][0]
# __________________________________________________________________________________________________
# add_11 (Add)                    (None, 37, 168)      0           add_9[0][0]
#                                                                  multiply_23[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 168, 37)      0           add_2[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 168, 37)      0           add_3[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 37, 1008)     0           add_10[0][0]
#                                                                  add_11[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 168, 222)     0           add_4[0][0]
#                                                                  add_5[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 37, 168)      175728      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 168, 168)     65688       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 37, 168)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 168, 168)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 205, 168)     0           dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 205, 168)     62832       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 205, 168)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 168)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 24)           4056        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,093,845
# Trainable params: 1,093,845
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 4235

# %%
    model3.compile(loss=MAEMD, optimizer='adam', metrics=['mse','mae', MAEMD])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    epochs = 1000
    #root_squared_mean_error
    history3 = LossHistory()
    history3.init()
    hist3 = model3.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history3, early_stopping])
    model3.save('Basic Ramp Model_woPN.h5')
    gc.collect()
# Out:
# Epoch 1/1000
# 131/131 [==============================] - 15s 83ms/step - loss: 0.2171 - mse: 0.0294 - mae: 0.1203 - MAEMD: 0.2170 - val_loss: 0.1941 - val_mse: 0.0124 - val_mae: 0.0866 - val_MAEMD: 0.1935
# Epoch 2/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1535 - mse: 0.0166 - mae: 0.1024 - MAEMD: 0.1535 - val_loss: 0.1377 - val_mse: 0.0183 - val_mae: 0.1092 - val_MAEMD: 0.1374
# Epoch 3/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1344 - mse: 0.0183 - mae: 0.1092 - MAEMD: 0.1344 - val_loss: 0.1352 - val_mse: 0.0186 - val_mae: 0.1106 - val_MAEMD: 0.1348
# Epoch 4/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1318 - mse: 0.0183 - mae: 0.1091 - MAEMD: 0.1317 - val_loss: 0.1326 - val_mse: 0.0181 - val_mae: 0.1089 - val_MAEMD: 0.1322
# Epoch 5/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1302 - mse: 0.0183 - mae: 0.1089 - MAEMD: 0.1301 - val_loss: 0.1313 - val_mse: 0.0181 - val_mae: 0.1092 - val_MAEMD: 0.1310
# Epoch 6/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1291 - mse: 0.0182 - mae: 0.1086 - MAEMD: 0.1290 - val_loss: 0.1304 - val_mse: 0.0184 - val_mae: 0.1100 - val_MAEMD: 0.1300
# Epoch 7/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1281 - mse: 0.0181 - mae: 0.1084 - MAEMD: 0.1281 - val_loss: 0.1296 - val_mse: 0.0187 - val_mae: 0.1110 - val_MAEMD: 0.1292
# Epoch 8/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1272 - mse: 0.0180 - mae: 0.1079 - MAEMD: 0.1271 - val_loss: 0.1285 - val_mse: 0.0183 - val_mae: 0.1096 - val_MAEMD: 0.1282
# Epoch 9/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1263 - mse: 0.0178 - mae: 0.1072 - MAEMD: 0.1262 - val_loss: 0.1289 - val_mse: 0.0195 - val_mae: 0.1135 - val_MAEMD: 0.1287
# Epoch 10/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1253 - mse: 0.0177 - mae: 0.1069 - MAEMD: 0.1252 - val_loss: 0.1274 - val_mse: 0.0178 - val_mae: 0.1074 - val_MAEMD: 0.1271
# Epoch 11/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1240 - mse: 0.0175 - mae: 0.1060 - MAEMD: 0.1240 - val_loss: 0.1276 - val_mse: 0.0187 - val_mae: 0.1104 - val_MAEMD: 0.1274
# Epoch 12/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1232 - mse: 0.0174 - mae: 0.1055 - MAEMD: 0.1231 - val_loss: 0.1266 - val_mse: 0.0183 - val_mae: 0.1088 - val_MAEMD: 0.1265
# Epoch 13/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1219 - mse: 0.0172 - mae: 0.1048 - MAEMD: 0.1218 - val_loss: 0.1267 - val_mse: 0.0173 - val_mae: 0.1053 - val_MAEMD: 0.1265
# Epoch 14/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.1207 - mse: 0.0170 - mae: 0.1040 - MAEMD: 0.1206 - val_loss: 0.1273 - val_mse: 0.0173 - val_mae: 0.1052 - val_MAEMD: 0.1270
# Epoch 15/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1189 - mse: 0.0167 - mae: 0.1029 - MAEMD: 0.1189 - val_loss: 0.1274 - val_mse: 0.0178 - val_mae: 0.1068 - val_MAEMD: 0.1272
# Epoch 16/1000
# 131/131 [==============================] - 9s 71ms/step - loss: 0.1175 - mse: 0.0165 - mae: 0.1020 - MAEMD: 0.1175 - val_loss: 0.1260 - val_mse: 0.0177 - val_mae: 0.1062 - val_MAEMD: 0.1258
# Epoch 17/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.1156 - mse: 0.0162 - mae: 0.1009 - MAEMD: 0.1156 - val_loss: 0.1287 - val_mse: 0.0179 - val_mae: 0.1069 - val_MAEMD: 0.1285
# Epoch 18/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1141 - mse: 0.0160 - mae: 0.1000 - MAEMD: 0.1140 - val_loss: 0.1254 - val_mse: 0.0168 - val_mae: 0.1033 - val_MAEMD: 0.1253
# Epoch 19/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1132 - mse: 0.0158 - mae: 0.0995 - MAEMD: 0.1132 - val_loss: 0.1249 - val_mse: 0.0159 - val_mae: 0.0999 - val_MAEMD: 0.1246
# Epoch 20/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1115 - mse: 0.0155 - mae: 0.0984 - MAEMD: 0.1114 - val_loss: 0.1265 - val_mse: 0.0168 - val_mae: 0.1034 - val_MAEMD: 0.1263
# Epoch 21/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1105 - mse: 0.0153 - mae: 0.0978 - MAEMD: 0.1105 - val_loss: 0.1270 - val_mse: 0.0170 - val_mae: 0.1040 - val_MAEMD: 0.1268
# Epoch 22/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1086 - mse: 0.0151 - mae: 0.0968 - MAEMD: 0.1086 - val_loss: 0.1272 - val_mse: 0.0171 - val_mae: 0.1044 - val_MAEMD: 0.1271
# Epoch 23/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1068 - mse: 0.0148 - mae: 0.0958 - MAEMD: 0.1068 - val_loss: 0.1271 - val_mse: 0.0164 - val_mae: 0.1019 - val_MAEMD: 0.1268
# Epoch 24/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1046 - mse: 0.0146 - mae: 0.0950 - MAEMD: 0.1046 - val_loss: 0.1254 - val_mse: 0.0158 - val_mae: 0.0995 - val_MAEMD: 0.1253
# Epoch 25/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1031 - mse: 0.0145 - mae: 0.0947 - MAEMD: 0.1031 - val_loss: 0.1265 - val_mse: 0.0164 - val_mae: 0.1017 - val_MAEMD: 0.1263
# Epoch 26/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1025 - mse: 0.0145 - mae: 0.0946 - MAEMD: 0.1024 - val_loss: 0.1265 - val_mse: 0.0162 - val_mae: 0.1011 - val_MAEMD: 0.1263
# Epoch 27/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1017 - mse: 0.0144 - mae: 0.0944 - MAEMD: 0.1016 - val_loss: 0.1241 - val_mse: 0.0148 - val_mae: 0.0961 - val_MAEMD: 0.1239
# Epoch 28/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.1007 - mse: 0.0143 - mae: 0.0940 - MAEMD: 0.1007 - val_loss: 0.1244 - val_mse: 0.0152 - val_mae: 0.0972 - val_MAEMD: 0.1242
# Epoch 29/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0993 - mse: 0.0141 - mae: 0.0934 - MAEMD: 0.0993 - val_loss: 0.1246 - val_mse: 0.0150 - val_mae: 0.0963 - val_MAEMD: 0.1244
# Epoch 30/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0982 - mse: 0.0140 - mae: 0.0931 - MAEMD: 0.0981 - val_loss: 0.1237 - val_mse: 0.0156 - val_mae: 0.0987 - val_MAEMD: 0.1235
# Epoch 31/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0975 - mse: 0.0140 - mae: 0.0931 - MAEMD: 0.0975 - val_loss: 0.1241 - val_mse: 0.0156 - val_mae: 0.0986 - val_MAEMD: 0.1238
# Epoch 32/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0971 - mse: 0.0140 - mae: 0.0930 - MAEMD: 0.0971 - val_loss: 0.1233 - val_mse: 0.0149 - val_mae: 0.0962 - val_MAEMD: 0.1231
# Epoch 33/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0976 - mse: 0.0140 - mae: 0.0929 - MAEMD: 0.0976 - val_loss: 0.1231 - val_mse: 0.0146 - val_mae: 0.0948 - val_MAEMD: 0.1228
# Epoch 34/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0973 - mse: 0.0139 - mae: 0.0928 - MAEMD: 0.0972 - val_loss: 0.1237 - val_mse: 0.0147 - val_mae: 0.0956 - val_MAEMD: 0.1235
# Epoch 35/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0950 - mse: 0.0137 - mae: 0.0918 - MAEMD: 0.0950 - val_loss: 0.1236 - val_mse: 0.0147 - val_mae: 0.0957 - val_MAEMD: 0.1234
# Epoch 36/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0943 - mse: 0.0137 - mae: 0.0917 - MAEMD: 0.0942 - val_loss: 0.1238 - val_mse: 0.0160 - val_mae: 0.1001 - val_MAEMD: 0.1235
# Epoch 37/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0943 - mse: 0.0137 - mae: 0.0917 - MAEMD: 0.0942 - val_loss: 0.1264 - val_mse: 0.0166 - val_mae: 0.1018 - val_MAEMD: 0.1260
# Epoch 38/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0946 - mse: 0.0137 - mae: 0.0919 - MAEMD: 0.0946 - val_loss: 0.1268 - val_mse: 0.0165 - val_mae: 0.1014 - val_MAEMD: 0.1265
# Epoch 39/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0942 - mse: 0.0137 - mae: 0.0918 - MAEMD: 0.0941 - val_loss: 0.1287 - val_mse: 0.0168 - val_mae: 0.1021 - val_MAEMD: 0.1284
# Epoch 40/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0931 - mse: 0.0136 - mae: 0.0915 - MAEMD: 0.0931 - val_loss: 0.1253 - val_mse: 0.0164 - val_mae: 0.1012 - val_MAEMD: 0.1250
# Epoch 41/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0923 - mse: 0.0135 - mae: 0.0911 - MAEMD: 0.0922 - val_loss: 0.1251 - val_mse: 0.0161 - val_mae: 0.1005 - val_MAEMD: 0.1249
# Epoch 42/1000
# 131/131 [==============================] - 9s 69ms/step - loss: 0.0901 - mse: 0.0132 - mae: 0.0900 - MAEMD: 0.0901 - val_loss: 0.1244 - val_mse: 0.0157 - val_mae: 0.0990 - val_MAEMD: 0.1242
# Epoch 43/1000
# 131/131 [==============================] - 9s 70ms/step - loss: 0.0890 - mse: 0.0132 - mae: 0.0899 - MAEMD: 0.0889 - val_loss: 0.1269 - val_mse: 0.0169 - val_mae: 0.1034 - val_MAEMD: 0.1267
# 4581

# %%
with tf.device('/gpu:0'):
    model3 = keras.models.load_model('Basic Ramp Model_woPN.h5', custom_objects={'MAEMD': MAEMD})
    gc.collect()
    testPredict3 = model3.predict(teX, batch_size=b_size)

# %%
testPredict3 = model3.predict(teX, batch_size=b_size)
tePredict3 = testPredict3.reshape(-1)

print('Error Test Score > MSE == ', npMSE(testY, tePredict3), ' MAE == ', npMAE(testY, tePredict3), ' MAEMS == ', npMAEMD(testY, tePredict3))
# Out:
# Error Test Score > MSE ==  0.015482937397291924  MAE ==  0.09846961463256855  MAEMS ==  0.10817173195697713

# %% [markdown]
# ## Without PReLU

# %%
from keras import regularizers

num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1
    beta = 1
    hfilters = 168
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    pera = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(pera)
    den1b = Dense(timesteps, activation='sigmoid')(pera)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])   
    
    ## Permuted Attention Block
    per1 = Permute((2,1))(visible1)
    den2a = Dense(num_features, activation='tanh')(visible1)
    den2b = Dense(num_features, activation='sigmoid')(visible1)
    den2 = Multiply()([den2a, den2b])
    perb2 = Permute((2,1), name='attention_vec2')(den2)
    
    mul2 = Multiply()([per1, perb2])     
    
    ## Parallel DCCNN Blocks 1-1 ~ 3-1
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres01a = Add()([mul1, d1])   # (100, 25) (100, 25)
    rres01b = Subtract()([mul1, d1])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    rres02a = Add()([rres01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    rres02b = Subtract()([rres01b, d2])   # (100, 25) (100, 25) 
    rres02 = Concatenate()([rres02a, rres02b, rres01a, rres01b])
    #rres02 = Dropout(0.2)(rres02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres03a = Add()([rres02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    rres03b = Subtract()([rres02b, d2])
    rres10 = Concatenate()([rres03a, rres03b, rres02])

    ## Right-half DCCNN Blocks 1-2 ~ 3-2
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul2)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([mul2, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([mul2, d1])
    
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    #res02 = Dropout(0.2)(res02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])
    res10 = Concatenate()([res03a, res03b, res02])

    ## Output Blocks
    out1 = Conv1D(24*7, 1, padding='same', activation='relu')(res10)   # 256, 11X10=110
    out1 = Dropout(0.2)(out1)  
    
    out2 = Conv1D(24*7, 1, padding='same', activation='relu')(rres10)   # 256, 11X10=110
    out2 = Dropout(0.2)(out2)
    
    out = Concatenate(axis=1)([out1, out2])
    
    ## Output Block
    out = Conv1D(24*7, 1, padding='same', activation='relu')(out) # 512,  110X5=550
    out = Dropout(0.2)(out)

    #, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
    out = GlobalAveragePooling1D()(out) 

    out = Dense(output_timesteps)(out) 
    model4 = Model(inputs=[visible1], outputs=[out])
    
    print(model4.summary())
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_4 (InputLayer)            [(None, 168, 37)]    0
# __________________________________________________________________________________________________
# permute_5 (Permute)             (None, 37, 168)      0           input_4[0][0]
# __________________________________________________________________________________________________
# dense_13 (Dense)                (None, 168, 37)      1406        input_4[0][0]
# __________________________________________________________________________________________________
# dense_14 (Dense)                (None, 168, 37)      1406        input_4[0][0]
# __________________________________________________________________________________________________
# dense_11 (Dense)                (None, 37, 168)      28392       permute_5[0][0]
# __________________________________________________________________________________________________
# dense_12 (Dense)                (None, 37, 168)      28392       permute_5[0][0]
# __________________________________________________________________________________________________
# multiply_70 (Multiply)          (None, 168, 37)      0           dense_13[0][0]
#                                                                  dense_14[0][0]
# __________________________________________________________________________________________________
# multiply_68 (Multiply)          (None, 37, 168)      0           dense_11[0][0]
#                                                                  dense_12[0][0]
# __________________________________________________________________________________________________
# permute_6 (Permute)             (None, 37, 168)      0           input_4[0][0]
# __________________________________________________________________________________________________
# attention_vec2 (Permute)        (None, 37, 168)      0           multiply_70[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 168, 37)      0           multiply_68[0][0]
# __________________________________________________________________________________________________
# multiply_71 (Multiply)          (None, 37, 168)      0           permute_6[0][0]
#                                                                  attention_vec2[0][0]
# __________________________________________________________________________________________________
# multiply_69 (Multiply)          (None, 168, 37)      0           input_4[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_76 (Conv1D)              (None, 37, 168)      28392       multiply_71[0][0]
# __________________________________________________________________________________________________
# conv1d_66 (Conv1D)              (None, 168, 168)     6384        multiply_69[0][0]
# __________________________________________________________________________________________________
# activation_140 (Activation)     (None, 37, 168)      0           conv1d_76[0][0]
# __________________________________________________________________________________________________
# activation_141 (Activation)     (None, 37, 168)      0           conv1d_76[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 168, 168)     0           conv1d_66[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 168, 168)     0           conv1d_66[0][0]
# __________________________________________________________________________________________________
# multiply_82 (Multiply)          (None, 37, 168)      0           activation_140[0][0]
#                                                                  activation_141[0][0]
# __________________________________________________________________________________________________
# multiply_72 (Multiply)          (None, 168, 168)     0           activation_120[0][0]
#                                                                  activation_121[0][0]
# __________________________________________________________________________________________________
# conv1d_77 (Conv1D)              (None, 37, 168)      56616       multiply_82[0][0]
# __________________________________________________________________________________________________
# conv1d_67 (Conv1D)              (None, 168, 37)      12469       multiply_72[0][0]
# __________________________________________________________________________________________________
# activation_142 (Activation)     (None, 37, 168)      0           conv1d_77[0][0]
# __________________________________________________________________________________________________
# activation_143 (Activation)     (None, 37, 168)      0           conv1d_77[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 168, 37)      0           conv1d_67[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 168, 37)      0           conv1d_67[0][0]
# __________________________________________________________________________________________________
# multiply_83 (Multiply)          (None, 37, 168)      0           activation_142[0][0]
#                                                                  activation_143[0][0]
# __________________________________________________________________________________________________
# multiply_73 (Multiply)          (None, 168, 37)      0           activation_122[0][0]
#                                                                  activation_123[0][0]
# __________________________________________________________________________________________________
# add_27 (Add)                    (None, 37, 168)      0           multiply_71[0][0]
#                                                                  multiply_83[0][0]
# __________________________________________________________________________________________________
# subtract_15 (Subtract)          (None, 37, 168)      0           multiply_71[0][0]
#                                                                  multiply_83[0][0]
# __________________________________________________________________________________________________
# add_24 (Add)                    (None, 168, 37)      0           multiply_69[0][0]
#                                                                  multiply_73[0][0]
# __________________________________________________________________________________________________
# subtract_12 (Subtract)          (None, 168, 37)      0           multiply_69[0][0]
#                                                                  multiply_73[0][0]
# __________________________________________________________________________________________________
# conv1d_78 (Conv1D)              (None, 37, 168)      28392       add_27[0][0]
# __________________________________________________________________________________________________
# conv1d_80 (Conv1D)              (None, 37, 168)      28392       subtract_15[0][0]
# __________________________________________________________________________________________________
# conv1d_68 (Conv1D)              (None, 168, 168)     6384        add_24[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 168, 168)     6384        subtract_12[0][0]
# __________________________________________________________________________________________________
# activation_144 (Activation)     (None, 37, 168)      0           conv1d_78[0][0]
# __________________________________________________________________________________________________
# activation_145 (Activation)     (None, 37, 168)      0           conv1d_78[0][0]
# __________________________________________________________________________________________________
# activation_148 (Activation)     (None, 37, 168)      0           conv1d_80[0][0]
# __________________________________________________________________________________________________
# activation_149 (Activation)     (None, 37, 168)      0           conv1d_80[0][0]
# __________________________________________________________________________________________________
# activation_124 (Activation)     (None, 168, 168)     0           conv1d_68[0][0]
# __________________________________________________________________________________________________
# activation_125 (Activation)     (None, 168, 168)     0           conv1d_68[0][0]
# __________________________________________________________________________________________________
# activation_128 (Activation)     (None, 168, 168)     0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# activation_129 (Activation)     (None, 168, 168)     0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# multiply_84 (Multiply)          (None, 37, 168)      0           activation_144[0][0]
#                                                                  activation_145[0][0]
# __________________________________________________________________________________________________
# multiply_86 (Multiply)          (None, 37, 168)      0           activation_148[0][0]
#                                                                  activation_149[0][0]
# __________________________________________________________________________________________________
# multiply_74 (Multiply)          (None, 168, 168)     0           activation_124[0][0]
#                                                                  activation_125[0][0]
# __________________________________________________________________________________________________
# multiply_76 (Multiply)          (None, 168, 168)     0           activation_128[0][0]
#                                                                  activation_129[0][0]
# __________________________________________________________________________________________________
# conv1d_79 (Conv1D)              (None, 37, 168)      56616       multiply_84[0][0]
# __________________________________________________________________________________________________
# conv1d_81 (Conv1D)              (None, 37, 168)      56616       multiply_86[0][0]
# __________________________________________________________________________________________________
# conv1d_69 (Conv1D)              (None, 168, 37)      12469       multiply_74[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 168, 37)      12469       multiply_76[0][0]
# __________________________________________________________________________________________________
# activation_146 (Activation)     (None, 37, 168)      0           conv1d_79[0][0]
# __________________________________________________________________________________________________
# activation_147 (Activation)     (None, 37, 168)      0           conv1d_79[0][0]
# __________________________________________________________________________________________________
# activation_150 (Activation)     (None, 37, 168)      0           conv1d_81[0][0]
# __________________________________________________________________________________________________
# activation_151 (Activation)     (None, 37, 168)      0           conv1d_81[0][0]
# __________________________________________________________________________________________________
# activation_126 (Activation)     (None, 168, 37)      0           conv1d_69[0][0]
# __________________________________________________________________________________________________
# activation_127 (Activation)     (None, 168, 37)      0           conv1d_69[0][0]
# __________________________________________________________________________________________________
# activation_130 (Activation)     (None, 168, 37)      0           conv1d_71[0][0]
# __________________________________________________________________________________________________
# activation_131 (Activation)     (None, 168, 37)      0           conv1d_71[0][0]
# __________________________________________________________________________________________________
# multiply_85 (Multiply)          (None, 37, 168)      0           activation_146[0][0]
#                                                                  activation_147[0][0]
# __________________________________________________________________________________________________
# multiply_87 (Multiply)          (None, 37, 168)      0           activation_150[0][0]
#                                                                  activation_151[0][0]
# __________________________________________________________________________________________________
# multiply_75 (Multiply)          (None, 168, 37)      0           activation_126[0][0]
#                                                                  activation_127[0][0]
# __________________________________________________________________________________________________
# multiply_77 (Multiply)          (None, 168, 37)      0           activation_130[0][0]
#                                                                  activation_131[0][0]
# __________________________________________________________________________________________________
# add_28 (Add)                    (None, 37, 168)      0           add_27[0][0]
#                                                                  multiply_85[0][0]
# __________________________________________________________________________________________________
# subtract_16 (Subtract)          (None, 37, 168)      0           subtract_15[0][0]
#                                                                  multiply_87[0][0]
# __________________________________________________________________________________________________
# add_25 (Add)                    (None, 168, 37)      0           add_24[0][0]
#                                                                  multiply_75[0][0]
# __________________________________________________________________________________________________
# subtract_13 (Subtract)          (None, 168, 37)      0           subtract_12[0][0]
#                                                                  multiply_77[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 37, 672)      0           add_28[0][0]
#                                                                  subtract_16[0][0]
#                                                                  add_27[0][0]
#                                                                  subtract_15[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 168, 148)     0           add_25[0][0]
#                                                                  subtract_13[0][0]
#                                                                  add_24[0][0]
#                                                                  subtract_12[0][0]
# __________________________________________________________________________________________________
# conv1d_82 (Conv1D)              (None, 37, 168)      113064      concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv1d_84 (Conv1D)              (None, 37, 168)      113064      concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv1d_72 (Conv1D)              (None, 168, 168)     25032       concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv1d_74 (Conv1D)              (None, 168, 168)     25032       concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_152 (Activation)     (None, 37, 168)      0           conv1d_82[0][0]
# __________________________________________________________________________________________________
# activation_153 (Activation)     (None, 37, 168)      0           conv1d_82[0][0]
# __________________________________________________________________________________________________
# activation_156 (Activation)     (None, 37, 168)      0           conv1d_84[0][0]
# __________________________________________________________________________________________________
# activation_157 (Activation)     (None, 37, 168)      0           conv1d_84[0][0]
# __________________________________________________________________________________________________
# activation_132 (Activation)     (None, 168, 168)     0           conv1d_72[0][0]
# __________________________________________________________________________________________________
# activation_133 (Activation)     (None, 168, 168)     0           conv1d_72[0][0]
# __________________________________________________________________________________________________
# activation_136 (Activation)     (None, 168, 168)     0           conv1d_74[0][0]
# __________________________________________________________________________________________________
# activation_137 (Activation)     (None, 168, 168)     0           conv1d_74[0][0]
# __________________________________________________________________________________________________
# multiply_88 (Multiply)          (None, 37, 168)      0           activation_152[0][0]
#                                                                  activation_153[0][0]
# __________________________________________________________________________________________________
# multiply_90 (Multiply)          (None, 37, 168)      0           activation_156[0][0]
#                                                                  activation_157[0][0]
# __________________________________________________________________________________________________
# multiply_78 (Multiply)          (None, 168, 168)     0           activation_132[0][0]
#                                                                  activation_133[0][0]
# __________________________________________________________________________________________________
# multiply_80 (Multiply)          (None, 168, 168)     0           activation_136[0][0]
#                                                                  activation_137[0][0]
# __________________________________________________________________________________________________
# conv1d_83 (Conv1D)              (None, 37, 168)      56616       multiply_88[0][0]
# __________________________________________________________________________________________________
# conv1d_85 (Conv1D)              (None, 37, 168)      56616       multiply_90[0][0]
# __________________________________________________________________________________________________
# conv1d_73 (Conv1D)              (None, 168, 37)      12469       multiply_78[0][0]
# __________________________________________________________________________________________________
# conv1d_75 (Conv1D)              (None, 168, 37)      12469       multiply_80[0][0]
# __________________________________________________________________________________________________
# activation_154 (Activation)     (None, 37, 168)      0           conv1d_83[0][0]
# __________________________________________________________________________________________________
# activation_155 (Activation)     (None, 37, 168)      0           conv1d_83[0][0]
# __________________________________________________________________________________________________
# activation_158 (Activation)     (None, 37, 168)      0           conv1d_85[0][0]
# __________________________________________________________________________________________________
# activation_159 (Activation)     (None, 37, 168)      0           conv1d_85[0][0]
# __________________________________________________________________________________________________
# activation_134 (Activation)     (None, 168, 37)      0           conv1d_73[0][0]
# __________________________________________________________________________________________________
# activation_135 (Activation)     (None, 168, 37)      0           conv1d_73[0][0]
# __________________________________________________________________________________________________
# activation_138 (Activation)     (None, 168, 37)      0           conv1d_75[0][0]
# __________________________________________________________________________________________________
# activation_139 (Activation)     (None, 168, 37)      0           conv1d_75[0][0]
# __________________________________________________________________________________________________
# multiply_89 (Multiply)          (None, 37, 168)      0           activation_154[0][0]
#                                                                  activation_155[0][0]
# __________________________________________________________________________________________________
# multiply_91 (Multiply)          (None, 37, 168)      0           activation_158[0][0]
#                                                                  activation_159[0][0]
# __________________________________________________________________________________________________
# multiply_79 (Multiply)          (None, 168, 37)      0           activation_134[0][0]
#                                                                  activation_135[0][0]
# __________________________________________________________________________________________________
# multiply_81 (Multiply)          (None, 168, 37)      0           activation_138[0][0]
#                                                                  activation_139[0][0]
# __________________________________________________________________________________________________
# add_29 (Add)                    (None, 37, 168)      0           add_28[0][0]
#                                                                  multiply_89[0][0]
# __________________________________________________________________________________________________
# subtract_17 (Subtract)          (None, 37, 168)      0           subtract_16[0][0]
#                                                                  multiply_91[0][0]
# __________________________________________________________________________________________________
# add_26 (Add)                    (None, 168, 37)      0           add_25[0][0]
#                                                                  multiply_79[0][0]
# __________________________________________________________________________________________________
# subtract_14 (Subtract)          (None, 168, 37)      0           subtract_13[0][0]
#                                                                  multiply_81[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 37, 1008)     0           add_29[0][0]
#                                                                  subtract_17[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 168, 222)     0           add_26[0][0]
#                                                                  subtract_14[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv1d_86 (Conv1D)              (None, 37, 168)      169512      concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv1d_87 (Conv1D)              (None, 168, 168)     37464       concatenate_15[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 37, 168)      0           conv1d_86[0][0]
# __________________________________________________________________________________________________
# dropout_7 (Dropout)             (None, 168, 168)     0           conv1d_87[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 205, 168)     0           dropout_6[0][0]
#                                                                  dropout_7[0][0]
# __________________________________________________________________________________________________
# conv1d_88 (Conv1D)              (None, 205, 168)     28392       concatenate_18[0][0]
# __________________________________________________________________________________________________
# dropout_8 (Dropout)             (None, 205, 168)     0           conv1d_88[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_3 (Glo (None, 168)          0           dropout_8[0][0]
# __________________________________________________________________________________________________
# dense_15 (Dense)                (None, 24)           4056        global_average_pooling1d_3[0][0]
# ==================================================================================================
# Total params: 1,024,965
# Trainable params: 1,024,965
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 5074

# %%
    model4.compile(loss=MAEMD, optimizer='adam', metrics=['mse','mae', MAEMD])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    epochs = 1000
    #root_squared_mean_error
    history4 = LossHistory()
    history4.init()
    hist4 = model4.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history4, early_stopping])
    model4.save('Basic Ramp Model_woPrelu.h5')
    gc.collect()
# Out:
# Epoch 1/1000
# 131/131 [==============================] - 12s 74ms/step - loss: 0.2171 - mse: 0.0294 - mae: 0.1209 - MAEMD: 0.2171 - val_loss: 0.1927 - val_mse: 0.0127 - val_mae: 0.0872 - val_MAEMD: 0.1929
# Epoch 2/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1554 - mse: 0.0169 - mae: 0.1033 - MAEMD: 0.1554 - val_loss: 0.1369 - val_mse: 0.0189 - val_mae: 0.1110 - val_MAEMD: 0.1366
# Epoch 3/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1343 - mse: 0.0187 - mae: 0.1101 - MAEMD: 0.1343 - val_loss: 0.1328 - val_mse: 0.0189 - val_mae: 0.1114 - val_MAEMD: 0.1326
# Epoch 4/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1318 - mse: 0.0187 - mae: 0.1103 - MAEMD: 0.1318 - val_loss: 0.1312 - val_mse: 0.0186 - val_mae: 0.1102 - val_MAEMD: 0.1311
# Epoch 5/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1301 - mse: 0.0186 - mae: 0.1099 - MAEMD: 0.1302 - val_loss: 0.1310 - val_mse: 0.0192 - val_mae: 0.1122 - val_MAEMD: 0.1309
# Epoch 6/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1292 - mse: 0.0186 - mae: 0.1098 - MAEMD: 0.1292 - val_loss: 0.1293 - val_mse: 0.0188 - val_mae: 0.1108 - val_MAEMD: 0.1292
# Epoch 7/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1286 - mse: 0.0185 - mae: 0.1096 - MAEMD: 0.1286 - val_loss: 0.1285 - val_mse: 0.0185 - val_mae: 0.1097 - val_MAEMD: 0.1284
# Epoch 8/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1280 - mse: 0.0185 - mae: 0.1096 - MAEMD: 0.1280 - val_loss: 0.1282 - val_mse: 0.0184 - val_mae: 0.1094 - val_MAEMD: 0.1281
# Epoch 9/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1276 - mse: 0.0184 - mae: 0.1092 - MAEMD: 0.1276 - val_loss: 0.1281 - val_mse: 0.0184 - val_mae: 0.1097 - val_MAEMD: 0.1279
# Epoch 10/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1268 - mse: 0.0182 - mae: 0.1087 - MAEMD: 0.1268 - val_loss: 0.1270 - val_mse: 0.0181 - val_mae: 0.1086 - val_MAEMD: 0.1269
# Epoch 11/1000
# 131/131 [==============================] - 9s 66ms/step - loss: 0.1259 - mse: 0.0180 - mae: 0.1080 - MAEMD: 0.1259 - val_loss: 0.1263 - val_mse: 0.0182 - val_mae: 0.1088 - val_MAEMD: 0.1262
# Epoch 12/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1250 - mse: 0.0179 - mae: 0.1073 - MAEMD: 0.1250 - val_loss: 0.1264 - val_mse: 0.0187 - val_mae: 0.1103 - val_MAEMD: 0.1262
# Epoch 13/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1248 - mse: 0.0179 - mae: 0.1073 - MAEMD: 0.1248 - val_loss: 0.1272 - val_mse: 0.0185 - val_mae: 0.1094 - val_MAEMD: 0.1270
# Epoch 14/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1239 - mse: 0.0177 - mae: 0.1067 - MAEMD: 0.1239 - val_loss: 0.1270 - val_mse: 0.0185 - val_mae: 0.1095 - val_MAEMD: 0.1269
# Epoch 15/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1230 - mse: 0.0176 - mae: 0.1060 - MAEMD: 0.1230 - val_loss: 0.1262 - val_mse: 0.0185 - val_mae: 0.1092 - val_MAEMD: 0.1261
# Epoch 16/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1221 - mse: 0.0175 - mae: 0.1057 - MAEMD: 0.1221 - val_loss: 0.1270 - val_mse: 0.0181 - val_mae: 0.1079 - val_MAEMD: 0.1270
# Epoch 17/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1215 - mse: 0.0174 - mae: 0.1054 - MAEMD: 0.1215 - val_loss: 0.1267 - val_mse: 0.0180 - val_mae: 0.1073 - val_MAEMD: 0.1266
# Epoch 18/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1206 - mse: 0.0173 - mae: 0.1049 - MAEMD: 0.1207 - val_loss: 0.1264 - val_mse: 0.0178 - val_mae: 0.1063 - val_MAEMD: 0.1263
# Epoch 19/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1200 - mse: 0.0172 - mae: 0.1045 - MAEMD: 0.1201 - val_loss: 0.1255 - val_mse: 0.0178 - val_mae: 0.1064 - val_MAEMD: 0.1255
# Epoch 20/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1193 - mse: 0.0171 - mae: 0.1042 - MAEMD: 0.1193 - val_loss: 0.1252 - val_mse: 0.0173 - val_mae: 0.1044 - val_MAEMD: 0.1252
# Epoch 21/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1185 - mse: 0.0170 - mae: 0.1035 - MAEMD: 0.1185 - val_loss: 0.1251 - val_mse: 0.0172 - val_mae: 0.1042 - val_MAEMD: 0.1251
# Epoch 22/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1176 - mse: 0.0169 - mae: 0.1033 - MAEMD: 0.1176 - val_loss: 0.1257 - val_mse: 0.0172 - val_mae: 0.1038 - val_MAEMD: 0.1258
# Epoch 23/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1173 - mse: 0.0169 - mae: 0.1032 - MAEMD: 0.1174 - val_loss: 0.1254 - val_mse: 0.0173 - val_mae: 0.1044 - val_MAEMD: 0.1255
# Epoch 24/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1165 - mse: 0.0168 - mae: 0.1026 - MAEMD: 0.1165 - val_loss: 0.1255 - val_mse: 0.0176 - val_mae: 0.1055 - val_MAEMD: 0.1255
# Epoch 25/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1150 - mse: 0.0166 - mae: 0.1021 - MAEMD: 0.1151 - val_loss: 0.1246 - val_mse: 0.0165 - val_mae: 0.1015 - val_MAEMD: 0.1247
# Epoch 26/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1142 - mse: 0.0165 - mae: 0.1017 - MAEMD: 0.1142 - val_loss: 0.1254 - val_mse: 0.0172 - val_mae: 0.1041 - val_MAEMD: 0.1254
# Epoch 27/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1132 - mse: 0.0164 - mae: 0.1014 - MAEMD: 0.1132 - val_loss: 0.1250 - val_mse: 0.0167 - val_mae: 0.1023 - val_MAEMD: 0.1250
# Epoch 28/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1123 - mse: 0.0163 - mae: 0.1010 - MAEMD: 0.1123 - val_loss: 0.1261 - val_mse: 0.0174 - val_mae: 0.1043 - val_MAEMD: 0.1261
# Epoch 29/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1115 - mse: 0.0162 - mae: 0.1006 - MAEMD: 0.1115 - val_loss: 0.1256 - val_mse: 0.0170 - val_mae: 0.1032 - val_MAEMD: 0.1255
# Epoch 30/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1106 - mse: 0.0161 - mae: 0.1002 - MAEMD: 0.1106 - val_loss: 0.1271 - val_mse: 0.0173 - val_mae: 0.1042 - val_MAEMD: 0.1270
# Epoch 31/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1103 - mse: 0.0161 - mae: 0.1002 - MAEMD: 0.1103 - val_loss: 0.1261 - val_mse: 0.0163 - val_mae: 0.1010 - val_MAEMD: 0.1260
# Epoch 32/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1100 - mse: 0.0161 - mae: 0.1001 - MAEMD: 0.1100 - val_loss: 0.1254 - val_mse: 0.0165 - val_mae: 0.1021 - val_MAEMD: 0.1252
# Epoch 33/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1087 - mse: 0.0159 - mae: 0.0994 - MAEMD: 0.1087 - val_loss: 0.1248 - val_mse: 0.0162 - val_mae: 0.1008 - val_MAEMD: 0.1247
# Epoch 34/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1083 - mse: 0.0158 - mae: 0.0992 - MAEMD: 0.1083 - val_loss: 0.1246 - val_mse: 0.0164 - val_mae: 0.1013 - val_MAEMD: 0.1246
# Epoch 35/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1082 - mse: 0.0157 - mae: 0.0989 - MAEMD: 0.1082 - val_loss: 0.1241 - val_mse: 0.0163 - val_mae: 0.1014 - val_MAEMD: 0.1239
# Epoch 36/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1079 - mse: 0.0157 - mae: 0.0988 - MAEMD: 0.1079 - val_loss: 0.1250 - val_mse: 0.0167 - val_mae: 0.1023 - val_MAEMD: 0.1249
# Epoch 37/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1059 - mse: 0.0155 - mae: 0.0979 - MAEMD: 0.1059 - val_loss: 0.1249 - val_mse: 0.0165 - val_mae: 0.1018 - val_MAEMD: 0.1249
# Epoch 38/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1047 - mse: 0.0153 - mae: 0.0975 - MAEMD: 0.1047 - val_loss: 0.1250 - val_mse: 0.0164 - val_mae: 0.1014 - val_MAEMD: 0.1249
# Epoch 39/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1038 - mse: 0.0152 - mae: 0.0970 - MAEMD: 0.1038 - val_loss: 0.1251 - val_mse: 0.0163 - val_mae: 0.1011 - val_MAEMD: 0.1250
# Epoch 40/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1024 - mse: 0.0151 - mae: 0.0966 - MAEMD: 0.1024 - val_loss: 0.1248 - val_mse: 0.0162 - val_mae: 0.1008 - val_MAEMD: 0.1247
# Epoch 41/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1017 - mse: 0.0150 - mae: 0.0964 - MAEMD: 0.1017 - val_loss: 0.1244 - val_mse: 0.0174 - val_mae: 0.1046 - val_MAEMD: 0.1243
# Epoch 42/1000
# 131/131 [==============================] - 9s 68ms/step - loss: 0.1015 - mse: 0.0150 - mae: 0.0963 - MAEMD: 0.1015 - val_loss: 0.1241 - val_mse: 0.0165 - val_mae: 0.1018 - val_MAEMD: 0.1240
# Epoch 43/1000
# 131/131 [==============================] - 9s 66ms/step - loss: 0.1020 - mse: 0.0150 - mae: 0.0964 - MAEMD: 0.1021 - val_loss: 0.1255 - val_mse: 0.0167 - val_mae: 0.1028 - val_MAEMD: 0.1255
# Epoch 44/1000
# 131/131 [==============================] - 9s 66ms/step - loss: 0.1029 - mse: 0.0150 - mae: 0.0964 - MAEMD: 0.1029 - val_loss: 0.1283 - val_mse: 0.0174 - val_mae: 0.1054 - val_MAEMD: 0.1283
# Epoch 45/1000
# 131/131 [==============================] - 9s 67ms/step - loss: 0.1012 - mse: 0.0148 - mae: 0.0957 - MAEMD: 0.1012 - val_loss: 0.1250 - val_mse: 0.0165 - val_mae: 0.1026 - val_MAEMD: 0.1250
# 4603

# %%
with tf.device('/gpu:0'):
    model4 = keras.models.load_model('Basic Ramp Model_woPrelu.h5', custom_objects={'MAEMD': MAEMD})
    gc.collect()
    testPredict4 = model4.predict(teX, batch_size=b_size)

# %%
testPredict4 = model4.predict(teX, batch_size=b_size)
tePredict4 = testPredict4.reshape(-1)

print('Error Test Score > MSE == ', npMSE(testY, tePredict4), ' MAE == ', npMAE(testY, tePredict4), ' MAEMS == ', npMAEMD(testY, tePredict4))
# Out:
# Error Test Score > MSE ==  0.015349471324590228  MAE ==  0.09855305307264312  MAEMS ==  0.10558177241384827

# %% [markdown]
# ## Proposed

# %%
with tf.device('/gpu:0'):
    ramp_model = keras.models.load_model('Basic Ramp Model Final_lead.h5', custom_objects={'MAEMD': MAEMD})
    gc.collect()
    testPredict5 = ramp_model.predict(teX, batch_size=b_size)

# %%
tePredict5 = testPredict5.reshape(-1)
print('Error Test Score > MAEMD == ', npMAEMD(testY, tePredict))
print('Error Test Score > MAEMD == ', npMAEMD(testY, tePredict2))
print('Error Test Score > MAEMD == ', npMAEMD(testY, tePredict3))
print('Error Test Score > MAEMD == ', npMAEMD(testY, tePredict4))
print('Error Test Score > MAEMD == ', npMAEMD(testY, tePredict5))
# Out:
# Error Test Score > MAEMD ==  0.10749349925427328
# Error Test Score > MAEMD ==  0.10970228456036886
# Error Test Score > MAEMD ==  0.10817173195697713
# Error Test Score > MAEMD ==  0.10558177241384827
# Error Test Score > MAEMD ==  0.103274032513692
