# %%
import tensorflow as tf

import pandas as pd
import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
#from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply, Subtract
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout, SpatialDropout1D
from scipy import signal
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pylab as plt
import matplotlib.dates as mdates
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc
from keijzer import *
from tensorflow import keras
from keras.models import Model
from keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply, Embedding, Layer, Reshape
from keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
#from keras.ops import convert_to_tensor, convert_to_numpy
#from keras.utils import plot_model
from keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))



def root_squared_mean_error(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))+K.mean(K.abs(y_pred - y_true))

from keras.layers.advanced_activations import PReLU

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '0' # 여러개 사용시 '0,1,2' 식으로 하나의 문자열에 입력
gpus = tf.config.experimental.list_physical_devices('GPU') # 호스트 러나임에 표시되는 GPU 장치 목록 반환

if gpus: # 반환된 GPU 장치 목록이 있다면
    try: # 해당 장치에 대한 메모리 증가 활성화 여부 설정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e: # try문 실패시에 에러문구 출력
        print(e)

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Import Data & Preprocessing

# %%
data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2020.csv'
data_source1 = pd.read_csv(data_path)
dat_source1 = pd.DataFrame(data_source1)
#dat_source1 = dat_source1.iloc[:-3,:]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2021.csv'
data_source2 = pd.read_csv(data_path)
dat_source2 = pd.DataFrame(data_source2)
dat_source2 = dat_source2.iloc[:8761,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2022.csv'
data_source3 = pd.read_csv(data_path)
dat_source3 = pd.DataFrame(data_source3)
dat_source3 = dat_source3.iloc[:8760,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2023.csv'
data_source4 = pd.read_csv(data_path)
dat_source4 = pd.DataFrame(data_source4)
dat_source4 = dat_source4.iloc[:8760,:9]

dat_arr1 = np.array(dat_source1)
dat_arr2 = np.array(dat_source2)
dat_arr3 = np.array(dat_source3)
dat_arr4 = np.array(dat_source4)

dat_arr = np.concatenate([dat_arr1, dat_arr2, dat_arr3, dat_arr4],axis=0)
dat_arr.shape # 8784, 8761, 8760, 8760

dat_source = pd.DataFrame(dat_arr, columns=['Time-Date stamp','Date','ERCOT Load','Total Wind Output','Total Wind Installed','Wind Output, % of Load','Wind Output, % of Installed','1-hr MW change','1-hr % change'])
dat_source
# Out:
#            Time-Date stamp    Date ERCOT Load Total Wind Output  \
# 0      01-01-2020 00:00:00  Jan-01      36823             12335
# 1      01-01-2020 01:00:00  Jan-01      36511             13300
# 2      01-01-2020 02:00:00  Jan-01      36022             13586
# 3      01-01-2020 03:00:00  Jan-01      35790             14107
# 4      01-01-2020 04:00:00  Jan-01      35642             14887
# ...                    ...     ...        ...               ...
# 35060  12-31-2023 20:00:00  Dec-31      44887             17161
# 35061  12-31-2023 21:00:00  Dec-31      44013             18301
# 35062  12-31-2023 22:00:00  Dec-31      43280             18607
# 35063  12-31-2023 23:00:00  Dec-31      42319             17866
# 35064  01-01-2024 00:00:00  Jan-01      41682             15869
#
#       Total Wind Installed Wind Output, % of Load Wind Output, % of Installed  \
# 0                    27040                   33.5                      45.617
# 1                    27040                   36.4                      49.187
# 2                    27040                   37.7                      50.245
# 3                    27040                   39.4                      52.171
# 4                    27040                   41.8                      55.055
# ...                    ...                    ...                         ...
# 35060                38631                  38.23                       44.42
# 35061                38631                  41.58                       47.37
# 35062                38631                  42.99                       48.17
# 35063                38631                  42.22                       46.25
# 35064                38631                  38.07                       41.08
#
#       1-hr MW change 1-hr % change
# 0                NaN           NaN
# 1              965.4         7.826
# 2              286.2         2.152
# 3              520.9         3.834
# 4              779.6         5.527
# ...              ...           ...
# 35060           2858         19.99
# 35061           1139          6.64
# 35062            307          1.67
# 35063           -741         -3.98
# 35064          -1996        -11.17
#
# [35065 rows x 9 columns]

# %% [markdown]
# ### Dividing by Installed Capacity & Preprocessing

# %%
dat = pd.DataFrame()
dat['MW % change'] = np.array(dat_source.iloc[1:,3], dtype=float)-np.array(dat_source.iloc[0:-1,3], dtype=float)
dat['MW % change'] = np.divide(np.array(dat['MW % change']),np.array(dat_source.iloc[1:,4]))*100
dat['Total Wind Output'] = np.divide(np.array(dat_source.iloc[1:,3]), np.array(dat_source.iloc[1:,4]))

dat
# Out:
#       MW % change Total Wind Output
# 0         3.56879          0.491864
# 1         1.05769          0.502441
# 2         1.92678          0.521709
# 3         2.88462          0.550555
# 4       -0.580621          0.544749
# ...           ...               ...
# 35059      7.3982          0.444229
# 35060       2.951          0.473739
# 35061     0.79211           0.48166
# 35062    -1.91815          0.462478
# 35063    -5.16942          0.410784
#
# [35064 rows x 2 columns]

# %%
ramp_ratio = 20
load_ratio = 10
year_arr = np.concatenate([np.ones(8784)*2020, np.ones(8760)*2021, np.ones(8760)*2022, np.ones(8760)*2023])
year_df = pd.DataFrame(year_arr, columns=['Year'], dtype=int)
wind_df = pd.concat([year_df, dat], axis=1)
wind_df
# Out:
#        Year MW % change Total Wind Output
# 0      2020     3.56879          0.491864
# 1      2020     1.05769          0.502441
# 2      2020     1.92678          0.521709
# 3      2020     2.88462          0.550555
# 4      2020   -0.580621          0.544749
# ...     ...         ...               ...
# 35059  2023      7.3982          0.444229
# 35060  2023       2.951          0.473739
# 35061  2023     0.79211           0.48166
# 35062  2023    -1.91815          0.462478
# 35063  2023    -5.16942          0.410784
#
# [35064 rows x 3 columns]

# %%
wind_df = wind_df.reset_index(drop=True)
std_scaler = sklearn.preprocessing.MinMaxScaler()
std_scaler_load = sklearn.preprocessing.MinMaxScaler()
std_scaler_ramp = sklearn.preprocessing.MinMaxScaler()

wind_df[['Total Wind Output']] = std_scaler.fit_transform(wind_df[['Total Wind Output']])
wind_df[['MW % change']] = std_scaler_ramp.fit_transform(wind_df[['MW % change']])
#wind_df[['Wind Change, % of Load', 'Wind Change']] = std_scaler_ramp.fit_transform(wind_df[['Wind Change, % of Load', 'Wind Change']])
wind_df = wind_df.iloc[:-1,:]
wind_df
# Out:
#        Year  MW % change  Total Wind Output
# 0      2020     0.620197           0.644724
# 1      2020     0.544580           0.658617
# 2      2020     0.570751           0.683924
# 3      2020     0.599594           0.721813
# 4      2020     0.495246           0.714187
# ...     ...          ...                ...
# 35058  2023     0.774643           0.484984
# 35059  2023     0.735512           0.582157
# 35060  2023     0.601593           0.620917
# 35061  2023     0.536583           0.631322
# 35062  2023     0.454969           0.606127
#
# [35063 rows x 3 columns]

# %%
ramp_df = pd.DataFrame(wind_df)
ramp_df.columns=['Year', 'Wind Change', 'Wind Output']
ramp_df
# Out:
#        Year  Wind Change  Wind Output
# 0      2020     0.620197     0.644724
# 1      2020     0.544580     0.658617
# 2      2020     0.570751     0.683924
# 3      2020     0.599594     0.721813
# 4      2020     0.495246     0.714187
# ...     ...          ...          ...
# 35058  2023     0.774643     0.484984
# 35059  2023     0.735512     0.582157
# 35060  2023     0.601593     0.620917
# 35061  2023     0.536583     0.631322
# 35062  2023     0.454969     0.606127
#
# [35063 rows x 3 columns]

# %% [markdown]
# ## Wind Ramp Rate Forecasting

# %% [markdown]
# ### SVD-based Feature Generation

# %%
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc

def create_dataset(dataset, timesteps, output_timesteps, leadtime):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - leadtime - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps + leadtime):(i+timesteps+output_timesteps+leadtime), :])
    return np.array(dataX), np.array(dataY)

# %%
norm_df = np.array(wind_df['Wind Change']).reshape(-1,1)
timesteps = 24
output_timesteps = 1
num_features = 1
leadtime = 1
X, Y = create_dataset(norm_df, timesteps, output_timesteps, leadtime)
b_size = timesteps

# %%
dec_num = timesteps
high_ind = 12

addX = np.zeros((X.shape[0], dec_num, high_ind+1))

def svdadd(X, start, end, b_size):
    dec_x = X[start:end, :, :]
    U, S, Vh = svd(dec_x.reshape(b_size, -1))

    high_sig = np.matmul(np.matmul(U[:,:high_ind], np.diag(S[0:high_ind])), Vh[:high_ind,:])
    low_sig = X[:dec_num, :, :].reshape(b_size,-1)-high_sig

    rec_x = np.zeros((b_size, b_size, high_ind))
    #print(sum(S[0:high_ind])/sum(S))
    for i in range(high_ind):
        rec_x[:,:,i] = np.matmul((U[:,i]*S[i]).reshape(-1,1), Vh[i,:].reshape(1,-1))    
    return rec_x, low_sig

for k in range(X.shape[0]//dec_num):
    rec_x, low_sig = svdadd(X, k*dec_num, (k+1)*dec_num, b_size)
    addX[k*dec_num:k*dec_num+dec_num,:, :-1] = rec_x
    addX[k*dec_num:k*dec_num+dec_num,:, -1] = low_sig
    
rec_x, low_sig = svdadd(X, X.shape[0]-dec_num, X.shape[0], b_size)
addX[X.shape[0]-dec_num:X.shape[0], :, :-1] = rec_x
addX[X.shape[0]-dec_num:X.shape[0],:, -1] = low_sig

addX_det = addX[:, :, :-1]
addX_det = np.sum(addX_det, axis=2)
X = np.concatenate([X, addX], axis=2)
num_features = X.shape[2]

# %% [markdown]
# ### Training/Test Set Division & Shuffled Learning

# %%
trvaX, teX, trvaY, teY = train_test_split(X, Y, test_size=0.1, shuffle=False)

idx = np.arange(trvaX.shape[0])
np.random.shuffle(idx)
strvaX = trvaX[idx]
strvaY = trvaY[idx]
strvaY = strvaY.reshape(-1, output_timesteps)

trvaY = trvaY.reshape(-1, output_timesteps)
teY = teY.reshape(-1, output_timesteps)

strX, svaX, strY, svaY = train_test_split(strvaX, strvaY, test_size=0.3, shuffle=False)
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=0.3, shuffle=False)

trvaX.shape, trvaY.shape, teX.shape, teY.shape
# Out:
# ((31532, 24, 14), (31532, 1), (3504, 24, 14), (3504, 1))

# %% [markdown]
# ## Wind Ramp Rate Forecasting Basic Model

# %%
def MAEMD_1h(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true))*100

# %%
from keras.layers.advanced_activations import PReLU

# %%
from keras import regularizers

num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1
    beta = 1
    hfilters = 168
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    pera = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(pera)
    den1b = Dense(timesteps, activation='sigmoid')(pera)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])   
    
    ## Permuted Attention Block
    per1 = Permute((2,1))(visible1)
    den2a = Dense(num_features, activation='tanh')(visible1)
    den2b = Dense(num_features, activation='sigmoid')(visible1)
    den2 = Multiply()([den2a, den2b])
    perb2 = Permute((2,1), name='attention_vec2')(den2)
    
    mul2 = Multiply()([per1, perb2])     
    
    ## Parallel DCCNN Blocks 1-1 ~ 3-1
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres01a = Add()([mul1, d1])   # (100, 25) (100, 25)
    rres01b = Subtract()([mul1, d1])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    rres02a = Add()([rres01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    rres02b = Subtract()([rres01b, d2])   # (100, 25) (100, 25) 
    rres02 = Concatenate()([rres02a, rres02b, rres01a, rres01b])
    #rres02 = Dropout(0.2)(rres02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres03a = Add()([rres02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    rres03b = Subtract()([rres02b, d2])
    rres10 = Concatenate()([rres03a, rres03b, rres02])

    ## Right-half DCCNN Blocks 1-2 ~ 3-2
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul2)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([mul2, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([mul2, d1])
    
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    #res02 = Dropout(0.2)(res02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])
    res10 = Concatenate()([res03a, res03b, res02])

    ## Output Blocks
    out1 = Conv1D(24*7, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out1 = Dropout(0.2)(out1)  
    
    out2 = Conv1D(24*7, 1, padding='same', activation=PReLU())(rres10)   # 256, 11X10=110
    out2 = Dropout(0.2)(out2)
    
    out = Concatenate(axis=1)([out1, out2])
    
    ## Output Block
    out = Conv1D(24*7, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)

    #, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
    out = GlobalAveragePooling1D()(out) 

    out = Dense(output_timesteps)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 24, 14)]     0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 14, 24)       0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 24, 14)       210         input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 24, 14)       210         input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 14, 24)       600         permute[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 14, 24)       600         permute[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 24, 14)       0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 14, 24)       0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 14, 24)       0           input_1[0][0]
# __________________________________________________________________________________________________
# attention_vec2 (Permute)        (None, 14, 24)       0           multiply_2[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 24, 14)       0           multiply[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 14, 24)       0           permute_1[0][0]
#                                                                  attention_vec2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 24, 14)       0           input_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 14, 168)      4200        multiply_3[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 24, 168)      2520        multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 14, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 14, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 24, 168)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 24, 168)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 14, 168)      0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 24, 168)      0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 14, 24)       8088        multiply_14[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 24, 14)       4718        multiply_4[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 14, 24)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 14, 24)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 14)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 14)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 14, 24)       0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 24, 14)       0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 14, 24)       0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 14, 24)       0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 24, 14)       0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 24, 14)       0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 14, 168)      4200        add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 14, 168)      4200        subtract_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 24, 168)      2520        add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 24, 168)      2520        subtract[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 14, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 14, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 14, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 14, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 24, 168)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 24, 168)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 24, 168)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 24, 168)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 14, 168)      0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 14, 168)      0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 24, 168)      0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 24, 168)      0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 14, 24)       8088        multiply_16[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 14, 24)       8088        multiply_18[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 24, 14)       4718        multiply_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 24, 14)       4718        multiply_8[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 14, 24)       0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 14, 24)       0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 14, 24)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 14, 24)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 24, 14)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 24, 14)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 24, 14)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 24, 14)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 14, 24)       0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 14, 24)       0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 24, 14)       0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 24, 14)       0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 14, 24)       0           add_3[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 14, 24)       0           subtract_3[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 24, 14)       0           add[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 24, 14)       0           subtract[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 14, 96)       0           add_4[0][0]
#                                                                  subtract_4[0][0]
#                                                                  add_3[0][0]
#                                                                  subtract_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 24, 56)       0           add_1[0][0]
#                                                                  subtract_1[0][0]
#                                                                  add[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 14, 168)      16296       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 14, 168)      16296       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 24, 168)      9576        concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 24, 168)      9576        concatenate[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 14, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 14, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 14, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 14, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 24, 168)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 24, 168)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 24, 168)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 24, 168)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 14, 168)      0           activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 14, 168)      0           activation_36[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 24, 168)      0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 24, 168)      0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 14, 24)       8088        multiply_20[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 14, 24)       8088        multiply_22[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 24, 14)       4718        multiply_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 24, 14)       4718        multiply_12[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 14, 24)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 14, 24)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 14, 24)       0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 14, 24)       0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 24, 14)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 24, 14)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 24, 14)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 24, 14)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 14, 24)       0           activation_34[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 14, 24)       0           activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 24, 14)       0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 24, 14)       0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 14, 24)       0           add_4[0][0]
#                                                                  multiply_21[0][0]
# __________________________________________________________________________________________________
# subtract_5 (Subtract)           (None, 14, 24)       0           subtract_4[0][0]
#                                                                  multiply_23[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 24, 14)       0           add_1[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 24, 14)       0           subtract_1[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 14, 144)      0           add_5[0][0]
#                                                                  subtract_5[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 84)       0           add_2[0][0]
#                                                                  subtract_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 14, 168)      26712       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 24, 168)      18312       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 14, 168)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 24, 168)      0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 38, 168)      0           dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 38, 168)      34776       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 38, 168)      0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 168)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 1)            169         global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 217,523
# Trainable params: 217,523
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 1353

# %%
    model.compile(loss=MAEMD_1h, optimizer='adam', metrics=['mse','mae', MAEMD_1h])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    epochs = 1000
    history = LossHistory()
    history.init()

# %%
    # %%time
    b_size = output_timesteps*100
    #hist = model.fit(strvaX, strvaY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(teX, teY), callbacks=[history, early_stopping])  # , checkpoint
    hist = model.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 221/221 [==============================] - 11s 33ms/step - loss: 2.4331 - mse: 0.0159 - mae: 0.0897 - MAEMD_1h: 2.4322 - val_loss: 1.8794 - val_mse: 0.0088 - val_mae: 0.0695 - val_MAEMD_1h: 1.8813
# Epoch 2/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 1.8641 - mse: 0.0087 - mae: 0.0699 - MAEMD_1h: 1.8639 - val_loss: 1.7830 - val_mse: 0.0083 - val_mae: 0.0674 - val_MAEMD_1h: 1.7847
# Epoch 3/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.7852 - mse: 0.0082 - mae: 0.0674 - MAEMD_1h: 1.7851 - val_loss: 1.7192 - val_mse: 0.0076 - val_mae: 0.0642 - val_MAEMD_1h: 1.7209
# Epoch 4/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.7397 - mse: 0.0079 - mae: 0.0660 - MAEMD_1h: 1.7396 - val_loss: 1.6968 - val_mse: 0.0075 - val_mae: 0.0637 - val_MAEMD_1h: 1.6985
# Epoch 5/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.7056 - mse: 0.0076 - mae: 0.0648 - MAEMD_1h: 1.7055 - val_loss: 1.6539 - val_mse: 0.0072 - val_mae: 0.0624 - val_MAEMD_1h: 1.6557
# Epoch 6/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.6737 - mse: 0.0074 - mae: 0.0638 - MAEMD_1h: 1.6736 - val_loss: 1.6262 - val_mse: 0.0070 - val_mae: 0.0615 - val_MAEMD_1h: 1.6280
# Epoch 7/1000
# 221/221 [==============================] - 7s 32ms/step - loss: 1.6563 - mse: 0.0072 - mae: 0.0631 - MAEMD_1h: 1.6562 - val_loss: 1.6071 - val_mse: 0.0069 - val_mae: 0.0610 - val_MAEMD_1h: 1.6089
# Epoch 8/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.6301 - mse: 0.0070 - mae: 0.0622 - MAEMD_1h: 1.6300 - val_loss: 1.5919 - val_mse: 0.0070 - val_mae: 0.0621 - val_MAEMD_1h: 1.5937
# Epoch 9/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.6225 - mse: 0.0070 - mae: 0.0620 - MAEMD_1h: 1.6224 - val_loss: 1.5839 - val_mse: 0.0065 - val_mae: 0.0593 - val_MAEMD_1h: 1.5856
# Epoch 10/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.6037 - mse: 0.0069 - mae: 0.0614 - MAEMD_1h: 1.6037 - val_loss: 1.5685 - val_mse: 0.0065 - val_mae: 0.0592 - val_MAEMD_1h: 1.5701
# Epoch 11/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.6066 - mse: 0.0069 - mae: 0.0616 - MAEMD_1h: 1.6066 - val_loss: 1.5701 - val_mse: 0.0064 - val_mae: 0.0590 - val_MAEMD_1h: 1.5718
# Epoch 12/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.5960 - mse: 0.0068 - mae: 0.0613 - MAEMD_1h: 1.5959 - val_loss: 1.5649 - val_mse: 0.0064 - val_mae: 0.0588 - val_MAEMD_1h: 1.5664
# Epoch 13/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.5904 - mse: 0.0068 - mae: 0.0610 - MAEMD_1h: 1.5903 - val_loss: 1.5671 - val_mse: 0.0063 - val_mae: 0.0585 - val_MAEMD_1h: 1.5688
# Epoch 14/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.5574 - mse: 0.0066 - mae: 0.0599 - MAEMD_1h: 1.5574 - val_loss: 1.5488 - val_mse: 0.0062 - val_mae: 0.0581 - val_MAEMD_1h: 1.5505
# Epoch 15/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.5538 - mse: 0.0066 - mae: 0.0599 - MAEMD_1h: 1.5538 - val_loss: 1.5553 - val_mse: 0.0062 - val_mae: 0.0578 - val_MAEMD_1h: 1.5571
# Epoch 16/1000
# 221/221 [==============================] - 7s 29ms/step - loss: 1.5518 - mse: 0.0065 - mae: 0.0596 - MAEMD_1h: 1.5518 - val_loss: 1.5458 - val_mse: 0.0062 - val_mae: 0.0578 - val_MAEMD_1h: 1.5476
# Epoch 17/1000
# 221/221 [==============================] - 7s 29ms/step - loss: 1.5368 - mse: 0.0064 - mae: 0.0592 - MAEMD_1h: 1.5369 - val_loss: 1.5309 - val_mse: 0.0063 - val_mae: 0.0587 - val_MAEMD_1h: 1.5328
# Epoch 18/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.5143 - mse: 0.0063 - mae: 0.0585 - MAEMD_1h: 1.5144 - val_loss: 1.5529 - val_mse: 0.0061 - val_mae: 0.0574 - val_MAEMD_1h: 1.5546
# Epoch 19/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.5168 - mse: 0.0063 - mae: 0.0584 - MAEMD_1h: 1.5168 - val_loss: 1.5517 - val_mse: 0.0061 - val_mae: 0.0575 - val_MAEMD_1h: 1.5534
# Epoch 20/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.5268 - mse: 0.0063 - mae: 0.0588 - MAEMD_1h: 1.5268 - val_loss: 1.5191 - val_mse: 0.0064 - val_mae: 0.0593 - val_MAEMD_1h: 1.5209
# Epoch 21/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.5106 - mse: 0.0062 - mae: 0.0582 - MAEMD_1h: 1.5107 - val_loss: 1.5269 - val_mse: 0.0066 - val_mae: 0.0601 - val_MAEMD_1h: 1.5287
# Epoch 22/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4985 - mse: 0.0061 - mae: 0.0578 - MAEMD_1h: 1.4986 - val_loss: 1.5117 - val_mse: 0.0063 - val_mae: 0.0588 - val_MAEMD_1h: 1.5136
# Epoch 23/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4803 - mse: 0.0060 - mae: 0.0572 - MAEMD_1h: 1.4803 - val_loss: 1.5113 - val_mse: 0.0062 - val_mae: 0.0578 - val_MAEMD_1h: 1.5130
# Epoch 24/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4686 - mse: 0.0060 - mae: 0.0568 - MAEMD_1h: 1.4686 - val_loss: 1.5222 - val_mse: 0.0060 - val_mae: 0.0573 - val_MAEMD_1h: 1.5238
# Epoch 25/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4669 - mse: 0.0060 - mae: 0.0568 - MAEMD_1h: 1.4670 - val_loss: 1.4988 - val_mse: 0.0061 - val_mae: 0.0577 - val_MAEMD_1h: 1.5003
# Epoch 26/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4644 - mse: 0.0060 - mae: 0.0567 - MAEMD_1h: 1.4645 - val_loss: 1.4951 - val_mse: 0.0062 - val_mae: 0.0580 - val_MAEMD_1h: 1.4967
# Epoch 27/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4579 - mse: 0.0059 - mae: 0.0565 - MAEMD_1h: 1.4578 - val_loss: 1.4941 - val_mse: 0.0062 - val_mae: 0.0583 - val_MAEMD_1h: 1.4959
# Epoch 28/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4432 - mse: 0.0058 - mae: 0.0561 - MAEMD_1h: 1.4433 - val_loss: 1.4975 - val_mse: 0.0063 - val_mae: 0.0589 - val_MAEMD_1h: 1.4994
# Epoch 29/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4450 - mse: 0.0058 - mae: 0.0560 - MAEMD_1h: 1.4451 - val_loss: 1.4984 - val_mse: 0.0064 - val_mae: 0.0591 - val_MAEMD_1h: 1.4999
# Epoch 30/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4374 - mse: 0.0058 - mae: 0.0560 - MAEMD_1h: 1.4374 - val_loss: 1.5054 - val_mse: 0.0059 - val_mae: 0.0565 - val_MAEMD_1h: 1.5070
# Epoch 31/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4354 - mse: 0.0058 - mae: 0.0558 - MAEMD_1h: 1.4353 - val_loss: 1.4924 - val_mse: 0.0059 - val_mae: 0.0566 - val_MAEMD_1h: 1.4939
# Epoch 32/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.4232 - mse: 0.0057 - mae: 0.0554 - MAEMD_1h: 1.4233 - val_loss: 1.4899 - val_mse: 0.0061 - val_mae: 0.0577 - val_MAEMD_1h: 1.4918
# Epoch 33/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4230 - mse: 0.0057 - mae: 0.0554 - MAEMD_1h: 1.4231 - val_loss: 1.4928 - val_mse: 0.0065 - val_mae: 0.0597 - val_MAEMD_1h: 1.4943
# Epoch 34/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4058 - mse: 0.0057 - mae: 0.0549 - MAEMD_1h: 1.4058 - val_loss: 1.4982 - val_mse: 0.0064 - val_mae: 0.0592 - val_MAEMD_1h: 1.4999
# Epoch 35/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4095 - mse: 0.0056 - mae: 0.0549 - MAEMD_1h: 1.4096 - val_loss: 1.4772 - val_mse: 0.0058 - val_mae: 0.0559 - val_MAEMD_1h: 1.4790
# Epoch 36/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.4003 - mse: 0.0057 - mae: 0.0548 - MAEMD_1h: 1.4004 - val_loss: 1.4851 - val_mse: 0.0060 - val_mae: 0.0570 - val_MAEMD_1h: 1.4867
# Epoch 37/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3979 - mse: 0.0056 - mae: 0.0544 - MAEMD_1h: 1.3980 - val_loss: 1.4883 - val_mse: 0.0060 - val_mae: 0.0574 - val_MAEMD_1h: 1.4899
# Epoch 38/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3783 - mse: 0.0055 - mae: 0.0540 - MAEMD_1h: 1.3785 - val_loss: 1.4718 - val_mse: 0.0059 - val_mae: 0.0566 - val_MAEMD_1h: 1.4734
# Epoch 39/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3799 - mse: 0.0055 - mae: 0.0540 - MAEMD_1h: 1.3800 - val_loss: 1.4801 - val_mse: 0.0058 - val_mae: 0.0562 - val_MAEMD_1h: 1.4817
# Epoch 40/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3858 - mse: 0.0055 - mae: 0.0541 - MAEMD_1h: 1.3859 - val_loss: 1.4821 - val_mse: 0.0062 - val_mae: 0.0584 - val_MAEMD_1h: 1.4836
# Epoch 41/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3662 - mse: 0.0055 - mae: 0.0536 - MAEMD_1h: 1.3661 - val_loss: 1.4818 - val_mse: 0.0062 - val_mae: 0.0586 - val_MAEMD_1h: 1.4836
# Epoch 42/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3739 - mse: 0.0055 - mae: 0.0539 - MAEMD_1h: 1.3738 - val_loss: 1.4773 - val_mse: 0.0062 - val_mae: 0.0582 - val_MAEMD_1h: 1.4790
# Epoch 43/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3657 - mse: 0.0055 - mae: 0.0536 - MAEMD_1h: 1.3658 - val_loss: 1.4860 - val_mse: 0.0063 - val_mae: 0.0592 - val_MAEMD_1h: 1.4877
# Epoch 44/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3518 - mse: 0.0054 - mae: 0.0532 - MAEMD_1h: 1.3518 - val_loss: 1.4863 - val_mse: 0.0064 - val_mae: 0.0593 - val_MAEMD_1h: 1.4877
# Epoch 45/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3555 - mse: 0.0054 - mae: 0.0534 - MAEMD_1h: 1.3555 - val_loss: 1.4671 - val_mse: 0.0060 - val_mae: 0.0571 - val_MAEMD_1h: 1.4687
# Epoch 46/1000
# 221/221 [==============================] - 7s 30ms/step - loss: 1.3507 - mse: 0.0054 - mae: 0.0531 - MAEMD_1h: 1.3507 - val_loss: 1.4879 - val_mse: 0.0064 - val_mae: 0.0594 - val_MAEMD_1h: 1.4895
# Epoch 47/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3548 - mse: 0.0054 - mae: 0.0531 - MAEMD_1h: 1.3548 - val_loss: 1.5618 - val_mse: 0.0073 - val_mae: 0.0647 - val_MAEMD_1h: 1.5632
# Epoch 48/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3396 - mse: 0.0053 - mae: 0.0529 - MAEMD_1h: 1.3396 - val_loss: 1.4770 - val_mse: 0.0060 - val_mae: 0.0570 - val_MAEMD_1h: 1.4783
# Epoch 49/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3444 - mse: 0.0053 - mae: 0.0528 - MAEMD_1h: 1.3444 - val_loss: 1.4853 - val_mse: 0.0063 - val_mae: 0.0593 - val_MAEMD_1h: 1.4865
# Epoch 50/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3267 - mse: 0.0052 - mae: 0.0523 - MAEMD_1h: 1.3267 - val_loss: 1.5098 - val_mse: 0.0067 - val_mae: 0.0611 - val_MAEMD_1h: 1.5113
# Epoch 51/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3282 - mse: 0.0052 - mae: 0.0524 - MAEMD_1h: 1.3283 - val_loss: 1.4926 - val_mse: 0.0064 - val_mae: 0.0595 - val_MAEMD_1h: 1.4941
# Epoch 52/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3312 - mse: 0.0053 - mae: 0.0525 - MAEMD_1h: 1.3312 - val_loss: 1.5010 - val_mse: 0.0066 - val_mae: 0.0607 - val_MAEMD_1h: 1.5024
# Epoch 53/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3226 - mse: 0.0052 - mae: 0.0522 - MAEMD_1h: 1.3226 - val_loss: 1.5285 - val_mse: 0.0069 - val_mae: 0.0624 - val_MAEMD_1h: 1.5298
# Epoch 54/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3042 - mse: 0.0051 - mae: 0.0516 - MAEMD_1h: 1.3041 - val_loss: 1.4645 - val_mse: 0.0061 - val_mae: 0.0579 - val_MAEMD_1h: 1.4659
# Epoch 55/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3038 - mse: 0.0051 - mae: 0.0516 - MAEMD_1h: 1.3038 - val_loss: 1.4884 - val_mse: 0.0065 - val_mae: 0.0599 - val_MAEMD_1h: 1.4894
# Epoch 56/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3247 - mse: 0.0052 - mae: 0.0523 - MAEMD_1h: 1.3248 - val_loss: 1.4754 - val_mse: 0.0063 - val_mae: 0.0592 - val_MAEMD_1h: 1.4767
# Epoch 57/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.3159 - mse: 0.0052 - mae: 0.0518 - MAEMD_1h: 1.3159 - val_loss: 1.5224 - val_mse: 0.0069 - val_mae: 0.0623 - val_MAEMD_1h: 1.5237
# Epoch 58/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 1.3088 - mse: 0.0052 - mae: 0.0519 - MAEMD_1h: 1.3088 - val_loss: 1.4826 - val_mse: 0.0064 - val_mae: 0.0593 - val_MAEMD_1h: 1.4841
# Epoch 59/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 1.3162 - mse: 0.0052 - mae: 0.0520 - MAEMD_1h: 1.3163 - val_loss: 1.5495 - val_mse: 0.0073 - val_mae: 0.0645 - val_MAEMD_1h: 1.5507
# Epoch 60/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 1.2986 - mse: 0.0051 - mae: 0.0514 - MAEMD_1h: 1.2986 - val_loss: 1.5130 - val_mse: 0.0068 - val_mae: 0.0620 - val_MAEMD_1h: 1.5142
# Epoch 61/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 1.3262 - mse: 0.0052 - mae: 0.0523 - MAEMD_1h: 1.3261 - val_loss: 1.6294 - val_mse: 0.0080 - val_mae: 0.0684 - val_MAEMD_1h: 1.6306
# Epoch 62/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 1.3249 - mse: 0.0052 - mae: 0.0523 - MAEMD_1h: 1.3248 - val_loss: 1.5411 - val_mse: 0.0071 - val_mae: 0.0636 - val_MAEMD_1h: 1.5422
# Epoch 63/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 1.2970 - mse: 0.0051 - mae: 0.0513 - MAEMD_1h: 1.2970 - val_loss: 1.5453 - val_mse: 0.0072 - val_mae: 0.0639 - val_MAEMD_1h: 1.5464
# Epoch 64/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 1.2837 - mse: 0.0050 - mae: 0.0509 - MAEMD_1h: 1.2837 - val_loss: 1.5614 - val_mse: 0.0073 - val_mae: 0.0645 - val_MAEMD_1h: 1.5623
# Wall time: 7min

# %% [markdown]
# ### Saving Basic Model Training Results

# %%
model.save('Basic Ramp Model Final_fh1.h5')

# %%
gc.collect()
# Out:
# 4592

# %%
loss_history = hist.history['loss']
valloss_history = hist.history['val_loss']

# %% [markdown]
# ## Basic Model Test Results

# %%
batch_size = b_size
testPredict = model.predict(teX, batch_size=batch_size)

# %%
def npMAEMS(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true))*100
def npMAEMD(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true-np.mean(y_true)))*100
def npMSE(y_true, y_pred):
    return np.mean(np.square(-y_true+y_pred))
def npMAE(y_true, y_pred):
    return np.mean(abs(-y_true+y_pred))

# %%
tePredict = testPredict.reshape(-1)
testY = teY.reshape(-1)
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMS == ', npMAEMD(testY, tePredict))
# Out:
# Error Test Score > MSE ==  0.005699526047145536  MAE ==  0.05748823252481075  MAEMS ==  0.08653558589825623

# %% [markdown]
# ## Wind Ramp Rate FFEL Model

# %%
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=1/6, shuffle=False)
trY = trY.reshape(-1,output_timesteps)
vaY = vaY.reshape(-1,output_timesteps)

# %%
trainPredict = model.predict(trX, batch_size=batch_size)
validPredict = model.predict(vaX, batch_size=batch_size)

# %%
e_tr = trainPredict - trY
e_va = validPredict - vaY
errors = np.vstack([e_tr, e_va])
prediction = np.vstack([trainPredict, validPredict])
print(errors.shape)
print(prediction.shape)
# Out:
# (31532, 1)
# (31532, 1)

# %%
norm_df2 = pd.DataFrame(norm_df).iloc[:prediction.shape[0], :]
norm_df2.columns = ['Normalized Ramp']
norm_df2.head()
# Out:
#    Normalized Ramp
# 0         0.620197
# 1         0.544580
# 2         0.570751
# 3         0.599594
# 4         0.495246

# %%
Prindex = ['Prediction1']
Erindex = ['Error1']

pr_df = pd.DataFrame(prediction, columns=Prindex)
pr_df
# Out:
#        Prediction1
# 0         0.514616
# 1         0.514230
# 2         0.538362
# 3         0.535952
# 4         0.507150
# ...            ...
# 31527     0.651483
# 31528     0.682623
# 31529     0.762604
# 31530     0.697734
# 31531     0.770028
#
# [31532 rows x 1 columns]

# %%
er_df = pd.DataFrame(errors, columns=Erindex)
er_df
# Out:
#          Error1
# 0      0.029950
# 1     -0.073559
# 2      0.045344
# 3      0.094940
# 4      0.055225
# ...         ...
# 31527  0.023180
# 31528  0.034338
# 31529  0.103929
# 31530  0.027710
# 31531  0.087455
#
# [31532 rows x 1 columns]

# %%
norm_df2 = pd.concat([norm_df2, pr_df, er_df],axis=1)
norm_df2.head()
# Out:
#    Normalized Ramp  Prediction1    Error1
# 0         0.620197     0.514616  0.029950
# 1         0.544580     0.514230 -0.073559
# 2         0.570751     0.538362  0.045344
# 3         0.599594     0.535952  0.094940
# 4         0.495246     0.507150  0.055225

# %%
norm_df22 = pd.DataFrame(norm_df).iloc[prediction.shape[0]+timesteps:, :]
norm_df22.columns = ['Normalized Wind']
npnorm22 = np.array(norm_df22)

# %%
pr_df = pd.DataFrame(tePredict.reshape(-1,1))
pr_df
# Out:
#              0
# 0     0.756552
# 1     0.625011
# 2     0.535332
# 3     0.507461
# 4     0.543504
# ...        ...
# 3499  0.550286
# 3500  0.533430
# 3501  0.721213
# 3502  0.712027
# 3503  0.780394
#
# [3504 rows x 1 columns]

# %%
teY = testY.reshape(-1,1)
e_te = testPredict-teY
er_df = pd.DataFrame(e_te, columns=Erindex)
er_df
# Out:
#         Error1
# 0     0.152307
# 1     0.144811
# 2     0.194523
# 3     0.214208
# 4     0.108223
# ...        ...
# 3499 -0.030885
# 3500 -0.047428
# 3501 -0.053429
# 3502 -0.023485
# 3503  0.178801
#
# [3504 rows x 1 columns]

# %%
prnorm = np.array(pr_df)
ernorm =np.array(er_df)
print(ernorm.shape)
# Out:
# (3504, 1)

# %%
etedat = np.concatenate((npnorm22[:prnorm.shape[0],:], prnorm, ernorm), axis=1)
#etedat[169:171,:]

# %%
eteX, eteY = create_dataset(etedat, timesteps, 1, 0)
eteY.shape
# Out:
# (3478, 1, 3)

# %%
eteY = eteY[:,:,-1:].reshape(-1,1)

# %%
norm_df2 = np.array(norm_df2)
Xe, Ye = create_dataset(norm_df2, timesteps, 1, 0)
Ye.shape
# Out:
# (31506, 1, 3)

# %%
Ye = Ye[:,:,-1:].reshape(-1, 1)
print(Xe.shape)
print(Ye.shape)
# Out:
# (31506, 24, 3)
# (31506, 1)

# %%
trXe, vaXe, trYe, vaYe = train_test_split(Xe, Ye, test_size=0.3, shuffle=False)

# %%
gc.collect()
# Out:
# 6278

# %%
idx = np.arange(Xe.shape[0])
np.random.shuffle(idx)
Xe = Xe[idx]
Ye = Ye[idx]

# %%
eteX.shape, eteY.shape, Xe.shape, Ye.shape
# Out:
# ((3478, 24, 3), (3478, 1), (31506, 24, 3), (31506, 1))

# %%
def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))*10+K.mean(K.abs(y_pred - y_true))

# %%
num_features = Xe.shape[2]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1.2
    beta = 1
    hfilters = 256
    hkernel_size1 = 2
    hkernel_size2 = 4
    visible1e = Input(shape=(timesteps, num_features))
   
    per1e = Permute((2,1))(visible1e)
    den1ae = Dense(timesteps, activation='tanh')(per1e)
    den1be = Dense(timesteps, activation='sigmoid')(per1e)
    den1e = Multiply()([den1ae, den1be])
    per2e = Permute((2,1), name='attention_vec')(den1e)
    mul1e = Multiply()([visible1e, per2e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res01ae = Add()([visible1e, d1e])   # (100, 25) (100, 25)
    res01be = Subtract()([visible1e, d1e])

    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01ae)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    
    d1e = Multiply()([d1ae, d1be])
    res02ae = Add()([res01ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01be) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res02be = Subtract()([res01be, d2e])   # (100, 25) (100, 25) 
    res02e = Concatenate()([res02ae, res02be, res01ae, res01be])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res03ae = Add()([res02ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res03be = Subtract()([res02be, d2e])   # (100, 25) (100, 25)
    res03e = Concatenate()([res03ae, res03be, res02e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    res04ae = Add()([res03ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res04be = Subtract()([res02be, d2e])   # (100, 25) (100, 25)
    res04e = Concatenate()([res04ae, res04be, res03e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res05ae = Add()([res04ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res05be = Subtract()([res04be, d2e])   # (100, 25) (100, 25)
    res05e = Concatenate()([res05ae, res05be, res04e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])

    res06ae = Add()([res05ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])

    res06be = Subtract()([res05be, d2e])   # (100, 25) (100, 25)
    res06e = Concatenate()([res05ae, res05be])
    
    res10e = Concatenate()([res02e, res03e, res04e, res05e, res06e])   # 
    
    #print('res10 :', res10.shape)  # (None, 24, 11) 
    
    oute = Conv1D(timesteps*5, 1, padding='same', activation=PReLU())(res10e)   # 256, 11X10=110
    oute = Dropout(0.2)(oute)   #SpatialDropout1D
    
    oute = Conv1D(timesteps*3, 1, padding='same', activation=PReLU())(oute) # 512,  110X5=550
    oute = Dropout(0.2)(oute)
    
    oute = GlobalAveragePooling1D()(oute) # pool_size=2, strides=1
    
    oute = Dense(1)(oute) 
    modele = Model(inputs=[visible1e], outputs=[oute])
    
    print(modele.summary())
    
    modele.compile(loss=mse_mae, optimizer='adam', metrics=['mse','mae','mape'])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = 168
    epochs = 1000

    history_e = LossHistory()
    history_e.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 24, 3)]      0
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 3, 24)        0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 3, 24)        600         permute_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 3, 24)        600         permute_2[0][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 3, 24)        0           dense_5[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 24, 3)        0           multiply_24[0][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 24, 3)        0           input_2[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 24, 256)      1792        multiply_25[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 24, 256)      0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 24, 256)      0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 24, 256)      0           activation_40[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 24, 3)        3075        multiply_26[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 24, 3)        0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 24, 3)        0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 24, 3)        0           activation_42[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 24, 3)        0           input_2[0][0]
#                                                                  multiply_27[0][0]
# __________________________________________________________________________________________________
# subtract_6 (Subtract)           (None, 24, 3)        0           input_2[0][0]
#                                                                  multiply_27[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 24, 256)      1792        add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 24, 256)      1792        subtract_6[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 24, 256)      0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 24, 256)      0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 24, 256)      0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 24, 256)      0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 24, 256)      0           activation_44[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 24, 256)      0           activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 24, 3)        3075        multiply_28[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 24, 3)        3075        multiply_30[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 24, 3)        0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 24, 3)        0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 24, 3)        0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 24, 3)        0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 24, 3)        0           activation_46[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 24, 3)        0           activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 24, 3)        0           add_6[0][0]
#                                                                  multiply_29[0][0]
# __________________________________________________________________________________________________
# subtract_7 (Subtract)           (None, 24, 3)        0           subtract_6[0][0]
#                                                                  multiply_31[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 24, 12)       0           add_7[0][0]
#                                                                  subtract_7[0][0]
#                                                                  add_6[0][0]
#                                                                  subtract_6[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 24, 256)      6400        concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 24, 256)      6400        concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 24, 256)      0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 24, 256)      0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 24, 256)      0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 24, 256)      0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 24, 256)      0           activation_52[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 24, 256)      0           activation_56[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 24, 3)        3075        multiply_32[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 24, 3)        3075        multiply_34[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 24, 3)        0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 24, 3)        0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 24, 3)        0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 24, 3)        0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 24, 3)        0           activation_54[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 24, 3)        0           activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 24, 3)        0           add_7[0][0]
#                                                                  multiply_33[0][0]
# __________________________________________________________________________________________________
# subtract_8 (Subtract)           (None, 24, 3)        0           subtract_7[0][0]
#                                                                  multiply_35[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 24, 18)       0           add_8[0][0]
#                                                                  subtract_8[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 24, 256)      9472        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 24, 256)      9472        concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 24, 256)      0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 24, 256)      0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 24, 256)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 24, 256)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 24, 256)      0           activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 24, 256)      0           activation_64[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 24, 3)        3075        multiply_36[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 24, 3)        3075        multiply_38[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 24, 3)        0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 24, 3)        0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 24, 3)        0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 24, 3)        0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 24, 3)        0           activation_62[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 24, 3)        0           activation_66[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 24, 3)        0           add_8[0][0]
#                                                                  multiply_37[0][0]
# __________________________________________________________________________________________________
# subtract_9 (Subtract)           (None, 24, 3)        0           subtract_7[0][0]
#                                                                  multiply_39[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 24, 24)       0           add_9[0][0]
#                                                                  subtract_9[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 24, 256)      12544       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 24, 256)      12544       concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 24, 256)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 24, 256)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 24, 256)      0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 24, 256)      0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 24, 256)      0           activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 24, 256)      0           activation_72[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 24, 3)        3075        multiply_40[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 24, 3)        3075        multiply_42[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 24, 3)        0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 24, 3)        0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 24, 3)        0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 24, 3)        0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 24, 3)        0           activation_70[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 24, 3)        0           activation_74[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 24, 3)        0           add_9[0][0]
#                                                                  multiply_41[0][0]
# __________________________________________________________________________________________________
# subtract_10 (Subtract)          (None, 24, 3)        0           subtract_9[0][0]
#                                                                  multiply_43[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 24, 30)       0           add_10[0][0]
#                                                                  subtract_10[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 24, 6)        0           add_10[0][0]
#                                                                  subtract_10[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 24, 90)       0           concatenate_5[0][0]
#                                                                  concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  concatenate_8[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 24, 120)      13800       concatenate_10[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 24, 120)      0           conv1d_45[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 24, 72)       10440       dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 72)       0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 72)           0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 1)            73          global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 115,396
# Trainable params: 115,396
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 2538

# %%
# %%time
    histe = modele.fit(trXe, trYe, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(vaXe, vaYe), callbacks=[history_e, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 221/221 [==============================] - 10s 31ms/step - loss: 0.1375 - mse: 0.0076 - mae: 0.0616 - mape: 2320.2910 - val_loss: 0.0828 - val_mse: 0.0037 - val_mae: 0.0457 - val_mape: 571.3116
# Epoch 2/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.1006 - mse: 0.0049 - mae: 0.0514 - mape: 1327.0707 - val_loss: 0.0711 - val_mse: 0.0031 - val_mae: 0.0405 - val_mape: 301.8257
# Epoch 3/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0963 - mse: 0.0047 - mae: 0.0497 - mape: 928.9177 - val_loss: 0.0718 - val_mse: 0.0031 - val_mae: 0.0409 - val_mape: 376.8763
# Epoch 4/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0951 - mse: 0.0046 - mae: 0.0493 - mape: 1081.4147 - val_loss: 0.0707 - val_mse: 0.0030 - val_mae: 0.0405 - val_mape: 364.0834
# Epoch 5/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0946 - mse: 0.0046 - mae: 0.0491 - mape: 1143.9896 - val_loss: 0.0704 - val_mse: 0.0030 - val_mae: 0.0403 - val_mape: 344.0301
# Epoch 6/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0940 - mse: 0.0045 - mae: 0.0488 - mape: 1335.6193 - val_loss: 0.0692 - val_mse: 0.0029 - val_mae: 0.0398 - val_mape: 326.4053
# Epoch 7/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0934 - mse: 0.0045 - mae: 0.0486 - mape: 1015.7723 - val_loss: 0.0697 - val_mse: 0.0030 - val_mae: 0.0400 - val_mape: 312.7516
# Epoch 8/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0932 - mse: 0.0045 - mae: 0.0485 - mape: 954.3604 - val_loss: 0.0696 - val_mse: 0.0030 - val_mae: 0.0400 - val_mape: 296.4109
# Epoch 9/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0929 - mse: 0.0045 - mae: 0.0484 - mape: 1221.5833 - val_loss: 0.0697 - val_mse: 0.0030 - val_mae: 0.0401 - val_mape: 336.0256
# Epoch 10/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0928 - mse: 0.0044 - mae: 0.0484 - mape: 1201.2142 - val_loss: 0.0712 - val_mse: 0.0030 - val_mae: 0.0409 - val_mape: 394.3977
# Epoch 11/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0925 - mse: 0.0044 - mae: 0.0483 - mape: 1363.5486 - val_loss: 0.0703 - val_mse: 0.0030 - val_mae: 0.0405 - val_mape: 369.4972
# Epoch 12/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0925 - mse: 0.0044 - mae: 0.0483 - mape: 1148.2400 - val_loss: 0.0697 - val_mse: 0.0030 - val_mae: 0.0402 - val_mape: 371.0666
# Epoch 13/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0922 - mse: 0.0044 - mae: 0.0482 - mape: 1103.2894 - val_loss: 0.0706 - val_mse: 0.0030 - val_mae: 0.0407 - val_mape: 401.4870
# Epoch 14/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0923 - mse: 0.0044 - mae: 0.0482 - mape: 1267.2566 - val_loss: 0.0694 - val_mse: 0.0029 - val_mae: 0.0400 - val_mape: 359.8784
# Epoch 15/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0920 - mse: 0.0044 - mae: 0.0481 - mape: 1256.3776 - val_loss: 0.0699 - val_mse: 0.0030 - val_mae: 0.0403 - val_mape: 370.7072
# Epoch 16/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0919 - mse: 0.0044 - mae: 0.0481 - mape: 1035.2572 - val_loss: 0.0690 - val_mse: 0.0029 - val_mae: 0.0397 - val_mape: 322.5157
# Epoch 17/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0918 - mse: 0.0044 - mae: 0.0480 - mape: 1255.5159 - val_loss: 0.0684 - val_mse: 0.0029 - val_mae: 0.0394 - val_mape: 313.6283
# Epoch 18/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0918 - mse: 0.0044 - mae: 0.0481 - mape: 1314.3971 - val_loss: 0.0689 - val_mse: 0.0029 - val_mae: 0.0398 - val_mape: 358.0842
# Epoch 19/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0914 - mse: 0.0044 - mae: 0.0479 - mape: 1099.6229 - val_loss: 0.0681 - val_mse: 0.0029 - val_mae: 0.0393 - val_mape: 313.7093
# Epoch 20/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0912 - mse: 0.0043 - mae: 0.0478 - mape: 1330.7526 - val_loss: 0.0685 - val_mse: 0.0029 - val_mae: 0.0396 - val_mape: 348.9426
# Epoch 21/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0911 - mse: 0.0043 - mae: 0.0478 - mape: 1156.6365 - val_loss: 0.0685 - val_mse: 0.0029 - val_mae: 0.0396 - val_mape: 325.3376
# Epoch 22/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0910 - mse: 0.0043 - mae: 0.0478 - mape: 999.5352 - val_loss: 0.0682 - val_mse: 0.0029 - val_mae: 0.0395 - val_mape: 318.5868
# Epoch 23/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0907 - mse: 0.0043 - mae: 0.0477 - mape: 901.7752 - val_loss: 0.0686 - val_mse: 0.0029 - val_mae: 0.0397 - val_mape: 340.4653
# Epoch 24/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0905 - mse: 0.0043 - mae: 0.0476 - mape: 1222.1377 - val_loss: 0.0686 - val_mse: 0.0029 - val_mae: 0.0397 - val_mape: 344.8086
# Epoch 25/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0907 - mse: 0.0043 - mae: 0.0476 - mape: 1022.4539 - val_loss: 0.0687 - val_mse: 0.0029 - val_mae: 0.0397 - val_mape: 359.9702
# Epoch 26/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0902 - mse: 0.0043 - mae: 0.0475 - mape: 1262.9526 - val_loss: 0.0682 - val_mse: 0.0029 - val_mae: 0.0395 - val_mape: 349.7648
# Epoch 27/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0903 - mse: 0.0043 - mae: 0.0475 - mape: 967.0129 - val_loss: 0.0680 - val_mse: 0.0029 - val_mae: 0.0394 - val_mape: 344.9590
# Epoch 28/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0903 - mse: 0.0043 - mae: 0.0475 - mape: 1202.5098 - val_loss: 0.0680 - val_mse: 0.0029 - val_mae: 0.0394 - val_mape: 332.5429
# Epoch 29/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0900 - mse: 0.0043 - mae: 0.0474 - mape: 1126.7490 - val_loss: 0.0677 - val_mse: 0.0028 - val_mae: 0.0393 - val_mape: 335.5020
# Epoch 30/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0900 - mse: 0.0043 - mae: 0.0474 - mape: 1068.2239 - val_loss: 0.0681 - val_mse: 0.0029 - val_mae: 0.0395 - val_mape: 358.7499
# Epoch 31/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0897 - mse: 0.0042 - mae: 0.0473 - mape: 1078.1362 - val_loss: 0.0677 - val_mse: 0.0029 - val_mae: 0.0392 - val_mape: 296.9027
# Epoch 32/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0896 - mse: 0.0042 - mae: 0.0473 - mape: 1361.0892 - val_loss: 0.0680 - val_mse: 0.0029 - val_mae: 0.0392 - val_mape: 276.2462
# Epoch 33/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0893 - mse: 0.0042 - mae: 0.0472 - mape: 964.0703 - val_loss: 0.0681 - val_mse: 0.0029 - val_mae: 0.0394 - val_mape: 306.1017
# Epoch 34/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0897 - mse: 0.0042 - mae: 0.0473 - mape: 1155.9612 - val_loss: 0.0680 - val_mse: 0.0029 - val_mae: 0.0393 - val_mape: 294.4243
# Epoch 35/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0891 - mse: 0.0042 - mae: 0.0471 - mape: 1108.0598 - val_loss: 0.0681 - val_mse: 0.0029 - val_mae: 0.0394 - val_mape: 340.9992
# Epoch 36/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0889 - mse: 0.0042 - mae: 0.0470 - mape: 1084.1991 - val_loss: 0.0677 - val_mse: 0.0028 - val_mae: 0.0392 - val_mape: 312.5219
# Epoch 37/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0888 - mse: 0.0042 - mae: 0.0470 - mape: 1149.1064 - val_loss: 0.0681 - val_mse: 0.0029 - val_mae: 0.0394 - val_mape: 317.0495
# Epoch 38/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0885 - mse: 0.0042 - mae: 0.0468 - mape: 1243.1482 - val_loss: 0.0684 - val_mse: 0.0029 - val_mae: 0.0396 - val_mape: 340.5832
# Epoch 39/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0885 - mse: 0.0042 - mae: 0.0469 - mape: 1107.1656 - val_loss: 0.0683 - val_mse: 0.0029 - val_mae: 0.0395 - val_mape: 334.7613
# Epoch 40/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0889 - mse: 0.0042 - mae: 0.0470 - mape: 1309.6379 - val_loss: 0.0681 - val_mse: 0.0029 - val_mae: 0.0394 - val_mape: 318.4416
# Epoch 41/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0879 - mse: 0.0041 - mae: 0.0467 - mape: 1193.8893 - val_loss: 0.0691 - val_mse: 0.0029 - val_mae: 0.0399 - val_mape: 351.6764
# Epoch 42/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0878 - mse: 0.0041 - mae: 0.0466 - mape: 753.2300 - val_loss: 0.0684 - val_mse: 0.0029 - val_mae: 0.0396 - val_mape: 338.9291
# Epoch 43/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0877 - mse: 0.0041 - mae: 0.0466 - mape: 1219.6882 - val_loss: 0.0684 - val_mse: 0.0029 - val_mae: 0.0395 - val_mape: 322.0937
# Epoch 44/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 0.0877 - mse: 0.0041 - mae: 0.0466 - mape: 1045.1431 - val_loss: 0.0686 - val_mse: 0.0029 - val_mae: 0.0396 - val_mape: 330.4550
# Epoch 45/1000
# 221/221 [==============================] - 6s 29ms/step - loss: 0.0877 - mse: 0.0041 - mae: 0.0467 - mape: 1127.7927 - val_loss: 0.0684 - val_mse: 0.0029 - val_mae: 0.0395 - val_mape: 316.7895
# Epoch 46/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0868 - mse: 0.0040 - mae: 0.0463 - mape: 1322.3301 - val_loss: 0.0686 - val_mse: 0.0029 - val_mae: 0.0397 - val_mape: 340.8666

# %% [markdown]
# ### Saving FFEL Model Training Results

# %%
eloss_history = histe.history['loss']
valeloss_history = histe.history['val_loss']

# %%
modele.save('Error Learning Ramp Model_fh1.h5')

# %%
gc.collect()
# Out:
# 4570

# %% [markdown]
# ## FFEL Model Test Results

# %%
trainePredict = modele.predict(Xe, batch_size=batch_size)
etePredict = modele.predict(eteX, batch_size=batch_size)

# %%
trePredict = trainePredict.reshape([-1])
trainYe = Ye.reshape([-1])

print('Error Training Score > MSE == ', (np.mean(np.square(trainYe-trePredict))), ' MAE == ', mean_absolute_error(trainYe,trePredict), ' RMSE == ', np.sqrt(np.mean(np.square(trainYe-trePredict))))
# Out:
# Error Training Score > MSE ==  0.003746499951436067  MAE ==  0.044665371524871426  RMSE ==  0.06120865912136997

# %%
etestPredict = etePredict.reshape([-1])
testYe = eteY.reshape([-1])

print('Error Training Score > MSE == ', (np.mean(np.square(testYe-etestPredict))), ' MAE == ', mean_absolute_error(testYe,etestPredict), ' RMSE == ', np.sqrt(np.mean(np.square(testYe-etestPredict))))
# Out:
# Error Training Score > MSE ==  0.003199156086938112  MAE ==  0.04227892631098167  RMSE ==  0.05656108279495816

# %% [markdown]
# ## Final Prediction Results

# %%
testPredict = tePredict.reshape(-1,1)
addtestPredict = -etePredict + testPredict[timesteps:-2,:]
print(addtestPredict.shape)
# Out:
# (3478, 1)

# %%
print('Error Test Score > MSE == ', (np.mean(np.square(teY[timesteps:-2,:]-testPredict[timesteps:-2,:]))), ' MAE == ', mean_absolute_error(teY[timesteps:-2,:], testPredict[timesteps:-2,:]), 'MAPE == ', mean_absolute_percentage_error(teY[timesteps:-2,:], testPredict[timesteps:-2,:]))
print('Error Test Score > MSE == ', (np.mean(np.square(teY[timesteps:-2,:]-addtestPredict))), ' MAE == ', mean_absolute_error(teY[timesteps:-2,:], addtestPredict), 'MAPE == ', mean_absolute_percentage_error(teY[timesteps:-2,:], addtestPredict))
# Out:
# Error Test Score > MSE ==  0.005630744597240438  MAE ==  0.05713347348801163 MAPE ==  12.796281462748588
# Error Test Score > MSE ==  0.0031991560805802325  MAE ==  0.042278926081096554 MAPE ==  8.801453999046622
