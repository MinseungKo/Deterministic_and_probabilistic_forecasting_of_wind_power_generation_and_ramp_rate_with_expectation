# %%
import tensorflow as tf

import pandas as pd
import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
#from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply, Subtract
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout, SpatialDropout1D
from scipy import signal
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pylab as plt
import matplotlib.dates as mdates
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc
from keijzer import *
from tensorflow import keras
from keras.models import Model
from keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply, Embedding, Layer, Reshape
from keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
#from keras.ops import convert_to_tensor, convert_to_numpy
#from keras.utils import plot_model
from keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))



def root_squared_mean_error(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))+K.mean(K.abs(y_pred - y_true))

from keras.layers.advanced_activations import PReLU

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
import scipy as sc

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '0' # 여러개 사용시 '0,1,2' 식으로 하나의 문자열에 입력
gpus = tf.config.experimental.list_physical_devices('GPU') # 호스트 러나임에 표시되는 GPU 장치 목록 반환

if gpus: # 반환된 GPU 장치 목록이 있다면
    try: # 해당 장치에 대한 메모리 증가 활성화 여부 설정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e: # try문 실패시에 에러문구 출력
        print(e)

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Import Data & Preprocessing

# %%
data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2020.csv'
data_source1 = pd.read_csv(data_path)
dat_source1 = pd.DataFrame(data_source1)
#dat_source1 = dat_source1.iloc[:-3,:]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2021.csv'
data_source2 = pd.read_csv(data_path)
dat_source2 = pd.DataFrame(data_source2)
dat_source2 = dat_source2.iloc[:8761,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2022.csv'
data_source3 = pd.read_csv(data_path)
dat_source3 = pd.DataFrame(data_source3)
dat_source3 = dat_source3.iloc[:8760,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2023.csv'
data_source4 = pd.read_csv(data_path)
dat_source4 = pd.DataFrame(data_source4)
dat_source4 = dat_source4.iloc[:8760,:9]

dat_arr1 = np.array(dat_source1)
dat_arr2 = np.array(dat_source2)
dat_arr3 = np.array(dat_source3)
dat_arr4 = np.array(dat_source4)

dat_arr = np.concatenate([dat_arr1, dat_arr2, dat_arr3, dat_arr4],axis=0)
dat_arr.shape # 8784, 8761, 8760, 8760

dat_source = pd.DataFrame(dat_arr, columns=['Time-Date stamp','Date','ERCOT Load','Total Wind Output','Total Wind Installed','Wind Output, % of Load','Wind Output, % of Installed','1-hr MW change','1-hr % change'])
dat_source
# Out:
#            Time-Date stamp    Date ERCOT Load Total Wind Output  \
# 0      01-01-2020 00:00:00  Jan-01      36823             12335
# 1      01-01-2020 01:00:00  Jan-01      36511             13300
# 2      01-01-2020 02:00:00  Jan-01      36022             13586
# 3      01-01-2020 03:00:00  Jan-01      35790             14107
# 4      01-01-2020 04:00:00  Jan-01      35642             14887
# ...                    ...     ...        ...               ...
# 35060  12-31-2023 20:00:00  Dec-31      44887             17161
# 35061  12-31-2023 21:00:00  Dec-31      44013             18301
# 35062  12-31-2023 22:00:00  Dec-31      43280             18607
# 35063  12-31-2023 23:00:00  Dec-31      42319             17866
# 35064  01-01-2024 00:00:00  Jan-01      41682             15869
#
#       Total Wind Installed Wind Output, % of Load Wind Output, % of Installed  \
# 0                    27040                   33.5                      45.617
# 1                    27040                   36.4                      49.187
# 2                    27040                   37.7                      50.245
# 3                    27040                   39.4                      52.171
# 4                    27040                   41.8                      55.055
# ...                    ...                    ...                         ...
# 35060                38631                  38.23                       44.42
# 35061                38631                  41.58                       47.37
# 35062                38631                  42.99                       48.17
# 35063                38631                  42.22                       46.25
# 35064                38631                  38.07                       41.08
#
#       1-hr MW change 1-hr % change
# 0                NaN           NaN
# 1              965.4         7.826
# 2              286.2         2.152
# 3              520.9         3.834
# 4              779.6         5.527
# ...              ...           ...
# 35060           2858         19.99
# 35061           1139          6.64
# 35062            307          1.67
# 35063           -741         -3.98
# 35064          -1996        -11.17
#
# [35065 rows x 9 columns]

# %% [markdown]
# ### Dividing by Installed Capacity & Preprocessing

# %%
dat = pd.DataFrame()
dat['MW % change'] = np.array(dat_source.iloc[1:,3], dtype=float)-np.array(dat_source.iloc[0:-1,3], dtype=float)
dat['MW % change'] = np.divide(np.array(dat['MW % change']),np.array(dat_source.iloc[1:,4]))*100
dat['Total Wind Output'] = np.divide(np.array(dat_source.iloc[1:,3]), np.array(dat_source.iloc[1:,4]))

dat
# Out:
#       MW % change Total Wind Output
# 0         3.56879          0.491864
# 1         1.05769          0.502441
# 2         1.92678          0.521709
# 3         2.88462          0.550555
# 4       -0.580621          0.544749
# ...           ...               ...
# 35059      7.3982          0.444229
# 35060       2.951          0.473739
# 35061     0.79211           0.48166
# 35062    -1.91815          0.462478
# 35063    -5.16942          0.410784
#
# [35064 rows x 2 columns]

# %%
ramp_ratio = 20
load_ratio = 10
year_arr = np.concatenate([np.ones(8784)*2020, np.ones(8760)*2021, np.ones(8760)*2022, np.ones(8760)*2023])
year_df = pd.DataFrame(year_arr, columns=['Year'], dtype=int)
wind_df = pd.concat([year_df, dat], axis=1)
wind_df
# Out:
#        Year MW % change Total Wind Output
# 0      2020     3.56879          0.491864
# 1      2020     1.05769          0.502441
# 2      2020     1.92678          0.521709
# 3      2020     2.88462          0.550555
# 4      2020   -0.580621          0.544749
# ...     ...         ...               ...
# 35059  2023      7.3982          0.444229
# 35060  2023       2.951          0.473739
# 35061  2023     0.79211           0.48166
# 35062  2023    -1.91815          0.462478
# 35063  2023    -5.16942          0.410784
#
# [35064 rows x 3 columns]

# %%
wind_df = wind_df.reset_index(drop=True)

std_scaler = sklearn.preprocessing.MinMaxScaler()
std_scaler_load = sklearn.preprocessing.MinMaxScaler()
std_scaler_ramp = sklearn.preprocessing.MinMaxScaler()

wind_df[['Total Wind Output']] = std_scaler.fit_transform(wind_df[['Total Wind Output']])
wind_df[['MW % change']] = std_scaler_ramp.fit_transform(wind_df[['MW % change']])
wind_df = wind_df.iloc[:-1,:]
wind_df
# Out:
#        Year  MW % change  Total Wind Output
# 0      2020     0.620197           0.644724
# 1      2020     0.544580           0.658617
# 2      2020     0.570751           0.683924
# 3      2020     0.599594           0.721813
# 4      2020     0.495246           0.714187
# ...     ...          ...                ...
# 35058  2023     0.774643           0.484984
# 35059  2023     0.735512           0.582157
# 35060  2023     0.601593           0.620917
# 35061  2023     0.536583           0.631322
# 35062  2023     0.454969           0.606127
#
# [35063 rows x 3 columns]

# %%
ramp_df = pd.DataFrame(wind_df)
ramp_df.columns=['Year', 'Wind Change', 'Wind Output']
ramp_df
# Out:
#        Year  Wind Change  Wind Output
# 0      2020     0.620197     0.644724
# 1      2020     0.544580     0.658617
# 2      2020     0.570751     0.683924
# 3      2020     0.599594     0.721813
# 4      2020     0.495246     0.714187
# ...     ...          ...          ...
# 35058  2023     0.774643     0.484984
# 35059  2023     0.735512     0.582157
# 35060  2023     0.601593     0.620917
# 35061  2023     0.536583     0.631322
# 35062  2023     0.454969     0.606127
#
# [35063 rows x 3 columns]

# %% [markdown]
# ## Wind Generation Forecasting

# %% [markdown]
# ### SVD-based Feature Generation

# %%
def create_dataset(dataset, timesteps, output_timesteps, leadtime):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - leadtime - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps + leadtime):(i+timesteps+output_timesteps+leadtime), :])
    return np.array(dataX), np.array(dataY)

def svdadd(X, start, end, b_size):
    dec_x = X[start:end, :, :]
    U, S, Vh = svd(dec_x.reshape(b_size, -1), full_matrices=True)

    high_sig = np.matmul(np.matmul(U[:,:high_ind], np.diag(S[0:high_ind])), Vh[:high_ind,:])
    low_sig = X[:dec_num, :, :].reshape(b_size,-1)-high_sig

    rec_x = np.zeros((b_size, b_size, high_ind))
    
    for i in range(high_ind):
        rec_x[:,:,i] = np.matmul((U[:,i]*S[i]).reshape(-1,1), Vh[i,:].reshape(1,-1))    
    return rec_x, low_sig

# %%
norm_df = np.array(wind_df.iloc[:,2]).reshape(-1,1)
timesteps = 24
output_timesteps = 1
leadtime = 1
num_features = 1
X, Y = create_dataset(norm_df, timesteps, output_timesteps, leadtime)
b_size = timesteps

# %%
dec_num = timesteps
high_ind = 12

addX = np.zeros((X.shape[0], dec_num, high_ind+1))

for k in range(X.shape[0]//dec_num):
    rec_x, low_sig = svdadd(X, k*dec_num, (k+1)*dec_num, b_size)
    addX[k*dec_num:k*dec_num+dec_num,:, :-1] = rec_x
    addX[k*dec_num:k*dec_num+dec_num,:, -1] = low_sig
    
rec_x, low_sig = svdadd(X, X.shape[0]-dec_num, X.shape[0], b_size)
addX[X.shape[0]-dec_num:X.shape[0], :, :-1] = rec_x
addX[X.shape[0]-dec_num:X.shape[0],:, -1] = low_sig

addX_det = addX[:, :, :-1]
addX_det = np.sum(addX_det, axis=2)
X = np.concatenate([X, addX], axis=2)
num_features = X.shape[2]

# %% [markdown]
# ### Training/Test Set Division & Shuffled Learning

# %%
trvaX, teX, trvaY, teY = train_test_split(X, Y, test_size=0.1, shuffle=False)

idx = np.arange(trvaX.shape[0])
np.random.shuffle(idx)
strvaX = trvaX[idx]
strvaY = trvaY[idx]
strvaY = strvaY.reshape(-1, output_timesteps)

trvaY = trvaY.reshape(-1, output_timesteps)
teY = teY.reshape(-1, output_timesteps)

strX, svaX, strY, svaY = train_test_split(strvaX, strvaY, test_size=0.3, shuffle=False)
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=0.3, shuffle=False)

trvaX.shape, trvaY.shape, teX.shape, teY.shape
# Out:
# ((31532, 24, 14), (31532, 1), (3504, 24, 14), (3504, 1))

# %% [markdown]
# ## Wind Generation Forecasting Basic Model

# %%
def MAEMS(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true))*100

# %%
from keras.layers.advanced_activations import PReLU

# %%
num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1.2
    beta = 1
    hfilters = 256
    hkernel_size1 = 1
    hkernel_size2 = 2
    
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    per1 = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(per1)
    den1b = Dense(timesteps, activation='sigmoid')(per1)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])
    
    ## Series PN DCCNN Blocks 1 ~ 6
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([visible1, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([visible1, d1])

    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])   # (100, 25) (100, 25)
    res03 = Concatenate()([res03a, res03b, res02])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res04a = Add()([res03a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res04b = Subtract()([res02b, d2])   # (100, 25) (100, 25)
    res04 = Concatenate()([res04a, res04b, res03])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res05a = Add()([res04a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res05b = Subtract()([res04b, d2])   # (100, 25) (100, 25)
    res05 = Concatenate()([res05a, res05b, res04])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])

    res06a = Add()([res05a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])

    res06b = Subtract()([res05b, d2])   # (100, 25) (100, 25)
    res06 = Concatenate()([res05a, res05b])
    
    res10 = Concatenate()([res02, res03, res04, res05, res06])   # 
    
    #print('res10 :', res10.shap)  # (None, 24, 11) 
    
    ## Output Block
    out = Conv1D(timesteps*5, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out = Dropout(0.2)(out)   #SpatialDropout1D
    
    out = Conv1D(timesteps*3, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)
    
    out = GlobalAveragePooling1D()(out) # pool_size=2, strides=1
    
    out = Dense(output_timesteps)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 24, 14)]     0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 14, 24)       0           input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 14, 24)       600         permute[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 14, 24)       600         permute[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 14, 24)       0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 24, 14)       0           multiply[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 24, 14)       0           input_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 24, 256)      3840        multiply_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 24, 256)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 24, 256)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 24, 256)      0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 24, 14)       7182        multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 24, 14)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 24, 14)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 24, 14)       0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 24, 14)       0           input_1[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 24, 14)       0           input_1[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 24, 256)      3840        add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 24, 256)      3840        subtract[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 24, 256)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 24, 256)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 24, 256)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 24, 256)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 24, 256)      0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 24, 256)      0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 24, 14)       7182        multiply_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 24, 14)       7182        multiply_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 24, 14)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 24, 14)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 24, 14)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 24, 14)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 24, 14)       0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 24, 14)       0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 24, 14)       0           add[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 24, 14)       0           subtract[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 24, 56)       0           add_1[0][0]
#                                                                  subtract_1[0][0]
#                                                                  add[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 24, 256)      14592       concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 24, 256)      14592       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 24, 256)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 24, 256)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 24, 256)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 24, 256)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 24, 256)      0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 24, 256)      0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 24, 14)       7182        multiply_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 24, 14)       7182        multiply_10[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 24, 14)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 24, 14)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 24, 14)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 24, 14)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 24, 14)       0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 24, 14)       0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 24, 14)       0           add_1[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 24, 14)       0           subtract_1[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 24, 84)       0           add_2[0][0]
#                                                                  subtract_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 24, 256)      21760       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 24, 256)      21760       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 24, 256)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 24, 256)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 24, 256)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 24, 256)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 24, 256)      0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 24, 256)      0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 24, 14)       7182        multiply_12[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 24, 14)       7182        multiply_14[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 24, 14)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 24, 14)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 24, 14)       0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 24, 14)       0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 24, 14)       0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 24, 14)       0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 24, 14)       0           add_2[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 24, 14)       0           subtract_1[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 24, 112)      0           add_3[0][0]
#                                                                  subtract_3[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 24, 256)      28928       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 24, 256)      28928       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 24, 256)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 24, 256)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 24, 256)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 24, 256)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 24, 256)      0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 24, 256)      0           activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 24, 14)       7182        multiply_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 24, 14)       7182        multiply_18[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 24, 14)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 24, 14)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 24, 14)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 24, 14)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 24, 14)       0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 24, 14)       0           activation_34[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 24, 14)       0           add_3[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 24, 14)       0           subtract_3[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 24, 140)      0           add_4[0][0]
#                                                                  subtract_4[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 24, 28)       0           add_4[0][0]
#                                                                  subtract_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 24, 420)      0           concatenate[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 24, 120)      53400       concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 24, 120)      0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 24, 72)       10440       dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 24, 72)       0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 72)           0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            73          global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 271,831
# Trainable params: 271,831
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 1923

# %%
    model.compile(loss=MAEMS, optimizer='adam', metrics=['mse','mae', MAEMS])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    epochs = 1000
    #root_squared_mean_error
    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint

# %%
    # %%time
    b_size = output_timesteps*100
    hist = model.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 221/221 [==============================] - 10s 31ms/step - loss: 2.4380 - mse: 0.0295 - mae: 0.1281 - MAEMS: 2.4376 - val_loss: 2.0390 - val_mse: 0.0087 - val_mae: 0.0763 - val_MAEMS: 2.0381
# Epoch 2/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.6664 - mse: 0.0094 - mae: 0.0767 - MAEMS: 1.6666 - val_loss: 1.3243 - val_mse: 0.0074 - val_mae: 0.0676 - val_MAEMS: 1.3238
# Epoch 3/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.4753 - mse: 0.0067 - mae: 0.0640 - MAEMS: 1.4755 - val_loss: 1.2260 - val_mse: 0.0052 - val_mae: 0.0557 - val_MAEMS: 1.2257
# Epoch 4/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.3749 - mse: 0.0057 - mae: 0.0589 - MAEMS: 1.3750 - val_loss: 1.1307 - val_mse: 0.0040 - val_mae: 0.0480 - val_MAEMS: 1.1302
# Epoch 5/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.2773 - mse: 0.0047 - mae: 0.0538 - MAEMS: 1.2778 - val_loss: 1.0785 - val_mse: 0.0034 - val_mae: 0.0451 - val_MAEMS: 1.0784
# Epoch 6/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.2242 - mse: 0.0043 - mae: 0.0511 - MAEMS: 1.2244 - val_loss: 1.3792 - val_mse: 0.0033 - val_mae: 0.0455 - val_MAEMS: 1.3790
# Epoch 7/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.1698 - mse: 0.0039 - mae: 0.0486 - MAEMS: 1.1697 - val_loss: 1.1779 - val_mse: 0.0028 - val_mae: 0.0407 - val_MAEMS: 1.1777
# Epoch 8/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.1476 - mse: 0.0037 - mae: 0.0477 - MAEMS: 1.1478 - val_loss: 1.0232 - val_mse: 0.0029 - val_mae: 0.0421 - val_MAEMS: 1.0229
# Epoch 9/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.1129 - mse: 0.0035 - mae: 0.0464 - MAEMS: 1.1131 - val_loss: 0.9673 - val_mse: 0.0027 - val_mae: 0.0395 - val_MAEMS: 0.9672
# Epoch 10/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 1.0928 - mse: 0.0034 - mae: 0.0456 - MAEMS: 1.0929 - val_loss: 0.9867 - val_mse: 0.0026 - val_mae: 0.0393 - val_MAEMS: 0.9867
# Epoch 11/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.0772 - mse: 0.0034 - mae: 0.0450 - MAEMS: 1.0773 - val_loss: 1.0251 - val_mse: 0.0032 - val_mae: 0.0438 - val_MAEMS: 1.0251
# Epoch 12/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.0397 - mse: 0.0033 - mae: 0.0441 - MAEMS: 1.0398 - val_loss: 0.9505 - val_mse: 0.0030 - val_mae: 0.0428 - val_MAEMS: 0.9503
# Epoch 13/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.0407 - mse: 0.0032 - mae: 0.0437 - MAEMS: 1.0411 - val_loss: 1.0854 - val_mse: 0.0025 - val_mae: 0.0392 - val_MAEMS: 1.0847
# Epoch 14/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 1.0378 - mse: 0.0031 - mae: 0.0434 - MAEMS: 1.0381 - val_loss: 1.0802 - val_mse: 0.0024 - val_mae: 0.0378 - val_MAEMS: 1.0797
# Epoch 15/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.9979 - mse: 0.0030 - mae: 0.0422 - MAEMS: 0.9980 - val_loss: 1.1528 - val_mse: 0.0024 - val_mae: 0.0387 - val_MAEMS: 1.1525
# Epoch 16/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.9896 - mse: 0.0029 - mae: 0.0420 - MAEMS: 0.9896 - val_loss: 1.1844 - val_mse: 0.0027 - val_mae: 0.0414 - val_MAEMS: 1.1839
# Epoch 17/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.9868 - mse: 0.0030 - mae: 0.0424 - MAEMS: 0.9869 - val_loss: 1.0117 - val_mse: 0.0023 - val_mae: 0.0366 - val_MAEMS: 1.0114
# Epoch 18/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.9764 - mse: 0.0029 - mae: 0.0413 - MAEMS: 0.9764 - val_loss: 0.8959 - val_mse: 0.0021 - val_mae: 0.0344 - val_MAEMS: 0.8957
# Epoch 19/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.9363 - mse: 0.0027 - mae: 0.0400 - MAEMS: 0.9364 - val_loss: 0.9358 - val_mse: 0.0020 - val_mae: 0.0340 - val_MAEMS: 0.9357
# Epoch 20/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.9546 - mse: 0.0028 - mae: 0.0411 - MAEMS: 0.9547 - val_loss: 0.8809 - val_mse: 0.0021 - val_mae: 0.0347 - val_MAEMS: 0.8806
# Epoch 21/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.9463 - mse: 0.0028 - mae: 0.0406 - MAEMS: 0.9464 - val_loss: 0.8899 - val_mse: 0.0021 - val_mae: 0.0343 - val_MAEMS: 0.8896
# Epoch 22/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.9292 - mse: 0.0026 - mae: 0.0396 - MAEMS: 0.9293 - val_loss: 0.8705 - val_mse: 0.0019 - val_mae: 0.0333 - val_MAEMS: 0.8702
# Epoch 23/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.9195 - mse: 0.0026 - mae: 0.0396 - MAEMS: 0.9196 - val_loss: 0.8498 - val_mse: 0.0021 - val_mae: 0.0346 - val_MAEMS: 0.8495
# Epoch 24/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.9277 - mse: 0.0027 - mae: 0.0398 - MAEMS: 0.9280 - val_loss: 1.1677 - val_mse: 0.0023 - val_mae: 0.0376 - val_MAEMS: 1.1669
# Epoch 25/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.9028 - mse: 0.0026 - mae: 0.0388 - MAEMS: 0.9030 - val_loss: 0.9851 - val_mse: 0.0021 - val_mae: 0.0348 - val_MAEMS: 0.9846
# Epoch 26/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.9024 - mse: 0.0026 - mae: 0.0393 - MAEMS: 0.9025 - val_loss: 0.9370 - val_mse: 0.0020 - val_mae: 0.0346 - val_MAEMS: 0.9366
# Epoch 27/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.8891 - mse: 0.0025 - mae: 0.0388 - MAEMS: 0.8894 - val_loss: 0.9021 - val_mse: 0.0020 - val_mae: 0.0339 - val_MAEMS: 0.9018
# Epoch 28/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.8794 - mse: 0.0024 - mae: 0.0379 - MAEMS: 0.8795 - val_loss: 0.9372 - val_mse: 0.0021 - val_mae: 0.0353 - val_MAEMS: 0.9367
# Epoch 29/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.8732 - mse: 0.0023 - mae: 0.0372 - MAEMS: 0.8733 - val_loss: 0.9486 - val_mse: 0.0021 - val_mae: 0.0358 - val_MAEMS: 0.9481
# Epoch 30/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.8611 - mse: 0.0024 - mae: 0.0375 - MAEMS: 0.8611 - val_loss: 0.8974 - val_mse: 0.0019 - val_mae: 0.0331 - val_MAEMS: 0.8972
# Epoch 31/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.8552 - mse: 0.0023 - mae: 0.0369 - MAEMS: 0.8552 - val_loss: 0.8054 - val_mse: 0.0018 - val_mae: 0.0320 - val_MAEMS: 0.8050
# Epoch 32/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.8522 - mse: 0.0024 - mae: 0.0371 - MAEMS: 0.8524 - val_loss: 0.8271 - val_mse: 0.0019 - val_mae: 0.0331 - val_MAEMS: 0.8269
# Epoch 33/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.8456 - mse: 0.0023 - mae: 0.0364 - MAEMS: 0.8457 - val_loss: 0.9609 - val_mse: 0.0019 - val_mae: 0.0336 - val_MAEMS: 0.9604
# Epoch 34/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.8358 - mse: 0.0023 - mae: 0.0365 - MAEMS: 0.8359 - val_loss: 0.8001 - val_mse: 0.0019 - val_mae: 0.0322 - val_MAEMS: 0.8002
# Epoch 35/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.8434 - mse: 0.0023 - mae: 0.0367 - MAEMS: 0.8438 - val_loss: 1.0937 - val_mse: 0.0022 - val_mae: 0.0373 - val_MAEMS: 1.0931
# Epoch 36/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.8486 - mse: 0.0023 - mae: 0.0368 - MAEMS: 0.8486 - val_loss: 0.9264 - val_mse: 0.0019 - val_mae: 0.0334 - val_MAEMS: 0.9260
# Epoch 37/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.8324 - mse: 0.0023 - mae: 0.0368 - MAEMS: 0.8324 - val_loss: 0.8153 - val_mse: 0.0021 - val_mae: 0.0347 - val_MAEMS: 0.8151
# Epoch 38/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.8235 - mse: 0.0022 - mae: 0.0360 - MAEMS: 0.8236 - val_loss: 0.7959 - val_mse: 0.0018 - val_mae: 0.0319 - val_MAEMS: 0.7958
# Epoch 39/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.8253 - mse: 0.0022 - mae: 0.0361 - MAEMS: 0.8255 - val_loss: 1.0939 - val_mse: 0.0022 - val_mae: 0.0374 - val_MAEMS: 1.0932
# Epoch 40/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.8237 - mse: 0.0022 - mae: 0.0360 - MAEMS: 0.8236 - val_loss: 0.8442 - val_mse: 0.0018 - val_mae: 0.0322 - val_MAEMS: 0.8437
# Epoch 41/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.8130 - mse: 0.0022 - mae: 0.0355 - MAEMS: 0.8130 - val_loss: 0.8623 - val_mse: 0.0018 - val_mae: 0.0330 - val_MAEMS: 0.8620
# Epoch 42/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.8066 - mse: 0.0022 - mae: 0.0357 - MAEMS: 0.8068 - val_loss: 0.9016 - val_mse: 0.0023 - val_mae: 0.0375 - val_MAEMS: 0.9010
# Epoch 43/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.7973 - mse: 0.0022 - mae: 0.0354 - MAEMS: 0.7972 - val_loss: 0.8476 - val_mse: 0.0018 - val_mae: 0.0320 - val_MAEMS: 0.8470
# Epoch 44/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7932 - mse: 0.0021 - mae: 0.0350 - MAEMS: 0.7931 - val_loss: 0.8182 - val_mse: 0.0019 - val_mae: 0.0328 - val_MAEMS: 0.8178
# Epoch 45/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7887 - mse: 0.0021 - mae: 0.0351 - MAEMS: 0.7887 - val_loss: 0.8996 - val_mse: 0.0019 - val_mae: 0.0331 - val_MAEMS: 0.8989
# Epoch 46/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.7820 - mse: 0.0020 - mae: 0.0343 - MAEMS: 0.7820 - val_loss: 0.7820 - val_mse: 0.0017 - val_mae: 0.0308 - val_MAEMS: 0.7817
# Epoch 47/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7806 - mse: 0.0020 - mae: 0.0344 - MAEMS: 0.7806 - val_loss: 0.8836 - val_mse: 0.0018 - val_mae: 0.0325 - val_MAEMS: 0.8830
# Epoch 48/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7694 - mse: 0.0020 - mae: 0.0343 - MAEMS: 0.7695 - val_loss: 0.9751 - val_mse: 0.0019 - val_mae: 0.0337 - val_MAEMS: 0.9745
# Epoch 49/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7920 - mse: 0.0021 - mae: 0.0347 - MAEMS: 0.7919 - val_loss: 0.7623 - val_mse: 0.0017 - val_mae: 0.0310 - val_MAEMS: 0.7620
# Epoch 50/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7713 - mse: 0.0020 - mae: 0.0341 - MAEMS: 0.7714 - val_loss: 0.8074 - val_mse: 0.0019 - val_mae: 0.0328 - val_MAEMS: 0.8068
# Epoch 51/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7577 - mse: 0.0020 - mae: 0.0339 - MAEMS: 0.7578 - val_loss: 0.8723 - val_mse: 0.0018 - val_mae: 0.0328 - val_MAEMS: 0.8716
# Epoch 52/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7715 - mse: 0.0021 - mae: 0.0346 - MAEMS: 0.7715 - val_loss: 0.7718 - val_mse: 0.0017 - val_mae: 0.0314 - val_MAEMS: 0.7714
# Epoch 53/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7590 - mse: 0.0020 - mae: 0.0339 - MAEMS: 0.7590 - val_loss: 0.8251 - val_mse: 0.0019 - val_mae: 0.0332 - val_MAEMS: 0.8247
# Epoch 54/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7452 - mse: 0.0020 - mae: 0.0336 - MAEMS: 0.7453 - val_loss: 0.8514 - val_mse: 0.0018 - val_mae: 0.0329 - val_MAEMS: 0.8508
# Epoch 55/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7536 - mse: 0.0020 - mae: 0.0340 - MAEMS: 0.7536 - val_loss: 0.8242 - val_mse: 0.0019 - val_mae: 0.0335 - val_MAEMS: 0.8236
# Epoch 56/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7633 - mse: 0.0020 - mae: 0.0341 - MAEMS: 0.7634 - val_loss: 0.8544 - val_mse: 0.0018 - val_mae: 0.0321 - val_MAEMS: 0.8536
# Epoch 57/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.7292 - mse: 0.0019 - mae: 0.0328 - MAEMS: 0.7293 - val_loss: 0.8671 - val_mse: 0.0018 - val_mae: 0.0327 - val_MAEMS: 0.8662
# Epoch 58/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.7505 - mse: 0.0020 - mae: 0.0337 - MAEMS: 0.7506 - val_loss: 0.8017 - val_mse: 0.0019 - val_mae: 0.0336 - val_MAEMS: 0.8012
# Epoch 59/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.7376 - mse: 0.0019 - mae: 0.0330 - MAEMS: 0.7375 - val_loss: 0.7788 - val_mse: 0.0017 - val_mae: 0.0308 - val_MAEMS: 0.7785
# Wall time: 5min 57s

# %%
gc.collect()
# Out:
# 4601

# %% [markdown]
# ## Saving Results & Figures

# %%
loss_history = hist.history['loss']
valloss_history = hist.history['val_loss']

# %%
#np.savetxt('losshistory.txt',(loss_history,valloss_history))
model.save('Basic Model Final_fh1.h5')

# %% [markdown]
# ## Basic Model Test Results

# %%
batch_size = b_size
testPredict = model.predict(teX, batch_size=batch_size)

# %%
def npMAEMS(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true))*100
def npMAEMD(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true-np.mean(y_true)))*100
def npMSE(y_true, y_pred):
    return np.mean(np.square(-y_true+y_pred))
def npMAE(y_true, y_pred):
    return np.mean(abs(-y_true+y_pred))

# %%
tePredict = testPredict.reshape(-1)
testY = teY.reshape(-1)
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMD == ', npMAEMD(testY, tePredict))
# Out:
# Error Test Score > MSE ==  0.0014714612314261795  MAE ==  0.029122771839655996  MAEMD ==  0.11338629604363659

# %% [markdown]
# ## Wind Generation FFEL Model

# %%
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=1/6, shuffle=False)
trY = trY.reshape(-1,output_timesteps)
vaY = vaY.reshape(-1,output_timesteps)

# %%
trainPredict = model.predict(trX, batch_size=batch_size)
validPredict = model.predict(vaX, batch_size=batch_size)

# %%
e_tr = trainPredict - trY
e_va = validPredict - vaY
errors = np.vstack([e_tr, e_va])
prediction = np.vstack([trainPredict, validPredict])
print(errors.shape)
print(prediction.shape)
# Out:
# (31532, 1)
# (31532, 1)

# %%
norm_df2 = pd.DataFrame(norm_df).iloc[:prediction.shape[0], :]
norm_df2.columns = ['Normalized Wind']
norm_df2.head()
# Out:
#    Normalized Wind
# 0         0.644724
# 1         0.658617
# 2         0.683924
# 3         0.721813
# 4         0.714187

# %%
Prindex = ['Prediction1']
Erindex = ['Error1']

pr_df = pd.DataFrame(prediction, columns=Prindex)
pr_df
# Out:
#        Prediction1
# 0         0.705698
# 1         0.735707
# 2         0.767117
# 3         0.781181
# 4         0.730203
# ...            ...
# 31527     0.332515
# 31528     0.378504
# 31529     0.430836
# 31530     0.532108
# 31531     0.634929
#
# [31532 rows x 1 columns]

# %%
er_df = pd.DataFrame(errors, columns=Erindex)
er_df
# Out:
#          Error1
# 0     -0.008974
# 1     -0.011706
# 2      0.028302
# 3      0.073649
# 4      0.049193
# ...         ...
# 31527  0.009341
# 31528 -0.003796
# 31529 -0.015123
# 31530  0.017540
# 31531  0.046279
#
# [31532 rows x 1 columns]

# %%
norm_df2 = pd.concat([norm_df2, pr_df, er_df],axis=1)
norm_df2.head()
# Out:
#    Normalized Wind  Prediction1    Error1
# 0         0.644724     0.705698 -0.008974
# 1         0.658617     0.735707 -0.011706
# 2         0.683924     0.767117  0.028302
# 3         0.721813     0.781181  0.073649
# 4         0.714187     0.730203  0.049193

# %%
norm_df22 = pd.DataFrame(norm_df).iloc[prediction.shape[0]+timesteps:, :]
norm_df22.columns = ['Normalized Wind']
npnorm22 = np.array(norm_df22)

# %%
pr_df = pd.DataFrame(tePredict.reshape(-1,output_timesteps))
pr_df
# Out:
#              0
# 0     0.643773
# 1     0.623531
# 2     0.632386
# 3     0.619002
# 4     0.526136
# ...        ...
# 3499  0.331235
# 3500  0.335922
# 3501  0.399632
# 3502  0.459162
# 3503  0.630847
#
# [3504 rows x 1 columns]

# %%
teY = testY.reshape(-1,output_timesteps)
e_te = testPredict-teY
er_df = pd.DataFrame(e_te, columns=Erindex)
er_df
# Out:
#         Error1
# 0     0.015206
# 1     0.009153
# 2     0.092997
# 3     0.175344
# 4     0.116260
# ...        ...
# 3499 -0.009791
# 3500 -0.034821
# 3501 -0.085352
# 3502 -0.122995
# 3503  0.009929
#
# [3504 rows x 1 columns]

# %%
prnorm = np.array(pr_df)
ernorm =np.array(er_df)
print(ernorm.shape)
# Out:
# (3504, 1)

# %%
etedat = np.concatenate((npnorm22[:prnorm.shape[0],:], prnorm, ernorm), axis=1)
etedat[169:171,:]
# Out:
# array([[0.47426657, 0.52241433, 0.08558983],
#        [0.4368245 , 0.47737813, 0.07684525]])

# %%
#output_timesteps = 1
eteX, eteY = create_dataset(etedat, timesteps, 1, 0)
eteY.shape
# Out:
# (3478, 1, 3)

# %%
eteY = eteY[:,:,-output_timesteps:].reshape(-1,output_timesteps)

# %%
norm_df2 = np.array(norm_df2)
Xe, Ye = create_dataset(norm_df2, timesteps, 1, 0)
Ye.shape
# Out:
# (31506, 1, 3)

# %%
Ye = Ye[:,:,-output_timesteps:].reshape(-1,output_timesteps)
print(Xe.shape)
print(Ye.shape)
# Out:
# (31506, 24, 3)
# (31506, 1)

# %%
trXe, vaXe, trYe, vaYe = train_test_split(Xe, Ye, test_size=0.3, shuffle=False)

# %%
gc.collect()
# Out:
# 4187

# %%
eteX.shape, eteY.shape, Xe.shape, Ye.shape
# Out:
# ((3478, 24, 3), (3478, 1), (31506, 24, 3), (31506, 1))

# %%
def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))*10+K.mean(K.abs(y_pred - y_true))

# %%
num_features = Xe.shape[2]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1.2
    beta = 1
    hfilters = 256
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1e = Input(shape=(timesteps, num_features))
   
    per1e = Permute((2,1))(visible1e)
    den1ae = Dense(timesteps, activation='tanh')(per1e)
    den1be = Dense(timesteps, activation='sigmoid')(per1e)
    den1e = Multiply()([den1ae, den1be])
    per2e = Permute((2,1), name='attention_vec')(den1e)
    mul1e = Multiply()([visible1e, per2e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res01ae = Add()([visible1e, d1e])   # (100, 25) (100, 25)
    res01be = Subtract()([visible1e, d1e])

    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01ae)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    
    d1e = Multiply()([d1ae, d1be])
    res02ae = Add()([res01ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01be) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res02be = Subtract()([res01be, d2e])   # (100, 25) (100, 25) 
    res02e = Concatenate()([res02ae, res02be, res01ae, res01be])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res03ae = Add()([res02ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res03be = Subtract()([res02be, d2e])   # (100, 25) (100, 25)
    res03e = Concatenate()([res03ae, res03be, res02e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    res04ae = Add()([res03ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res04be = Subtract()([res02be, d2e])   # (100, 25) (100, 25)
    res04e = Concatenate()([res04ae, res04be, res03e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res05ae = Add()([res04ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res05be = Subtract()([res04be, d2e])   # (100, 25) (100, 25)
    res05e = Concatenate()([res05ae, res05be, res04e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])

    res06ae = Add()([res05ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])

    res06be = Subtract()([res05be, d2e])   # (100, 25) (100, 25)
    res06e = Concatenate()([res05ae, res05be])
    
    res10e = Concatenate()([res02e, res03e, res04e, res05e, res06e])   # 
    
    #print('res10 :', res10.shape)  # (None, 24, 11) 
    
    oute = Conv1D(timesteps*5, 1, padding='same', activation=PReLU())(res10e)   # 256, 11X10=110
    oute = Dropout(0.2)(oute)   #SpatialDropout1D
    
    oute = Conv1D(timesteps*3, 1, padding='same', activation=PReLU())(oute) # 512,  110X5=550
    oute = Dropout(0.2)(oute)
    
    oute = GlobalAveragePooling1D()(oute) # pool_size=2, strides=1
    
    oute = Dense(output_timesteps)(oute) 
    modele = Model(inputs=[visible1e], outputs=[oute])
    
    print(modele.summary())
    
    modele.compile(loss=mse_mae, optimizer='adam', metrics=['mse','mae','mape'])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = b_size
    epochs = 1000

    history_e = LossHistory()
    history_e.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 24, 3)]      0
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 3, 24)        0           input_3[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 3, 24)        600         permute_2[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 3, 24)        600         permute_2[0][0]
# __________________________________________________________________________________________________
# multiply_48 (Multiply)          (None, 3, 24)        0           dense_6[0][0]
#                                                                  dense_7[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 24, 3)        0           multiply_48[0][0]
# __________________________________________________________________________________________________
# multiply_49 (Multiply)          (None, 24, 3)        0           input_3[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_48 (Conv1D)              (None, 24, 256)      1024        multiply_49[0][0]
# __________________________________________________________________________________________________
# activation_88 (Activation)      (None, 24, 256)      0           conv1d_48[0][0]
# __________________________________________________________________________________________________
# activation_89 (Activation)      (None, 24, 256)      0           conv1d_48[0][0]
# __________________________________________________________________________________________________
# multiply_50 (Multiply)          (None, 24, 256)      0           activation_88[0][0]
#                                                                  activation_89[0][0]
# __________________________________________________________________________________________________
# conv1d_49 (Conv1D)              (None, 24, 3)        1539        multiply_50[0][0]
# __________________________________________________________________________________________________
# activation_90 (Activation)      (None, 24, 3)        0           conv1d_49[0][0]
# __________________________________________________________________________________________________
# activation_91 (Activation)      (None, 24, 3)        0           conv1d_49[0][0]
# __________________________________________________________________________________________________
# multiply_51 (Multiply)          (None, 24, 3)        0           activation_90[0][0]
#                                                                  activation_91[0][0]
# __________________________________________________________________________________________________
# add_12 (Add)                    (None, 24, 3)        0           input_3[0][0]
#                                                                  multiply_51[0][0]
# __________________________________________________________________________________________________
# subtract_12 (Subtract)          (None, 24, 3)        0           input_3[0][0]
#                                                                  multiply_51[0][0]
# __________________________________________________________________________________________________
# conv1d_50 (Conv1D)              (None, 24, 256)      1024        add_12[0][0]
# __________________________________________________________________________________________________
# conv1d_52 (Conv1D)              (None, 24, 256)      1024        subtract_12[0][0]
# __________________________________________________________________________________________________
# activation_92 (Activation)      (None, 24, 256)      0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# activation_93 (Activation)      (None, 24, 256)      0           conv1d_50[0][0]
# __________________________________________________________________________________________________
# activation_96 (Activation)      (None, 24, 256)      0           conv1d_52[0][0]
# __________________________________________________________________________________________________
# activation_97 (Activation)      (None, 24, 256)      0           conv1d_52[0][0]
# __________________________________________________________________________________________________
# multiply_52 (Multiply)          (None, 24, 256)      0           activation_92[0][0]
#                                                                  activation_93[0][0]
# __________________________________________________________________________________________________
# multiply_54 (Multiply)          (None, 24, 256)      0           activation_96[0][0]
#                                                                  activation_97[0][0]
# __________________________________________________________________________________________________
# conv1d_51 (Conv1D)              (None, 24, 3)        1539        multiply_52[0][0]
# __________________________________________________________________________________________________
# conv1d_53 (Conv1D)              (None, 24, 3)        1539        multiply_54[0][0]
# __________________________________________________________________________________________________
# activation_94 (Activation)      (None, 24, 3)        0           conv1d_51[0][0]
# __________________________________________________________________________________________________
# activation_95 (Activation)      (None, 24, 3)        0           conv1d_51[0][0]
# __________________________________________________________________________________________________
# activation_98 (Activation)      (None, 24, 3)        0           conv1d_53[0][0]
# __________________________________________________________________________________________________
# activation_99 (Activation)      (None, 24, 3)        0           conv1d_53[0][0]
# __________________________________________________________________________________________________
# multiply_53 (Multiply)          (None, 24, 3)        0           activation_94[0][0]
#                                                                  activation_95[0][0]
# __________________________________________________________________________________________________
# multiply_55 (Multiply)          (None, 24, 3)        0           activation_98[0][0]
#                                                                  activation_99[0][0]
# __________________________________________________________________________________________________
# add_13 (Add)                    (None, 24, 3)        0           add_12[0][0]
#                                                                  multiply_53[0][0]
# __________________________________________________________________________________________________
# subtract_13 (Subtract)          (None, 24, 3)        0           subtract_12[0][0]
#                                                                  multiply_55[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 24, 12)       0           add_13[0][0]
#                                                                  subtract_13[0][0]
#                                                                  add_12[0][0]
#                                                                  subtract_12[0][0]
# __________________________________________________________________________________________________
# conv1d_54 (Conv1D)              (None, 24, 256)      3328        concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv1d_56 (Conv1D)              (None, 24, 256)      3328        concatenate_12[0][0]
# __________________________________________________________________________________________________
# activation_100 (Activation)     (None, 24, 256)      0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# activation_101 (Activation)     (None, 24, 256)      0           conv1d_54[0][0]
# __________________________________________________________________________________________________
# activation_104 (Activation)     (None, 24, 256)      0           conv1d_56[0][0]
# __________________________________________________________________________________________________
# activation_105 (Activation)     (None, 24, 256)      0           conv1d_56[0][0]
# __________________________________________________________________________________________________
# multiply_56 (Multiply)          (None, 24, 256)      0           activation_100[0][0]
#                                                                  activation_101[0][0]
# __________________________________________________________________________________________________
# multiply_58 (Multiply)          (None, 24, 256)      0           activation_104[0][0]
#                                                                  activation_105[0][0]
# __________________________________________________________________________________________________
# conv1d_55 (Conv1D)              (None, 24, 3)        1539        multiply_56[0][0]
# __________________________________________________________________________________________________
# conv1d_57 (Conv1D)              (None, 24, 3)        1539        multiply_58[0][0]
# __________________________________________________________________________________________________
# activation_102 (Activation)     (None, 24, 3)        0           conv1d_55[0][0]
# __________________________________________________________________________________________________
# activation_103 (Activation)     (None, 24, 3)        0           conv1d_55[0][0]
# __________________________________________________________________________________________________
# activation_106 (Activation)     (None, 24, 3)        0           conv1d_57[0][0]
# __________________________________________________________________________________________________
# activation_107 (Activation)     (None, 24, 3)        0           conv1d_57[0][0]
# __________________________________________________________________________________________________
# multiply_57 (Multiply)          (None, 24, 3)        0           activation_102[0][0]
#                                                                  activation_103[0][0]
# __________________________________________________________________________________________________
# multiply_59 (Multiply)          (None, 24, 3)        0           activation_106[0][0]
#                                                                  activation_107[0][0]
# __________________________________________________________________________________________________
# add_14 (Add)                    (None, 24, 3)        0           add_13[0][0]
#                                                                  multiply_57[0][0]
# __________________________________________________________________________________________________
# subtract_14 (Subtract)          (None, 24, 3)        0           subtract_13[0][0]
#                                                                  multiply_59[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 24, 18)       0           add_14[0][0]
#                                                                  subtract_14[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv1d_58 (Conv1D)              (None, 24, 256)      4864        concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv1d_60 (Conv1D)              (None, 24, 256)      4864        concatenate_13[0][0]
# __________________________________________________________________________________________________
# activation_108 (Activation)     (None, 24, 256)      0           conv1d_58[0][0]
# __________________________________________________________________________________________________
# activation_109 (Activation)     (None, 24, 256)      0           conv1d_58[0][0]
# __________________________________________________________________________________________________
# activation_112 (Activation)     (None, 24, 256)      0           conv1d_60[0][0]
# __________________________________________________________________________________________________
# activation_113 (Activation)     (None, 24, 256)      0           conv1d_60[0][0]
# __________________________________________________________________________________________________
# multiply_60 (Multiply)          (None, 24, 256)      0           activation_108[0][0]
#                                                                  activation_109[0][0]
# __________________________________________________________________________________________________
# multiply_62 (Multiply)          (None, 24, 256)      0           activation_112[0][0]
#                                                                  activation_113[0][0]
# __________________________________________________________________________________________________
# conv1d_59 (Conv1D)              (None, 24, 3)        1539        multiply_60[0][0]
# __________________________________________________________________________________________________
# conv1d_61 (Conv1D)              (None, 24, 3)        1539        multiply_62[0][0]
# __________________________________________________________________________________________________
# activation_110 (Activation)     (None, 24, 3)        0           conv1d_59[0][0]
# __________________________________________________________________________________________________
# activation_111 (Activation)     (None, 24, 3)        0           conv1d_59[0][0]
# __________________________________________________________________________________________________
# activation_114 (Activation)     (None, 24, 3)        0           conv1d_61[0][0]
# __________________________________________________________________________________________________
# activation_115 (Activation)     (None, 24, 3)        0           conv1d_61[0][0]
# __________________________________________________________________________________________________
# multiply_61 (Multiply)          (None, 24, 3)        0           activation_110[0][0]
#                                                                  activation_111[0][0]
# __________________________________________________________________________________________________
# multiply_63 (Multiply)          (None, 24, 3)        0           activation_114[0][0]
#                                                                  activation_115[0][0]
# __________________________________________________________________________________________________
# add_15 (Add)                    (None, 24, 3)        0           add_14[0][0]
#                                                                  multiply_61[0][0]
# __________________________________________________________________________________________________
# subtract_15 (Subtract)          (None, 24, 3)        0           subtract_13[0][0]
#                                                                  multiply_63[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 24, 24)       0           add_15[0][0]
#                                                                  subtract_15[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv1d_62 (Conv1D)              (None, 24, 256)      6400        concatenate_14[0][0]
# __________________________________________________________________________________________________
# conv1d_64 (Conv1D)              (None, 24, 256)      6400        concatenate_14[0][0]
# __________________________________________________________________________________________________
# activation_116 (Activation)     (None, 24, 256)      0           conv1d_62[0][0]
# __________________________________________________________________________________________________
# activation_117 (Activation)     (None, 24, 256)      0           conv1d_62[0][0]
# __________________________________________________________________________________________________
# activation_120 (Activation)     (None, 24, 256)      0           conv1d_64[0][0]
# __________________________________________________________________________________________________
# activation_121 (Activation)     (None, 24, 256)      0           conv1d_64[0][0]
# __________________________________________________________________________________________________
# multiply_64 (Multiply)          (None, 24, 256)      0           activation_116[0][0]
#                                                                  activation_117[0][0]
# __________________________________________________________________________________________________
# multiply_66 (Multiply)          (None, 24, 256)      0           activation_120[0][0]
#                                                                  activation_121[0][0]
# __________________________________________________________________________________________________
# conv1d_63 (Conv1D)              (None, 24, 3)        1539        multiply_64[0][0]
# __________________________________________________________________________________________________
# conv1d_65 (Conv1D)              (None, 24, 3)        1539        multiply_66[0][0]
# __________________________________________________________________________________________________
# activation_118 (Activation)     (None, 24, 3)        0           conv1d_63[0][0]
# __________________________________________________________________________________________________
# activation_119 (Activation)     (None, 24, 3)        0           conv1d_63[0][0]
# __________________________________________________________________________________________________
# activation_122 (Activation)     (None, 24, 3)        0           conv1d_65[0][0]
# __________________________________________________________________________________________________
# activation_123 (Activation)     (None, 24, 3)        0           conv1d_65[0][0]
# __________________________________________________________________________________________________
# multiply_65 (Multiply)          (None, 24, 3)        0           activation_118[0][0]
#                                                                  activation_119[0][0]
# __________________________________________________________________________________________________
# multiply_67 (Multiply)          (None, 24, 3)        0           activation_122[0][0]
#                                                                  activation_123[0][0]
# __________________________________________________________________________________________________
# add_16 (Add)                    (None, 24, 3)        0           add_15[0][0]
#                                                                  multiply_65[0][0]
# __________________________________________________________________________________________________
# subtract_16 (Subtract)          (None, 24, 3)        0           subtract_15[0][0]
#                                                                  multiply_67[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 24, 30)       0           add_16[0][0]
#                                                                  subtract_16[0][0]
#                                                                  concatenate_14[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 24, 6)        0           add_16[0][0]
#                                                                  subtract_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 24, 90)       0           concatenate_12[0][0]
#                                                                  concatenate_13[0][0]
#                                                                  concatenate_14[0][0]
#                                                                  concatenate_15[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv1d_70 (Conv1D)              (None, 24, 120)      13800       concatenate_17[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 24, 120)      0           conv1d_70[0][0]
# __________________________________________________________________________________________________
# conv1d_71 (Conv1D)              (None, 24, 72)       10440       dropout_4[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 24, 72)       0           conv1d_71[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_2 (Glo (None, 72)           0           dropout_5[0][0]
# __________________________________________________________________________________________________
# dense_8 (Dense)                 (None, 1)            73          global_average_pooling1d_2[0][0]
# ==================================================================================================
# Total params: 71,620
# Trainable params: 71,620
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 3757

# %%
# %%time
    histe = modele.fit(trXe, trYe, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(vaXe, vaYe), callbacks=[history_e, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 221/221 [==============================] - 10s 31ms/step - loss: 0.0584 - mse: 0.0023 - mae: 0.0350 - mape: 581.3569 - val_loss: 0.0408 - val_mse: 0.0013 - val_mae: 0.0277 - val_mape: 485.4600
# Epoch 2/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0439 - mse: 0.0015 - mae: 0.0290 - mape: 307.5120 - val_loss: 0.0332 - val_mse: 9.7496e-04 - val_mae: 0.0234 - val_mape: 353.3731
# Epoch 3/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0379 - mse: 0.0012 - mae: 0.0260 - mape: 331.3281 - val_loss: 0.0301 - val_mse: 8.3407e-04 - val_mae: 0.0218 - val_mape: 386.4883
# Epoch 4/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0360 - mse: 0.0011 - mae: 0.0250 - mape: 519.2486 - val_loss: 0.0283 - val_mse: 7.5968e-04 - val_mae: 0.0207 - val_mape: 322.2680
# Epoch 5/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0347 - mse: 0.0010 - mae: 0.0243 - mape: 472.3404 - val_loss: 0.0282 - val_mse: 7.4974e-04 - val_mae: 0.0207 - val_mape: 330.6994
# Epoch 6/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0342 - mse: 0.0010 - mae: 0.0240 - mape: 519.2733 - val_loss: 0.0276 - val_mse: 7.2579e-04 - val_mae: 0.0203 - val_mape: 289.6403
# Epoch 7/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0336 - mse: 9.9208e-04 - mae: 0.0237 - mape: 461.1928 - val_loss: 0.0273 - val_mse: 7.1263e-04 - val_mae: 0.0202 - val_mape: 327.0949
# Epoch 8/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0333 - mse: 9.8006e-04 - mae: 0.0235 - mape: 460.6172 - val_loss: 0.0269 - val_mse: 7.0124e-04 - val_mae: 0.0199 - val_mape: 326.4054
# Epoch 9/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0331 - mse: 9.7076e-04 - mae: 0.0234 - mape: 538.7168 - val_loss: 0.0272 - val_mse: 7.0959e-04 - val_mae: 0.0201 - val_mape: 338.6225
# Epoch 10/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0332 - mse: 9.7375e-04 - mae: 0.0234 - mape: 477.5565 - val_loss: 0.0271 - val_mse: 7.0435e-04 - val_mae: 0.0200 - val_mape: 326.4199
# Epoch 11/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0328 - mse: 9.5647e-04 - mae: 0.0232 - mape: 474.1192 - val_loss: 0.0267 - val_mse: 6.9321e-04 - val_mae: 0.0198 - val_mape: 330.8169
# Epoch 12/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0330 - mse: 9.6256e-04 - mae: 0.0233 - mape: 481.4595 - val_loss: 0.0267 - val_mse: 6.8998e-04 - val_mae: 0.0198 - val_mape: 319.8379
# Epoch 13/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0326 - mse: 9.4912e-04 - mae: 0.0231 - mape: 505.1953 - val_loss: 0.0268 - val_mse: 6.9170e-04 - val_mae: 0.0198 - val_mape: 351.2693
# Epoch 14/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0326 - mse: 9.4535e-04 - mae: 0.0231 - mape: 467.9388 - val_loss: 0.0266 - val_mse: 6.8677e-04 - val_mae: 0.0197 - val_mape: 334.6371
# Epoch 15/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0324 - mse: 9.4117e-04 - mae: 0.0230 - mape: 505.5273 - val_loss: 0.0267 - val_mse: 6.9341e-04 - val_mae: 0.0198 - val_mape: 337.2289
# Epoch 16/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0322 - mse: 9.2927e-04 - mae: 0.0229 - mape: 488.8377 - val_loss: 0.0265 - val_mse: 6.8252e-04 - val_mae: 0.0196 - val_mape: 351.7115
# Epoch 17/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0322 - mse: 9.3112e-04 - mae: 0.0229 - mape: 489.3401 - val_loss: 0.0265 - val_mse: 6.8423e-04 - val_mae: 0.0197 - val_mape: 351.5959
# Epoch 18/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0323 - mse: 9.3196e-04 - mae: 0.0230 - mape: 441.3649 - val_loss: 0.0264 - val_mse: 6.8038e-04 - val_mae: 0.0196 - val_mape: 353.4991
# Epoch 19/1000
# 221/221 [==============================] - 6s 26ms/step - loss: 0.0323 - mse: 9.3371e-04 - mae: 0.0229 - mape: 464.3939 - val_loss: 0.0266 - val_mse: 6.8572e-04 - val_mae: 0.0197 - val_mape: 343.1918
# Epoch 20/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0321 - mse: 9.2557e-04 - mae: 0.0229 - mape: 445.0052 - val_loss: 0.0265 - val_mse: 6.8075e-04 - val_mae: 0.0197 - val_mape: 341.9334
# Epoch 21/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0320 - mse: 9.2392e-04 - mae: 0.0228 - mape: 451.9585 - val_loss: 0.0264 - val_mse: 6.7891e-04 - val_mae: 0.0196 - val_mape: 343.1198
# Epoch 22/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0320 - mse: 9.2327e-04 - mae: 0.0228 - mape: 461.8820 - val_loss: 0.0265 - val_mse: 6.8006e-04 - val_mae: 0.0197 - val_mape: 358.7134
# Epoch 23/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0320 - mse: 9.1755e-04 - mae: 0.0228 - mape: 492.2026 - val_loss: 0.0263 - val_mse: 6.7515e-04 - val_mae: 0.0195 - val_mape: 349.9743
# Epoch 24/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0318 - mse: 9.1675e-04 - mae: 0.0227 - mape: 471.6774 - val_loss: 0.0264 - val_mse: 6.7661e-04 - val_mae: 0.0196 - val_mape: 369.2608
# Epoch 25/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0319 - mse: 9.1649e-04 - mae: 0.0228 - mape: 454.5891 - val_loss: 0.0262 - val_mse: 6.7202e-04 - val_mae: 0.0195 - val_mape: 372.4789
# Epoch 26/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0318 - mse: 9.1521e-04 - mae: 0.0227 - mape: 547.8135 - val_loss: 0.0263 - val_mse: 6.7703e-04 - val_mae: 0.0196 - val_mape: 316.9706
# Epoch 27/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0318 - mse: 9.1134e-04 - mae: 0.0226 - mape: 475.5432 - val_loss: 0.0261 - val_mse: 6.6744e-04 - val_mae: 0.0194 - val_mape: 358.2266
# Epoch 28/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0318 - mse: 9.1385e-04 - mae: 0.0227 - mape: 500.1650 - val_loss: 0.0263 - val_mse: 6.7723e-04 - val_mae: 0.0196 - val_mape: 310.3507
# Epoch 29/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0316 - mse: 9.0236e-04 - mae: 0.0225 - mape: 423.4545 - val_loss: 0.0264 - val_mse: 6.7792e-04 - val_mae: 0.0196 - val_mape: 378.3306
# Epoch 30/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0317 - mse: 9.0711e-04 - mae: 0.0226 - mape: 460.3713 - val_loss: 0.0264 - val_mse: 6.7719e-04 - val_mae: 0.0197 - val_mape: 396.5769
# Epoch 31/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0316 - mse: 9.0275e-04 - mae: 0.0225 - mape: 483.9533 - val_loss: 0.0265 - val_mse: 6.7834e-04 - val_mae: 0.0197 - val_mape: 375.0562
# Epoch 32/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0317 - mse: 9.0616e-04 - mae: 0.0226 - mape: 440.4697 - val_loss: 0.0260 - val_mse: 6.6486e-04 - val_mae: 0.0194 - val_mape: 348.9416
# Epoch 33/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0316 - mse: 9.0384e-04 - mae: 0.0225 - mape: 496.8066 - val_loss: 0.0262 - val_mse: 6.7174e-04 - val_mae: 0.0195 - val_mape: 378.4668
# Epoch 34/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0316 - mse: 9.0189e-04 - mae: 0.0225 - mape: 439.8299 - val_loss: 0.0260 - val_mse: 6.6218e-04 - val_mae: 0.0193 - val_mape: 341.0740
# Epoch 35/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0314 - mse: 8.9430e-04 - mae: 0.0224 - mape: 477.7393 - val_loss: 0.0261 - val_mse: 6.6559e-04 - val_mae: 0.0194 - val_mape: 344.3181
# Epoch 36/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0314 - mse: 8.9615e-04 - mae: 0.0224 - mape: 484.6293 - val_loss: 0.0260 - val_mse: 6.6334e-04 - val_mae: 0.0194 - val_mape: 335.3120
# Epoch 37/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0314 - mse: 8.9459e-04 - mae: 0.0224 - mape: 495.8159 - val_loss: 0.0260 - val_mse: 6.6345e-04 - val_mae: 0.0194 - val_mape: 340.2134
# Epoch 38/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0313 - mse: 8.8838e-04 - mae: 0.0224 - mape: 564.3076 - val_loss: 0.0260 - val_mse: 6.6420e-04 - val_mae: 0.0194 - val_mape: 347.2398
# Epoch 39/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0314 - mse: 8.9587e-04 - mae: 0.0225 - mape: 477.1992 - val_loss: 0.0259 - val_mse: 6.6044e-04 - val_mae: 0.0193 - val_mape: 379.6927
# Epoch 40/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0313 - mse: 8.9190e-04 - mae: 0.0224 - mape: 502.5511 - val_loss: 0.0259 - val_mse: 6.5956e-04 - val_mae: 0.0193 - val_mape: 351.6944
# Epoch 41/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0312 - mse: 8.8719e-04 - mae: 0.0223 - mape: 507.8398 - val_loss: 0.0260 - val_mse: 6.6387e-04 - val_mae: 0.0194 - val_mape: 355.8673
# Epoch 42/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0311 - mse: 8.8659e-04 - mae: 0.0223 - mape: 486.3776 - val_loss: 0.0260 - val_mse: 6.6151e-04 - val_mae: 0.0194 - val_mape: 368.3893
# Epoch 43/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0311 - mse: 8.8336e-04 - mae: 0.0223 - mape: 481.8746 - val_loss: 0.0259 - val_mse: 6.5856e-04 - val_mae: 0.0193 - val_mape: 368.4379
# Epoch 44/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0312 - mse: 8.8724e-04 - mae: 0.0223 - mape: 511.3537 - val_loss: 0.0260 - val_mse: 6.6186e-04 - val_mae: 0.0193 - val_mape: 369.0844
# Epoch 45/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0312 - mse: 8.8561e-04 - mae: 0.0223 - mape: 491.7961 - val_loss: 0.0261 - val_mse: 6.6424e-04 - val_mae: 0.0194 - val_mape: 386.3766
# Epoch 46/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0310 - mse: 8.8065e-04 - mae: 0.0222 - mape: 470.5021 - val_loss: 0.0259 - val_mse: 6.5711e-04 - val_mae: 0.0193 - val_mape: 357.0098
# Epoch 47/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0309 - mse: 8.7641e-04 - mae: 0.0221 - mape: 487.7944 - val_loss: 0.0259 - val_mse: 6.5868e-04 - val_mae: 0.0193 - val_mape: 387.5201
# Epoch 48/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0310 - mse: 8.8031e-04 - mae: 0.0222 - mape: 423.1445 - val_loss: 0.0260 - val_mse: 6.6228e-04 - val_mae: 0.0194 - val_mape: 392.7637
# Epoch 49/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0309 - mse: 8.7615e-04 - mae: 0.0222 - mape: 520.7590 - val_loss: 0.0260 - val_mse: 6.6180e-04 - val_mae: 0.0193 - val_mape: 376.8894
# Epoch 50/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0309 - mse: 8.7938e-04 - mae: 0.0221 - mape: 492.7854 - val_loss: 0.0259 - val_mse: 6.6002e-04 - val_mae: 0.0193 - val_mape: 391.0383
# Epoch 51/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0308 - mse: 8.7294e-04 - mae: 0.0221 - mape: 503.8910 - val_loss: 0.0259 - val_mse: 6.5794e-04 - val_mae: 0.0193 - val_mape: 369.3434
# Epoch 52/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0308 - mse: 8.7278e-04 - mae: 0.0221 - mape: 496.4876 - val_loss: 0.0259 - val_mse: 6.5751e-04 - val_mae: 0.0193 - val_mape: 355.3625
# Epoch 53/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0308 - mse: 8.7405e-04 - mae: 0.0221 - mape: 462.8004 - val_loss: 0.0259 - val_mse: 6.6055e-04 - val_mae: 0.0193 - val_mape: 343.7860
# Epoch 54/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0307 - mse: 8.6776e-04 - mae: 0.0220 - mape: 486.7605 - val_loss: 0.0261 - val_mse: 6.6488e-04 - val_mae: 0.0194 - val_mape: 356.7487
# Epoch 55/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0307 - mse: 8.7053e-04 - mae: 0.0220 - mape: 438.2407 - val_loss: 0.0259 - val_mse: 6.5950e-04 - val_mae: 0.0193 - val_mape: 383.9725
# Epoch 56/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0307 - mse: 8.6620e-04 - mae: 0.0220 - mape: 457.1147 - val_loss: 0.0259 - val_mse: 6.5819e-04 - val_mae: 0.0193 - val_mape: 355.7893
# Epoch 57/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0304 - mse: 8.5791e-04 - mae: 0.0219 - mape: 465.6074 - val_loss: 0.0259 - val_mse: 6.5648e-04 - val_mae: 0.0193 - val_mape: 355.7267
# Epoch 58/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0305 - mse: 8.6146e-04 - mae: 0.0219 - mape: 501.1992 - val_loss: 0.0259 - val_mse: 6.5906e-04 - val_mae: 0.0193 - val_mape: 351.1534
# Epoch 59/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0305 - mse: 8.5934e-04 - mae: 0.0219 - mape: 520.3046 - val_loss: 0.0258 - val_mse: 6.5446e-04 - val_mae: 0.0193 - val_mape: 390.0173
# Epoch 60/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0305 - mse: 8.5961e-04 - mae: 0.0219 - mape: 497.7173 - val_loss: 0.0259 - val_mse: 6.5760e-04 - val_mae: 0.0193 - val_mape: 366.7108
# Epoch 61/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0304 - mse: 8.5699e-04 - mae: 0.0219 - mape: 448.9488 - val_loss: 0.0257 - val_mse: 6.5347e-04 - val_mae: 0.0192 - val_mape: 365.1595
# Epoch 62/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0304 - mse: 8.5649e-04 - mae: 0.0218 - mape: 524.8140 - val_loss: 0.0259 - val_mse: 6.5748e-04 - val_mae: 0.0193 - val_mape: 357.9047
# Epoch 63/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0304 - mse: 8.5726e-04 - mae: 0.0218 - mape: 510.5448 - val_loss: 0.0260 - val_mse: 6.6214e-04 - val_mae: 0.0193 - val_mape: 386.5486
# Epoch 64/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0303 - mse: 8.5020e-04 - mae: 0.0218 - mape: 515.0973 - val_loss: 0.0261 - val_mse: 6.6312e-04 - val_mae: 0.0194 - val_mape: 425.7998
# Epoch 65/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0302 - mse: 8.4794e-04 - mae: 0.0217 - mape: 435.9396 - val_loss: 0.0259 - val_mse: 6.5901e-04 - val_mae: 0.0193 - val_mape: 397.1282
# Epoch 66/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0302 - mse: 8.4722e-04 - mae: 0.0217 - mape: 477.7647 - val_loss: 0.0261 - val_mse: 6.6523e-04 - val_mae: 0.0195 - val_mape: 374.0616
# Epoch 67/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0303 - mse: 8.5027e-04 - mae: 0.0217 - mape: 451.6690 - val_loss: 0.0264 - val_mse: 6.7194e-04 - val_mae: 0.0196 - val_mape: 423.3265
# Epoch 68/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0301 - mse: 8.4713e-04 - mae: 0.0217 - mape: 483.7297 - val_loss: 0.0260 - val_mse: 6.6145e-04 - val_mae: 0.0194 - val_mape: 408.6690
# Epoch 69/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0301 - mse: 8.4390e-04 - mae: 0.0216 - mape: 496.6662 - val_loss: 0.0264 - val_mse: 6.7543e-04 - val_mae: 0.0196 - val_mape: 417.0252
# Epoch 70/1000
# 221/221 [==============================] - 6s 28ms/step - loss: 0.0301 - mse: 8.4581e-04 - mae: 0.0217 - mape: 453.6095 - val_loss: 0.0262 - val_mse: 6.6648e-04 - val_mae: 0.0195 - val_mape: 403.3463
# Epoch 71/1000
# 221/221 [==============================] - 6s 27ms/step - loss: 0.0299 - mse: 8.3637e-04 - mae: 0.0216 - mape: 507.1463 - val_loss: 0.0261 - val_mse: 6.6373e-04 - val_mae: 0.0195 - val_mape: 380.4047

# %% [markdown]
# ### Saving FFEL Model Training Results

# %%
eloss_history = histe.history['loss']
valeloss_history = histe.history['val_loss']

# %%
gc.collect()
# Out:
# 230211

# %%
modele.save('Error Learning Model_fh1.h5')

# %% [markdown]
# ## FFEL Model Test Results

# %%
trainePredict = modele.predict(Xe, batch_size=batch_size)
etePredict = modele.predict(eteX, batch_size=batch_size)

# %%
trePredict = trainePredict.reshape([-1])
trainYe = Ye.reshape([-1])

print('Error Training Score > MSE == ', (np.mean(np.square(trainYe-trePredict))), ' MAE == ', mean_absolute_error(trainYe,trePredict), ' RMSE == ', np.sqrt(np.mean(np.square(trainYe-trePredict))))
# Out:
# Error Training Score > MSE ==  0.00076058992686187  MAE ==  0.020615412007590494  RMSE ==  0.027578794876895366

# %%
etestPredict = etePredict.reshape([-1])
testYe = eteY.reshape([-1])

print('Error Training Score > MSE == ', (np.mean(np.square(testYe-etestPredict))), ' MAE == ', mean_absolute_error(testYe,etestPredict), ' RMSE == ', np.sqrt(np.mean(np.square(testYe-etestPredict))))
# Out:
# Error Training Score > MSE ==  0.0007381920654206188  MAE ==  0.02046788414278428  RMSE ==  0.027169690197361818

# %% [markdown]
# ## Final Prediction Results

# %%
testPredict = tePredict.reshape(-1,1)
addtestPredict = -etePredict + testPredict[timesteps:-2,:]
print(addtestPredict.shape)
# Out:
# (3478, 1)

# %%
print('Error Test Score > MSE == ', (np.mean(np.square(teY[timesteps:-2,:]-testPredict[timesteps:-2,:]))), ' MAE == ', mean_absolute_error(teY[timesteps:-2,:], testPredict[timesteps:-2,:]), 'MAPE == ', mean_absolute_percentage_error(teY[timesteps:-2,:], testPredict[timesteps:-2,:]))
print('Error Test Score > MSE == ', (np.mean(np.square(teY[timesteps:-2,:]-addtestPredict))), ' MAE == ', mean_absolute_error(teY[timesteps:-2,:], addtestPredict), 'MAPE == ', mean_absolute_percentage_error(teY[timesteps:-2,:], addtestPredict))
# Out:
# Error Test Score > MSE ==  0.0014524701411472067  MAE ==  0.02898474054227111 MAPE ==  11.96688290143424
# Error Test Score > MSE ==  0.0007381920602187625  MAE ==  0.020467884144792597 MAPE ==  8.26832110476965
