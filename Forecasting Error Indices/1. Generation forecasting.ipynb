# %%
import tensorflow as tf

import pandas as pd
import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
#from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply, Subtract
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout, SpatialDropout1D
from scipy import signal
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pylab as plt
import matplotlib.dates as mdates
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc
from keijzer import *
from tensorflow import keras
from keras.models import Model
from keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply, Embedding, Layer, Reshape
from keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
#from keras.ops import convert_to_tensor, convert_to_numpy
#from keras.utils import plot_model
from keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))



def root_squared_mean_error(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))+K.mean(K.abs(y_pred - y_true))

from keras.layers.advanced_activations import PReLU

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
import scipy as sc

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '0' # 여러개 사용시 '0,1,2' 식으로 하나의 문자열에 입력
gpus = tf.config.experimental.list_physical_devices('GPU') # 호스트 러나임에 표시되는 GPU 장치 목록 반환

if gpus: # 반환된 GPU 장치 목록이 있다면
    try: # 해당 장치에 대한 메모리 증가 활성화 여부 설정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e: # try문 실패시에 에러문구 출력
        print(e)

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Import Data & Preprocessing

# %%
data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2020.csv'
data_source1 = pd.read_csv(data_path)
dat_source1 = pd.DataFrame(data_source1)
#dat_source1 = dat_source1.iloc[:-3,:]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2021.csv'
data_source2 = pd.read_csv(data_path)
dat_source2 = pd.DataFrame(data_source2)
dat_source2 = dat_source2.iloc[:8761,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2022.csv'
data_source3 = pd.read_csv(data_path)
dat_source3 = pd.DataFrame(data_source3)
dat_source3 = dat_source3.iloc[:8760,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2023.csv'
data_source4 = pd.read_csv(data_path)
dat_source4 = pd.DataFrame(data_source4)
dat_source4 = dat_source4.iloc[:8760,:9]

dat_arr1 = np.array(dat_source1)
dat_arr2 = np.array(dat_source2)
dat_arr3 = np.array(dat_source3)
dat_arr4 = np.array(dat_source4)

dat_arr = np.concatenate([dat_arr1, dat_arr2, dat_arr3, dat_arr4],axis=0)
dat_arr.shape # 8784, 8761, 8760, 8760

dat_source = pd.DataFrame(dat_arr, columns=['Time-Date stamp','Date','ERCOT Load','Total Wind Output','Total Wind Installed','Wind Output, % of Load','Wind Output, % of Installed','1-hr MW change','1-hr % change'])
dat_source
# Out:
#            Time-Date stamp    Date ERCOT Load Total Wind Output  \
# 0      01-01-2020 00:00:00  Jan-01      36823             12335
# 1      01-01-2020 01:00:00  Jan-01      36511             13300
# 2      01-01-2020 02:00:00  Jan-01      36022             13586
# 3      01-01-2020 03:00:00  Jan-01      35790             14107
# 4      01-01-2020 04:00:00  Jan-01      35642             14887
# ...                    ...     ...        ...               ...
# 35060  12-31-2023 20:00:00  Dec-31      44887             17161
# 35061  12-31-2023 21:00:00  Dec-31      44013             18301
# 35062  12-31-2023 22:00:00  Dec-31      43280             18607
# 35063  12-31-2023 23:00:00  Dec-31      42319             17866
# 35064  01-01-2024 00:00:00  Jan-01      41682             15869
#
#       Total Wind Installed Wind Output, % of Load Wind Output, % of Installed  \
# 0                    27040                   33.5                      45.617
# 1                    27040                   36.4                      49.187
# 2                    27040                   37.7                      50.245
# 3                    27040                   39.4                      52.171
# 4                    27040                   41.8                      55.055
# ...                    ...                    ...                         ...
# 35060                38631                  38.23                       44.42
# 35061                38631                  41.58                       47.37
# 35062                38631                  42.99                       48.17
# 35063                38631                  42.22                       46.25
# 35064                38631                  38.07                       41.08
#
#       1-hr MW change 1-hr % change
# 0                NaN           NaN
# 1              965.4         7.826
# 2              286.2         2.152
# 3              520.9         3.834
# 4              779.6         5.527
# ...              ...           ...
# 35060           2858         19.99
# 35061           1139          6.64
# 35062            307          1.67
# 35063           -741         -3.98
# 35064          -1996        -11.17
#
# [35065 rows x 9 columns]

# %% [markdown]
# ### Dividing by Installed Capacity & Preprocessing

# %%
dat = pd.DataFrame()
dat['MW % change'] = np.array(dat_source.iloc[1:,3], dtype=float)-np.array(dat_source.iloc[0:-1,3], dtype=float)
dat['MW % change'] = np.divide(np.array(dat['MW % change']),np.array(dat_source.iloc[1:,4]))*100
dat['Total Wind Output'] = np.divide(np.array(dat_source.iloc[1:,3]), np.array(dat_source.iloc[1:,4]))

dat
# Out:
#       MW % change Total Wind Output
# 0         3.56879          0.491864
# 1         1.05769          0.502441
# 2         1.92678          0.521709
# 3         2.88462          0.550555
# 4       -0.580621          0.544749
# ...           ...               ...
# 35059      7.3982          0.444229
# 35060       2.951          0.473739
# 35061     0.79211           0.48166
# 35062    -1.91815          0.462478
# 35063    -5.16942          0.410784
#
# [35064 rows x 2 columns]

# %%
ramp_ratio = 20
load_ratio = 10
year_arr = np.concatenate([np.ones(8784)*2020, np.ones(8760)*2021, np.ones(8760)*2022, np.ones(8760)*2023])
year_df = pd.DataFrame(year_arr, columns=['Year'], dtype=int)
wind_df = pd.concat([year_df, dat], axis=1)
wind_df
# Out:
#        Year MW % change Total Wind Output
# 0      2020     3.56879          0.491864
# 1      2020     1.05769          0.502441
# 2      2020     1.92678          0.521709
# 3      2020     2.88462          0.550555
# 4      2020   -0.580621          0.544749
# ...     ...         ...               ...
# 35059  2023      7.3982          0.444229
# 35060  2023       2.951          0.473739
# 35061  2023     0.79211           0.48166
# 35062  2023    -1.91815          0.462478
# 35063  2023    -5.16942          0.410784
#
# [35064 rows x 3 columns]

# %%
wind_df = wind_df.reset_index(drop=True)

std_scaler = sklearn.preprocessing.MinMaxScaler()
std_scaler_load = sklearn.preprocessing.MinMaxScaler()
std_scaler_ramp = sklearn.preprocessing.MinMaxScaler()

wind_df[['Total Wind Output']] = std_scaler.fit_transform(wind_df[['Total Wind Output']])
wind_df[['MW % change']] = std_scaler_ramp.fit_transform(wind_df[['MW % change']])
wind_df = wind_df.iloc[:-1,:]
wind_df
# Out:
#        Year  MW % change  Total Wind Output
# 0      2020     0.620197           0.644724
# 1      2020     0.544580           0.658617
# 2      2020     0.570751           0.683924
# 3      2020     0.599594           0.721813
# 4      2020     0.495246           0.714187
# ...     ...          ...                ...
# 35058  2023     0.774643           0.484984
# 35059  2023     0.735512           0.582157
# 35060  2023     0.601593           0.620917
# 35061  2023     0.536583           0.631322
# 35062  2023     0.454969           0.606127
#
# [35063 rows x 3 columns]

# %%
ramp_df = pd.DataFrame(wind_df)
ramp_df.columns=['Year', 'Wind Change', 'Wind Output']
ramp_df
# Out:
#        Year  Wind Change  Wind Output
# 0      2020     0.620197     0.644724
# 1      2020     0.544580     0.658617
# 2      2020     0.570751     0.683924
# 3      2020     0.599594     0.721813
# 4      2020     0.495246     0.714187
# ...     ...          ...          ...
# 35058  2023     0.774643     0.484984
# 35059  2023     0.735512     0.582157
# 35060  2023     0.601593     0.620917
# 35061  2023     0.536583     0.631322
# 35062  2023     0.454969     0.606127
#
# [35063 rows x 3 columns]

# %% [markdown]
# ## Wind Generation Forecasting

# %% [markdown]
# ### SVD-based Feature Generation

# %%
def create_dataset(dataset, timesteps, output_timesteps, leadtime):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - leadtime - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps + leadtime):(i+timesteps+output_timesteps+leadtime), :])
    return np.array(dataX), np.array(dataY)

def svdadd(X, start, end, b_size):
    dec_x = X[start:end, :, :]
    U, S, Vh = svd(dec_x.reshape(b_size, -1), full_matrices=True)

    high_sig = np.matmul(np.matmul(U[:,:high_ind], np.diag(S[0:high_ind])), Vh[:high_ind,:])
    low_sig = X[:dec_num, :, :].reshape(b_size,-1)-high_sig

    rec_x = np.zeros((b_size, b_size, high_ind))
    
    for i in range(high_ind):
        rec_x[:,:,i] = np.matmul((U[:,i]*S[i]).reshape(-1,1), Vh[i,:].reshape(1,-1))    
    return rec_x, low_sig

# %%
norm_df = np.array(wind_df.iloc[:,2]).reshape(-1,1)
timesteps = 24*7
output_timesteps = 24
leadtime = 6
num_features = 1
X, Y = create_dataset(norm_df, timesteps, output_timesteps, leadtime)
b_size = timesteps

# %%
dec_num = timesteps
high_ind = 35

addX = np.zeros((X.shape[0], dec_num, high_ind+1))

for k in range(X.shape[0]//dec_num):
    rec_x, low_sig = svdadd(X, k*dec_num, (k+1)*dec_num, b_size)
    addX[k*dec_num:k*dec_num+dec_num,:, :-1] = rec_x
    addX[k*dec_num:k*dec_num+dec_num,:, -1] = low_sig
    
rec_x, low_sig = svdadd(X, X.shape[0]-dec_num, X.shape[0], b_size)
addX[X.shape[0]-dec_num:X.shape[0], :, :-1] = rec_x
addX[X.shape[0]-dec_num:X.shape[0],:, -1] = low_sig

addX_det = addX[:, :, :-1]
addX_det = np.sum(addX_det, axis=2)
X = np.concatenate([X, addX], axis=2)
num_features = X.shape[2]

# %% [markdown]
# ### Training/Test Set Division & Shuffled Learning

# %%
trvaX, teX, trvaY, teY = train_test_split(X, Y, test_size=0.1, shuffle=False)

idx = np.arange(trvaX.shape[0])
np.random.shuffle(idx)
strvaX = trvaX[idx]
strvaY = trvaY[idx]
strvaY = strvaY.reshape(-1, output_timesteps)

trvaY = trvaY.reshape(-1, output_timesteps)
teY = teY.reshape(-1, output_timesteps)

strX, svaX, strY, svaY = train_test_split(strvaX, strvaY, test_size=0.3, shuffle=False)
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=0.3, shuffle=False)

trvaX.shape, trvaY.shape, teX.shape, teY.shape
# Out:
# ((31377, 168, 37), (31377, 24), (3487, 168, 37), (3487, 24))

# %% [markdown]
# ## Model Trained with MSE

# %%
def MAEMS(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true))*100

# %%
from keras.layers.advanced_activations import PReLU

# %%
num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1.2
    beta = 1
    hfilters = 256
    hkernel_size1 = 1
    hkernel_size2 = 2
    
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    per1 = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(per1)
    den1b = Dense(timesteps, activation='sigmoid')(per1)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])
    
    ## Series PN DCCNN Blocks 1 ~ 6
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([visible1, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([visible1, d1])

    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])   # (100, 25) (100, 25)
    res03 = Concatenate()([res03a, res03b, res02])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res04a = Add()([res03a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res04b = Subtract()([res02b, d2])   # (100, 25) (100, 25)
    res04 = Concatenate()([res04a, res04b, res03])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res05a = Add()([res04a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res05b = Subtract()([res04b, d2])   # (100, 25) (100, 25)
    res05 = Concatenate()([res05a, res05b, res04])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])

    res06a = Add()([res05a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])

    res06b = Subtract()([res05b, d2])   # (100, 25) (100, 25)
    res06 = Concatenate()([res05a, res05b])
    
    res10 = Concatenate()([res02, res03, res04, res05, res06])   # 
    
    #print('res10 :', res10.shap)  # (None, 24, 11) 
    
    ## Output Block
    out = Conv1D(720, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out = Dropout(0.2)(out)   #SpatialDropout1D
    
    out = Conv1D(360, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)
    
    out = GlobalAveragePooling1D()(out) # pool_size=2, strides=1
    
    out = Dense(24)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 168, 37)]    0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 37, 168)      0           input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 37, 168)      28392       permute[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 37, 168)      28392       permute[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 37, 168)      0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 168, 37)      0           multiply[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 168, 37)      0           input_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 168, 256)     9728        multiply_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 168, 256)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 168, 256)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 168, 256)     0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 168, 37)      18981       multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 168, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 168, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 168, 37)      0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 168, 37)      0           input_1[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 168, 37)      0           input_1[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 168, 256)     9728        add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 168, 256)     9728        subtract[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 168, 256)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 168, 256)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 168, 256)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 168, 256)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 168, 256)     0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 168, 256)     0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 168, 37)      18981       multiply_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 168, 37)      18981       multiply_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 168, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 168, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 168, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 168, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 168, 37)      0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 168, 37)      0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 168, 37)      0           add[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 168, 37)      0           subtract[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 168, 148)     0           add_1[0][0]
#                                                                  subtract_1[0][0]
#                                                                  add[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 168, 256)     38144       concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 168, 256)     38144       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 168, 256)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 168, 256)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 168, 256)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 168, 256)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 168, 256)     0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 168, 256)     0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 168, 37)      18981       multiply_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 168, 37)      18981       multiply_10[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 168, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 168, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 168, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 168, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 168, 37)      0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 168, 37)      0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 168, 37)      0           add_1[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 168, 37)      0           subtract_1[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 168, 222)     0           add_2[0][0]
#                                                                  subtract_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 168, 256)     57088       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 168, 256)     57088       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 168, 256)     0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 168, 256)     0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 168, 256)     0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 168, 256)     0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 168, 256)     0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 168, 256)     0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 168, 37)      18981       multiply_12[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 168, 37)      18981       multiply_14[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 168, 37)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 168, 37)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 168, 37)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 168, 37)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 168, 37)      0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 168, 37)      0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 168, 37)      0           add_2[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 168, 37)      0           subtract_1[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 168, 296)     0           add_3[0][0]
#                                                                  subtract_3[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 168, 256)     76032       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 168, 256)     76032       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 168, 256)     0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 168, 256)     0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 168, 256)     0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 168, 256)     0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 168, 256)     0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 168, 256)     0           activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 168, 37)      18981       multiply_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 168, 37)      18981       multiply_18[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 168, 37)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 168, 37)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 168, 37)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 168, 37)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 168, 37)      0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 168, 37)      0           activation_34[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 168, 37)      0           add_3[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 168, 37)      0           subtract_3[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 168, 370)     0           add_4[0][0]
#                                                                  subtract_4[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 168, 74)      0           add_4[0][0]
#                                                                  subtract_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 168, 1110)    0           concatenate[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 168, 720)     920880      concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 168, 720)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 168, 360)     320040      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 168, 360)     0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 360)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 24)           8664        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,848,909
# Trainable params: 1,848,909
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 2153

# %%
    model.compile(loss='mse', optimizer='adam', metrics=['mse','mae', MAEMS])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = 168
    epochs = 1000
    #root_squared_mean_error
    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint

# %%
    # %%time
    b_size = 168
    hist = model.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 131/131 [==============================] - 23s 148ms/step - loss: 0.0494 - mse: 0.0494 - mae: 0.1863 - MAEMS: 5.4044 - val_loss: 0.0399 - val_mse: 0.0399 - val_mae: 0.1668 - val_MAEMS: 4.2254
# Epoch 2/1000
# 131/131 [==============================] - 18s 134ms/step - loss: 0.0350 - mse: 0.0350 - mae: 0.1538 - MAEMS: 4.3499 - val_loss: 0.0326 - val_mse: 0.0326 - val_mae: 0.1460 - val_MAEMS: 3.6780
# Epoch 3/1000
# 131/131 [==============================] - 18s 134ms/step - loss: 0.0310 - mse: 0.0310 - mae: 0.1427 - MAEMS: 4.0075 - val_loss: 0.0298 - val_mse: 0.0298 - val_mae: 0.1384 - val_MAEMS: 3.6251
# Epoch 4/1000
# 131/131 [==============================] - 18s 134ms/step - loss: 0.0282 - mse: 0.0282 - mae: 0.1352 - MAEMS: 3.7743 - val_loss: 0.0278 - val_mse: 0.0278 - val_mae: 0.1330 - val_MAEMS: 3.2421
# Epoch 5/1000
# 131/131 [==============================] - 18s 134ms/step - loss: 0.0253 - mse: 0.0253 - mae: 0.1273 - MAEMS: 3.5281 - val_loss: 0.0245 - val_mse: 0.0245 - val_mae: 0.1255 - val_MAEMS: 3.6602
# Epoch 6/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0230 - mse: 0.0230 - mae: 0.1211 - MAEMS: 3.3358 - val_loss: 0.0219 - val_mse: 0.0219 - val_mae: 0.1183 - val_MAEMS: 3.1960
# Epoch 7/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0206 - mse: 0.0206 - mae: 0.1143 - MAEMS: 3.1281 - val_loss: 0.0197 - val_mse: 0.0197 - val_mae: 0.1119 - val_MAEMS: 3.1183
# Epoch 8/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0181 - mse: 0.0181 - mae: 0.1069 - MAEMS: 2.8987 - val_loss: 0.0174 - val_mse: 0.0174 - val_mae: 0.1051 - val_MAEMS: 3.0362
# Epoch 9/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0162 - mse: 0.0162 - mae: 0.1010 - MAEMS: 2.7271 - val_loss: 0.0154 - val_mse: 0.0154 - val_mae: 0.0985 - val_MAEMS: 2.6937
# Epoch 10/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0141 - mse: 0.0141 - mae: 0.0939 - MAEMS: 2.5216 - val_loss: 0.0147 - val_mse: 0.0147 - val_mae: 0.0961 - val_MAEMS: 2.9232
# Epoch 11/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0132 - mse: 0.0132 - mae: 0.0910 - MAEMS: 2.4395 - val_loss: 0.0145 - val_mse: 0.0145 - val_mae: 0.0956 - val_MAEMS: 2.9978
# Epoch 12/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0117 - mse: 0.0117 - mae: 0.0857 - MAEMS: 2.2954 - val_loss: 0.0135 - val_mse: 0.0135 - val_mae: 0.0922 - val_MAEMS: 2.9363
# Epoch 13/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0112 - mse: 0.0112 - mae: 0.0838 - MAEMS: 2.2479 - val_loss: 0.0116 - val_mse: 0.0116 - val_mae: 0.0854 - val_MAEMS: 2.5710
# Epoch 14/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0101 - mse: 0.0101 - mae: 0.0794 - MAEMS: 2.1248 - val_loss: 0.0129 - val_mse: 0.0129 - val_mae: 0.0906 - val_MAEMS: 2.8860
# Epoch 15/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0086 - mse: 0.0086 - mae: 0.0730 - MAEMS: 1.9422 - val_loss: 0.0118 - val_mse: 0.0118 - val_mae: 0.0868 - val_MAEMS: 2.7939
# Epoch 16/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0079 - mse: 0.0079 - mae: 0.0700 - MAEMS: 1.8624 - val_loss: 0.0092 - val_mse: 0.0092 - val_mae: 0.0760 - val_MAEMS: 2.2691
# Epoch 17/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0073 - mse: 0.0073 - mae: 0.0675 - MAEMS: 1.7952 - val_loss: 0.0093 - val_mse: 0.0093 - val_mae: 0.0764 - val_MAEMS: 2.3567
# Epoch 18/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0070 - mse: 0.0070 - mae: 0.0660 - MAEMS: 1.7581 - val_loss: 0.0075 - val_mse: 0.0075 - val_mae: 0.0681 - val_MAEMS: 1.9510
# Epoch 19/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0063 - mse: 0.0063 - mae: 0.0627 - MAEMS: 1.6656 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0647 - val_MAEMS: 1.8776
# Epoch 20/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0607 - MAEMS: 1.6128 - val_loss: 0.0068 - val_mse: 0.0068 - val_mae: 0.0648 - val_MAEMS: 1.8869
# Epoch 21/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0058 - mse: 0.0058 - mae: 0.0601 - MAEMS: 1.6007 - val_loss: 0.0071 - val_mse: 0.0071 - val_mae: 0.0659 - val_MAEMS: 1.9032
# Epoch 22/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0061 - mse: 0.0061 - mae: 0.0618 - MAEMS: 1.6521 - val_loss: 0.0082 - val_mse: 0.0082 - val_mae: 0.0723 - val_MAEMS: 2.1641
# Epoch 23/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0059 - mse: 0.0059 - mae: 0.0610 - MAEMS: 1.6334 - val_loss: 0.0060 - val_mse: 0.0060 - val_mae: 0.0611 - val_MAEMS: 1.4980
# Epoch 24/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0053 - mse: 0.0053 - mae: 0.0574 - MAEMS: 1.5336 - val_loss: 0.0050 - val_mse: 0.0050 - val_mae: 0.0551 - val_MAEMS: 1.4811
# Epoch 25/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0046 - mse: 0.0046 - mae: 0.0538 - MAEMS: 1.4314 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0545 - val_MAEMS: 1.4853
# Epoch 26/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0050 - mse: 0.0050 - mae: 0.0559 - MAEMS: 1.4927 - val_loss: 0.0047 - val_mse: 0.0047 - val_mae: 0.0538 - val_MAEMS: 1.4920
# Epoch 27/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0054 - mse: 0.0054 - mae: 0.0581 - MAEMS: 1.5614 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0566 - val_MAEMS: 1.6571
# Epoch 28/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0047 - mse: 0.0047 - mae: 0.0541 - MAEMS: 1.4474 - val_loss: 0.0052 - val_mse: 0.0052 - val_mae: 0.0566 - val_MAEMS: 1.6903
# Epoch 29/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0043 - mse: 0.0043 - mae: 0.0517 - MAEMS: 1.3813 - val_loss: 0.0051 - val_mse: 0.0051 - val_mae: 0.0560 - val_MAEMS: 1.6559
# Epoch 30/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0039 - mse: 0.0039 - mae: 0.0492 - MAEMS: 1.3127 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0542 - val_MAEMS: 1.6221
# Epoch 31/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0481 - MAEMS: 1.2809 - val_loss: 0.0049 - val_mse: 0.0049 - val_mae: 0.0546 - val_MAEMS: 1.6401
# Epoch 32/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0471 - MAEMS: 1.2546 - val_loss: 0.0048 - val_mse: 0.0048 - val_mae: 0.0543 - val_MAEMS: 1.6209
# Epoch 33/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0461 - MAEMS: 1.2284 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0504 - val_MAEMS: 1.4825
# Epoch 34/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0458 - MAEMS: 1.2203 - val_loss: 0.0037 - val_mse: 0.0037 - val_mae: 0.0471 - val_MAEMS: 1.3211
# Epoch 35/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0460 - MAEMS: 1.2310 - val_loss: 0.0046 - val_mse: 0.0046 - val_mae: 0.0534 - val_MAEMS: 1.6335
# Epoch 36/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0035 - mse: 0.0035 - mae: 0.0465 - MAEMS: 1.2438 - val_loss: 0.0045 - val_mse: 0.0045 - val_mae: 0.0533 - val_MAEMS: 1.6281
# Epoch 37/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0459 - MAEMS: 1.2253 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0516 - val_MAEMS: 1.5652
# Epoch 38/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0461 - MAEMS: 1.2334 - val_loss: 0.0043 - val_mse: 0.0043 - val_mae: 0.0516 - val_MAEMS: 1.5606
# Epoch 39/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0474 - MAEMS: 1.2734 - val_loss: 0.0065 - val_mse: 0.0065 - val_mae: 0.0654 - val_MAEMS: 2.0214
# Epoch 40/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0036 - mse: 0.0036 - mae: 0.0473 - MAEMS: 1.2731 - val_loss: 0.0041 - val_mse: 0.0041 - val_mae: 0.0504 - val_MAEMS: 1.4983
# Epoch 41/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0034 - mse: 0.0034 - mae: 0.0458 - MAEMS: 1.2254 - val_loss: 0.0042 - val_mse: 0.0042 - val_mae: 0.0512 - val_MAEMS: 1.5467
# Epoch 42/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0433 - MAEMS: 1.1567 - val_loss: 0.0067 - val_mse: 0.0067 - val_mae: 0.0677 - val_MAEMS: 2.1459
# Epoch 43/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0031 - mse: 0.0031 - mae: 0.0440 - MAEMS: 1.1778 - val_loss: 0.0058 - val_mse: 0.0058 - val_mae: 0.0626 - val_MAEMS: 1.9644
# Epoch 44/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0037 - mse: 0.0037 - mae: 0.0479 - MAEMS: 1.2920 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0473 - val_MAEMS: 1.4135
# Epoch 45/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0038 - mse: 0.0038 - mae: 0.0487 - MAEMS: 1.3108 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0448 - val_MAEMS: 1.2954
# Epoch 46/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0454 - MAEMS: 1.2210 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0455 - val_MAEMS: 1.3334
# Epoch 47/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0429 - MAEMS: 1.1490 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0467 - val_MAEMS: 1.3841
# Epoch 48/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0419 - MAEMS: 1.1207 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0430 - val_MAEMS: 1.2234
# Epoch 49/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0028 - mse: 0.0028 - mae: 0.0419 - MAEMS: 1.1206 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0434 - val_MAEMS: 1.2519
# Epoch 50/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0029 - mse: 0.0029 - mae: 0.0425 - MAEMS: 1.1395 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0453 - val_MAEMS: 1.3050
# Epoch 51/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0443 - MAEMS: 1.1894 - val_loss: 0.0054 - val_mse: 0.0054 - val_mae: 0.0585 - val_MAEMS: 1.8490
# Epoch 52/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0032 - mse: 0.0032 - mae: 0.0450 - MAEMS: 1.2131 - val_loss: 0.0066 - val_mse: 0.0066 - val_mae: 0.0661 - val_MAEMS: 2.1274
# Epoch 53/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0033 - mse: 0.0033 - mae: 0.0453 - MAEMS: 1.2211 - val_loss: 0.0038 - val_mse: 0.0038 - val_mae: 0.0490 - val_MAEMS: 1.4851
# Epoch 54/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0030 - mse: 0.0030 - mae: 0.0437 - MAEMS: 1.1763 - val_loss: 0.0030 - val_mse: 0.0030 - val_mae: 0.0426 - val_MAEMS: 1.2005
# Epoch 55/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0026 - mse: 0.0026 - mae: 0.0402 - MAEMS: 1.0796 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0470 - val_MAEMS: 1.4043
# Epoch 56/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0023 - mse: 0.0023 - mae: 0.0379 - MAEMS: 1.0116 - val_loss: 0.0036 - val_mse: 0.0036 - val_mae: 0.0473 - val_MAEMS: 1.4408
# Epoch 57/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0369 - MAEMS: 0.9857 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0474 - val_MAEMS: 1.4601
# Epoch 58/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0022 - mse: 0.0022 - mae: 0.0366 - MAEMS: 0.9737 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0451 - val_MAEMS: 1.3794
# Epoch 59/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0021 - mse: 0.0021 - mae: 0.0358 - MAEMS: 0.9544 - val_loss: 0.0032 - val_mse: 0.0032 - val_mae: 0.0453 - val_MAEMS: 1.3634
# Epoch 60/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0356 - MAEMS: 0.9479 - val_loss: 0.0035 - val_mse: 0.0035 - val_mae: 0.0473 - val_MAEMS: 1.4685
# Epoch 61/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0355 - MAEMS: 0.9456 - val_loss: 0.0031 - val_mse: 0.0031 - val_mae: 0.0440 - val_MAEMS: 1.3104
# Epoch 62/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0356 - MAEMS: 0.9501 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0463 - val_MAEMS: 1.4043
# Epoch 63/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0354 - MAEMS: 0.9445 - val_loss: 0.0033 - val_mse: 0.0033 - val_mae: 0.0453 - val_MAEMS: 1.3981
# Epoch 64/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0020 - mse: 0.0020 - mae: 0.0356 - MAEMS: 0.9515 - val_loss: 0.0034 - val_mse: 0.0034 - val_mae: 0.0462 - val_MAEMS: 1.4184
# Wall time: 18min 57s

# %%
gc.collect()
# Out:
# 4601

# %%
#np.savetxt('losshistory.txt',(loss_history,valloss_history))
model.save('Basic Model Final_mse.h5')

# %%
with tf.device('/gpu:0'):
    model = keras.models.load_model('Basic Model Final_mse.h5', custom_objects={'MAEMS': MAEMS})
    gc.collect()

# %%
batch_size = 168
testPredict = model.predict(teX, batch_size=batch_size)

# %%
def npMAEMS(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true))*100
def npMAEMD(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true-np.mean(y_true)))*100
def npMSE(y_true, y_pred):
    return np.mean(np.square(-y_true+y_pred))
def npMAE(y_true, y_pred):
    return np.mean(abs(-y_true+y_pred))

# %%
tePredict = testPredict.reshape(-1)
testY = teY.reshape(-1)
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMS == ', npMAEMS(testY, tePredict))
# Out:
# Error Test Score > MSE ==  0.027227923141193332  MAE ==  0.13308981035836942  MAEMS ==  2.8671490561762223

# %% [markdown]
# ## Model Trained with MAE

# %%
num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1.2
    beta = 1
    hfilters = 256
    hkernel_size1 = 1
    hkernel_size2 = 2
    
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    per1 = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(per1)
    den1b = Dense(timesteps, activation='sigmoid')(per1)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])
    
    ## Series PN DCCNN Blocks 1 ~ 6
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([visible1, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([visible1, d1])

    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])   # (100, 25) (100, 25)
    res03 = Concatenate()([res03a, res03b, res02])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res04a = Add()([res03a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res04b = Subtract()([res02b, d2])   # (100, 25) (100, 25)
    res04 = Concatenate()([res04a, res04b, res03])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res05a = Add()([res04a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res05b = Subtract()([res04b, d2])   # (100, 25) (100, 25)
    res05 = Concatenate()([res05a, res05b, res04])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])

    res06a = Add()([res05a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])

    res06b = Subtract()([res05b, d2])   # (100, 25) (100, 25)
    res06 = Concatenate()([res05a, res05b])
    
    res10 = Concatenate()([res02, res03, res04, res05, res06])   # 
    
    #print('res10 :', res10.shap)  # (None, 24, 11) 
    
    ## Output Block
    out = Conv1D(720, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out = Dropout(0.2)(out)   #SpatialDropout1D
    
    out = Conv1D(360, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)
    
    out = GlobalAveragePooling1D()(out) # pool_size=2, strides=1
    
    out = Dense(24)(out) 
    model2 = Model(inputs=[visible1], outputs=[out])
    
    print(model2.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 168, 37)]    0
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 37, 168)      0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 37, 168)      28392       permute_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 37, 168)      28392       permute_1[0][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 37, 168)      0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 168, 37)      0           multiply_24[0][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 168, 37)      0           input_2[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 168, 256)     9728        multiply_25[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 168, 256)     0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 168, 256)     0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 168, 256)     0           activation_44[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 168, 37)      18981       multiply_26[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 168, 37)      0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 168, 37)      0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 168, 37)      0           activation_46[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 168, 37)      0           input_2[0][0]
#                                                                  multiply_27[0][0]
# __________________________________________________________________________________________________
# subtract_6 (Subtract)           (None, 168, 37)      0           input_2[0][0]
#                                                                  multiply_27[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 168, 256)     9728        add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 168, 256)     9728        subtract_6[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 168, 256)     0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 168, 256)     0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 168, 256)     0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 168, 256)     0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 168, 256)     0           activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 168, 256)     0           activation_52[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 168, 37)      18981       multiply_28[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 168, 37)      18981       multiply_30[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 168, 37)      0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 168, 37)      0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 168, 37)      0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 168, 37)      0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 168, 37)      0           activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 168, 37)      0           activation_54[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 168, 37)      0           add_6[0][0]
#                                                                  multiply_29[0][0]
# __________________________________________________________________________________________________
# subtract_7 (Subtract)           (None, 168, 37)      0           subtract_6[0][0]
#                                                                  multiply_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 168, 148)     0           add_7[0][0]
#                                                                  subtract_7[0][0]
#                                                                  add_6[0][0]
#                                                                  subtract_6[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 168, 256)     38144       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 168, 256)     38144       concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 168, 256)     0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 168, 256)     0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 168, 256)     0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 168, 256)     0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 168, 256)     0           activation_56[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 168, 256)     0           activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 168, 37)      18981       multiply_32[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 168, 37)      18981       multiply_34[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 168, 37)      0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 168, 37)      0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 168, 37)      0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 168, 37)      0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 168, 37)      0           activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 168, 37)      0           activation_62[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 168, 37)      0           add_7[0][0]
#                                                                  multiply_33[0][0]
# __________________________________________________________________________________________________
# subtract_8 (Subtract)           (None, 168, 37)      0           subtract_7[0][0]
#                                                                  multiply_35[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 168, 222)     0           add_8[0][0]
#                                                                  subtract_8[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 168, 256)     57088       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 168, 256)     57088       concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 168, 256)     0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 168, 256)     0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 168, 256)     0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 168, 256)     0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 168, 256)     0           activation_64[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 168, 256)     0           activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 168, 37)      18981       multiply_36[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 168, 37)      18981       multiply_38[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 168, 37)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 168, 37)      0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 168, 37)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 168, 37)      0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 168, 37)      0           activation_66[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 168, 37)      0           activation_70[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 168, 37)      0           add_8[0][0]
#                                                                  multiply_37[0][0]
# __________________________________________________________________________________________________
# subtract_9 (Subtract)           (None, 168, 37)      0           subtract_7[0][0]
#                                                                  multiply_39[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 168, 296)     0           add_9[0][0]
#                                                                  subtract_9[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 168, 256)     76032       concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 168, 256)     76032       concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 168, 256)     0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 168, 256)     0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 168, 256)     0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 168, 256)     0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 168, 256)     0           activation_72[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 168, 256)     0           activation_76[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 168, 37)      18981       multiply_40[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 168, 37)      18981       multiply_42[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 168, 37)      0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 168, 37)      0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 168, 37)      0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 168, 37)      0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 168, 37)      0           activation_74[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 168, 37)      0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 168, 37)      0           add_9[0][0]
#                                                                  multiply_41[0][0]
# __________________________________________________________________________________________________
# subtract_10 (Subtract)          (None, 168, 37)      0           subtract_9[0][0]
#                                                                  multiply_43[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 168, 370)     0           add_10[0][0]
#                                                                  subtract_10[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 168, 74)      0           add_10[0][0]
#                                                                  subtract_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 168, 1110)    0           concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  concatenate_8[0][0]
#                                                                  concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 168, 720)     920880      concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 168, 720)     0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 168, 360)     320040      dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 168, 360)     0           conv1d_47[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 360)          0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 24)           8664        global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 1,848,909
# Trainable params: 1,848,909
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 3343

# %%
    model2.compile(loss='mae', optimizer='adam', metrics=['mse','mae', MAEMS])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = 100
    epochs = 1000
    #root_squared_mean_error
    history2 = LossHistory()
    history2.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint

# %%
    # %%time
    b_size = 168
    hist2 = model2.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history2, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
#   6/131 [>.............................] - ETA: 14s - loss: 0.2624 - mse: 0.1075 - mae: 0.2624 - MAEMS: 8.4060WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0551s vs `on_train_batch_end` time: 0.0669s). Check your callbacks.
# 131/131 [==============================] - 21s 142ms/step - loss: 0.1836 - mse: 0.0490 - mae: 0.1836 - MAEMS: 5.2853 - val_loss: 0.1572 - val_mse: 0.0378 - val_mae: 0.1572 - val_MAEMS: 3.9461
# Epoch 2/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.1496 - mse: 0.0347 - mae: 0.1496 - MAEMS: 4.1759 - val_loss: 0.1452 - val_mse: 0.0336 - val_mae: 0.1452 - val_MAEMS: 3.5901
# Epoch 3/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.1400 - mse: 0.0311 - mae: 0.1400 - MAEMS: 3.8676 - val_loss: 0.1369 - val_mse: 0.0302 - val_mae: 0.1369 - val_MAEMS: 3.4758
# Epoch 4/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.1333 - mse: 0.0286 - mae: 0.1333 - MAEMS: 3.6624 - val_loss: 0.1295 - val_mse: 0.0273 - val_mae: 0.1295 - val_MAEMS: 3.4348
# Epoch 5/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.1264 - mse: 0.0262 - mae: 0.1264 - MAEMS: 3.4650 - val_loss: 0.1232 - val_mse: 0.0250 - val_mae: 0.1232 - val_MAEMS: 3.1859
# Epoch 6/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.1183 - mse: 0.0233 - mae: 0.1183 - MAEMS: 3.2164 - val_loss: 0.1172 - val_mse: 0.0227 - val_mae: 0.1172 - val_MAEMS: 3.5317
# Epoch 7/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.1118 - mse: 0.0210 - mae: 0.1118 - MAEMS: 3.0283 - val_loss: 0.1148 - val_mse: 0.0217 - val_mae: 0.1148 - val_MAEMS: 3.6295
# Epoch 8/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.1039 - mse: 0.0184 - mae: 0.1039 - MAEMS: 2.8128 - val_loss: 0.1049 - val_mse: 0.0185 - val_mae: 0.1049 - val_MAEMS: 3.1383
# Epoch 9/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0958 - mse: 0.0158 - mae: 0.0958 - MAEMS: 2.5684 - val_loss: 0.0973 - val_mse: 0.0161 - val_mae: 0.0973 - val_MAEMS: 2.8328
# Epoch 10/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0907 - mse: 0.0143 - mae: 0.0907 - MAEMS: 2.4277 - val_loss: 0.1053 - val_mse: 0.0179 - val_mae: 0.1053 - val_MAEMS: 3.3461
# Epoch 11/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0859 - mse: 0.0128 - mae: 0.0859 - MAEMS: 2.2950 - val_loss: 0.0959 - val_mse: 0.0151 - val_mae: 0.0959 - val_MAEMS: 2.9239
# Epoch 12/1000
# 131/131 [==============================] - 18s 137ms/step - loss: 0.0807 - mse: 0.0113 - mae: 0.0807 - MAEMS: 2.1597 - val_loss: 0.0827 - val_mse: 0.0118 - val_mae: 0.0827 - val_MAEMS: 2.3964
# Epoch 13/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0754 - mse: 0.0099 - mae: 0.0754 - MAEMS: 2.0159 - val_loss: 0.0840 - val_mse: 0.0119 - val_mae: 0.0840 - val_MAEMS: 2.5361
# Epoch 14/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0755 - mse: 0.0098 - mae: 0.0755 - MAEMS: 2.0231 - val_loss: 0.0737 - val_mse: 0.0096 - val_mae: 0.0737 - val_MAEMS: 1.9108
# Epoch 15/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0695 - mse: 0.0084 - mae: 0.0695 - MAEMS: 1.8549 - val_loss: 0.0699 - val_mse: 0.0086 - val_mae: 0.0699 - val_MAEMS: 1.9371
# Epoch 16/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0646 - mse: 0.0073 - mae: 0.0646 - MAEMS: 1.7219 - val_loss: 0.0653 - val_mse: 0.0076 - val_mae: 0.0653 - val_MAEMS: 1.8120
# Epoch 17/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0636 - mse: 0.0070 - mae: 0.0636 - MAEMS: 1.6972 - val_loss: 0.0656 - val_mse: 0.0076 - val_mae: 0.0656 - val_MAEMS: 1.7045
# Epoch 18/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0636 - mse: 0.0069 - mae: 0.0636 - MAEMS: 1.6981 - val_loss: 0.0648 - val_mse: 0.0073 - val_mae: 0.0648 - val_MAEMS: 1.8662
# Epoch 19/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0606 - mse: 0.0063 - mae: 0.0606 - MAEMS: 1.6213 - val_loss: 0.0685 - val_mse: 0.0079 - val_mae: 0.0685 - val_MAEMS: 2.1184
# Epoch 20/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0583 - mse: 0.0058 - mae: 0.0583 - MAEMS: 1.5540 - val_loss: 0.0826 - val_mse: 0.0106 - val_mae: 0.0826 - val_MAEMS: 2.6792
# Epoch 21/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0564 - mse: 0.0055 - mae: 0.0564 - MAEMS: 1.5079 - val_loss: 0.0695 - val_mse: 0.0079 - val_mae: 0.0695 - val_MAEMS: 2.1839
# Epoch 22/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0527 - mse: 0.0048 - mae: 0.0527 - MAEMS: 1.4000 - val_loss: 0.0658 - val_mse: 0.0071 - val_mae: 0.0658 - val_MAEMS: 2.0127
# Epoch 23/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0526 - mse: 0.0047 - mae: 0.0526 - MAEMS: 1.4026 - val_loss: 0.0588 - val_mse: 0.0059 - val_mae: 0.0588 - val_MAEMS: 1.7364
# Epoch 24/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0513 - mse: 0.0045 - mae: 0.0513 - MAEMS: 1.3674 - val_loss: 0.0577 - val_mse: 0.0057 - val_mae: 0.0577 - val_MAEMS: 1.7179
# Epoch 25/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0521 - mse: 0.0046 - mae: 0.0521 - MAEMS: 1.3868 - val_loss: 0.0677 - val_mse: 0.0075 - val_mae: 0.0677 - val_MAEMS: 2.1013
# Epoch 26/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0509 - mse: 0.0044 - mae: 0.0509 - MAEMS: 1.3588 - val_loss: 0.0745 - val_mse: 0.0086 - val_mae: 0.0745 - val_MAEMS: 2.3355
# Epoch 27/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0511 - mse: 0.0044 - mae: 0.0511 - MAEMS: 1.3692 - val_loss: 0.0621 - val_mse: 0.0063 - val_mae: 0.0621 - val_MAEMS: 1.8691
# Epoch 28/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0510 - mse: 0.0044 - mae: 0.0510 - MAEMS: 1.3683 - val_loss: 0.0553 - val_mse: 0.0053 - val_mae: 0.0553 - val_MAEMS: 1.5758
# Epoch 29/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0528 - mse: 0.0046 - mae: 0.0528 - MAEMS: 1.4235 - val_loss: 0.0481 - val_mse: 0.0041 - val_mae: 0.0481 - val_MAEMS: 1.2692
# Epoch 30/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0477 - mse: 0.0038 - mae: 0.0477 - MAEMS: 1.2767 - val_loss: 0.0473 - val_mse: 0.0040 - val_mae: 0.0473 - val_MAEMS: 1.3188
# Epoch 31/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0449 - mse: 0.0034 - mae: 0.0449 - MAEMS: 1.2003 - val_loss: 0.0465 - val_mse: 0.0038 - val_mae: 0.0465 - val_MAEMS: 1.3200
# Epoch 32/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0442 - mse: 0.0033 - mae: 0.0442 - MAEMS: 1.1813 - val_loss: 0.0471 - val_mse: 0.0039 - val_mae: 0.0471 - val_MAEMS: 1.3354
# Epoch 33/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0436 - mse: 0.0032 - mae: 0.0436 - MAEMS: 1.1634 - val_loss: 0.0485 - val_mse: 0.0040 - val_mae: 0.0485 - val_MAEMS: 1.4048
# Epoch 34/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0435 - mse: 0.0032 - mae: 0.0435 - MAEMS: 1.1628 - val_loss: 0.0486 - val_mse: 0.0041 - val_mae: 0.0486 - val_MAEMS: 1.4510
# Epoch 35/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0445 - mse: 0.0033 - mae: 0.0445 - MAEMS: 1.1928 - val_loss: 0.0479 - val_mse: 0.0039 - val_mae: 0.0479 - val_MAEMS: 1.3870
# Epoch 36/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0444 - mse: 0.0033 - mae: 0.0444 - MAEMS: 1.1953 - val_loss: 0.0482 - val_mse: 0.0040 - val_mae: 0.0482 - val_MAEMS: 1.4277
# Epoch 37/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0435 - mse: 0.0032 - mae: 0.0435 - MAEMS: 1.1715 - val_loss: 0.0496 - val_mse: 0.0041 - val_mae: 0.0496 - val_MAEMS: 1.4478
# Epoch 38/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0441 - mse: 0.0032 - mae: 0.0441 - MAEMS: 1.1819 - val_loss: 0.0461 - val_mse: 0.0037 - val_mae: 0.0461 - val_MAEMS: 1.1574
# Epoch 39/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0455 - mse: 0.0034 - mae: 0.0455 - MAEMS: 1.2273 - val_loss: 0.0439 - val_mse: 0.0033 - val_mae: 0.0439 - val_MAEMS: 1.2173
# Epoch 40/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0439 - mse: 0.0032 - mae: 0.0439 - MAEMS: 1.1795 - val_loss: 0.0416 - val_mse: 0.0031 - val_mae: 0.0416 - val_MAEMS: 1.1259
# Epoch 41/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0402 - mse: 0.0027 - mae: 0.0402 - MAEMS: 1.0736 - val_loss: 0.0438 - val_mse: 0.0033 - val_mae: 0.0438 - val_MAEMS: 1.2664
# Epoch 42/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0397 - mse: 0.0026 - mae: 0.0397 - MAEMS: 1.0597 - val_loss: 0.0462 - val_mse: 0.0036 - val_mae: 0.0462 - val_MAEMS: 1.3797
# Epoch 43/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0399 - mse: 0.0027 - mae: 0.0399 - MAEMS: 1.0676 - val_loss: 0.0430 - val_mse: 0.0032 - val_mae: 0.0430 - val_MAEMS: 1.2457
# Epoch 44/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0402 - mse: 0.0027 - mae: 0.0402 - MAEMS: 1.0778 - val_loss: 0.0426 - val_mse: 0.0031 - val_mae: 0.0426 - val_MAEMS: 1.2119
# Epoch 45/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0428 - mse: 0.0030 - mae: 0.0428 - MAEMS: 1.1575 - val_loss: 0.0416 - val_mse: 0.0030 - val_mae: 0.0416 - val_MAEMS: 1.1359
# Epoch 46/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0444 - mse: 0.0032 - mae: 0.0444 - MAEMS: 1.2007 - val_loss: 0.0428 - val_mse: 0.0032 - val_mae: 0.0428 - val_MAEMS: 1.2102
# Epoch 47/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0429 - mse: 0.0030 - mae: 0.0429 - MAEMS: 1.1624 - val_loss: 0.0618 - val_mse: 0.0058 - val_mae: 0.0618 - val_MAEMS: 1.9960
# Epoch 48/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0416 - mse: 0.0028 - mae: 0.0416 - MAEMS: 1.1205 - val_loss: 0.0511 - val_mse: 0.0041 - val_mae: 0.0511 - val_MAEMS: 1.5697
# Epoch 49/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0389 - mse: 0.0025 - mae: 0.0389 - MAEMS: 1.0469 - val_loss: 0.0472 - val_mse: 0.0037 - val_mae: 0.0472 - val_MAEMS: 1.4531
# Epoch 50/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0382 - mse: 0.0024 - mae: 0.0382 - MAEMS: 1.0234 - val_loss: 0.0454 - val_mse: 0.0035 - val_mae: 0.0454 - val_MAEMS: 1.3432
# Epoch 51/1000
# 131/131 [==============================] - 19s 147ms/step - loss: 0.0379 - mse: 0.0024 - mae: 0.0379 - MAEMS: 1.0165 - val_loss: 0.0436 - val_mse: 0.0032 - val_mae: 0.0436 - val_MAEMS: 1.2969
# Epoch 52/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0384 - mse: 0.0025 - mae: 0.0384 - MAEMS: 1.0325 - val_loss: 0.0442 - val_mse: 0.0032 - val_mae: 0.0442 - val_MAEMS: 1.3171
# Epoch 53/1000
# 131/131 [==============================] - 18s 137ms/step - loss: 0.0392 - mse: 0.0025 - mae: 0.0392 - MAEMS: 1.0572 - val_loss: 0.0398 - val_mse: 0.0028 - val_mae: 0.0398 - val_MAEMS: 1.1320
# Epoch 54/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0396 - mse: 0.0026 - mae: 0.0396 - MAEMS: 1.0678 - val_loss: 0.0375 - val_mse: 0.0025 - val_mae: 0.0375 - val_MAEMS: 1.0076
# Epoch 55/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0434 - mse: 0.0031 - mae: 0.0434 - MAEMS: 1.1736 - val_loss: 0.0444 - val_mse: 0.0034 - val_mae: 0.0444 - val_MAEMS: 1.3065
# Epoch 56/1000
# 131/131 [==============================] - 18s 137ms/step - loss: 0.0419 - mse: 0.0029 - mae: 0.0419 - MAEMS: 1.1354 - val_loss: 0.0505 - val_mse: 0.0041 - val_mae: 0.0505 - val_MAEMS: 1.5873
# Epoch 57/1000
# 131/131 [==============================] - 18s 137ms/step - loss: 0.0373 - mse: 0.0023 - mae: 0.0373 - MAEMS: 1.0042 - val_loss: 0.0427 - val_mse: 0.0030 - val_mae: 0.0427 - val_MAEMS: 1.3013
# Epoch 58/1000
# 131/131 [==============================] - 18s 137ms/step - loss: 0.0356 - mse: 0.0021 - mae: 0.0356 - MAEMS: 0.9548 - val_loss: 0.0452 - val_mse: 0.0034 - val_mae: 0.0452 - val_MAEMS: 1.4101
# Epoch 59/1000
# 131/131 [==============================] - 18s 137ms/step - loss: 0.0354 - mse: 0.0021 - mae: 0.0354 - MAEMS: 0.9493 - val_loss: 0.0445 - val_mse: 0.0033 - val_mae: 0.0445 - val_MAEMS: 1.3928
# Epoch 60/1000
# 131/131 [==============================] - 18s 137ms/step - loss: 0.0350 - mse: 0.0020 - mae: 0.0350 - MAEMS: 0.9404 - val_loss: 0.0443 - val_mse: 0.0032 - val_mae: 0.0443 - val_MAEMS: 1.3469
# Epoch 61/1000
# 131/131 [==============================] - 18s 137ms/step - loss: 0.0353 - mse: 0.0021 - mae: 0.0353 - MAEMS: 0.9453 - val_loss: 0.0521 - val_mse: 0.0042 - val_mae: 0.0521 - val_MAEMS: 1.6693
# Epoch 62/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0354 - mse: 0.0021 - mae: 0.0354 - MAEMS: 0.9504 - val_loss: 0.0476 - val_mse: 0.0036 - val_mae: 0.0476 - val_MAEMS: 1.4527
# Epoch 63/1000
# 131/131 [==============================] - 18s 135ms/step - loss: 0.0356 - mse: 0.0021 - mae: 0.0356 - MAEMS: 0.9584 - val_loss: 0.0440 - val_mse: 0.0032 - val_mae: 0.0440 - val_MAEMS: 1.3437
# Epoch 64/1000
# 131/131 [==============================] - 18s 136ms/step - loss: 0.0355 - mse: 0.0021 - mae: 0.0355 - MAEMS: 0.9539 - val_loss: 0.0443 - val_mse: 0.0033 - val_mae: 0.0443 - val_MAEMS: 1.3562
# Wall time: 19min 1s

# %%
gc.collect()
# Out:
# 4601

# %%
#np.savetxt('losshistory.txt',(loss_history,valloss_history))
model2.save('Basic Model Final_mae.h5')

# %%
with tf.device('/gpu:0'):
    model2 = keras.models.load_model('Basic Model Final_mae.h5', custom_objects={'MAEMS': MAEMS})
    gc.collect()

# %%
testPredict2 = model2.predict(teX, batch_size=batch_size)
tePredict2 = testPredict2.reshape(-1)

# %% [markdown]
# ## Proposed Model

# %%
with tf.device('/gpu:0'):
    model3 = keras.models.load_model('Basic Model Final_lead.h5', custom_objects={'MAEMS': MAEMS})
    gc.collect()

# %%
testPredict3 = model3.predict(teX, batch_size=batch_size)
tePredict3 = testPredict3.reshape(-1)

# %%
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMS == ', npMAEMS(testY, tePredict))
print('Error Test Score > MSE == ', npMSE(testY, tePredict2), ' MAE == ', npMAE(testY, tePredict2), ' MAEMS == ', npMAEMS(testY, tePredict2))
print('Error Test Score > MSE == ', npMSE(testY, tePredict3), ' MAE == ', npMAE(testY, tePredict3), ' MAEMS == ', npMAEMS(testY, tePredict3))
# Out:
# Error Test Score > MSE ==  0.027227923141193332  MAE ==  0.13308981035836942  MAEMS ==  2.8671490561762223
# Error Test Score > MSE ==  0.028031291429987035  MAE ==  0.13457001603766094  MAEMS ==  2.8558440656792388
# Error Test Score > MSE ==  0.032836721856768156  MAE ==  0.14583632600714025  MAEMS ==  2.3040104722921315

# %%
hgen = testY>0.8
testY2 = testY[hgen]
tePredict = tePredict[hgen]
tePredict2 = tePredict2[hgen]
tePredict3 = tePredict3[hgen]

# %%
print('Error Test Score > MSE == ', npMSE(testY2, tePredict), ' MAE == ', npMAE(testY2, tePredict), ' MAEMS == ', npMAEMS(testY2, tePredict))
print('Error Test Score > MSE == ', npMSE(testY2, tePredict2), ' MAE == ', npMAE(testY2, tePredict2), ' MAEMS == ', npMAEMS(testY2, tePredict2))
print('Error Test Score > MSE == ', npMSE(testY2, tePredict3), ' MAE == ', npMAE(testY2, tePredict3), ' MAEMS == ', npMAEMS(testY2, tePredict3))
# Out:
# Error Test Score > MSE ==  0.07438461522116858  MAE ==  0.2427495053309863  MAEMS ==  16.45408172622537
# Error Test Score > MSE ==  0.06563540038306762  MAE ==  0.22798114938996003  MAEMS ==  15.442091655026125
# Error Test Score > MSE ==  0.03806075293943188  MAE ==  0.18053776427410118  MAEMS ==  12.18167477891607
