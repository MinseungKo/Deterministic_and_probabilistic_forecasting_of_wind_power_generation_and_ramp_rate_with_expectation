# %%
import tensorflow as tf

import pandas as pd
import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
#from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply, Subtract
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout, SpatialDropout1D
from scipy import signal
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pylab as plt
import matplotlib.dates as mdates
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc
from keijzer import *
from tensorflow import keras
from keras.models import Model
from keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply, Embedding, Layer, Reshape
from keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
#from keras.ops import convert_to_tensor, convert_to_numpy
#from keras.utils import plot_model
from keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))



def root_squared_mean_error(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))+K.mean(K.abs(y_pred - y_true))

from keras.layers.advanced_activations import PReLU

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '0' # 여러개 사용시 '0,1,2' 식으로 하나의 문자열에 입력
gpus = tf.config.experimental.list_physical_devices('GPU') # 호스트 러나임에 표시되는 GPU 장치 목록 반환

if gpus: # 반환된 GPU 장치 목록이 있다면
    try: # 해당 장치에 대한 메모리 증가 활성화 여부 설정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e: # try문 실패시에 에러문구 출력
        print(e)

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Import Data & Preprocessing

# %%
data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2020.csv'
data_source1 = pd.read_csv(data_path)
dat_source1 = pd.DataFrame(data_source1)
#dat_source1 = dat_source1.iloc[:-3,:]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2021.csv'
data_source2 = pd.read_csv(data_path)
dat_source2 = pd.DataFrame(data_source2)
dat_source2 = dat_source2.iloc[:8761,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2022.csv'
data_source3 = pd.read_csv(data_path)
dat_source3 = pd.DataFrame(data_source3)
dat_source3 = dat_source3.iloc[:8760,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2023.csv'
data_source4 = pd.read_csv(data_path)
dat_source4 = pd.DataFrame(data_source4)
dat_source4 = dat_source4.iloc[:8760,:9]

dat_arr1 = np.array(dat_source1)
dat_arr2 = np.array(dat_source2)
dat_arr3 = np.array(dat_source3)
dat_arr4 = np.array(dat_source4)

dat_arr = np.concatenate([dat_arr1, dat_arr2, dat_arr3, dat_arr4],axis=0)
dat_arr.shape # 8784, 8761, 8760, 8760

dat_source = pd.DataFrame(dat_arr, columns=['Time-Date stamp','Date','ERCOT Load','Total Wind Output','Total Wind Installed','Wind Output, % of Load','Wind Output, % of Installed','1-hr MW change','1-hr % change'])
dat_source
# Out:
#            Time-Date stamp    Date ERCOT Load Total Wind Output  \
# 0      01-01-2020 00:00:00  Jan-01      36823             12335
# 1      01-01-2020 01:00:00  Jan-01      36511             13300
# 2      01-01-2020 02:00:00  Jan-01      36022             13586
# 3      01-01-2020 03:00:00  Jan-01      35790             14107
# 4      01-01-2020 04:00:00  Jan-01      35642             14887
# ...                    ...     ...        ...               ...
# 35060  12-31-2023 20:00:00  Dec-31      44887             17161
# 35061  12-31-2023 21:00:00  Dec-31      44013             18301
# 35062  12-31-2023 22:00:00  Dec-31      43280             18607
# 35063  12-31-2023 23:00:00  Dec-31      42319             17866
# 35064  01-01-2024 00:00:00  Jan-01      41682             15869
#
#       Total Wind Installed Wind Output, % of Load Wind Output, % of Installed  \
# 0                    27040                   33.5                      45.617
# 1                    27040                   36.4                      49.187
# 2                    27040                   37.7                      50.245
# 3                    27040                   39.4                      52.171
# 4                    27040                   41.8                      55.055
# ...                    ...                    ...                         ...
# 35060                38631                  38.23                       44.42
# 35061                38631                  41.58                       47.37
# 35062                38631                  42.99                       48.17
# 35063                38631                  42.22                       46.25
# 35064                38631                  38.07                       41.08
#
#       1-hr MW change 1-hr % change
# 0                NaN           NaN
# 1              965.4         7.826
# 2              286.2         2.152
# 3              520.9         3.834
# 4              779.6         5.527
# ...              ...           ...
# 35060           2858         19.99
# 35061           1139          6.64
# 35062            307          1.67
# 35063           -741         -3.98
# 35064          -1996        -11.17
#
# [35065 rows x 9 columns]

# %% [markdown]
# ### Dividing by Installed Capacity & Preprocessing

# %%
dat = pd.DataFrame()
dat['MW % change'] = np.array(dat_source.iloc[1:,3], dtype=float)-np.array(dat_source.iloc[0:-1,3], dtype=float)
dat['MW % change'] = np.divide(np.array(dat['MW % change']),np.array(dat_source.iloc[1:,4]))*100
dat['Total Wind Output'] = np.divide(np.array(dat_source.iloc[1:,3]), np.array(dat_source.iloc[1:,4]))

dat
# Out:
#       MW % change Total Wind Output
# 0         3.56879          0.491864
# 1         1.05769          0.502441
# 2         1.92678          0.521709
# 3         2.88462          0.550555
# 4       -0.580621          0.544749
# ...           ...               ...
# 35059      7.3982          0.444229
# 35060       2.951          0.473739
# 35061     0.79211           0.48166
# 35062    -1.91815          0.462478
# 35063    -5.16942          0.410784
#
# [35064 rows x 2 columns]

# %%
ramp_ratio = 20
load_ratio = 10
year_arr = np.concatenate([np.ones(8784)*2020, np.ones(8760)*2021, np.ones(8760)*2022, np.ones(8760)*2023])
year_df = pd.DataFrame(year_arr, columns=['Year'], dtype=int)
wind_df = pd.concat([year_df, dat], axis=1)
wind_df
# Out:
#        Year MW % change Total Wind Output
# 0      2020     3.56879          0.491864
# 1      2020     1.05769          0.502441
# 2      2020     1.92678          0.521709
# 3      2020     2.88462          0.550555
# 4      2020   -0.580621          0.544749
# ...     ...         ...               ...
# 35059  2023      7.3982          0.444229
# 35060  2023       2.951          0.473739
# 35061  2023     0.79211           0.48166
# 35062  2023    -1.91815          0.462478
# 35063  2023    -5.16942          0.410784
#
# [35064 rows x 3 columns]

# %%
wind_df = wind_df.reset_index(drop=True)
std_scaler = sklearn.preprocessing.MinMaxScaler()
std_scaler_load = sklearn.preprocessing.MinMaxScaler()
std_scaler_ramp = sklearn.preprocessing.MinMaxScaler()

wind_df[['Total Wind Output']] = std_scaler.fit_transform(wind_df[['Total Wind Output']])
wind_df[['MW % change']] = std_scaler_ramp.fit_transform(wind_df[['MW % change']])
#wind_df[['Wind Change, % of Load', 'Wind Change']] = std_scaler_ramp.fit_transform(wind_df[['Wind Change, % of Load', 'Wind Change']])
wind_df = wind_df.iloc[:-1,:]
wind_df
# Out:
#        Year  MW % change  Total Wind Output
# 0      2020     0.620197           0.644724
# 1      2020     0.544580           0.658617
# 2      2020     0.570751           0.683924
# 3      2020     0.599594           0.721813
# 4      2020     0.495246           0.714187
# ...     ...          ...                ...
# 35058  2023     0.774643           0.484984
# 35059  2023     0.735512           0.582157
# 35060  2023     0.601593           0.620917
# 35061  2023     0.536583           0.631322
# 35062  2023     0.454969           0.606127
#
# [35063 rows x 3 columns]

# %%
ramp_df = pd.DataFrame(wind_df)
ramp_df.columns=['Year', 'Wind Change', 'Wind Output']
ramp_df
# Out:
#        Year  Wind Change  Wind Output
# 0      2020     0.620197     0.644724
# 1      2020     0.544580     0.658617
# 2      2020     0.570751     0.683924
# 3      2020     0.599594     0.721813
# 4      2020     0.495246     0.714187
# ...     ...          ...          ...
# 35058  2023     0.774643     0.484984
# 35059  2023     0.735512     0.582157
# 35060  2023     0.601593     0.620917
# 35061  2023     0.536583     0.631322
# 35062  2023     0.454969     0.606127
#
# [35063 rows x 3 columns]

# %% [markdown]
# ## Wind Ramp Rate Forecasting

# %% [markdown]
# ### SVD-based Feature Generation

# %%
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc

def create_dataset(dataset, timesteps, output_timesteps, leadtime):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - leadtime - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps + leadtime):(i+timesteps+output_timesteps+leadtime), :])
    return np.array(dataX), np.array(dataY)

# %%
norm_df = np.array(wind_df['Wind Change']).reshape(-1,1)
timesteps = 24*6
output_timesteps = 12
num_features = 1
leadtime = 4
X, Y = create_dataset(norm_df, timesteps, output_timesteps, leadtime)
b_size = timesteps

# %%
dec_num = timesteps
high_ind = 35

addX = np.zeros((X.shape[0], dec_num, high_ind+1))

def svdadd(X, start, end, b_size):
    dec_x = X[start:end, :, :]
    U, S, Vh = svd(dec_x.reshape(b_size, -1))

    high_sig = np.matmul(np.matmul(U[:,:high_ind], np.diag(S[0:high_ind])), Vh[:high_ind,:])
    low_sig = X[:dec_num, :, :].reshape(b_size,-1)-high_sig

    rec_x = np.zeros((b_size, b_size, high_ind))
    #print(sum(S[0:high_ind])/sum(S))
    for i in range(high_ind):
        rec_x[:,:,i] = np.matmul((U[:,i]*S[i]).reshape(-1,1), Vh[i,:].reshape(1,-1))    
    return rec_x, low_sig

for k in range(X.shape[0]//dec_num):
    rec_x, low_sig = svdadd(X, k*dec_num, (k+1)*dec_num, b_size)
    addX[k*dec_num:k*dec_num+dec_num,:, :-1] = rec_x
    addX[k*dec_num:k*dec_num+dec_num,:, -1] = low_sig
    
rec_x, low_sig = svdadd(X, X.shape[0]-dec_num, X.shape[0], b_size)
addX[X.shape[0]-dec_num:X.shape[0], :, :-1] = rec_x
addX[X.shape[0]-dec_num:X.shape[0],:, -1] = low_sig

addX_det = addX[:, :, :-1]
addX_det = np.sum(addX_det, axis=2)
X = np.concatenate([X, addX], axis=2)
num_features = X.shape[2]

# %% [markdown]
# ### Training/Test Set Division & Shuffled Learning

# %%
trvaX, teX, trvaY, teY = train_test_split(X, Y, test_size=0.1, shuffle=False)

idx = np.arange(trvaX.shape[0])
np.random.shuffle(idx)
strvaX = trvaX[idx]
strvaY = trvaY[idx]
strvaY = strvaY.reshape(-1, output_timesteps)

trvaY = trvaY.reshape(-1, output_timesteps)
teY = teY.reshape(-1, output_timesteps)

strX, svaX, strY, svaY = train_test_split(strvaX, strvaY, test_size=0.3, shuffle=False)
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=0.3, shuffle=False)

trvaX.shape, trvaY.shape, teX.shape, teY.shape
# Out:
# ((31411, 144, 37), (31411, 12), (3491, 144, 37), (3491, 12))

# %% [markdown]
# ## Wind Ramp Rate Forecasting Basic Model

# %%
def MAEMD(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

# %%
from keras.layers.advanced_activations import PReLU

# %%
from keras import regularizers

num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1
    beta = 1
    hfilters = 168
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    pera = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(pera)
    den1b = Dense(timesteps, activation='sigmoid')(pera)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])   
    
    ## Permuted Attention Block
    per1 = Permute((2,1))(visible1)
    den2a = Dense(num_features, activation='tanh')(visible1)
    den2b = Dense(num_features, activation='sigmoid')(visible1)
    den2 = Multiply()([den2a, den2b])
    perb2 = Permute((2,1), name='attention_vec2')(den2)
    
    mul2 = Multiply()([per1, perb2])     
    
    ## Parallel DCCNN Blocks 1-1 ~ 3-1
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres01a = Add()([mul1, d1])   # (100, 25) (100, 25)
    rres01b = Subtract()([mul1, d1])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    rres02a = Add()([rres01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(rres01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    rres02b = Subtract()([rres01b, d2])   # (100, 25) (100, 25) 
    rres02 = Concatenate()([rres02a, rres02b, rres01a, rres01b])
    #rres02 = Dropout(0.2)(rres02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    rres03a = Add()([rres02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(rres02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    rres03b = Subtract()([rres02b, d2])
    rres10 = Concatenate()([rres03a, rres03b, rres02])

    ## Right-half DCCNN Blocks 1-2 ~ 3-2
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul2)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([mul2, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([mul2, d1])
    
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    #res02 = Dropout(0.2)(res02)
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=timesteps, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])
    res10 = Concatenate()([res03a, res03b, res02])

    ## Output Blocks
    out1 = Conv1D(24*7, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out1 = Dropout(0.2)(out1)  
    
    out2 = Conv1D(24*7, 1, padding='same', activation=PReLU())(rres10)   # 256, 11X10=110
    out2 = Dropout(0.2)(out2)
    
    out = Concatenate(axis=1)([out1, out2])
    
    ## Output Block
    out = Conv1D(24*7, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)

    #, kernel_regularizer=regularizers.L1L2(l1=1e-5, l2=1e-4)
    out = GlobalAveragePooling1D()(out) 

    out = Dense(output_timesteps)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 144, 37)]    0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 37, 144)      0           input_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 144, 37)      1406        input_1[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 144, 37)      1406        input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 37, 144)      20880       permute[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 37, 144)      20880       permute[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 144, 37)      0           dense_2[0][0]
#                                                                  dense_3[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 37, 144)      0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 37, 144)      0           input_1[0][0]
# __________________________________________________________________________________________________
# attention_vec2 (Permute)        (None, 37, 144)      0           multiply_2[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 144, 37)      0           multiply[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 37, 144)      0           permute_1[0][0]
#                                                                  attention_vec2[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 144, 37)      0           input_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 37, 168)      24360       multiply_3[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 144, 168)     6384        multiply_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 37, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 37, 168)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 144, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 144, 168)     0           conv1d[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 37, 168)      0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 144, 168)     0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 37, 144)      48528       multiply_14[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 144, 37)      12469       multiply_4[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 37, 144)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 37, 144)      0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 144, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 144, 37)      0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 37, 144)      0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 144, 37)      0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 37, 144)      0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 37, 144)      0           multiply_3[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 144, 37)      0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 144, 37)      0           multiply_1[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 37, 168)      24360       add_3[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 37, 168)      24360       subtract_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 144, 168)     6384        add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 144, 168)     6384        subtract[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 37, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 37, 168)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 37, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 37, 168)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 144, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 144, 168)     0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 144, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 144, 168)     0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 37, 168)      0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 37, 168)      0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 144, 168)     0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 144, 168)     0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 37, 144)      48528       multiply_16[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 37, 144)      48528       multiply_18[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 144, 37)      12469       multiply_6[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 144, 37)      12469       multiply_8[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 37, 144)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 37, 144)      0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 37, 144)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 37, 144)      0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 144, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 144, 37)      0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 144, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 144, 37)      0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 37, 144)      0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 37, 144)      0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 144, 37)      0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 144, 37)      0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 37, 144)      0           add_3[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 37, 144)      0           subtract_3[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 144, 37)      0           add[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 144, 37)      0           subtract[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 37, 576)      0           add_4[0][0]
#                                                                  subtract_4[0][0]
#                                                                  add_3[0][0]
#                                                                  subtract_3[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 144, 148)     0           add_1[0][0]
#                                                                  subtract_1[0][0]
#                                                                  add[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 37, 168)      96936       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_18 (Conv1D)              (None, 37, 168)      96936       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 144, 168)     25032       concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 144, 168)     25032       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 37, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 37, 168)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 37, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_37 (Activation)      (None, 37, 168)      0           conv1d_18[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 144, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 144, 168)     0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 144, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 144, 168)     0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_20 (Multiply)          (None, 37, 168)      0           activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# multiply_22 (Multiply)          (None, 37, 168)      0           activation_36[0][0]
#                                                                  activation_37[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 144, 168)     0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 144, 168)     0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 37, 144)      48528       multiply_20[0][0]
# __________________________________________________________________________________________________
# conv1d_19 (Conv1D)              (None, 37, 144)      48528       multiply_22[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 144, 37)      12469       multiply_10[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 144, 37)      12469       multiply_12[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 37, 144)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 37, 144)      0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_38 (Activation)      (None, 37, 144)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_39 (Activation)      (None, 37, 144)      0           conv1d_19[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 144, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 144, 37)      0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 144, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 144, 37)      0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_21 (Multiply)          (None, 37, 144)      0           activation_34[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# multiply_23 (Multiply)          (None, 37, 144)      0           activation_38[0][0]
#                                                                  activation_39[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 144, 37)      0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 144, 37)      0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# add_5 (Add)                     (None, 37, 144)      0           add_4[0][0]
#                                                                  multiply_21[0][0]
# __________________________________________________________________________________________________
# subtract_5 (Subtract)           (None, 37, 144)      0           subtract_4[0][0]
#                                                                  multiply_23[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 144, 37)      0           add_1[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 144, 37)      0           subtract_1[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 37, 864)      0           add_5[0][0]
#                                                                  subtract_5[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 144, 222)     0           add_2[0][0]
#                                                                  subtract_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_20 (Conv1D)              (None, 37, 168)      151536      concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv1d_21 (Conv1D)              (None, 144, 168)     61656       concatenate_1[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 37, 168)      0           conv1d_20[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 144, 168)     0           conv1d_21[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 181, 168)     0           dropout[0][0]
#                                                                  dropout_1[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 181, 168)     58800       concatenate_4[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 181, 168)     0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 168)          0           dropout_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 12)           2028        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 959,745
# Trainable params: 959,745
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 1503

# %%
    model.compile(loss=MAEMD, optimizer='adam', metrics=['mse','mae', MAEMD])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = timesteps
    epochs = 1000
    #root_squared_mean_error
    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint

# %%
    # %%time
    b_size = timesteps
    #hist = model.fit(strvaX, strvaY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(teX, teY), callbacks=[history, early_stopping])  # , checkpoint
    hist = model.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 153/153 [==============================] - 82s 411ms/step - loss: 0.2082 - mse: 0.0279 - mae: 0.1180 - MAEMD: 0.2081 - val_loss: 0.1608 - val_mse: 0.0155 - val_mae: 0.0990 - val_MAEMD: 0.1607
# Epoch 2/1000
# 153/153 [==============================] - 94s 617ms/step - loss: 0.1459 - mse: 0.0170 - mae: 0.1036 - MAEMD: 0.1459 - val_loss: 0.1370 - val_mse: 0.0166 - val_mae: 0.1040 - val_MAEMD: 0.1370
# Epoch 3/1000
# 153/153 [==============================] - 97s 631ms/step - loss: 0.1358 - mse: 0.0177 - mae: 0.1070 - MAEMD: 0.1358 - val_loss: 0.1340 - val_mse: 0.0178 - val_mae: 0.1084 - val_MAEMD: 0.1340
# Epoch 4/1000
# 153/153 [==============================] - 96s 630ms/step - loss: 0.1325 - mse: 0.0177 - mae: 0.1071 - MAEMD: 0.1325 - val_loss: 0.1304 - val_mse: 0.0175 - val_mae: 0.1073 - val_MAEMD: 0.1304
# Epoch 5/1000
# 153/153 [==============================] - 97s 636ms/step - loss: 0.1295 - mse: 0.0174 - mae: 0.1060 - MAEMD: 0.1295 - val_loss: 0.1253 - val_mse: 0.0160 - val_mae: 0.1018 - val_MAEMD: 0.1252
# Epoch 6/1000
# 153/153 [==============================] - 97s 631ms/step - loss: 0.1270 - mse: 0.0172 - mae: 0.1049 - MAEMD: 0.1270 - val_loss: 0.1244 - val_mse: 0.0155 - val_mae: 0.0993 - val_MAEMD: 0.1243
# Epoch 7/1000
# 153/153 [==============================] - 94s 618ms/step - loss: 0.1252 - mse: 0.0168 - mae: 0.1034 - MAEMD: 0.1252 - val_loss: 0.1233 - val_mse: 0.0153 - val_mae: 0.0988 - val_MAEMD: 0.1232
# Epoch 8/1000
# 153/153 [==============================] - 98s 634ms/step - loss: 0.1233 - mse: 0.0165 - mae: 0.1024 - MAEMD: 0.1233 - val_loss: 0.1244 - val_mse: 0.0152 - val_mae: 0.0986 - val_MAEMD: 0.1243
# Epoch 9/1000
# 153/153 [==============================] - 95s 620ms/step - loss: 0.1205 - mse: 0.0159 - mae: 0.1003 - MAEMD: 0.1205 - val_loss: 0.1245 - val_mse: 0.0156 - val_mae: 0.0998 - val_MAEMD: 0.1244
# Epoch 10/1000
# 153/153 [==============================] - 93s 609ms/step - loss: 0.1190 - mse: 0.0158 - mae: 0.0996 - MAEMD: 0.1190 - val_loss: 0.1216 - val_mse: 0.0150 - val_mae: 0.0977 - val_MAEMD: 0.1215
# Epoch 11/1000
# 153/153 [==============================] - 95s 620ms/step - loss: 0.1167 - mse: 0.0154 - mae: 0.0984 - MAEMD: 0.1167 - val_loss: 0.1203 - val_mse: 0.0146 - val_mae: 0.0960 - val_MAEMD: 0.1202
# Epoch 12/1000
# 153/153 [==============================] - 89s 582ms/step - loss: 0.1141 - mse: 0.0150 - mae: 0.0969 - MAEMD: 0.1141 - val_loss: 0.1205 - val_mse: 0.0143 - val_mae: 0.0950 - val_MAEMD: 0.1203
# Epoch 13/1000
# 153/153 [==============================] - 96s 629ms/step - loss: 0.1119 - mse: 0.0147 - mae: 0.0959 - MAEMD: 0.1119 - val_loss: 0.1191 - val_mse: 0.0146 - val_mae: 0.0963 - val_MAEMD: 0.1190
# Epoch 14/1000
# 153/153 [==============================] - 95s 618ms/step - loss: 0.1098 - mse: 0.0145 - mae: 0.0951 - MAEMD: 0.1099 - val_loss: 0.1251 - val_mse: 0.0163 - val_mae: 0.1027 - val_MAEMD: 0.1250
# Epoch 15/1000
# 153/153 [==============================] - 97s 631ms/step - loss: 0.1082 - mse: 0.0145 - mae: 0.0951 - MAEMD: 0.1082 - val_loss: 0.1246 - val_mse: 0.0154 - val_mae: 0.0995 - val_MAEMD: 0.1246
# Epoch 16/1000
# 153/153 [==============================] - 95s 621ms/step - loss: 0.1070 - mse: 0.0144 - mae: 0.0947 - MAEMD: 0.1070 - val_loss: 0.1191 - val_mse: 0.0140 - val_mae: 0.0940 - val_MAEMD: 0.1190
# Epoch 17/1000
# 153/153 [==============================] - 95s 622ms/step - loss: 0.1057 - mse: 0.0143 - mae: 0.0941 - MAEMD: 0.1057 - val_loss: 0.1196 - val_mse: 0.0146 - val_mae: 0.0959 - val_MAEMD: 0.1195
# Epoch 18/1000
# 153/153 [==============================] - 94s 617ms/step - loss: 0.1038 - mse: 0.0142 - mae: 0.0939 - MAEMD: 0.1038 - val_loss: 0.1203 - val_mse: 0.0143 - val_mae: 0.0950 - val_MAEMD: 0.1202
# Epoch 19/1000
# 153/153 [==============================] - 90s 589ms/step - loss: 0.1029 - mse: 0.0142 - mae: 0.0937 - MAEMD: 0.1029 - val_loss: 0.1203 - val_mse: 0.0145 - val_mae: 0.0958 - val_MAEMD: 0.1202
# Epoch 20/1000
# 153/153 [==============================] - 89s 583ms/step - loss: 0.1018 - mse: 0.0142 - mae: 0.0936 - MAEMD: 0.1018 - val_loss: 0.1186 - val_mse: 0.0146 - val_mae: 0.0957 - val_MAEMD: 0.1185
# Epoch 21/1000
# 153/153 [==============================] - 89s 583ms/step - loss: 0.1004 - mse: 0.0141 - mae: 0.0933 - MAEMD: 0.1004 - val_loss: 0.1189 - val_mse: 0.0135 - val_mae: 0.0915 - val_MAEMD: 0.1188
# Epoch 22/1000
# 153/153 [==============================] - 96s 627ms/step - loss: 0.1002 - mse: 0.0141 - mae: 0.0935 - MAEMD: 0.1002 - val_loss: 0.1189 - val_mse: 0.0136 - val_mae: 0.0920 - val_MAEMD: 0.1187
# Epoch 23/1000
# 153/153 [==============================] - 98s 642ms/step - loss: 0.1012 - mse: 0.0143 - mae: 0.0941 - MAEMD: 0.1012 - val_loss: 0.1195 - val_mse: 0.0144 - val_mae: 0.0949 - val_MAEMD: 0.1194
# Epoch 24/1000
# 153/153 [==============================] - 100s 657ms/step - loss: 0.0998 - mse: 0.0141 - mae: 0.0934 - MAEMD: 0.0998 - val_loss: 0.1190 - val_mse: 0.0144 - val_mae: 0.0947 - val_MAEMD: 0.1189
# Epoch 25/1000
# 153/153 [==============================] - 96s 624ms/step - loss: 0.0975 - mse: 0.0139 - mae: 0.0927 - MAEMD: 0.0975 - val_loss: 0.1187 - val_mse: 0.0136 - val_mae: 0.0915 - val_MAEMD: 0.1185
# Epoch 26/1000
# 153/153 [==============================] - 100s 651ms/step - loss: 0.0948 - mse: 0.0137 - mae: 0.0917 - MAEMD: 0.0948 - val_loss: 0.1178 - val_mse: 0.0142 - val_mae: 0.0939 - val_MAEMD: 0.1177
# Epoch 27/1000
# 153/153 [==============================] - 97s 638ms/step - loss: 0.0940 - mse: 0.0137 - mae: 0.0918 - MAEMD: 0.0940 - val_loss: 0.1197 - val_mse: 0.0141 - val_mae: 0.0934 - val_MAEMD: 0.1196
# Epoch 28/1000
# 153/153 [==============================] - 97s 637ms/step - loss: 0.0931 - mse: 0.0137 - mae: 0.0917 - MAEMD: 0.0931 - val_loss: 0.1184 - val_mse: 0.0142 - val_mae: 0.0937 - val_MAEMD: 0.1182
# Epoch 29/1000
# 153/153 [==============================] - 96s 630ms/step - loss: 0.0923 - mse: 0.0137 - mae: 0.0917 - MAEMD: 0.0923 - val_loss: 0.1170 - val_mse: 0.0141 - val_mae: 0.0934 - val_MAEMD: 0.1169
# Epoch 30/1000
# 153/153 [==============================] - 98s 644ms/step - loss: 0.0910 - mse: 0.0135 - mae: 0.0911 - MAEMD: 0.0910 - val_loss: 0.1176 - val_mse: 0.0134 - val_mae: 0.0909 - val_MAEMD: 0.1174
# Epoch 31/1000
# 153/153 [==============================] - 94s 614ms/step - loss: 0.0902 - mse: 0.0135 - mae: 0.0911 - MAEMD: 0.0902 - val_loss: 0.1193 - val_mse: 0.0141 - val_mae: 0.0933 - val_MAEMD: 0.1191
# Epoch 32/1000
# 153/153 [==============================] - 96s 631ms/step - loss: 0.0890 - mse: 0.0135 - mae: 0.0908 - MAEMD: 0.0891 - val_loss: 0.1185 - val_mse: 0.0139 - val_mae: 0.0926 - val_MAEMD: 0.1184
# Epoch 33/1000
# 153/153 [==============================] - 94s 617ms/step - loss: 0.0884 - mse: 0.0134 - mae: 0.0905 - MAEMD: 0.0884 - val_loss: 0.1188 - val_mse: 0.0141 - val_mae: 0.0936 - val_MAEMD: 0.1187
# Epoch 34/1000
# 153/153 [==============================] - 100s 655ms/step - loss: 0.0875 - mse: 0.0134 - mae: 0.0905 - MAEMD: 0.0875 - val_loss: 0.1184 - val_mse: 0.0139 - val_mae: 0.0928 - val_MAEMD: 0.1183
# Epoch 35/1000
# 153/153 [==============================] - 105s 686ms/step - loss: 0.0876 - mse: 0.0133 - mae: 0.0903 - MAEMD: 0.0876 - val_loss: 0.1185 - val_mse: 0.0143 - val_mae: 0.0941 - val_MAEMD: 0.1183
# Epoch 36/1000
# 153/153 [==============================] - 104s 675ms/step - loss: 0.0864 - mse: 0.0133 - mae: 0.0901 - MAEMD: 0.0864 - val_loss: 0.1179 - val_mse: 0.0140 - val_mae: 0.0932 - val_MAEMD: 0.1177
# Epoch 37/1000
# 153/153 [==============================] - 95s 619ms/step - loss: 0.0858 - mse: 0.0133 - mae: 0.0900 - MAEMD: 0.0858 - val_loss: 0.1175 - val_mse: 0.0141 - val_mae: 0.0934 - val_MAEMD: 0.1173
# Epoch 38/1000
# 153/153 [==============================] - 91s 596ms/step - loss: 0.0855 - mse: 0.0132 - mae: 0.0897 - MAEMD: 0.0855 - val_loss: 0.1188 - val_mse: 0.0145 - val_mae: 0.0950 - val_MAEMD: 0.1187
# Epoch 39/1000
# 153/153 [==============================] - 96s 630ms/step - loss: 0.0854 - mse: 0.0132 - mae: 0.0898 - MAEMD: 0.0854 - val_loss: 0.1180 - val_mse: 0.0140 - val_mae: 0.0932 - val_MAEMD: 0.1178
# Wall time: 1h 2min 2s

# %% [markdown]
# ### Saving Basic Model Training Results

# %%
model.save('Basic Ramp Model Final_fh12.h5')

# %%
gc.collect()
# Out:
# 4592

# %%
loss_history = hist.history['loss']
valloss_history = hist.history['val_loss']

# %% [markdown]
# ## Basic Model Test Results

# %%
testPredict = model.predict(teX, batch_size=batch_size)

# %%
def npMAEMS(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true))*100
def npMAEMD(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true-np.mean(y_true)))*100
def npMSE(y_true, y_pred):
    return np.mean(np.square(-y_true+y_pred))
def npMAE(y_true, y_pred):
    return np.mean(abs(-y_true+y_pred))

# %%
tePredict = testPredict.reshape(-1)
testY = teY.reshape(-1)
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMS == ', npMAEMD(testY, tePredict))
# Out:
# Error Test Score > MSE ==  0.012877223765622883  MAE ==  0.08953137240019018  MAEMS ==  0.09640088260216916

# %% [markdown]
# ## Wind Ramp Rate FFEL Model

# %%
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=1/6, shuffle=False)
trY = trY.reshape(-1,output_timesteps)
vaY = vaY.reshape(-1,output_timesteps)

# %%
trainPredict = model.predict(trX, batch_size=batch_size)
validPredict = model.predict(vaX, batch_size=batch_size)

# %%
e_tr = trainPredict - trY
e_va = validPredict - vaY
errors = np.vstack([e_tr, e_va])
prediction = np.vstack([trainPredict, validPredict])
print(errors.shape)
print(prediction.shape)
# Out:
# (31411, 12)
# (31411, 12)

# %%
norm_df2 = pd.DataFrame(norm_df).iloc[:prediction.shape[0], :]
norm_df2.columns = ['Normalized Ramp']
norm_df2.head()
# Out:
#    Normalized Ramp
# 0         0.620197
# 1         0.544580
# 2         0.570751
# 3         0.599594
# 4         0.495246

# %%
Prindex = ['Prediction1', 'Prediction2','Prediction3','Prediction4','Prediction5','Prediction6','Prediction7','Prediction8','Prediction9','Prediction10','Prediction11','Prediction12']
Erindex = ['Error1', 'Error2','Error3','Error4','Error5','Error6','Error7','Error8','Error9','Error10','Error11','Error12']

pr_df = pd.DataFrame(prediction, columns=Prindex)
pr_df
# Out:
#        Prediction1  Prediction2  Prediction3  Prediction4  Prediction5  \
# 0         0.576944     0.552743     0.563341     0.493121     0.408325
# 1         0.538577     0.550591     0.492083     0.416955     0.389544
# 2         0.549176     0.526222     0.433467     0.398326     0.593109
# 3         0.538702     0.467881     0.471990     0.658254     0.617754
# 4         0.384145     0.436745     0.623044     0.571493     0.391706
# ...            ...          ...          ...          ...          ...
# 31406     0.622352     0.684375     0.695968     0.778953     0.746770
# 31407     0.581286     0.647596     0.628323     0.565861     0.510710
# 31408     0.595082     0.636028     0.584006     0.463814     0.386808
# 31409     0.733840     0.687098     0.559241     0.401101     0.386054
# 31410     0.658695     0.578189     0.480098     0.410835     0.419968
#
#        Prediction6  Prediction7  Prediction8  Prediction9  Prediction10  \
# 0         0.406069     0.521226     0.553002     0.515943      0.567649
# 1         0.506517     0.521203     0.517316     0.591400      0.646456
# 2         0.592674     0.520525     0.508530     0.499884      0.435490
# 3         0.497131     0.489012     0.455205     0.452697      0.421618
# 4         0.415081     0.515201     0.457060     0.404837      0.486248
# ...            ...          ...          ...          ...           ...
# 31406     0.570206     0.381604     0.400599     0.312627      0.342640
# 31407     0.443483     0.490750     0.420683     0.351688      0.414586
# 31408     0.378333     0.440461     0.414857     0.438971      0.471312
# 31409     0.375634     0.363663     0.421679     0.443951      0.445000
# 31410     0.412178     0.439940     0.452547     0.399495      0.363007
#
#        Prediction11  Prediction12
# 0          0.528050      0.424374
# 1          0.519673      0.419093
# 2          0.386742      0.383212
# 3          0.489446      0.669960
# 4          0.688747      0.758979
# ...             ...           ...
# 31406      0.400805      0.380967
# 31407      0.442777      0.406025
# 31408      0.378733      0.282537
# 31409      0.467745      0.575575
# 31410      0.443149      0.364404
#
# [31411 rows x 12 columns]

# %%
er_df = pd.DataFrame(errors, columns=Erindex)
er_df
# Out:
#          Error1    Error2    Error3    Error4    Error5    Error6    Error7  \
# 0      0.025014 -0.059659 -0.049394 -0.102019 -0.104293 -0.003204 -0.066340
# 1     -0.073824 -0.062145 -0.103057 -0.095664 -0.019728 -0.081050 -0.192763
# 2     -0.063560 -0.068918 -0.079152 -0.010947  0.005542 -0.121292 -0.078958
# 3     -0.056438 -0.044738  0.062717  0.070687 -0.096211 -0.102352 -0.023607
# 4     -0.128474  0.027473  0.035477 -0.142473 -0.207777 -0.097538  0.040335
# ...         ...       ...       ...       ...       ...       ...       ...
# 31406 -0.036323  0.014351  0.013395  0.174708  0.266570  0.229397  0.088351
# 31407 -0.088739 -0.034977  0.024077  0.085661  0.169901  0.150230  0.055469
# 31408 -0.087491  0.031783  0.103806  0.123005  0.093555 -0.056949 -0.267289
# 31409  0.129595  0.206898  0.218432  0.107848 -0.049227 -0.332115 -0.222838
# 31410  0.178495  0.237380  0.186845 -0.024446 -0.287781 -0.174324 -0.004933
#
#          Error8    Error9   Error10   Error11   Error12
# 0     -0.160963 -0.083540  0.055031  0.053184 -0.043365
# 1     -0.082167  0.078781  0.171590  0.051935  0.026303
# 2     -0.004089  0.025018 -0.032248 -0.006049 -0.112257
# 3     -0.019661 -0.015041  0.028827 -0.006023 -0.213279
# 4     -0.010679  0.012047 -0.009221 -0.194492  0.035325
# ...         ...       ...       ...       ...       ...
# 31406 -0.034683 -0.395123 -0.243862 -0.044068 -0.120413
# 31407 -0.287067 -0.234813 -0.030287 -0.058603 -0.143870
# 31408 -0.171645 -0.005902 -0.030069 -0.171162 -0.154822
# 31409 -0.023194 -0.057429 -0.104896  0.030386  0.088421
# 31410 -0.048833 -0.150401 -0.074353 -0.044004  0.011367
#
# [31411 rows x 12 columns]

# %%
norm_df2 = pd.concat([norm_df2, pr_df, er_df],axis=1)
norm_df2.head()
# Out:
#    Normalized Ramp  Prediction1  Prediction2  Prediction3  Prediction4  \
# 0         0.620197     0.576944     0.552743     0.563341     0.493121
# 1         0.544580     0.538577     0.550591     0.492083     0.416955
# 2         0.570751     0.549176     0.526222     0.433467     0.398326
# 3         0.599594     0.538702     0.467881     0.471990     0.658254
# 4         0.495246     0.384145     0.436745     0.623044     0.571493
#
#    Prediction5  Prediction6  Prediction7  Prediction8  Prediction9  ...  \
# 0     0.408325     0.406069     0.521226     0.553002     0.515943  ...
# 1     0.389544     0.506517     0.521203     0.517316     0.591400  ...
# 2     0.593109     0.592674     0.520525     0.508530     0.499884  ...
# 3     0.617754     0.497131     0.489012     0.455205     0.452697  ...
# 4     0.391706     0.415081     0.515201     0.457060     0.404837  ...
#
#      Error3    Error4    Error5    Error6    Error7    Error8    Error9  \
# 0 -0.049394 -0.102019 -0.104293 -0.003204 -0.066340 -0.160963 -0.083540
# 1 -0.103057 -0.095664 -0.019728 -0.081050 -0.192763 -0.082167  0.078781
# 2 -0.079152 -0.010947  0.005542 -0.121292 -0.078958 -0.004089  0.025018
# 3  0.062717  0.070687 -0.096211 -0.102352 -0.023607 -0.019661 -0.015041
# 4  0.035477 -0.142473 -0.207777 -0.097538  0.040335 -0.010679  0.012047
#
#     Error10   Error11   Error12
# 0  0.055031  0.053184 -0.043365
# 1  0.171590  0.051935  0.026303
# 2 -0.032248 -0.006049 -0.112257
# 3  0.028827 -0.006023 -0.213279
# 4 -0.009221 -0.194492  0.035325
#
# [5 rows x 25 columns]

# %%
norm_df22 = pd.DataFrame(norm_df).iloc[prediction.shape[0]+timesteps:, :]
norm_df22.columns = ['Normalized Wind']
npnorm22 = np.array(norm_df22)

# %%
pr_df = pd.DataFrame(tePredict.reshape(-1,12))
pr_df
# Out:
#             0         1         2         3         4         5         6   \
# 0     0.569626  0.486957  0.401701  0.289378  0.291180  0.360890  0.485229
# 1     0.444172  0.431101  0.294488  0.176223  0.204284  0.379527  0.398808
# 2     0.352566  0.332039  0.286100  0.280012  0.363542  0.344059  0.367165
# 3     0.327348  0.363582  0.417275  0.413158  0.329513  0.353855  0.484363
# 4     0.315212  0.365783  0.352309  0.271984  0.312949  0.439980  0.351323
# ...        ...       ...       ...       ...       ...       ...       ...
# 3486  0.278861  0.327042  0.339846  0.213460  0.328741  0.390500  0.524273
# 3487  0.461214  0.475044  0.405985  0.297391  0.500918  0.541814  0.616275
# 3488  0.537132  0.499227  0.442107  0.479796  0.561478  0.438583  0.426091
# 3489  0.468449  0.422549  0.447049  0.363853  0.381873  0.310004  0.400983
# 3490  0.520686  0.552137  0.594506  0.375572  0.408873  0.387314  0.317501
#
#             7         8         9         10        11
# 0     0.414722  0.381292  0.520389  0.389873  0.284724
# 1     0.398596  0.629990  0.477531  0.333508  0.310682
# 2     0.508501  0.404863  0.216263  0.242895  0.373913
# 3     0.345341  0.240361  0.337335  0.498731  0.600383
# 4     0.353594  0.406051  0.468890  0.493729  0.555659
# ...        ...       ...       ...       ...       ...
# 3486  0.560072  0.535437  0.559962  0.449489  0.410496
# 3487  0.556881  0.532883  0.509687  0.367808  0.312976
# 3488  0.370012  0.211754  0.091271  0.154969  0.443015
# 3489  0.472121  0.379340  0.406832  0.630483  0.676744
# 3490  0.337958  0.324671  0.485831  0.622800  0.571034
#
# [3491 rows x 12 columns]

# %%
teY = testY.reshape(-1,12)
e_te = testPredict-teY
er_df = pd.DataFrame(e_te, columns=Erindex)
er_df
# Out:
#         Error1    Error2    Error3    Error4    Error5    Error6    Error7  \
# 0     0.228817  0.193704 -0.033581 -0.418372 -0.295321 -0.083983 -0.016151
# 1     0.150919 -0.004180 -0.413261 -0.410279 -0.240589 -0.121854 -0.151087
# 2    -0.082715 -0.375711 -0.300402 -0.164860 -0.137838 -0.205836 -0.070194
# 3    -0.380402 -0.222919 -0.027598 -0.088223 -0.220383 -0.083505 -0.002791
# 4    -0.271290 -0.079090 -0.149071 -0.277911 -0.124411 -0.047174 -0.001715
# ...        ...       ...       ...       ...       ...       ...       ...
# 3486 -0.128636 -0.034543 -0.015736 -0.210719  0.113702 -0.066886 -0.070851
# 3487  0.099630  0.119461 -0.018193  0.082353  0.043533 -0.053309  0.142598
# 3488  0.181549  0.075048  0.227069  0.022411 -0.033645 -0.035094 -0.049379
# 3489  0.044270  0.207511 -0.010336 -0.231270 -0.091804 -0.165466 -0.139029
# 3490  0.305648  0.094752 -0.000618 -0.098105 -0.066597 -0.152699 -0.235530
#
#         Error8    Error9   Error10   Error11   Error12
# 0    -0.135174 -0.056068  0.033235  0.036835 -0.045295
# 1    -0.038764  0.142836  0.124493  0.003489 -0.071129
# 2     0.021347  0.051825 -0.113756 -0.138916 -0.064725
# 3    -0.007697 -0.089658 -0.044476  0.060093  0.056882
# 4     0.023575  0.024240  0.030251 -0.049773  0.012557
# ...        ...       ...       ...       ...       ...
# 3486  0.086396  0.059967  0.019950 -0.103541 -0.170675
# 3487  0.081411 -0.007129 -0.043343 -0.213363 -0.267882
# 3488 -0.170001 -0.341276 -0.489900 -0.425889 -0.331628
# 3489 -0.080910 -0.201830 -0.174026 -0.144160 -0.058768
# 3490 -0.243212 -0.256188 -0.288812 -0.112712 -0.030559
#
# [3491 rows x 12 columns]

# %%
prnorm = np.array(pr_df)
ernorm =np.array(er_df)
print(ernorm.shape)
# Out:
# (3491, 12)

# %%
etedat = np.concatenate((npnorm22[:prnorm.shape[0],:], prnorm, ernorm), axis=1)
#etedat[169:171,:]

# %%
eteX, eteY = create_dataset(etedat, timesteps, 1, 0)
eteY.shape
# Out:
# (3345, 1, 25)

# %%
eteY = eteY[:,:,-12:].reshape(-1,12)

# %%
norm_df2 = np.array(norm_df2)
output_timesteps = 1
Xe, Ye = create_dataset(norm_df2, timesteps, 1, 0)
Ye.shape
# Out:
# (31265, 1, 25)

# %%
Ye = Ye[:,:,-12:].reshape(-1, 12)
print(Xe.shape)
print(Ye.shape)
# Out:
# (31265, 144, 25)
# (31265, 12)

# %%
trXe, vaXe, trYe, vaYe = train_test_split(Xe, Ye, test_size=0.3, shuffle=False)

# %%
gc.collect()
# Out:
# 6278

# %%
eteX.shape, eteY.shape, Xe.shape, Ye.shape
# Out:
# ((3345, 144, 25), (3345, 12), (31265, 144, 25), (31265, 12))

# %%
def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))*10+K.mean(K.abs(y_pred - y_true))

# %%
num_features = Xe.shape[2]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1.2
    beta = 1
    hfilters = 256
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1e = Input(shape=(timesteps, num_features))
   
    per1e = Permute((2,1))(visible1e)
    den1ae = Dense(timesteps, activation='tanh')(per1e)
    den1be = Dense(timesteps, activation='sigmoid')(per1e)
    den1e = Multiply()([den1ae, den1be])
    per2e = Permute((2,1), name='attention_vec')(den1e)
    mul1e = Multiply()([visible1e, per2e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res01ae = Add()([visible1e, d1e])   # (100, 25) (100, 25)
    res01be = Subtract()([visible1e, d1e])

    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01ae)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    
    d1e = Multiply()([d1ae, d1be])
    res02ae = Add()([res01ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01be) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res02be = Subtract()([res01be, d2e])   # (100, 25) (100, 25) 
    res02e = Concatenate()([res02ae, res02be, res01ae, res01be])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res03ae = Add()([res02ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res03be = Subtract()([res02be, d2e])   # (100, 25) (100, 25)
    res03e = Concatenate()([res03ae, res03be, res02e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    res04ae = Add()([res03ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res04be = Subtract()([res02be, d2e])   # (100, 25) (100, 25)
    res04e = Concatenate()([res04ae, res04be, res03e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res05ae = Add()([res04ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res05be = Subtract()([res04be, d2e])   # (100, 25) (100, 25)
    res05e = Concatenate()([res05ae, res05be, res04e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])

    res06ae = Add()([res05ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])

    res06be = Subtract()([res05be, d2e])   # (100, 25) (100, 25)
    res06e = Concatenate()([res05ae, res05be])
    
    res10e = Concatenate()([res02e, res03e, res04e, res05e, res06e])   # 
    
    #print('res10 :', res10.shape)  # (None, 24, 11) 
    
    oute = Conv1D(timesteps*5, 1, padding='same', activation=PReLU())(res10e)   # 256, 11X10=110
    oute = Dropout(0.2)(oute)   #SpatialDropout1D
    
    oute = Conv1D(timesteps*3, 1, padding='same', activation=PReLU())(oute) # 512,  110X5=550
    oute = Dropout(0.2)(oute)
    
    oute = GlobalAveragePooling1D()(oute) # pool_size=2, strides=1
    
    oute = Dense(12)(oute) 
    modele = Model(inputs=[visible1e], outputs=[oute])
    
    print(modele.summary())
    
    modele.compile(loss=mse_mae, optimizer='adam', metrics=['mse','mae','mape'])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = 168
    epochs = 1000

    history_e = LossHistory()
    history_e.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 144, 25)]    0
# __________________________________________________________________________________________________
# permute_2 (Permute)             (None, 25, 144)      0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 25, 144)      20880       permute_2[0][0]
# __________________________________________________________________________________________________
# dense_6 (Dense)                 (None, 25, 144)      20880       permute_2[0][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 25, 144)      0           dense_5[0][0]
#                                                                  dense_6[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 144, 25)      0           multiply_24[0][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 144, 25)      0           input_2[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 144, 256)     6656        multiply_25[0][0]
# __________________________________________________________________________________________________
# activation_40 (Activation)      (None, 144, 256)     0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# activation_41 (Activation)      (None, 144, 256)     0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 144, 256)     0           activation_40[0][0]
#                                                                  activation_41[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 144, 25)      12825       multiply_26[0][0]
# __________________________________________________________________________________________________
# activation_42 (Activation)      (None, 144, 25)      0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_43 (Activation)      (None, 144, 25)      0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 144, 25)      0           activation_42[0][0]
#                                                                  activation_43[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 144, 25)      0           input_2[0][0]
#                                                                  multiply_27[0][0]
# __________________________________________________________________________________________________
# subtract_6 (Subtract)           (None, 144, 25)      0           input_2[0][0]
#                                                                  multiply_27[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 144, 256)     6656        add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 144, 256)     6656        subtract_6[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 144, 256)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 144, 256)     0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 144, 256)     0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 144, 256)     0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 144, 256)     0           activation_44[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 144, 256)     0           activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 144, 25)      12825       multiply_28[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 144, 25)      12825       multiply_30[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 144, 25)      0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 144, 25)      0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 144, 25)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 144, 25)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 144, 25)      0           activation_46[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 144, 25)      0           activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 144, 25)      0           add_6[0][0]
#                                                                  multiply_29[0][0]
# __________________________________________________________________________________________________
# subtract_7 (Subtract)           (None, 144, 25)      0           subtract_6[0][0]
#                                                                  multiply_31[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 144, 100)     0           add_7[0][0]
#                                                                  subtract_7[0][0]
#                                                                  add_6[0][0]
#                                                                  subtract_6[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 144, 256)     25856       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 144, 256)     25856       concatenate_5[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 144, 256)     0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 144, 256)     0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 144, 256)     0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 144, 256)     0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 144, 256)     0           activation_52[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 144, 256)     0           activation_56[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 144, 25)      12825       multiply_32[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 144, 25)      12825       multiply_34[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 144, 25)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 144, 25)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 144, 25)      0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 144, 25)      0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 144, 25)      0           activation_54[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 144, 25)      0           activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 144, 25)      0           add_7[0][0]
#                                                                  multiply_33[0][0]
# __________________________________________________________________________________________________
# subtract_8 (Subtract)           (None, 144, 25)      0           subtract_7[0][0]
#                                                                  multiply_35[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 144, 150)     0           add_8[0][0]
#                                                                  subtract_8[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 144, 256)     38656       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 144, 256)     38656       concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 144, 256)     0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 144, 256)     0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 144, 256)     0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 144, 256)     0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 144, 256)     0           activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 144, 256)     0           activation_64[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 144, 25)      12825       multiply_36[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 144, 25)      12825       multiply_38[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 144, 25)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 144, 25)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 144, 25)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 144, 25)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 144, 25)      0           activation_62[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 144, 25)      0           activation_66[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 144, 25)      0           add_8[0][0]
#                                                                  multiply_37[0][0]
# __________________________________________________________________________________________________
# subtract_9 (Subtract)           (None, 144, 25)      0           subtract_7[0][0]
#                                                                  multiply_39[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 144, 200)     0           add_9[0][0]
#                                                                  subtract_9[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 144, 256)     51456       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 144, 256)     51456       concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 144, 256)     0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 144, 256)     0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 144, 256)     0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 144, 256)     0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 144, 256)     0           activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 144, 256)     0           activation_72[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 144, 25)      12825       multiply_40[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 144, 25)      12825       multiply_42[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 144, 25)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 144, 25)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 144, 25)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 144, 25)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 144, 25)      0           activation_70[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 144, 25)      0           activation_74[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 144, 25)      0           add_9[0][0]
#                                                                  multiply_41[0][0]
# __________________________________________________________________________________________________
# subtract_10 (Subtract)          (None, 144, 25)      0           subtract_9[0][0]
#                                                                  multiply_43[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 144, 250)     0           add_10[0][0]
#                                                                  subtract_10[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 144, 50)      0           add_10[0][0]
#                                                                  subtract_10[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 144, 750)     0           concatenate_5[0][0]
#                                                                  concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  concatenate_8[0][0]
#                                                                  concatenate_9[0][0]
# __________________________________________________________________________________________________
# conv1d_45 (Conv1D)              (None, 144, 720)     644400      concatenate_10[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 144, 720)     0           conv1d_45[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 144, 432)     373680      dropout_3[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 144, 432)     0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 432)          0           dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_7 (Dense)                 (None, 12)           5196        global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 1,432,365
# Trainable params: 1,432,365
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 2538

# %%
# %%time
    histe = modele.fit(trXe, trYe, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(vaXe, vaYe), callbacks=[history_e, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
#   6/152 [>.............................] - ETA: 3:08 - loss: 1.5173 - mse: 0.1264 - mae: 0.2532 - mape: 2056.9075WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.3701s vs `on_train_batch_end` time: 0.7675s). Check your callbacks.
# 152/152 [==============================] - 266s 2s/step - loss: 0.2483 - mse: 0.0159 - mae: 0.0898 - mape: 419.2016 - val_loss: 0.1575 - val_mse: 0.0085 - val_mae: 0.0726 - val_mape: 951.5339
# Epoch 2/1000
# 152/152 [==============================] - 276s 2s/step - loss: 0.1628 - mse: 0.0089 - mae: 0.0738 - mape: 423.5485 - val_loss: 0.1264 - val_mse: 0.0064 - val_mae: 0.0626 - val_mape: 1053.7777
# Epoch 3/1000
# 152/152 [==============================] - 289s 2s/step - loss: 0.1370 - mse: 0.0071 - mae: 0.0657 - mape: 470.0483 - val_loss: 0.1076 - val_mse: 0.0051 - val_mae: 0.0561 - val_mape: 979.6042
# Epoch 4/1000
# 152/152 [==============================] - 275s 2s/step - loss: 0.1233 - mse: 0.0062 - mae: 0.0613 - mape: 441.9853 - val_loss: 0.0975 - val_mse: 0.0045 - val_mae: 0.0524 - val_mape: 1178.0166
# Epoch 5/1000
# 152/152 [==============================] - 274s 2s/step - loss: 0.1150 - mse: 0.0056 - mae: 0.0585 - mape: 433.5725 - val_loss: 0.0913 - val_mse: 0.0041 - val_mae: 0.0501 - val_mape: 1084.9391
# Epoch 6/1000
# 152/152 [==============================] - 271s 2s/step - loss: 0.1082 - mse: 0.0052 - mae: 0.0562 - mape: 447.5393 - val_loss: 0.0874 - val_mse: 0.0039 - val_mae: 0.0486 - val_mape: 1203.4767
# Epoch 7/1000
# 152/152 [==============================] - 277s 2s/step - loss: 0.1029 - mse: 0.0049 - mae: 0.0543 - mape: 425.5537 - val_loss: 0.0849 - val_mse: 0.0037 - val_mae: 0.0476 - val_mape: 1211.5084
# Epoch 8/1000
# 152/152 [==============================] - 273s 2s/step - loss: 0.0994 - mse: 0.0046 - mae: 0.0530 - mape: 428.4718 - val_loss: 0.0841 - val_mse: 0.0037 - val_mae: 0.0473 - val_mape: 1216.5728
# Epoch 9/1000
# 152/152 [==============================] - 250s 2s/step - loss: 0.0972 - mse: 0.0045 - mae: 0.0522 - mape: 446.2138 - val_loss: 0.0842 - val_mse: 0.0037 - val_mae: 0.0473 - val_mape: 1179.3427
# Epoch 10/1000
# 152/152 [==============================] - 180s 1s/step - loss: 0.0964 - mse: 0.0045 - mae: 0.0519 - mape: 442.7211 - val_loss: 0.0838 - val_mse: 0.0037 - val_mae: 0.0472 - val_mape: 1147.1884
# Epoch 11/1000
# 152/152 [==============================] - 155s 1s/step - loss: 0.0954 - mse: 0.0044 - mae: 0.0515 - mape: 446.8595 - val_loss: 0.0823 - val_mse: 0.0036 - val_mae: 0.0466 - val_mape: 1033.2107
# Epoch 12/1000
# 152/152 [==============================] - 14s 95ms/step - loss: 0.0944 - mse: 0.0043 - mae: 0.0511 - mape: 456.1306 - val_loss: 0.0828 - val_mse: 0.0036 - val_mae: 0.0468 - val_mape: 965.6655
# Epoch 13/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0932 - mse: 0.0043 - mae: 0.0507 - mape: 451.6556 - val_loss: 0.0824 - val_mse: 0.0036 - val_mae: 0.0467 - val_mape: 957.0317
# Epoch 14/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0922 - mse: 0.0042 - mae: 0.0503 - mape: 420.5009 - val_loss: 0.0830 - val_mse: 0.0036 - val_mae: 0.0469 - val_mape: 913.9063
# Epoch 15/1000
# 152/152 [==============================] - 14s 95ms/step - loss: 0.0919 - mse: 0.0042 - mae: 0.0502 - mape: 426.8762 - val_loss: 0.0824 - val_mse: 0.0036 - val_mae: 0.0467 - val_mape: 973.3221
# Epoch 16/1000
# 152/152 [==============================] - 14s 95ms/step - loss: 0.0911 - mse: 0.0041 - mae: 0.0499 - mape: 411.7711 - val_loss: 0.0808 - val_mse: 0.0035 - val_mae: 0.0460 - val_mape: 962.7996
# Epoch 17/1000
# 152/152 [==============================] - 14s 95ms/step - loss: 0.0911 - mse: 0.0041 - mae: 0.0499 - mape: 406.3148 - val_loss: 0.0811 - val_mse: 0.0035 - val_mae: 0.0461 - val_mape: 1032.6757
# Epoch 18/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0898 - mse: 0.0040 - mae: 0.0494 - mape: 407.3065 - val_loss: 0.0814 - val_mse: 0.0035 - val_mae: 0.0462 - val_mape: 965.7729
# Epoch 19/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0894 - mse: 0.0040 - mae: 0.0492 - mape: 438.4959 - val_loss: 0.0824 - val_mse: 0.0036 - val_mae: 0.0466 - val_mape: 1093.9949
# Epoch 20/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0896 - mse: 0.0040 - mae: 0.0493 - mape: 429.5600 - val_loss: 0.0814 - val_mse: 0.0035 - val_mae: 0.0463 - val_mape: 1150.0985
# Epoch 21/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0896 - mse: 0.0040 - mae: 0.0493 - mape: 425.0779 - val_loss: 0.0820 - val_mse: 0.0035 - val_mae: 0.0465 - val_mape: 819.3824
# Epoch 22/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0864 - mse: 0.0038 - mae: 0.0480 - mape: 404.5865 - val_loss: 0.0832 - val_mse: 0.0036 - val_mae: 0.0470 - val_mape: 788.0436
# Epoch 23/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0856 - mse: 0.0038 - mae: 0.0478 - mape: 408.7113 - val_loss: 0.0848 - val_mse: 0.0037 - val_mae: 0.0477 - val_mape: 824.5756
# Epoch 24/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0857 - mse: 0.0038 - mae: 0.0477 - mape: 398.9192 - val_loss: 0.0828 - val_mse: 0.0036 - val_mae: 0.0467 - val_mape: 1080.4382
# Epoch 25/1000
# 152/152 [==============================] - 15s 96ms/step - loss: 0.0872 - mse: 0.0039 - mae: 0.0483 - mape: 429.9113 - val_loss: 0.0847 - val_mse: 0.0037 - val_mae: 0.0475 - val_mape: 963.9835
# Epoch 26/1000
# 152/152 [==============================] - 14s 95ms/step - loss: 0.0857 - mse: 0.0038 - mae: 0.0478 - mape: 395.9019 - val_loss: 0.0850 - val_mse: 0.0037 - val_mae: 0.0477 - val_mape: 1034.0170

# %% [markdown]
# ### Saving FFEL Model Training Results

# %%
eloss_history = histe.history['loss']
valeloss_history = histe.history['val_loss']

# %%
modele.save('Error Learning Ramp Model_fh12.h5')

# %%
gc.collect()
# Out:
# 4570

# %% [markdown]
# ## FFEL Model Test Results

# %%
trainePredict = modele.predict(Xe, batch_size=batch_size)
etePredict = modele.predict(eteX, batch_size=batch_size)

# %%
trePredict = trainePredict.reshape([-1])
trainYe = Ye.reshape([-1])

print('Error Training Score > MSE == ', (np.mean(np.square(trainYe-trePredict))), ' MAE == ', mean_absolute_error(trainYe,trePredict), ' RMSE == ', np.sqrt(np.mean(np.square(trainYe-trePredict))))
# Out:
# Error Training Score > MSE ==  0.003695841136758344  MAE ==  0.0473448617423577  RMSE ==  0.06079343004600369

# %%
etestPredict = etePredict.reshape([-1])
testYe = eteY.reshape([-1])

print('Error Training Score > MSE == ', (np.mean(np.square(testYe-etestPredict))), ' MAE == ', mean_absolute_error(testYe,etestPredict), ' RMSE == ', np.sqrt(np.mean(np.square(testYe-etestPredict))))
# Out:
# Error Training Score > MSE ==  0.004368571359662568  MAE ==  0.05136803931860675  RMSE ==  0.06609516895857494

# %% [markdown]
# ## Final Prediction Results

# %%
testPredict = tePredict.reshape(-1,12)
addtestPredict = -etePredict + testPredict[timesteps:-2,:]
print(addtestPredict.shape)
# Out:
# (3345, 12)

# %%
print('Error Test Score > MSE == ', (np.mean(np.square(teY[timesteps:-2,:]-testPredict[timesteps:-2,:]))), ' MAE == ', mean_absolute_error(teY[timesteps:-2,:], testPredict[timesteps:-2,:]), 'MAPE == ', mean_absolute_percentage_error(teY[timesteps:-2,:], testPredict[timesteps:-2,:]))
print('Error Test Score > MSE == ', (np.mean(np.square(teY[timesteps:-2,:]-addtestPredict))), ' MAE == ', mean_absolute_error(teY[timesteps:-2,:], addtestPredict), 'MAPE == ', mean_absolute_percentage_error(teY[timesteps:-2,:], addtestPredict))
# Out:
# Error Test Score > MSE ==  0.012836964015489147  MAE ==  0.08934994887150143 MAPE ==  18.053389355078796
# Error Test Score > MSE ==  0.0043685713599015  MAE ==  0.051368039296910056 MAPE ==  10.427107203598556
