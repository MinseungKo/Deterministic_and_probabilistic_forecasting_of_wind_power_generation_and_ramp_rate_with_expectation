# %%
import tensorflow as tf

import pandas as pd
import codecs
import numpy as np
import math
import csv
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import recall_score, precision_score # New
from sklearn.metrics import f1_score
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
import matplotlib.pyplot as plt
import tensorflow.keras.preprocessing
#from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Flatten, Add, Multiply, Subtract
from tensorflow.keras import backend as K
from tensorflow.keras.layers import Activation, BatchNormalization
# regularizers
from tensorflow.keras.layers import Conv1D, Conv2D
from tensorflow.keras.layers import MaxPooling1D
from tensorflow.keras.layers import concatenate
from tensorflow.keras.layers import LSTM, Bidirectional
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout, SpatialDropout1D
from scipy import signal
import openpyxl
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

from matplotlib import pylab as plt
import matplotlib.dates as mdates
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from numpy.linalg import svd
import gc
from keijzer import *
from tensorflow import keras
from keras.models import Model
from keras.layers import *
from tensorflow.keras.optimizers import Adam,SGD
from keras.layers import Dense, Input, Flatten, Add, concatenate, Dropout, Activation, Multiply, Embedding, Layer, Reshape
from keras.layers import LSTM, Bidirectional, GlobalMaxPooling1D, GlobalAveragePooling1D  
from keras.layers import Conv1D, AveragePooling1D, MaxPooling1D
#from keras.ops import convert_to_tensor, convert_to_numpy
#from keras.utils import plot_model
from keras import activations
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import ModelCheckpoint, CSVLogger, EarlyStopping, LearningRateScheduler, ReduceLROnPlateau
import math

class LossHistory(tensorflow.keras.callbacks.Callback):  # history = LossHistory()
    def init(self):  # history.init()
        self.losses = []
        # self.accs = []
        self.val_losses = []
        # self.val_accs = []
        self.rmses = []
        self.mses = []
        self.maes = []
        self.mapes = []
        self.val_rmses = []
        self.val_mses = []
        self.val_maes = []
        self.val_mapes = []

    def on_epoch_end(self, batch, logs={}):
        self.losses.append(logs.get('loss'))
        # self.accs.append(logs.get('acc'))
        self.val_losses.append(logs.get('val_loss'))
        # self.val_accs.append(logs.get('val_accuracy
        self.rmses.append(logs.get('root_mean_squared_error'))
        self.mses.append(logs.get('mean_squared_error'))
        self.maes.append(logs.get('mean_absolute_error'))
        self.mapes.append(logs.get('mean_absolute_percentage_error'))
        self.val_rmses.append(logs.get('val_root_mean_squared_error'))
        self.val_mses.append(logs.get('val_mean_squared_error'))
        self.val_maes.append(logs.get('val_mean_absolute_error'))
        self.val_mapes.append(logs.get('val_mean_absolute_percentage_error'))



def root_squared_mean_error(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true-K.mean(y_true)))*100

def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))+K.mean(K.abs(y_pred - y_true))

from keras.layers.advanced_activations import PReLU

def mean_absolute_percentage_error(y_true, y_pred):
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

def root_mean_squared_error(y_true, y_pred):
        return K.sqrt(K.mean(K.square(y_pred - y_true)))

# %%
import scipy as sc

# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = '0' # 여러개 사용시 '0,1,2' 식으로 하나의 문자열에 입력
gpus = tf.config.experimental.list_physical_devices('GPU') # 호스트 러나임에 표시되는 GPU 장치 목록 반환

if gpus: # 반환된 GPU 장치 목록이 있다면
    try: # 해당 장치에 대한 메모리 증가 활성화 여부 설정
        tf.config.experimental.set_memory_growth(gpus[0], True)
    except RuntimeError as e: # try문 실패시에 에러문구 출력
        print(e)

print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# ## Import Data & Preprocessing

# %%
data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2020.csv'
data_source1 = pd.read_csv(data_path)
dat_source1 = pd.DataFrame(data_source1)
#dat_source1 = dat_source1.iloc[:-3,:]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2021.csv'
data_source2 = pd.read_csv(data_path)
dat_source2 = pd.DataFrame(data_source2)
dat_source2 = dat_source2.iloc[:8761,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2022.csv'
data_source3 = pd.read_csv(data_path)
dat_source3 = pd.DataFrame(data_source3)
dat_source3 = dat_source3.iloc[:8760,:9]

data_path = 'C:/Users/smartgrid_AI/Desktop/windpower_ramprate/ercot_2023.csv'
data_source4 = pd.read_csv(data_path)
dat_source4 = pd.DataFrame(data_source4)
dat_source4 = dat_source4.iloc[:8760,:9]

dat_arr1 = np.array(dat_source1)
dat_arr2 = np.array(dat_source2)
dat_arr3 = np.array(dat_source3)
dat_arr4 = np.array(dat_source4)

dat_arr = np.concatenate([dat_arr1, dat_arr2, dat_arr3, dat_arr4],axis=0)
dat_arr.shape # 8784, 8761, 8760, 8760

dat_source = pd.DataFrame(dat_arr, columns=['Time-Date stamp','Date','ERCOT Load','Total Wind Output','Total Wind Installed','Wind Output, % of Load','Wind Output, % of Installed','1-hr MW change','1-hr % change'])
dat_source
# Out:
#            Time-Date stamp    Date ERCOT Load Total Wind Output  \
# 0      01-01-2020 00:00:00  Jan-01      36823             12335
# 1      01-01-2020 01:00:00  Jan-01      36511             13300
# 2      01-01-2020 02:00:00  Jan-01      36022             13586
# 3      01-01-2020 03:00:00  Jan-01      35790             14107
# 4      01-01-2020 04:00:00  Jan-01      35642             14887
# ...                    ...     ...        ...               ...
# 35060  12-31-2023 20:00:00  Dec-31      44887             17161
# 35061  12-31-2023 21:00:00  Dec-31      44013             18301
# 35062  12-31-2023 22:00:00  Dec-31      43280             18607
# 35063  12-31-2023 23:00:00  Dec-31      42319             17866
# 35064  01-01-2024 00:00:00  Jan-01      41682             15869
#
#       Total Wind Installed Wind Output, % of Load Wind Output, % of Installed  \
# 0                    27040                   33.5                      45.617
# 1                    27040                   36.4                      49.187
# 2                    27040                   37.7                      50.245
# 3                    27040                   39.4                      52.171
# 4                    27040                   41.8                      55.055
# ...                    ...                    ...                         ...
# 35060                38631                  38.23                       44.42
# 35061                38631                  41.58                       47.37
# 35062                38631                  42.99                       48.17
# 35063                38631                  42.22                       46.25
# 35064                38631                  38.07                       41.08
#
#       1-hr MW change 1-hr % change
# 0                NaN           NaN
# 1              965.4         7.826
# 2              286.2         2.152
# 3              520.9         3.834
# 4              779.6         5.527
# ...              ...           ...
# 35060           2858         19.99
# 35061           1139          6.64
# 35062            307          1.67
# 35063           -741         -3.98
# 35064          -1996        -11.17
#
# [35065 rows x 9 columns]

# %% [markdown]
# ### Dividing by Installed Capacity & Preprocessing

# %%
dat = pd.DataFrame()
dat['MW % change'] = np.array(dat_source.iloc[1:,3], dtype=float)-np.array(dat_source.iloc[0:-1,3], dtype=float)
dat['MW % change'] = np.divide(np.array(dat['MW % change']),np.array(dat_source.iloc[1:,4]))*100
dat['Total Wind Output'] = np.divide(np.array(dat_source.iloc[1:,3]), np.array(dat_source.iloc[1:,4]))

dat
# Out:
#       MW % change Total Wind Output
# 0         3.56879          0.491864
# 1         1.05769          0.502441
# 2         1.92678          0.521709
# 3         2.88462          0.550555
# 4       -0.580621          0.544749
# ...           ...               ...
# 35059      7.3982          0.444229
# 35060       2.951          0.473739
# 35061     0.79211           0.48166
# 35062    -1.91815          0.462478
# 35063    -5.16942          0.410784
#
# [35064 rows x 2 columns]

# %%
ramp_ratio = 20
load_ratio = 10
year_arr = np.concatenate([np.ones(8784)*2020, np.ones(8760)*2021, np.ones(8760)*2022, np.ones(8760)*2023])
year_df = pd.DataFrame(year_arr, columns=['Year'], dtype=int)
wind_df = pd.concat([year_df, dat], axis=1)
wind_df
# Out:
#        Year MW % change Total Wind Output
# 0      2020     3.56879          0.491864
# 1      2020     1.05769          0.502441
# 2      2020     1.92678          0.521709
# 3      2020     2.88462          0.550555
# 4      2020   -0.580621          0.544749
# ...     ...         ...               ...
# 35059  2023      7.3982          0.444229
# 35060  2023       2.951          0.473739
# 35061  2023     0.79211           0.48166
# 35062  2023    -1.91815          0.462478
# 35063  2023    -5.16942          0.410784
#
# [35064 rows x 3 columns]

# %%
wind_df = wind_df.reset_index(drop=True)

std_scaler = sklearn.preprocessing.MinMaxScaler()
std_scaler_load = sklearn.preprocessing.MinMaxScaler()
std_scaler_ramp = sklearn.preprocessing.MinMaxScaler()

wind_df[['Total Wind Output']] = std_scaler.fit_transform(wind_df[['Total Wind Output']])
wind_df[['MW % change']] = std_scaler_ramp.fit_transform(wind_df[['MW % change']])
wind_df = wind_df.iloc[:-1,:]
wind_df
# Out:
#        Year  MW % change  Total Wind Output
# 0      2020     0.620197           0.644724
# 1      2020     0.544580           0.658617
# 2      2020     0.570751           0.683924
# 3      2020     0.599594           0.721813
# 4      2020     0.495246           0.714187
# ...     ...          ...                ...
# 35058  2023     0.774643           0.484984
# 35059  2023     0.735512           0.582157
# 35060  2023     0.601593           0.620917
# 35061  2023     0.536583           0.631322
# 35062  2023     0.454969           0.606127
#
# [35063 rows x 3 columns]

# %%
ramp_df = pd.DataFrame(wind_df)
ramp_df.columns=['Year', 'Wind Change', 'Wind Output']
ramp_df
# Out:
#        Year  Wind Change  Wind Output
# 0      2020     0.620197     0.644724
# 1      2020     0.544580     0.658617
# 2      2020     0.570751     0.683924
# 3      2020     0.599594     0.721813
# 4      2020     0.495246     0.714187
# ...     ...          ...          ...
# 35058  2023     0.774643     0.484984
# 35059  2023     0.735512     0.582157
# 35060  2023     0.601593     0.620917
# 35061  2023     0.536583     0.631322
# 35062  2023     0.454969     0.606127
#
# [35063 rows x 3 columns]

# %% [markdown]
# ## Wind Generation Forecasting

# %% [markdown]
# ### SVD-based Feature Generation

# %%
def create_dataset(dataset, timesteps, output_timesteps, leadtime):
    dataX, dataY = [], []
    for i in range(len(dataset) - timesteps -output_timesteps - leadtime - 1):
        a = dataset[i:(i + timesteps), :]
        dataX.append(a)
        dataY.append(dataset[(i + timesteps + leadtime):(i+timesteps+output_timesteps+leadtime), :])
    return np.array(dataX), np.array(dataY)

def svdadd(X, start, end, b_size):
    dec_x = X[start:end, :, :]
    U, S, Vh = svd(dec_x.reshape(b_size, -1), full_matrices=True)

    high_sig = np.matmul(np.matmul(U[:,:high_ind], np.diag(S[0:high_ind])), Vh[:high_ind,:])
    low_sig = X[:dec_num, :, :].reshape(b_size,-1)-high_sig

    rec_x = np.zeros((b_size, b_size, high_ind))
    
    for i in range(high_ind):
        rec_x[:,:,i] = np.matmul((U[:,i]*S[i]).reshape(-1,1), Vh[i,:].reshape(1,-1))    
    return rec_x, low_sig

# %%
norm_df = np.array(wind_df.iloc[:,2]).reshape(-1,1)
timesteps = 24*4
output_timesteps = 6
leadtime = 3
num_features = 1
X, Y = create_dataset(norm_df, timesteps, output_timesteps, leadtime)
b_size = timesteps

# %%
dec_num = timesteps
high_ind = 35

addX = np.zeros((X.shape[0], dec_num, high_ind+1))

for k in range(X.shape[0]//dec_num):
    rec_x, low_sig = svdadd(X, k*dec_num, (k+1)*dec_num, b_size)
    addX[k*dec_num:k*dec_num+dec_num,:, :-1] = rec_x
    addX[k*dec_num:k*dec_num+dec_num,:, -1] = low_sig
    
rec_x, low_sig = svdadd(X, X.shape[0]-dec_num, X.shape[0], b_size)
addX[X.shape[0]-dec_num:X.shape[0], :, :-1] = rec_x
addX[X.shape[0]-dec_num:X.shape[0],:, -1] = low_sig

addX_det = addX[:, :, :-1]
addX_det = np.sum(addX_det, axis=2)
X = np.concatenate([X, addX], axis=2)
num_features = X.shape[2]

# %% [markdown]
# ### Training/Test Set Division & Shuffled Learning

# %%
trvaX, teX, trvaY, teY = train_test_split(X, Y, test_size=0.1, shuffle=False)

idx = np.arange(trvaX.shape[0])
np.random.shuffle(idx)
strvaX = trvaX[idx]
strvaY = trvaY[idx]
strvaY = strvaY.reshape(-1, output_timesteps)

trvaY = trvaY.reshape(-1, output_timesteps)
teY = teY.reshape(-1, output_timesteps)

strX, svaX, strY, svaY = train_test_split(strvaX, strvaY, test_size=0.3, shuffle=False)
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=0.3, shuffle=False)

trvaX.shape, trvaY.shape, teX.shape, teY.shape
# Out:
# ((31461, 96, 37), (31461, 6), (3496, 96, 37), (3496, 6))

# %% [markdown]
# ## Wind Generation Forecasting Basic Model

# %%
def MAEMS(y_true, y_pred):
    return K.mean((K.abs(y_pred - y_true))*K.square(y_true))*100

# %%
from keras.layers.advanced_activations import PReLU

# %%
num_features = trvaX.shape[2]
output_timesteps = trvaY.shape[1]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1.2
    beta = 1
    hfilters = 256
    hkernel_size1 = 1
    hkernel_size2 = 2
    
    visible1 = Input(shape=(timesteps, num_features))
   
    ## Attention Block
    per1 = Permute((2,1))(visible1)
    den1a = Dense(timesteps, activation='tanh')(per1)
    den1b = Dense(timesteps, activation='sigmoid')(per1)
    den1 = Multiply()([den1a, den1b])
    per2 = Permute((2,1), name='attention_vec')(den1)
    mul1 = Multiply()([visible1, per2])
    
    ## Series PN DCCNN Blocks 1 ~ 6
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res01a = Add()([visible1, d1])   # (100, 25) (100, 25)
    res01b = Subtract()([visible1, d1])

    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01a)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    
    d1 = Multiply()([d1a, d1b])
    res02a = Add()([res01a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01b) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res02b = Subtract()([res01b, d2])   # (100, 25) (100, 25) 
    res02 = Concatenate()([res02a, res02b, res01a, res01b])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res03a = Add()([res02a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res03b = Subtract()([res02b, d2])   # (100, 25) (100, 25)
    res03 = Concatenate()([res03a, res03b, res02])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    res04a = Add()([res03a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res04b = Subtract()([res02b, d2])   # (100, 25) (100, 25)
    res04 = Concatenate()([res04a, res04b, res03])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    res05a = Add()([res04a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    
    res05b = Subtract()([res04b, d2])   # (100, 25) (100, 25)
    res05 = Concatenate()([res05a, res05b, res04])
    
    d1 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05)
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])
    
    d1 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1)    
    d1a = Activation(activations.tanh)(d1)
    d1b = Activation(activations.sigmoid)(d1)
    d1 = Multiply()([d1a, d1b])

    res06a = Add()([res05a, d1])   # (100, 25) (100, 25)
    
    d2 = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])
    d2 = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d2) 
    d2a = Activation(activations.tanh)(d2)
    d2b = Activation(activations.sigmoid)(d2)
    d2 = Multiply()([d2a, d2b])

    res06b = Subtract()([res05b, d2])   # (100, 25) (100, 25)
    res06 = Concatenate()([res05a, res05b])
    
    res10 = Concatenate()([res02, res03, res04, res05, res06])   # 
    
    #print('res10 :', res10.shap)  # (None, 24, 11) 
    
    ## Output Block
    out = Conv1D(timesteps*5, 1, padding='same', activation=PReLU())(res10)   # 256, 11X10=110
    out = Dropout(0.2)(out)   #SpatialDropout1D
    
    out = Conv1D(timesteps*3, 1, padding='same', activation=PReLU())(out) # 512,  110X5=550
    out = Dropout(0.2)(out)
    
    out = GlobalAveragePooling1D()(out) # pool_size=2, strides=1
    
    out = Dense(output_timesteps)(out) 
    model = Model(inputs=[visible1], outputs=[out])
    
    print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 96, 37)]     0
# __________________________________________________________________________________________________
# permute (Permute)               (None, 37, 96)       0           input_1[0][0]
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 37, 96)       9312        permute[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 37, 96)       9312        permute[0][0]
# __________________________________________________________________________________________________
# multiply (Multiply)             (None, 37, 96)       0           dense[0][0]
#                                                                  dense_1[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 96, 37)       0           multiply[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, 96, 37)       0           input_1[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d (Conv1D)                 (None, 96, 256)      9728        multiply_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 96, 256)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 96, 256)      0           conv1d[0][0]
# __________________________________________________________________________________________________
# multiply_2 (Multiply)           (None, 96, 256)      0           activation[0][0]
#                                                                  activation_1[0][0]
# __________________________________________________________________________________________________
# conv1d_1 (Conv1D)               (None, 96, 37)       18981       multiply_2[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 96, 37)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 96, 37)       0           conv1d_1[0][0]
# __________________________________________________________________________________________________
# multiply_3 (Multiply)           (None, 96, 37)       0           activation_2[0][0]
#                                                                  activation_3[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 96, 37)       0           input_1[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# subtract (Subtract)             (None, 96, 37)       0           input_1[0][0]
#                                                                  multiply_3[0][0]
# __________________________________________________________________________________________________
# conv1d_2 (Conv1D)               (None, 96, 256)      9728        add[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 96, 256)      9728        subtract[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 96, 256)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 96, 256)      0           conv1d_2[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 96, 256)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, 96, 256)      0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# multiply_4 (Multiply)           (None, 96, 256)      0           activation_4[0][0]
#                                                                  activation_5[0][0]
# __________________________________________________________________________________________________
# multiply_6 (Multiply)           (None, 96, 256)      0           activation_8[0][0]
#                                                                  activation_9[0][0]
# __________________________________________________________________________________________________
# conv1d_3 (Conv1D)               (None, 96, 37)       18981       multiply_4[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 96, 37)       18981       multiply_6[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 96, 37)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 96, 37)       0           conv1d_3[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, 96, 37)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, 96, 37)       0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# multiply_5 (Multiply)           (None, 96, 37)       0           activation_6[0][0]
#                                                                  activation_7[0][0]
# __________________________________________________________________________________________________
# multiply_7 (Multiply)           (None, 96, 37)       0           activation_10[0][0]
#                                                                  activation_11[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 96, 37)       0           add[0][0]
#                                                                  multiply_5[0][0]
# __________________________________________________________________________________________________
# subtract_1 (Subtract)           (None, 96, 37)       0           subtract[0][0]
#                                                                  multiply_7[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 96, 148)      0           add_1[0][0]
#                                                                  subtract_1[0][0]
#                                                                  add[0][0]
#                                                                  subtract[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 96, 256)      38144       concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 96, 256)      38144       concatenate[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, 96, 256)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, 96, 256)      0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, 96, 256)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, 96, 256)      0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# multiply_8 (Multiply)           (None, 96, 256)      0           activation_12[0][0]
#                                                                  activation_13[0][0]
# __________________________________________________________________________________________________
# multiply_10 (Multiply)          (None, 96, 256)      0           activation_16[0][0]
#                                                                  activation_17[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 96, 37)       18981       multiply_8[0][0]
# __________________________________________________________________________________________________
# conv1d_9 (Conv1D)               (None, 96, 37)       18981       multiply_10[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, 96, 37)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, 96, 37)       0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, 96, 37)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, 96, 37)       0           conv1d_9[0][0]
# __________________________________________________________________________________________________
# multiply_9 (Multiply)           (None, 96, 37)       0           activation_14[0][0]
#                                                                  activation_15[0][0]
# __________________________________________________________________________________________________
# multiply_11 (Multiply)          (None, 96, 37)       0           activation_18[0][0]
#                                                                  activation_19[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 96, 37)       0           add_1[0][0]
#                                                                  multiply_9[0][0]
# __________________________________________________________________________________________________
# subtract_2 (Subtract)           (None, 96, 37)       0           subtract_1[0][0]
#                                                                  multiply_11[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 96, 222)      0           add_2[0][0]
#                                                                  subtract_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv1d_10 (Conv1D)              (None, 96, 256)      57088       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_12 (Conv1D)              (None, 96, 256)      57088       concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 96, 256)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, 96, 256)      0           conv1d_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 96, 256)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, 96, 256)      0           conv1d_12[0][0]
# __________________________________________________________________________________________________
# multiply_12 (Multiply)          (None, 96, 256)      0           activation_20[0][0]
#                                                                  activation_21[0][0]
# __________________________________________________________________________________________________
# multiply_14 (Multiply)          (None, 96, 256)      0           activation_24[0][0]
#                                                                  activation_25[0][0]
# __________________________________________________________________________________________________
# conv1d_11 (Conv1D)              (None, 96, 37)       18981       multiply_12[0][0]
# __________________________________________________________________________________________________
# conv1d_13 (Conv1D)              (None, 96, 37)       18981       multiply_14[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 96, 37)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, 96, 37)       0           conv1d_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 96, 37)       0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, 96, 37)       0           conv1d_13[0][0]
# __________________________________________________________________________________________________
# multiply_13 (Multiply)          (None, 96, 37)       0           activation_22[0][0]
#                                                                  activation_23[0][0]
# __________________________________________________________________________________________________
# multiply_15 (Multiply)          (None, 96, 37)       0           activation_26[0][0]
#                                                                  activation_27[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 96, 37)       0           add_2[0][0]
#                                                                  multiply_13[0][0]
# __________________________________________________________________________________________________
# subtract_3 (Subtract)           (None, 96, 37)       0           subtract_1[0][0]
#                                                                  multiply_15[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 96, 296)      0           add_3[0][0]
#                                                                  subtract_3[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv1d_14 (Conv1D)              (None, 96, 256)      76032       concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv1d_16 (Conv1D)              (None, 96, 256)      76032       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 96, 256)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_29 (Activation)      (None, 96, 256)      0           conv1d_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 96, 256)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# activation_33 (Activation)      (None, 96, 256)      0           conv1d_16[0][0]
# __________________________________________________________________________________________________
# multiply_16 (Multiply)          (None, 96, 256)      0           activation_28[0][0]
#                                                                  activation_29[0][0]
# __________________________________________________________________________________________________
# multiply_18 (Multiply)          (None, 96, 256)      0           activation_32[0][0]
#                                                                  activation_33[0][0]
# __________________________________________________________________________________________________
# conv1d_15 (Conv1D)              (None, 96, 37)       18981       multiply_16[0][0]
# __________________________________________________________________________________________________
# conv1d_17 (Conv1D)              (None, 96, 37)       18981       multiply_18[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 96, 37)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_31 (Activation)      (None, 96, 37)       0           conv1d_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 96, 37)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# activation_35 (Activation)      (None, 96, 37)       0           conv1d_17[0][0]
# __________________________________________________________________________________________________
# multiply_17 (Multiply)          (None, 96, 37)       0           activation_30[0][0]
#                                                                  activation_31[0][0]
# __________________________________________________________________________________________________
# multiply_19 (Multiply)          (None, 96, 37)       0           activation_34[0][0]
#                                                                  activation_35[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 96, 37)       0           add_3[0][0]
#                                                                  multiply_17[0][0]
# __________________________________________________________________________________________________
# subtract_4 (Subtract)           (None, 96, 37)       0           subtract_3[0][0]
#                                                                  multiply_19[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 96, 370)      0           add_4[0][0]
#                                                                  subtract_4[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 96, 74)       0           add_4[0][0]
#                                                                  subtract_4[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 96, 1110)     0           concatenate[0][0]
#                                                                  concatenate_1[0][0]
#                                                                  concatenate_2[0][0]
#                                                                  concatenate_3[0][0]
#                                                                  concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv1d_22 (Conv1D)              (None, 96, 480)      579360      concatenate_5[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 96, 480)      0           conv1d_22[0][0]
# __________________________________________________________________________________________________
# conv1d_23 (Conv1D)              (None, 96, 288)      166176      dropout[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 96, 288)      0           conv1d_23[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d (Globa (None, 288)          0           dropout_1[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 6)            1734        global_average_pooling1d[0][0]
# ==================================================================================================
# Total params: 1,308,435
# Trainable params: 1,308,435
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 1371

# %%
    model.compile(loss=MAEMS, optimizer='adam', metrics=['mse','mae', MAEMS])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    epochs = 1000
    #root_squared_mean_error
    history = LossHistory()
    history.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint

# %%
    # %%time
    b_size = timesteps
    hist = model.fit(strX, strY, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(svaX, svaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 3671/3671 [==============================] - 102s 27ms/step - loss: 2.8895 - mse: 0.0461 - mae: 0.1713 - MAEMS: 2.8893 - val_loss: 2.2568 - val_mse: 0.0282 - val_mae: 0.1331 - val_MAEMS: 2.2565
# Epoch 2/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 2.3413 - mse: 0.0252 - mae: 0.1261 - MAEMS: 2.3411 - val_loss: 2.1065 - val_mse: 0.0207 - val_mae: 0.1138 - val_MAEMS: 2.1058
# Epoch 3/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 2.1584 - mse: 0.0213 - mae: 0.1140 - MAEMS: 2.1581 - val_loss: 2.0434 - val_mse: 0.0204 - val_mae: 0.1105 - val_MAEMS: 2.0429
# Epoch 4/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 2.0695 - mse: 0.0193 - mae: 0.1076 - MAEMS: 2.0693 - val_loss: 1.9459 - val_mse: 0.0191 - val_mae: 0.1065 - val_MAEMS: 1.9450
# Epoch 5/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.9778 - mse: 0.0184 - mae: 0.1043 - MAEMS: 1.9776 - val_loss: 1.8400 - val_mse: 0.0155 - val_mae: 0.0953 - val_MAEMS: 1.8392
# Epoch 6/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.9033 - mse: 0.0176 - mae: 0.1012 - MAEMS: 1.9031 - val_loss: 1.7888 - val_mse: 0.0154 - val_mae: 0.0939 - val_MAEMS: 1.7880
# Epoch 7/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.8452 - mse: 0.0168 - mae: 0.0984 - MAEMS: 1.8450 - val_loss: 1.9856 - val_mse: 0.0137 - val_mae: 0.0915 - val_MAEMS: 1.9848
# Epoch 8/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.7954 - mse: 0.0162 - mae: 0.0961 - MAEMS: 1.7952 - val_loss: 1.7324 - val_mse: 0.0134 - val_mae: 0.0872 - val_MAEMS: 1.7317
# Epoch 9/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.7637 - mse: 0.0159 - mae: 0.0949 - MAEMS: 1.7635 - val_loss: 1.8016 - val_mse: 0.0146 - val_mae: 0.0929 - val_MAEMS: 1.8011
# Epoch 10/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.7130 - mse: 0.0151 - mae: 0.0924 - MAEMS: 1.7128 - val_loss: 1.6895 - val_mse: 0.0137 - val_mae: 0.0865 - val_MAEMS: 1.6887
# Epoch 11/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.6843 - mse: 0.0150 - mae: 0.0917 - MAEMS: 1.6842 - val_loss: 1.7524 - val_mse: 0.0117 - val_mae: 0.0815 - val_MAEMS: 1.7517
# Epoch 12/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.6433 - mse: 0.0146 - mae: 0.0905 - MAEMS: 1.6431 - val_loss: 1.6322 - val_mse: 0.0121 - val_mae: 0.0826 - val_MAEMS: 1.6317
# Epoch 13/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.6155 - mse: 0.0142 - mae: 0.0891 - MAEMS: 1.6153 - val_loss: 1.8486 - val_mse: 0.0109 - val_mae: 0.0792 - val_MAEMS: 1.8477
# Epoch 14/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.5828 - mse: 0.0141 - mae: 0.0884 - MAEMS: 1.5828 - val_loss: 1.5596 - val_mse: 0.0153 - val_mae: 0.0934 - val_MAEMS: 1.5593
# Epoch 15/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.5588 - mse: 0.0137 - mae: 0.0870 - MAEMS: 1.5586 - val_loss: 1.6055 - val_mse: 0.0109 - val_mae: 0.0780 - val_MAEMS: 1.6051
# Epoch 16/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.5264 - mse: 0.0130 - mae: 0.0847 - MAEMS: 1.5263 - val_loss: 1.5398 - val_mse: 0.0119 - val_mae: 0.0801 - val_MAEMS: 1.5393
# Epoch 17/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.5073 - mse: 0.0129 - mae: 0.0841 - MAEMS: 1.5072 - val_loss: 1.5706 - val_mse: 0.0107 - val_mae: 0.0768 - val_MAEMS: 1.5705
# Epoch 18/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.4858 - mse: 0.0127 - mae: 0.0834 - MAEMS: 1.4857 - val_loss: 1.5138 - val_mse: 0.0124 - val_mae: 0.0829 - val_MAEMS: 1.5135
# Epoch 19/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.4597 - mse: 0.0124 - mae: 0.0823 - MAEMS: 1.4597 - val_loss: 1.4894 - val_mse: 0.0140 - val_mae: 0.0885 - val_MAEMS: 1.4890
# Epoch 20/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.4357 - mse: 0.0122 - mae: 0.0816 - MAEMS: 1.4356 - val_loss: 1.4713 - val_mse: 0.0112 - val_mae: 0.0789 - val_MAEMS: 1.4705
# Epoch 21/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.4274 - mse: 0.0121 - mae: 0.0810 - MAEMS: 1.4272 - val_loss: 1.4817 - val_mse: 0.0114 - val_mae: 0.0797 - val_MAEMS: 1.4812
# Epoch 22/1000
# 3671/3671 [==============================] - 101s 28ms/step - loss: 1.3911 - mse: 0.0116 - mae: 0.0792 - MAEMS: 1.3909 - val_loss: 1.4778 - val_mse: 0.0118 - val_mae: 0.0819 - val_MAEMS: 1.4776
# Epoch 23/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.3726 - mse: 0.0112 - mae: 0.0778 - MAEMS: 1.3725 - val_loss: 1.4225 - val_mse: 0.0104 - val_mae: 0.0747 - val_MAEMS: 1.4221
# Epoch 24/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.3640 - mse: 0.0111 - mae: 0.0774 - MAEMS: 1.3639 - val_loss: 1.4861 - val_mse: 0.0132 - val_mae: 0.0855 - val_MAEMS: 1.4858
# Epoch 25/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.3486 - mse: 0.0109 - mae: 0.0766 - MAEMS: 1.3485 - val_loss: 1.4044 - val_mse: 0.0122 - val_mae: 0.0819 - val_MAEMS: 1.4039
# Epoch 26/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.3186 - mse: 0.0105 - mae: 0.0750 - MAEMS: 1.3186 - val_loss: 1.4608 - val_mse: 0.0113 - val_mae: 0.0796 - val_MAEMS: 1.4606
# Epoch 27/1000
# 3671/3671 [==============================] - 97s 26ms/step - loss: 1.3072 - mse: 0.0105 - mae: 0.0747 - MAEMS: 1.3070 - val_loss: 1.3826 - val_mse: 0.0098 - val_mae: 0.0729 - val_MAEMS: 1.3822
# Epoch 28/1000
# 3671/3671 [==============================] - 101s 28ms/step - loss: 1.2847 - mse: 0.0101 - mae: 0.0734 - MAEMS: 1.2846 - val_loss: 1.4479 - val_mse: 0.0092 - val_mae: 0.0719 - val_MAEMS: 1.4473
# Epoch 29/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.2748 - mse: 0.0100 - mae: 0.0730 - MAEMS: 1.2747 - val_loss: 1.4691 - val_mse: 0.0085 - val_mae: 0.0690 - val_MAEMS: 1.4687
# Epoch 30/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.2557 - mse: 0.0097 - mae: 0.0720 - MAEMS: 1.2555 - val_loss: 1.3358 - val_mse: 0.0099 - val_mae: 0.0734 - val_MAEMS: 1.3352
# Epoch 31/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.2432 - mse: 0.0096 - mae: 0.0714 - MAEMS: 1.2431 - val_loss: 1.5030 - val_mse: 0.0082 - val_mae: 0.0684 - val_MAEMS: 1.5024
# Epoch 32/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.2331 - mse: 0.0094 - mae: 0.0704 - MAEMS: 1.2330 - val_loss: 1.4181 - val_mse: 0.0156 - val_mae: 0.0939 - val_MAEMS: 1.4178
# Epoch 33/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.2201 - mse: 0.0092 - mae: 0.0696 - MAEMS: 1.2200 - val_loss: 1.4163 - val_mse: 0.0119 - val_mae: 0.0807 - val_MAEMS: 1.4159
# Epoch 34/1000
# 3671/3671 [==============================] - 97s 26ms/step - loss: 1.2181 - mse: 0.0092 - mae: 0.0699 - MAEMS: 1.2181 - val_loss: 1.4731 - val_mse: 0.0080 - val_mae: 0.0674 - val_MAEMS: 1.4724
# Epoch 35/1000
# 3671/3671 [==============================] - 96s 26ms/step - loss: 1.2005 - mse: 0.0091 - mae: 0.0694 - MAEMS: 1.2003 - val_loss: 1.3923 - val_mse: 0.0081 - val_mae: 0.0671 - val_MAEMS: 1.3917
# Epoch 36/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.1963 - mse: 0.0089 - mae: 0.0686 - MAEMS: 1.1962 - val_loss: 1.3284 - val_mse: 0.0080 - val_mae: 0.0660 - val_MAEMS: 1.3279
# Epoch 37/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.1745 - mse: 0.0086 - mae: 0.0675 - MAEMS: 1.1745 - val_loss: 1.2753 - val_mse: 0.0088 - val_mae: 0.0686 - val_MAEMS: 1.2747
# Epoch 38/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.1749 - mse: 0.0086 - mae: 0.0674 - MAEMS: 1.1748 - val_loss: 1.2711 - val_mse: 0.0088 - val_mae: 0.0682 - val_MAEMS: 1.2707
# Epoch 39/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.1563 - mse: 0.0085 - mae: 0.0666 - MAEMS: 1.1563 - val_loss: 1.2650 - val_mse: 0.0103 - val_mae: 0.0741 - val_MAEMS: 1.2647
# Epoch 40/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.1632 - mse: 0.0084 - mae: 0.0666 - MAEMS: 1.1631 - val_loss: 1.2710 - val_mse: 0.0077 - val_mae: 0.0644 - val_MAEMS: 1.2705
# Epoch 41/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.1421 - mse: 0.0081 - mae: 0.0653 - MAEMS: 1.1420 - val_loss: 1.3005 - val_mse: 0.0092 - val_mae: 0.0698 - val_MAEMS: 1.3001
# Epoch 42/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.1404 - mse: 0.0082 - mae: 0.0656 - MAEMS: 1.1404 - val_loss: 1.3405 - val_mse: 0.0081 - val_mae: 0.0665 - val_MAEMS: 1.3400
# Epoch 43/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.1368 - mse: 0.0082 - mae: 0.0654 - MAEMS: 1.1368 - val_loss: 1.3020 - val_mse: 0.0086 - val_mae: 0.0682 - val_MAEMS: 1.3017
# Epoch 44/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.1214 - mse: 0.0079 - mae: 0.0644 - MAEMS: 1.1213 - val_loss: 1.2387 - val_mse: 0.0074 - val_mae: 0.0633 - val_MAEMS: 1.2383
# Epoch 45/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.1145 - mse: 0.0079 - mae: 0.0643 - MAEMS: 1.1145 - val_loss: 1.2367 - val_mse: 0.0106 - val_mae: 0.0762 - val_MAEMS: 1.2364
# Epoch 46/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.1145 - mse: 0.0078 - mae: 0.0641 - MAEMS: 1.1144 - val_loss: 1.2686 - val_mse: 0.0091 - val_mae: 0.0704 - val_MAEMS: 1.2681
# Epoch 47/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.1046 - mse: 0.0077 - mae: 0.0634 - MAEMS: 1.1044 - val_loss: 1.2379 - val_mse: 0.0087 - val_mae: 0.0686 - val_MAEMS: 1.2376
# Epoch 48/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.0981 - mse: 0.0078 - mae: 0.0636 - MAEMS: 1.0979 - val_loss: 1.1984 - val_mse: 0.0086 - val_mae: 0.0680 - val_MAEMS: 1.1980
# Epoch 49/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.0986 - mse: 0.0077 - mae: 0.0633 - MAEMS: 1.0985 - val_loss: 1.2068 - val_mse: 0.0089 - val_mae: 0.0684 - val_MAEMS: 1.2063
# Epoch 50/1000
# 3671/3671 [==============================] - 97s 26ms/step - loss: 1.0946 - mse: 0.0076 - mae: 0.0629 - MAEMS: 1.0945 - val_loss: 1.2159 - val_mse: 0.0071 - val_mae: 0.0615 - val_MAEMS: 1.2156
# Epoch 51/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.0889 - mse: 0.0076 - mae: 0.0630 - MAEMS: 1.0888 - val_loss: 1.2804 - val_mse: 0.0070 - val_mae: 0.0619 - val_MAEMS: 1.2799
# Epoch 52/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.0777 - mse: 0.0073 - mae: 0.0619 - MAEMS: 1.0776 - val_loss: 1.2389 - val_mse: 0.0087 - val_mae: 0.0686 - val_MAEMS: 1.2385
# Epoch 53/1000
# 3671/3671 [==============================] - 101s 27ms/step - loss: 1.0733 - mse: 0.0073 - mae: 0.0620 - MAEMS: 1.0732 - val_loss: 1.1307 - val_mse: 0.0080 - val_mae: 0.0640 - val_MAEMS: 1.1302
# Epoch 54/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.0751 - mse: 0.0072 - mae: 0.0614 - MAEMS: 1.0751 - val_loss: 1.2737 - val_mse: 0.0068 - val_mae: 0.0612 - val_MAEMS: 1.2735
# Epoch 55/1000
# 3671/3671 [==============================] - 99s 27ms/step - loss: 1.0691 - mse: 0.0074 - mae: 0.0619 - MAEMS: 1.0690 - val_loss: 1.2761 - val_mse: 0.0070 - val_mae: 0.0618 - val_MAEMS: 1.2755
# Epoch 56/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.0621 - mse: 0.0072 - mae: 0.0613 - MAEMS: 1.0620 - val_loss: 1.2631 - val_mse: 0.0072 - val_mae: 0.0625 - val_MAEMS: 1.2626
# Epoch 57/1000
# 3671/3671 [==============================] - 97s 27ms/step - loss: 1.0668 - mse: 0.0073 - mae: 0.0618 - MAEMS: 1.0667 - val_loss: 1.1954 - val_mse: 0.0101 - val_mae: 0.0742 - val_MAEMS: 1.1951
# Epoch 58/1000
# 3671/3671 [==============================] - 100s 27ms/step - loss: 1.0669 - mse: 0.0072 - mae: 0.0612 - MAEMS: 1.0670 - val_loss: 1.1866 - val_mse: 0.0077 - val_mae: 0.0637 - val_MAEMS: 1.1863
# Epoch 59/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.0458 - mse: 0.0071 - mae: 0.0608 - MAEMS: 1.0457 - val_loss: 1.2974 - val_mse: 0.0077 - val_mae: 0.0653 - val_MAEMS: 1.2969
# Epoch 60/1000
# 3671/3671 [==============================] - 97s 27ms/step - loss: 1.0437 - mse: 0.0071 - mae: 0.0606 - MAEMS: 1.0435 - val_loss: 1.2038 - val_mse: 0.0075 - val_mae: 0.0636 - val_MAEMS: 1.2035
# Epoch 61/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.0434 - mse: 0.0070 - mae: 0.0603 - MAEMS: 1.0433 - val_loss: 1.1968 - val_mse: 0.0068 - val_mae: 0.0604 - val_MAEMS: 1.1964
# Epoch 62/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.0401 - mse: 0.0070 - mae: 0.0602 - MAEMS: 1.0400 - val_loss: 1.1517 - val_mse: 0.0076 - val_mae: 0.0631 - val_MAEMS: 1.1513
# Epoch 63/1000
# 3671/3671 [==============================] - 98s 27ms/step - loss: 1.0433 - mse: 0.0069 - mae: 0.0598 - MAEMS: 1.0432 - val_loss: 1.2555 - val_mse: 0.0071 - val_mae: 0.0621 - val_MAEMS: 1.2552
# Wall time: 1h 44min 4s

# %%
gc.collect()
# Out:
# 4594

# %% [markdown]
# ## Saving Results & Figures

# %%
loss_history = hist.history['loss']
valloss_history = hist.history['val_loss']

# %%
#np.savetxt('losshistory.txt',(loss_history,valloss_history))
model.save('Basic Model Final_fh6.h5')

# %% [markdown]
# ## Basic Model Test Results

# %%
batch_size = b_size
testPredict = model.predict(teX, batch_size=batch_size)

# %%
def npMAEMS(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true))*100
def npMAEMD(y_true, y_pred):
    return np.mean((abs(y_pred - y_true))*np.square(y_true-np.mean(y_true)))*100
def npMSE(y_true, y_pred):
    return np.mean(np.square(-y_true+y_pred))
def npMAE(y_true, y_pred):
    return np.mean(abs(-y_true+y_pred))

# %%
tePredict = testPredict.reshape(-1)
testY = teY.reshape(-1)
print('Error Test Score > MSE == ', npMSE(testY, tePredict), ' MAE == ', npMAE(testY, tePredict), ' MAEMD == ', npMAEMD(testY, tePredict))
# Out:
# Error Test Score > MSE ==  0.014739428840352226  MAE ==  0.09408256029429517  MAEMD ==  0.4006260880648382

# %% [markdown]
# ## Wind Generation FFEL Model

# %%
trX, vaX, trY, vaY = train_test_split(trvaX, trvaY, test_size=1/6, shuffle=False)
trY = trY.reshape(-1,output_timesteps)
vaY = vaY.reshape(-1,output_timesteps)

# %%
trainPredict = model.predict(trX, batch_size=batch_size)
validPredict = model.predict(vaX, batch_size=batch_size)

# %%
e_tr = trainPredict - trY
e_va = validPredict - vaY
errors = np.vstack([e_tr, e_va])
prediction = np.vstack([trainPredict, validPredict])
print(errors.shape)
print(prediction.shape)
# Out:
# (31461, 6)
# (31461, 6)

# %%
norm_df2 = pd.DataFrame(norm_df).iloc[:prediction.shape[0], :]
norm_df2.columns = ['Normalized Wind']
norm_df2.head()
# Out:
#    Normalized Wind
# 0         0.644724
# 1         0.658617
# 2         0.683924
# 3         0.721813
# 4         0.714187

# %%
Prindex = ['Prediction1', 'Prediction2','Prediction3','Prediction4','Prediction5','Prediction6',]
Erindex = ['Error1', 'Error2','Error3','Error4','Error5','Error6']

pr_df = pd.DataFrame(prediction, columns=Prindex)
pr_df
# Out:
#        Prediction1  Prediction2  Prediction3  Prediction4  Prediction5  \
# 0         0.690208     0.634687     0.605048     0.599545     0.559099
# 1         0.702010     0.649027     0.614276     0.611350     0.572941
# 2         0.660309     0.618649     0.594075     0.614930     0.598906
# 3         0.642676     0.602304     0.578967     0.611346     0.605695
# 4         0.613085     0.579068     0.560648     0.588374     0.586272
# ...            ...          ...          ...          ...          ...
# 31456     0.473100     0.539081     0.574133     0.619481     0.605058
# 31457     0.561447     0.610204     0.628042     0.654433     0.641705
# 31458     0.614667     0.638335     0.636946     0.652934     0.638120
# 31459     0.621048     0.623565     0.604005     0.610329     0.574222
# 31460     0.602122     0.594250     0.574219     0.583380     0.543913
#
#        Prediction6
# 0         0.553003
# 1         0.554344
# 2         0.594227
# 3         0.612597
# 4         0.600490
# ...            ...
# 31456     0.571890
# 31457     0.600558
# 31458     0.603000
# 31459     0.543687
# 31460     0.527646
#
# [31461 rows x 6 columns]

# %%
er_df = pd.DataFrame(errors, columns=Erindex)
er_df
# Out:
#          Error1    Error2    Error3    Error4    Error5    Error6
# 0     -0.151294 -0.167760 -0.139644 -0.095989 -0.054440  0.010432
# 1     -0.100438 -0.095665 -0.081258 -0.002189  0.030370  0.068072
# 2     -0.084383 -0.076885 -0.019464  0.072359  0.112634 -0.049575
# 3     -0.052858 -0.011236  0.036396  0.125073 -0.038106 -0.037082
# 4     -0.000454  0.036497  0.074376 -0.055428 -0.063407  0.121892
# ...         ...       ...       ...       ...       ...       ...
# 31456 -0.041467 -0.049568 -0.054434  0.005103  0.065669  0.128233
# 31457 -0.027203 -0.018363  0.013664  0.115044  0.198047  0.190682
# 31458 -0.013900  0.023957  0.097556  0.209277  0.228244  0.108061
# 31459  0.006670  0.084176  0.160347  0.200453  0.079282  0.016570
# 31460  0.062733  0.150593  0.164343  0.088440  0.016795  0.030126
#
# [31461 rows x 6 columns]

# %%
norm_df2 = pd.concat([norm_df2, pr_df, er_df],axis=1)
norm_df2.head()
# Out:
#    Normalized Wind  Prediction1  Prediction2  Prediction3  Prediction4  \
# 0         0.644724     0.690208     0.634687     0.605048     0.599545
# 1         0.658617     0.702010     0.649027     0.614276     0.611350
# 2         0.683924     0.660309     0.618649     0.594075     0.614930
# 3         0.721813     0.642676     0.602304     0.578967     0.611346
# 4         0.714187     0.613085     0.579068     0.560648     0.588374
#
#    Prediction5  Prediction6    Error1    Error2    Error3    Error4    Error5  \
# 0     0.559099     0.553003 -0.151294 -0.167760 -0.139644 -0.095989 -0.054440
# 1     0.572941     0.554344 -0.100438 -0.095665 -0.081258 -0.002189  0.030370
# 2     0.598906     0.594227 -0.084383 -0.076885 -0.019464  0.072359  0.112634
# 3     0.605695     0.612597 -0.052858 -0.011236  0.036396  0.125073 -0.038106
# 4     0.586272     0.600490 -0.000454  0.036497  0.074376 -0.055428 -0.063407
#
#      Error6
# 0  0.010432
# 1  0.068072
# 2 -0.049575
# 3 -0.037082
# 4  0.121892

# %%
norm_df22 = pd.DataFrame(norm_df).iloc[prediction.shape[0]+timesteps:, :]
norm_df22.columns = ['Normalized Wind']
npnorm22 = np.array(norm_df22)

# %%
pr_df = pd.DataFrame(tePredict.reshape(-1,output_timesteps))
pr_df
# Out:
#              0         1         2         3         4         5
# 0     0.556014  0.531810  0.505505  0.507430  0.458284  0.442086
# 1     0.512365  0.473144  0.444083  0.441269  0.386208  0.375406
# 2     0.484676  0.450063  0.430089  0.437444  0.401712  0.401805
# 3     0.408110  0.389594  0.386541  0.416430  0.386182  0.388129
# 4     0.356899  0.351871  0.352212  0.382619  0.333646  0.328115
# ...        ...       ...       ...       ...       ...       ...
# 3491  0.520655  0.520527  0.523400  0.554485  0.541086  0.547250
# 3492  0.441655  0.440666  0.451353  0.489474  0.475589  0.483822
# 3493  0.374087  0.363861  0.368443  0.419350  0.412579  0.425331
# 3494  0.326846  0.303053  0.298474  0.356205  0.347874  0.370697
# 3495  0.279777  0.253106  0.246494  0.300272  0.274107  0.293636
#
# [3496 rows x 6 columns]

# %%
teY = testY.reshape(-1,output_timesteps)
e_te = testPredict-teY
er_df = pd.DataFrame(e_te, columns=Erindex)
er_df
# Out:
#         Error1    Error2    Error3    Error4    Error5    Error6
# 0     0.112357  0.121934  0.010565 -0.019687 -0.039236 -0.050483
# 1     0.102489 -0.021796 -0.083035 -0.056251 -0.106362 -0.133374
# 2    -0.010264 -0.077055 -0.067430 -0.055125 -0.107068 -0.074100
# 3    -0.119007 -0.107926 -0.106029 -0.092350 -0.089723 -0.076620
# 4    -0.140620 -0.140699 -0.156568 -0.093286 -0.131103 -0.066979
# ...        ...       ...       ...       ...       ...       ...
# 3491  0.205674  0.222579  0.241704  0.260889  0.229912  0.206224
# 3492  0.143707  0.158970  0.157758  0.178300  0.134563  0.113079
# 3493  0.092392  0.070266  0.057270  0.078324  0.041837 -0.059653
# 3494  0.033250 -0.008120 -0.042551 -0.014537 -0.137109 -0.211460
# 3495 -0.031397 -0.087920 -0.124249 -0.184712 -0.308050 -0.327282
#
# [3496 rows x 6 columns]

# %%
prnorm = np.array(pr_df)
ernorm =np.array(er_df)
print(ernorm.shape)
# Out:
# (3496, 6)

# %%
etedat = np.concatenate((npnorm22[:prnorm.shape[0],:], prnorm, ernorm), axis=1)
etedat[169:171,:]
# Out:
# array([[0.4368245 , 0.6531809 , 0.63793254, 0.63529629, 0.6394105 ,
#         0.62035006, 0.60849118, 0.3346092 , 0.35624512, 0.39910412,
#         0.43703473, 0.44760722, 0.45858312],
#        [0.40053288, 0.54648191, 0.51382113, 0.50071251, 0.50534171,
#         0.47767547, 0.47227895, 0.26479449, 0.27762896, 0.29833675,
#         0.33259887, 0.32776741, 0.36368268]])

# %%
#output_timesteps = 1
eteX, eteY = create_dataset(etedat, timesteps, 1, 0)
eteY.shape
# Out:
# (3398, 1, 13)

# %%
eteY = eteY[:,:,-output_timesteps:].reshape(-1,output_timesteps)

# %%
norm_df2 = np.array(norm_df2)
Xe, Ye = create_dataset(norm_df2, timesteps, 1, 0)
Ye.shape
# Out:
# (31363, 1, 13)

# %%
Ye = Ye[:,:,-output_timesteps:].reshape(-1,output_timesteps)
print(Xe.shape)
print(Ye.shape)
# Out:
# (31363, 96, 13)
# (31363, 6)

# %%
trXe, vaXe, trYe, vaYe = train_test_split(Xe, Ye, test_size=0.3, shuffle=False)

# %%
gc.collect()
# Out:
# 6004

# %%
eteX.shape, eteY.shape, Xe.shape, Ye.shape
# Out:
# ((3398, 96, 13), (3398, 6), (31363, 96, 13), (31363, 6))

# %%
def mse_mae(y_true, y_pred):
    return K.mean(K.square(y_pred - y_true))*10+K.mean(K.abs(y_pred - y_true))

# %%
num_features = Xe.shape[2]

with tf.device('/gpu:0'):
    alpha=1.0
    gamma=1.2
    beta = 1
    hfilters = 256
    hkernel_size1 = 1
    hkernel_size2 = 2
    visible1e = Input(shape=(timesteps, num_features))
   
    per1e = Permute((2,1))(visible1e)
    den1ae = Dense(timesteps, activation='tanh')(per1e)
    den1be = Dense(timesteps, activation='sigmoid')(per1e)
    den1e = Multiply()([den1ae, den1be])
    per2e = Permute((2,1), name='attention_vec')(den1e)
    mul1e = Multiply()([visible1e, per2e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=1)(mul1e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res01ae = Add()([visible1e, d1e])   # (100, 25) (100, 25)
    res01be = Subtract()([visible1e, d1e])

    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01ae)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    
    d1e = Multiply()([d1ae, d1be])
    res02ae = Add()([res01ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res01be) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res02be = Subtract()([res01be, d2e])   # (100, 25) (100, 25) 
    res02e = Concatenate()([res02ae, res02be, res01ae, res01be])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res03ae = Add()([res02ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res02e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=8)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res03be = Subtract()([res02be, d2e])   # (100, 25) (100, 25)
    res03e = Concatenate()([res03ae, res03be, res02e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    res04ae = Add()([res03ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=8)(res03e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=4)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res04be = Subtract()([res02be, d2e])   # (100, 25) (100, 25)
    res04e = Concatenate()([res04ae, res04be, res03e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    res05ae = Add()([res04ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=4)(res04e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=2)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    
    res05be = Subtract()([res04be, d2e])   # (100, 25) (100, 25)
    res05e = Concatenate()([res05ae, res05be, res04e])
    
    d1e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05e)
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])
    
    d1e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d1e)    
    d1ae = Activation(activations.tanh)(d1e)
    d1be = Activation(activations.sigmoid)(d1e)
    d1e = Multiply()([d1ae, d1be])

    res06ae = Add()([res05ae, d1e])   # (100, 25) (100, 25)
    
    d2e = Conv1D(filters=round(hfilters*alpha), kernel_size=round(hkernel_size1*beta), padding='causal', dilation_rate=2)(res05e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])
    d2e = Conv1D(filters=num_features, kernel_size=round(hkernel_size2*beta), padding='causal', dilation_rate=1)(d2e) 
    d2ae = Activation(activations.tanh)(d2e)
    d2be = Activation(activations.sigmoid)(d2e)
    d2e = Multiply()([d2ae, d2be])

    res06be = Subtract()([res05be, d2e])   # (100, 25) (100, 25)
    res06e = Concatenate()([res05ae, res05be])
    
    res10e = Concatenate()([res02e, res03e, res04e, res05e, res06e])   # 
    
    #print('res10 :', res10.shape)  # (None, 24, 11) 
    
    oute = Conv1D(timesteps*5, 1, padding='same', activation=PReLU())(res10e)   # 256, 11X10=110
    oute = Dropout(0.2)(oute)   #SpatialDropout1D
    
    oute = Conv1D(timesteps*3, 1, padding='same', activation=PReLU())(oute) # 512,  110X5=550
    oute = Dropout(0.2)(oute)
    
    oute = GlobalAveragePooling1D()(oute) # pool_size=2, strides=1
    
    oute = Dense(output_timesteps)(oute) 
    modele = Model(inputs=[visible1e], outputs=[oute])
    
    print(modele.summary())
    
    modele.compile(loss=mse_mae, optimizer='adam', metrics=['mse','mae','mape'])
    early_stopping =EarlyStopping(monitor='val_loss', patience=10)
    batch_size = b_size
    epochs = 1000

    history_e = LossHistory()
    history_e.init()
    
    #hist = model.fit(trX, trY, epochs=epochs, batch_size=batch_size, shuffle=False, validation_data=(vaX, vaY), callbacks=[history, early_stopping])  # , checkpoint
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 96, 13)]     0
# __________________________________________________________________________________________________
# permute_1 (Permute)             (None, 13, 96)       0           input_2[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 13, 96)       9312        permute_1[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 13, 96)       9312        permute_1[0][0]
# __________________________________________________________________________________________________
# multiply_24 (Multiply)          (None, 13, 96)       0           dense_3[0][0]
#                                                                  dense_4[0][0]
# __________________________________________________________________________________________________
# attention_vec (Permute)         (None, 96, 13)       0           multiply_24[0][0]
# __________________________________________________________________________________________________
# multiply_25 (Multiply)          (None, 96, 13)       0           input_2[0][0]
#                                                                  attention_vec[0][0]
# __________________________________________________________________________________________________
# conv1d_24 (Conv1D)              (None, 96, 256)      3584        multiply_25[0][0]
# __________________________________________________________________________________________________
# activation_44 (Activation)      (None, 96, 256)      0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# activation_45 (Activation)      (None, 96, 256)      0           conv1d_24[0][0]
# __________________________________________________________________________________________________
# multiply_26 (Multiply)          (None, 96, 256)      0           activation_44[0][0]
#                                                                  activation_45[0][0]
# __________________________________________________________________________________________________
# conv1d_25 (Conv1D)              (None, 96, 13)       6669        multiply_26[0][0]
# __________________________________________________________________________________________________
# activation_46 (Activation)      (None, 96, 13)       0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# activation_47 (Activation)      (None, 96, 13)       0           conv1d_25[0][0]
# __________________________________________________________________________________________________
# multiply_27 (Multiply)          (None, 96, 13)       0           activation_46[0][0]
#                                                                  activation_47[0][0]
# __________________________________________________________________________________________________
# add_6 (Add)                     (None, 96, 13)       0           input_2[0][0]
#                                                                  multiply_27[0][0]
# __________________________________________________________________________________________________
# subtract_6 (Subtract)           (None, 96, 13)       0           input_2[0][0]
#                                                                  multiply_27[0][0]
# __________________________________________________________________________________________________
# conv1d_26 (Conv1D)              (None, 96, 256)      3584        add_6[0][0]
# __________________________________________________________________________________________________
# conv1d_28 (Conv1D)              (None, 96, 256)      3584        subtract_6[0][0]
# __________________________________________________________________________________________________
# activation_48 (Activation)      (None, 96, 256)      0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_49 (Activation)      (None, 96, 256)      0           conv1d_26[0][0]
# __________________________________________________________________________________________________
# activation_52 (Activation)      (None, 96, 256)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# activation_53 (Activation)      (None, 96, 256)      0           conv1d_28[0][0]
# __________________________________________________________________________________________________
# multiply_28 (Multiply)          (None, 96, 256)      0           activation_48[0][0]
#                                                                  activation_49[0][0]
# __________________________________________________________________________________________________
# multiply_30 (Multiply)          (None, 96, 256)      0           activation_52[0][0]
#                                                                  activation_53[0][0]
# __________________________________________________________________________________________________
# conv1d_27 (Conv1D)              (None, 96, 13)       6669        multiply_28[0][0]
# __________________________________________________________________________________________________
# conv1d_29 (Conv1D)              (None, 96, 13)       6669        multiply_30[0][0]
# __________________________________________________________________________________________________
# activation_50 (Activation)      (None, 96, 13)       0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_51 (Activation)      (None, 96, 13)       0           conv1d_27[0][0]
# __________________________________________________________________________________________________
# activation_54 (Activation)      (None, 96, 13)       0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# activation_55 (Activation)      (None, 96, 13)       0           conv1d_29[0][0]
# __________________________________________________________________________________________________
# multiply_29 (Multiply)          (None, 96, 13)       0           activation_50[0][0]
#                                                                  activation_51[0][0]
# __________________________________________________________________________________________________
# multiply_31 (Multiply)          (None, 96, 13)       0           activation_54[0][0]
#                                                                  activation_55[0][0]
# __________________________________________________________________________________________________
# add_7 (Add)                     (None, 96, 13)       0           add_6[0][0]
#                                                                  multiply_29[0][0]
# __________________________________________________________________________________________________
# subtract_7 (Subtract)           (None, 96, 13)       0           subtract_6[0][0]
#                                                                  multiply_31[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 96, 52)       0           add_7[0][0]
#                                                                  subtract_7[0][0]
#                                                                  add_6[0][0]
#                                                                  subtract_6[0][0]
# __________________________________________________________________________________________________
# conv1d_30 (Conv1D)              (None, 96, 256)      13568       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_32 (Conv1D)              (None, 96, 256)      13568       concatenate_6[0][0]
# __________________________________________________________________________________________________
# activation_56 (Activation)      (None, 96, 256)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_57 (Activation)      (None, 96, 256)      0           conv1d_30[0][0]
# __________________________________________________________________________________________________
# activation_60 (Activation)      (None, 96, 256)      0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# activation_61 (Activation)      (None, 96, 256)      0           conv1d_32[0][0]
# __________________________________________________________________________________________________
# multiply_32 (Multiply)          (None, 96, 256)      0           activation_56[0][0]
#                                                                  activation_57[0][0]
# __________________________________________________________________________________________________
# multiply_34 (Multiply)          (None, 96, 256)      0           activation_60[0][0]
#                                                                  activation_61[0][0]
# __________________________________________________________________________________________________
# conv1d_31 (Conv1D)              (None, 96, 13)       6669        multiply_32[0][0]
# __________________________________________________________________________________________________
# conv1d_33 (Conv1D)              (None, 96, 13)       6669        multiply_34[0][0]
# __________________________________________________________________________________________________
# activation_58 (Activation)      (None, 96, 13)       0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_59 (Activation)      (None, 96, 13)       0           conv1d_31[0][0]
# __________________________________________________________________________________________________
# activation_62 (Activation)      (None, 96, 13)       0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# activation_63 (Activation)      (None, 96, 13)       0           conv1d_33[0][0]
# __________________________________________________________________________________________________
# multiply_33 (Multiply)          (None, 96, 13)       0           activation_58[0][0]
#                                                                  activation_59[0][0]
# __________________________________________________________________________________________________
# multiply_35 (Multiply)          (None, 96, 13)       0           activation_62[0][0]
#                                                                  activation_63[0][0]
# __________________________________________________________________________________________________
# add_8 (Add)                     (None, 96, 13)       0           add_7[0][0]
#                                                                  multiply_33[0][0]
# __________________________________________________________________________________________________
# subtract_8 (Subtract)           (None, 96, 13)       0           subtract_7[0][0]
#                                                                  multiply_35[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 96, 78)       0           add_8[0][0]
#                                                                  subtract_8[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv1d_34 (Conv1D)              (None, 96, 256)      20224       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_36 (Conv1D)              (None, 96, 256)      20224       concatenate_7[0][0]
# __________________________________________________________________________________________________
# activation_64 (Activation)      (None, 96, 256)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_65 (Activation)      (None, 96, 256)      0           conv1d_34[0][0]
# __________________________________________________________________________________________________
# activation_68 (Activation)      (None, 96, 256)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# activation_69 (Activation)      (None, 96, 256)      0           conv1d_36[0][0]
# __________________________________________________________________________________________________
# multiply_36 (Multiply)          (None, 96, 256)      0           activation_64[0][0]
#                                                                  activation_65[0][0]
# __________________________________________________________________________________________________
# multiply_38 (Multiply)          (None, 96, 256)      0           activation_68[0][0]
#                                                                  activation_69[0][0]
# __________________________________________________________________________________________________
# conv1d_35 (Conv1D)              (None, 96, 13)       6669        multiply_36[0][0]
# __________________________________________________________________________________________________
# conv1d_37 (Conv1D)              (None, 96, 13)       6669        multiply_38[0][0]
# __________________________________________________________________________________________________
# activation_66 (Activation)      (None, 96, 13)       0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_67 (Activation)      (None, 96, 13)       0           conv1d_35[0][0]
# __________________________________________________________________________________________________
# activation_70 (Activation)      (None, 96, 13)       0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# activation_71 (Activation)      (None, 96, 13)       0           conv1d_37[0][0]
# __________________________________________________________________________________________________
# multiply_37 (Multiply)          (None, 96, 13)       0           activation_66[0][0]
#                                                                  activation_67[0][0]
# __________________________________________________________________________________________________
# multiply_39 (Multiply)          (None, 96, 13)       0           activation_70[0][0]
#                                                                  activation_71[0][0]
# __________________________________________________________________________________________________
# add_9 (Add)                     (None, 96, 13)       0           add_8[0][0]
#                                                                  multiply_37[0][0]
# __________________________________________________________________________________________________
# subtract_9 (Subtract)           (None, 96, 13)       0           subtract_7[0][0]
#                                                                  multiply_39[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 96, 104)      0           add_9[0][0]
#                                                                  subtract_9[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv1d_38 (Conv1D)              (None, 96, 256)      26880       concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv1d_40 (Conv1D)              (None, 96, 256)      26880       concatenate_8[0][0]
# __________________________________________________________________________________________________
# activation_72 (Activation)      (None, 96, 256)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_73 (Activation)      (None, 96, 256)      0           conv1d_38[0][0]
# __________________________________________________________________________________________________
# activation_76 (Activation)      (None, 96, 256)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# activation_77 (Activation)      (None, 96, 256)      0           conv1d_40[0][0]
# __________________________________________________________________________________________________
# multiply_40 (Multiply)          (None, 96, 256)      0           activation_72[0][0]
#                                                                  activation_73[0][0]
# __________________________________________________________________________________________________
# multiply_42 (Multiply)          (None, 96, 256)      0           activation_76[0][0]
#                                                                  activation_77[0][0]
# __________________________________________________________________________________________________
# conv1d_39 (Conv1D)              (None, 96, 13)       6669        multiply_40[0][0]
# __________________________________________________________________________________________________
# conv1d_41 (Conv1D)              (None, 96, 13)       6669        multiply_42[0][0]
# __________________________________________________________________________________________________
# activation_74 (Activation)      (None, 96, 13)       0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_75 (Activation)      (None, 96, 13)       0           conv1d_39[0][0]
# __________________________________________________________________________________________________
# activation_78 (Activation)      (None, 96, 13)       0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# activation_79 (Activation)      (None, 96, 13)       0           conv1d_41[0][0]
# __________________________________________________________________________________________________
# multiply_41 (Multiply)          (None, 96, 13)       0           activation_74[0][0]
#                                                                  activation_75[0][0]
# __________________________________________________________________________________________________
# multiply_43 (Multiply)          (None, 96, 13)       0           activation_78[0][0]
#                                                                  activation_79[0][0]
# __________________________________________________________________________________________________
# add_10 (Add)                    (None, 96, 13)       0           add_9[0][0]
#                                                                  multiply_41[0][0]
# __________________________________________________________________________________________________
# subtract_10 (Subtract)          (None, 96, 13)       0           subtract_9[0][0]
#                                                                  multiply_43[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 96, 130)      0           add_10[0][0]
#                                                                  subtract_10[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 96, 26)       0           add_10[0][0]
#                                                                  subtract_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 96, 390)      0           concatenate_6[0][0]
#                                                                  concatenate_7[0][0]
#                                                                  concatenate_8[0][0]
#                                                                  concatenate_9[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv1d_46 (Conv1D)              (None, 96, 480)      233760      concatenate_11[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 96, 480)      0           conv1d_46[0][0]
# __________________________________________________________________________________________________
# conv1d_47 (Conv1D)              (None, 96, 288)      166176      dropout_2[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 96, 288)      0           conv1d_47[0][0]
# __________________________________________________________________________________________________
# global_average_pooling1d_1 (Glo (None, 288)          0           dropout_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 6)            1734        global_average_pooling1d_1[0][0]
# ==================================================================================================
# Total params: 612,411
# Trainable params: 612,411
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
gc.collect()
# Out:
# 2538

# %%
# %%time
    histe = modele.fit(trXe, trYe, epochs=epochs, batch_size=b_size, shuffle=False, validation_data=(vaXe, vaYe), callbacks=[history_e, early_stopping])  # , checkpoint
# Out:
# Epoch 1/1000
# 3659/3659 [==============================] - 98s 26ms/step - loss: 0.0688 - mse: 0.0030 - mae: 0.0388 - mape: 1468.1790 - val_loss: 0.0496 - val_mse: 0.0018 - val_mae: 0.0316 - val_mape: 433.5390
# Epoch 2/1000
# 3659/3659 [==============================] - 95s 26ms/step - loss: 0.0460 - mse: 0.0016 - mae: 0.0299 - mape: 1427.5913 - val_loss: 0.0451 - val_mse: 0.0016 - val_mae: 0.0294 - val_mape: 394.0845
# Epoch 3/1000
# 3659/3659 [==============================] - 94s 26ms/step - loss: 0.0449 - mse: 0.0016 - mae: 0.0294 - mape: 1409.2504 - val_loss: 0.0459 - val_mse: 0.0016 - val_mae: 0.0299 - val_mape: 393.2421
# Epoch 4/1000
# 3659/3659 [==============================] - 95s 26ms/step - loss: 0.0441 - mse: 0.0015 - mae: 0.0290 - mape: 1214.6251 - val_loss: 0.0471 - val_mse: 0.0017 - val_mae: 0.0304 - val_mape: 412.2156
# Epoch 5/1000
# 3659/3659 [==============================] - 94s 26ms/step - loss: 0.0438 - mse: 0.0015 - mae: 0.0288 - mape: 1309.1440 - val_loss: 0.0470 - val_mse: 0.0017 - val_mae: 0.0304 - val_mape: 412.1009
# Epoch 6/1000
# 3659/3659 [==============================] - 94s 26ms/step - loss: 0.0435 - mse: 0.0015 - mae: 0.0286 - mape: 1320.1384 - val_loss: 0.0445 - val_mse: 0.0015 - val_mae: 0.0292 - val_mape: 398.2632
# Epoch 7/1000
# 3659/3659 [==============================] - 94s 26ms/step - loss: 0.0429 - mse: 0.0015 - mae: 0.0283 - mape: 984.3976 - val_loss: 0.0453 - val_mse: 0.0016 - val_mae: 0.0295 - val_mape: 401.1595
# Epoch 8/1000
# 3659/3659 [==============================] - 94s 26ms/step - loss: 0.0428 - mse: 0.0015 - mae: 0.0282 - mape: 1212.4722 - val_loss: 0.0452 - val_mse: 0.0016 - val_mae: 0.0295 - val_mape: 418.1447
# Epoch 9/1000
# 3659/3659 [==============================] - 94s 26ms/step - loss: 0.0420 - mse: 0.0014 - mae: 0.0279 - mape: 1461.6814 - val_loss: 0.0479 - val_mse: 0.0017 - val_mae: 0.0307 - val_mape: 393.0044
# Epoch 10/1000
# 3659/3659 [==============================] - 91s 25ms/step - loss: 0.0421 - mse: 0.0014 - mae: 0.0279 - mape: 1009.2303 - val_loss: 0.0459 - val_mse: 0.0016 - val_mae: 0.0299 - val_mape: 401.7799
# Epoch 11/1000
# 3659/3659 [==============================] - 92s 25ms/step - loss: 0.0417 - mse: 0.0014 - mae: 0.0277 - mape: 1081.9071 - val_loss: 0.0470 - val_mse: 0.0017 - val_mae: 0.0303 - val_mape: 383.1093
# Epoch 12/1000
# 3659/3659 [==============================] - 90s 24ms/step - loss: 0.0418 - mse: 0.0014 - mae: 0.0278 - mape: 1358.9136 - val_loss: 0.0464 - val_mse: 0.0016 - val_mae: 0.0301 - val_mape: 399.5712
# Epoch 13/1000
# 3659/3659 [==============================] - 93s 25ms/step - loss: 0.0413 - mse: 0.0014 - mae: 0.0275 - mape: 1068.9838 - val_loss: 0.0467 - val_mse: 0.0016 - val_mae: 0.0303 - val_mape: 422.1176
# Epoch 14/1000
# 3659/3659 [==============================] - 91s 25ms/step - loss: 0.0410 - mse: 0.0014 - mae: 0.0274 - mape: 952.6801 - val_loss: 0.0471 - val_mse: 0.0017 - val_mae: 0.0304 - val_mape: 411.9913
# Epoch 15/1000
# 3659/3659 [==============================] - 93s 25ms/step - loss: 0.0406 - mse: 0.0013 - mae: 0.0272 - mape: 1314.5189 - val_loss: 0.0478 - val_mse: 0.0017 - val_mae: 0.0309 - val_mape: 460.2213
# Epoch 16/1000
# 3659/3659 [==============================] - 94s 26ms/step - loss: 0.0402 - mse: 0.0013 - mae: 0.0269 - mape: 1209.7234 - val_loss: 0.0483 - val_mse: 0.0017 - val_mae: 0.0312 - val_mape: 440.8715

# %% [markdown]
# ### Saving FFEL Model Training Results

# %%
eloss_history = histe.history['loss']
valeloss_history = histe.history['val_loss']

# %%
gc.collect()
# Out:
# 4330

# %%
modele.save('Error Learning Model_fh6.h5')

# %% [markdown]
# ## FFEL Model Test Results

# %%
trainePredict = modele.predict(Xe, batch_size=batch_size)
etePredict = modele.predict(eteX, batch_size=batch_size)

# %%
trePredict = trainePredict.reshape([-1])
trainYe = Ye.reshape([-1])

print('Error Training Score > MSE == ', (np.mean(np.square(trainYe-trePredict))), ' MAE == ', mean_absolute_error(trainYe,trePredict), ' RMSE == ', np.sqrt(np.mean(np.square(trainYe-trePredict))))
# Out:
# Error Training Score > MSE ==  0.0015318847245391523  MAE ==  0.029589559767758275  RMSE ==  0.039139298978637216

# %%
etestPredict = etePredict.reshape([-1])
testYe = eteY.reshape([-1])

print('Error Training Score > MSE == ', (np.mean(np.square(testYe-etestPredict))), ' MAE == ', mean_absolute_error(testYe,etestPredict), ' RMSE == ', np.sqrt(np.mean(np.square(testYe-etestPredict))))
# Out:
# Error Training Score > MSE ==  0.004006777875133086  MAE ==  0.0484092386021476  RMSE ==  0.06329911433134816

# %% [markdown]
# ## Final Prediction Results

# %%
testPredict = tePredict.reshape(-1,6)
addtestPredict = -etePredict + testPredict[timesteps:-2,:]
print(addtestPredict.shape)
# Out:
# (3398, 6)

# %%
print('Error Test Score > MSE == ', (np.mean(np.square(teY[timesteps:-2,:]-testPredict[timesteps:-2,:]))), ' MAE == ', mean_absolute_error(teY[timesteps:-2,:], testPredict[timesteps:-2,:]), 'MAPE == ', mean_absolute_percentage_error(teY[timesteps:-2,:], testPredict[timesteps:-2,:]))
print('Error Test Score > MSE == ', (np.mean(np.square(teY[timesteps:-2,:]-addtestPredict))), ' MAE == ', mean_absolute_error(teY[timesteps:-2,:], addtestPredict), 'MAPE == ', mean_absolute_percentage_error(teY[timesteps:-2,:], addtestPredict))
# Out:
# Error Test Score > MSE ==  0.014641005540606038  MAE ==  0.09373503406374649 MAPE ==  44.51416372964035
# Error Test Score > MSE ==  0.004006777871467304  MAE ==  0.04840923854499055 MAPE ==  20.36629094935649
